# %%
# %pylab inline
#import pylab as plt
import numpy as np
import mpld3

#mpld3.enable_notebook()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['scatter', 'colors']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
fig, ax = pylab.subplots(subplot_kw=dict(axisbg='#EEEEEE'))
ax.grid(color='white', linestyle='solid')

N = 50
scatter = ax.scatter(np.random.normal(size=N),
                     np.random.normal(size=N),
                     c=np.random.random(size=N),
                     s = 1000 * np.random.random(size=N),
                     alpha=0.3,
                     cmap=plt.cm.jet)

ax.set_title("D3 Scatter Plot", size=18);

# %%
import mpld3

# %%
mpld3.enable_notebook()

# %%
np.random.seed(0)

P = np.random.random(size=10)
A = np.random.random(size=10)

x = np.linspace(0, 10, 100)
data = np.array([[x, Ai * np.sin(x / Pi)]
                 for (Ai, Pi) in zip(A, P)])

fig, ax = pylab.subplots(2)

points = ax[1].scatter(P, A, c=P + A,
                       s=200, alpha=0.5)
ax[1].set_xlabel('Period')
ax[1].set_ylabel('Amplitude')

colors = plt.cm.ScalarMappable().to_rgba(P + A)

for (x, l), c in zip(data, colors):
    ax[0].plot(x, l, c=c, alpha=0.5, lw=3)
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.py:239: FormatterWarning: Exception in text/html formatter: 'CompositeGenericTransform' object has no attribute 'contains_branch'
#   FormatterWarning,

# %%
pylab.show()
