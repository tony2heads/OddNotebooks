# %%
import katarchive
import datetime

# %%
# %matplotlib inline
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import katdal as katfile
import datetime

import logging
logging.root.setLevel(logging.ERROR)

# %%
katarchive.product_filter.only_ar1()
tel='m057'

# %%
f = katarchive.search_archive(startdate='15/05/2017')
start = datetime.datetime.strptime(f[-1].__str__().split('\'')[3],'%Y-%m-%d %H:%M:%S %Z')
end = datetime.datetime.strptime(f[0].__str__().split('\'')[3],'%Y-%m-%d %H:%M:%S %Z')
# Out:
# Searched using: CAS.ProductTypeName:(MeerKATAR1TelescopeProduct) AND CAS.ProductTransferStatus:RECEIVED AND StartTime:[2017-05-14T22:00:00Z TO 2017-06-21T21:59:59Z]
# Returning 1096 results

# %%
print 'First file in run: ' , start.isoformat()
print 'Last file in run: ' , end.isoformat()
# Out:
# First file in run:  2017-05-15T00:05:22
# Last file in run:  2017-06-21T00:00:10

# %%
sbd = []
pid = []
fnd = []
dud = []
antsd = []
scrd = []

for fi in f:
    print fi.metadata.Description,"\n", fi.metadata.InstructionSet,"\n==========\n"
# Out:
# MKAIV-449 Three calibrator Imaging
# /home/kat/katsdpscripts/AR1/observations/track.py /home/kat/katsdpscripts/AR1/catalogues/three_calib.csv --horizon=20 -t 300 -n off -m 28800 --repeat --description=MKAIV-449 Three calibrator Imaging --proposal-id=20170313LM-01 --program-block-id=45ob742487746 --issue-id=MKAIV-449 --sb-id-code=20170620-0028 --description=MKAIV-449 Three calibrator Imaging --observer=Lindsay --config-label=fb5270b,3d3d86f
# ==========
#
# COMM-187 CBF J1644-4559 - 4 ant
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-187 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 600 J1644-4559 --horizon 20 --sb-id-code=20170620-0014 --description=COMM-187 CBF J1644-4559 - 4 ant --observer=Sarah --config-label=fb5270b,3d3d86f
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170620-0013 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=fb5270b,3d3d86f
# ==========
#
# COMM-187 CBF J1644-4559 - 8 ant
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-187 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 600 J1644-4559 --ants=m000,m001,m002,m006,m008,m021,m042,m059 --horizon 20 --sb-id-code=20170620-0012 --description=COMM-187 CBF J1644-4559 - 8 ant --observer=Sarah --config-label=fb5270b,3d3d86f
# ==========
#
# COMM-187 CBF J1644-4559 - 4 ant
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-187 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 600 J1644-4559 --ants=m000,m001,m002,m006 --horizon 20 --sb-id-code=20170620-0011 --description=COMM-187 CBF J1644-4559 - 4 ant --observer=Sarah --config-label=fb5270b,3d3d86f
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170620-0010 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=fb5270b,3d3d86f
# ==========
#
# COMM-187 CBF J1644-4559 - 2 ant
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-187 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 600 J1644-4559 --ants=m000,m001 --horizon 20 --sb-id-code=20170620-0009 --description=COMM-187 CBF J1644-4559 - 2 ant --observer=Sarah --config-label=fb5270b,3d3d86f
# ==========
#
# COMM-187 CBF J1644-4559 - 1 ant
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-187 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 600 J1644-4559 --ants=m000 --horizon 20 --sb-id-code=20170620-0008 --description=COMM-187 CBF J1644-4559 - 1 ant --observer=Sarah --config-label=fb5270b,3d3d86f
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170620-0007 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=fb5270b,3d3d86f
# ==========
#
# COMM-185 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 1200 J1622-4950 --horizon 10 --sb-id-code=20170620-0027 --description=COMM-185 CBF J1622-4950 --observer=Maciej --config-label=fb5270b,3d3d86f
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170620-0026 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=fb5270b,3d3d86f
# ==========
#
# COMM-185 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 300 J1644-4559 --horizon 10 --sb-id-code=20170620-0025 --description=COMM-185 CBF J1644-4559 --observer=Maciej --config-label=fb5270b,3d3d86f
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170620-0024 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=fb5270b,3d3d86f
# ==========
#
# COMM-185 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 1200 J1622-4950 --horizon 10 --sb-id-code=20170620-0023 --description=COMM-185 CBF J1622-4950 --observer=Maciej Serylak --config-label=fb5270b,3d3d86f
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170620-0022 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=fb5270b,3d3d86f
# ==========
#
# COMM-185 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-185 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 300 J1644-4559 --horizon 10 --sb-id-code=20170620-0021 --description=COMM-185 CBF J1644-4559 --observer=Maciej Serylak --config-label=fb5270b,3d3d86f
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170620-0020 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=fb5270b,3d3d86f
# ==========
#
# COMM-185 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-185 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 1200 J1622-4950 --horizon 10 --sb-id-code=20170620-0019 --description=COMM-185 CBF J1622-4950 --observer=Maciej Serylak --config-label=fb5270b,3d3d86f
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170620-0018 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=fb5270b,3d3d86f
# ==========
#
# COMM-185 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-185 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 300 J1644-4559 --horizon 10 --sb-id-code=20170620-0017 --description=COMM-185 CBF J1644-4559 --observer=Maciej Serylak --config-label=fb5270b,3d3d86f
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170620-0016 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=fb5270b,3d3d86f
# ==========
#
# MKAIV-599 Interferometric Offset Pointing
# /home/kat/katsdpscripts/AR1/observations/interferometric_pointing.py /home/kat/katsdpscripts/AR1/catalogues/three_calib.csv --horizon=20 -t 64 -n off -m 720 --description=MKAIV-599 Interferometric Offset Pointing  --proposal-id=MKAIV-599 --program-block-id=MKAIV-599 --issue-id=MKAIV-599 --sb-id-code=20170620-0015 --description=MKAIV-599 Interferometric Offset Pointing  --observer=Buntu --config-label=fb5270b,3d3d86f
# ==========
#
# MKAIV-599 Interferometric Offset Pointing
# /home/kat/katsdpscripts/AR1/observations/interferometric_pointing.py /home/kat/katsdpscripts/AR1/catalogues/three_calib.csv --horizon=20 -t 64 -n off -m 720 --description=MKAIV-599 Interferometric Offset Pointing  --proposal-id=MKAIV-599 --program-block-id=MKAIV-599 --issue-id=MKAIV-599 --sb-id-code=20170620-0006 --description=MKAIV-599 Interferometric Offset Pointing  --observer=Lindsay --config-label=fb5270b,3d3d86f
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170620-0005 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=fb5270b,3d3d86f
# ==========
#
# MKAIV-584 Generic AR1 delaycal
# /home/kat/katsdpscripts/AR1/observations/calibrate_delays.py /home/kat/katsdpscripts/AR1/catalogues/three_calib.csv --horizon=20 -t 64 -n off --description=MKAIV-584 Generic AR1 delaycal --proposal-id=MKAIV-584 --program-block-id=MKAIV-584 --issue-id=MKAIV-584 --sb-id-code=20170620-0004 --description=MKAIV-584 Generic AR1 delaycal --observer=Lindsay --config-label=fb5270b,3d3d86f
# ==========
#
# MKAIV-584 Generic AR1 delaycal
# /home/kat/katsdpscripts/AR1/observations/calibrate_delays.py /home/kat/katsdpscripts/AR1/catalogues/three_calib.csv --horizon=20 -t 64 -n off --description=MKAIV-584 Generic AR1 delaycal --proposal-id=MKAIV-584 --program-block-id=MKAIV-584 --issue-id=MKAIV-584 --sb-id-code=20170620-0002 --description=MKAIV-584 Generic AR1 delaycal --observer=Audrey --config-label=cfdcbaa,3d3d86f
# ==========
#
# MKAIV-388 CBF J1939 2134
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-388 --backend=digifits --backend-args -t 0.0001531 -p 4 -B 856 -F 1284 -t 600 J1939 2134 --horizon 20 --sb-id-code=20170619-0029 --description=MKAIV-388 CBF J1939 2134 --observer=sarah --config-label=db5ef38,8141abb
# ==========
#
# MKAIV-388 CBF J1909-3744
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-388 --backend=digifits --backend-args -t 0.0001531 -p 4 -B 856 -F 1284 -t 600 J1909-3744 --horizon 20 --sb-id-code=20170619-0028 --description=MKAIV-388 CBF J1909-3744 --observer=sarah --config-label=db5ef38,8141abb
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170619-0027 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=db5ef38,8141abb
# ==========
#
# MKAIV-388 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-388 --backend=digifits --backend-args -t 0.0001531 -p 4 -B 856 -F 1284 -t 600 J1644-4559 --horizon 20 --sb-id-code=20170619-0026 --description=MKAIV-388 CBF J1644-4559 --observer=sarah --config-label=db5ef38,8141abb
# ==========
#
# MKAIV-388  CBF J1559-4438
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-388 --backend=digifits --backend-args -t 0.0001531 -p 4 -B 856 -F 1284 -t 600  J1559-4438 --horizon 20 --sb-id-code=20170619-0025 --description=MKAIV-388  CBF J1559-4438 --observer=sarah --config-label=db5ef38,8141abb
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170619-0024 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=db5ef38,8141abb
# ==========
#
# MKAIV-388 CBF J1909-3744
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-388 --backend=digifits --backend-args -t 0.0001531 -p 4 -B 856 -F 1284 -t 600 J1909-3744 --horizon 20 --sb-id-code=20170619-0023 --description=MKAIV-388 CBF J1909-3744 --observer=sarah --config-label=db5ef38,8141abb
# ==========
#
# MKAIV-388 CBF J1327-6222
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-388 --backend=digifits --backend-args -t 0.0001531 -p 4 -B 856 -F 1284 -t 600 J1327-6222 --horizon 20 --sb-id-code=20170619-0022 --description=MKAIV-388 CBF J1327-6222 --observer=sarah --config-label=db5ef38,8141abb
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170619-0021 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=db5ef38,8141abb
# ==========
#
# COMM-185 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 1200 J1622-4950 --horizon 10 --sb-id-code=20170619-0013 --description=COMM-185 CBF J1622-4950 --observer=Maciej --config-label=db5ef38,8141abb
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170619-0012 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=db5ef38,8141abb
# ==========
#
# COMM-185 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 300 J1644-4559 --horizon 10 --sb-id-code=20170619-0011 --description=COMM-185 CBF J1644-4559 --observer=Maciej --config-label=db5ef38,8141abb
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170619-0010 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=db5ef38,8141abb
# ==========
#
# COMM-185 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 1200 J1622-4950 --horizon 10 --sb-id-code=20170619-0009 --description=COMM-185 CBF J1622-4950 --observer=Maciej Serylak --config-label=db5ef38,8141abb
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170619-0008 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=db5ef38,8141abb
# ==========
#
# COMM-185 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-185 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 300 J1644-4559 --horizon 10 --sb-id-code=20170619-0007 --description=COMM-185 CBF J1644-4559 --observer=Maciej Serylak --config-label=db5ef38,8141abb
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170619-0006 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=db5ef38,8141abb
# ==========
#
# COMM-185 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-185 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 1200 J1622-4950 --horizon 10 --sb-id-code=20170619-0005 --description=COMM-185 CBF J1622-4950 --observer=Maciej Serylak --config-label=db5ef38,8141abb
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170619-0004 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=db5ef38,8141abb
# ==========
#
# COMM-185 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-185 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 300 J1644-4559 --horizon 10 --sb-id-code=20170619-0033 --description=COMM-185 CBF J1644-4559 --observer=Buntu --config-label=db5ef38,8141abb
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170619-0030 --description=MKAIV-405 Generic AR1 Phaseup --observer=Buntu --config-label=db5ef38,8141abb
# ==========
#
# MKAIV-584 Generic AR1 delaycal
# /home/kat/katsdpscripts/AR1/observations/calibrate_delays.py /home/kat/katsdpscripts/AR1/catalogues/three_calib.csv --horizon=20 -t 64 -n off --description=MKAIV-584 Generic AR1 delaycal --proposal-id=MKAIV-584 --program-block-id=MKAIV-584 --issue-id=MKAIV-584 --sb-id-code=20170619-0015 --description=MKAIV-584 Generic AR1 delaycal --observer=Buntu --config-label=db5ef38,8141abb
# ==========
#
# MKAIV-584 Generic AR1 delaycal
# /home/kat/katsdpscripts/AR1/observations/calibrate_delays.py /home/kat/katsdpscripts/AR1/catalogues/three_calib.csv --horizon=20 -t 64 -n off --description=MKAIV-584 Generic AR1 delaycal --proposal-id=MKAIV-584 --program-block-id=MKAIV-584 --issue-id=MKAIV-584 --sb-id-code=20170619-0014 --description=MKAIV-584 Generic AR1 delaycal --observer=Buntu --config-label=db5ef38,8141abb
# ==========
#
# MKAIV-584 Generic AR1 delaycal
# /home/kat/katsdpscripts/AR1/observations/calibrate_delays.py /home/kat/katsdpscripts/AR1/catalogues/three_calib.csv --horizon=20 -t 64 -n off --description=MKAIV-584 Generic AR1 delaycal --proposal-id=MKAIV-584 --program-block-id=MKAIV-584 --issue-id=MKAIV-584 --sb-id-code=20170619-0001 --description=MKAIV-584 Generic AR1 delaycal --observer=Lindsay --config-label=db5ef38,8141abb
# ==========
#
# MKAIV-393 Imaging observation DEEP8
# /home/kat/katsdpscripts/AR1/observations/image.py /home/kat/katsdpscripts/AR1/catalogues/DEEP8.csv --horizon=20 -t 900 -g 120 -b 1200 -i 20000 -m 43200 --description=MKAIV-393 Imaging observation DEEP8 --proposal-id=OPUS-131 --program-block-id=MKAIV-393 --issue-id=MKAIV-393 --sb-id-code=20170618-0041 --description=MKAIV-393 Imaging observation DEEP8 --observer=Tom --config-label=ac5315b,7593b30
# ==========
#
# COMM-185 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 1200 J1622-4950 --horizon 10 --sb-id-code=20170618-0040 --description=COMM-185 CBF J1622-4950 --observer=Maciej --config-label=ac5315b,7593b30
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170618-0039 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,7593b30
# ==========
#
# COMM-185 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 300 J1644-4559 --horizon 10 --sb-id-code=20170618-0038 --description=COMM-185 CBF J1644-4559 --observer=Maciej --config-label=ac5315b,7593b30
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170618-0037 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,7593b30
# ==========
#
# COMM-185 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 1200 J1622-4950 --horizon 10 --sb-id-code=20170618-0036 --description=COMM-185 CBF J1622-4950 --observer=Maciej Serylak --config-label=ac5315b,7593b30
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170618-0035 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,7593b30
# ==========
#
# COMM-185 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-185 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 300 J1644-4559 --horizon 10 --sb-id-code=20170618-0034 --description=COMM-185 CBF J1644-4559 --observer=Maciej Serylak --config-label=ac5315b,7593b30
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170618-0033 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,7593b30
# ==========
#
# COMM-185 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-185 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 1200 J1622-4950 --horizon 10 --sb-id-code=20170618-0032 --description=COMM-185 CBF J1622-4950 --observer=Maciej Serylak --config-label=ac5315b,7593b30
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170618-0031 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,7593b30
# ==========
#
# COMM-185 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-185 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 300 J1644-4559 --horizon 10 --sb-id-code=20170618-0030 --description=COMM-185 CBF J1644-4559 --observer=Maciej Serylak --config-label=ac5315b,7593b30
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170618-0029 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,7593b30
# ==========
#
# AR1: MKAIV-387 CBF J0953 0755
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-387 --issue-id=MKAIV-387 --backend=dspsr -B 856 -F 1284 -t 600 J0953 0755 --horizon 20 --sb-id-code=20170618-0009 --description=AR1: MKAIV-387 CBF J0953 0755 --observer=sarah --config-label=ac5315b,7593b30
# ==========
#
# AR1: MKAIV-387 CBF J0437-4715
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-387 --issue-id=MKAIV-387 --backend=dspsr -B 856 -F 1284 -t 600 J0437-4715 --horizon 20 --sb-id-code=20170618-0008 --description=AR1: MKAIV-387 CBF J0437-4715 --observer=sarah --config-label=ac5315b,7593b30
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170618-0007 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,7593b30
# ==========
#
# AR1: MKAIV-387 CBF J0835-4510
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-387 --issue-id=MKAIV-387 --backend=dspsr -B 856 -F 1284 -t 600 J0835-4510, radec,  08:35:20.61149,-45:10:34.8751 --horizon 20 --sb-id-code=20170618-0006 --description=AR1: MKAIV-387 CBF J0835-4510 --observer=sarah --config-label=ac5315b,7593b30
# ==========
#
# AR1: MKAIV-387 CBF J0742-2822
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-387 --issue-id=MKAIV-387 --backend=dspsr -B 856 -F 1284 -t 600 J0742-2822 --horizon 20 --sb-id-code=20170618-0005 --description=AR1: MKAIV-387 CBF J0742-2822 --observer=sarah --config-label=ac5315b,7593b30
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170618-0004 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,7593b30
# ==========
#
# AR1: MKAIV-387 CBF J0738-4042
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-387 --issue-id=MKAIV-387 --backend=dspsr -B 856 -F 1284 -t 600 J0738-4042 --horizon 20 --sb-id-code=20170618-0003 --description=AR1: MKAIV-387 CBF J0738-4042 --observer=sarah --config-label=ac5315b,7593b30
# ==========
#
# AR1: MKAIV-387 CBF J0437-4715
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-387 --issue-id=MKAIV-387 --backend=dspsr -B 856 -F 1284 -t 600 J0437-4715 --horizon 20 --sb-id-code=20170618-0002 --description=AR1: MKAIV-387 CBF J0437-4715 --observer=sarah --config-label=ac5315b,7593b30
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170618-0001 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,7593b30
# ==========
#
# MKAIV-584 Generic AR1 delaycal
# /home/kat/katsdpscripts/AR1/observations/calibrate_delays.py /home/kat/katsdpscripts/AR1/catalogues/three_calib.csv --horizon=20 -t 64 -n off --description=MKAIV-584 Generic AR1 delaycal --proposal-id=MKAIV-584 --program-block-id=MKAIV-584 --issue-id=MKAIV-584 --sb-id-code=20170618-0010 --description=MKAIV-584 Generic AR1 delaycal --observer=Audrey --config-label=ac5315b,7593b30
# ==========
#
# MKAIV-393 Imaging observation DEEP7
# /home/kat/katsdpscripts/AR1/observations/image.py /home/kat/katsdpscripts/AR1/catalogues/DEEP7.csv --horizon=20 -t 900 -g 120 -b 1200 -i 20000 -m 46800 --description=MKAIV-393 Imaging observation DEEP7 --proposal-id=OPUS-131 --program-block-id=MKAIV-393 --issue-id=MKAIV-393 --sb-id-code=20170617-0018 --description=MKAIV-393 Imaging observation DEEP7 --observer=Tom --config-label=ac5315b,2ac79c5
# ==========
#
# COMM-185 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 1200 J1622-4950 --horizon 10 --sb-id-code=20170617-0030 --description=COMM-185 CBF J1622-4950 --observer=Maciej --config-label=ac5315b,2ac79c5
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170617-0029 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,2ac79c5
# ==========
#
# COMM-185 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 300 J1644-4559 --horizon 10 --sb-id-code=20170617-0028 --description=COMM-185 CBF J1644-4559 --observer=Maciej --config-label=ac5315b,2ac79c5
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170617-0027 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,2ac79c5
# ==========
#
# COMM-185 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 1200 J1622-4950 --horizon 10 --sb-id-code=20170617-0026 --description=COMM-185 CBF J1622-4950 --observer=Maciej Serylak --config-label=ac5315b,2ac79c5
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170617-0025 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,2ac79c5
# ==========
#
# COMM-185 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-185 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 300 J1644-4559 --horizon 10 --sb-id-code=20170617-0024 --description=COMM-185 CBF J1644-4559 --observer=Maciej Serylak --config-label=ac5315b,2ac79c5
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170617-0023 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,2ac79c5
# ==========
#
# COMM-185 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-185 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 1200 J1622-4950 --horizon 10 --sb-id-code=20170617-0022 --description=COMM-185 CBF J1622-4950 --observer=Maciej Serylak --config-label=ac5315b,2ac79c5
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170617-0021 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,2ac79c5
# ==========
#
# COMM-185 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-185 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 300 J1644-4559 --horizon 10 --sb-id-code=20170617-0020 --description=COMM-185 CBF J1644-4559 --observer=Maciej Serylak --config-label=ac5315b,2ac79c5
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170617-0019 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,2ac79c5
# ==========
#
# MKAIV-584 Generic AR1 delaycal
# /home/kat/katsdpscripts/AR1/observations/calibrate_delays.py /home/kat/katsdpscripts/AR1/catalogues/three_calib.csv --horizon=20 -t 64 -n off --description=MKAIV-584 Generic AR1 delaycal --proposal-id=MKAIV-584 --program-block-id=MKAIV-584 --issue-id=MKAIV-584 --sb-id-code=20170617-0032 --description=MKAIV-584 Generic AR1 delaycal --observer=Audrey --config-label=ac5315b,2ac79c5
# ==========
#
# MKAIV-584 Generic AR1 delaycal
# /home/kat/katsdpscripts/AR1/observations/calibrate_delays.py /home/kat/katsdpscripts/AR1/catalogues/three_calib.csv --horizon=20 -t 64 -n off --description=MKAIV-584 Generic AR1 delaycal --proposal-id=MKAIV-584 --program-block-id=MKAIV-584 --issue-id=MKAIV-584 --sb-id-code=20170617-0031 --description=MKAIV-584 Generic AR1 delaycal --observer=Audrey --config-label=ac5315b,2ac79c5
# ==========
#
# MKAIV-584 Generic AR1 delaycal
# /home/kat/katsdpscripts/AR1/observations/calibrate_delays.py /home/kat/katsdpscripts/AR1/catalogues/three_calib.csv --horizon=20 -t 64 -n off --description=MKAIV-584 Generic AR1 delaycal --proposal-id=MKAIV-584 --program-block-id=MKAIV-584 --issue-id=MKAIV-584 --sb-id-code=20170617-0008 --description=MKAIV-584 Generic AR1 delaycal --observer=Audrey --config-label=ac5315b,2ac79c5
# ==========
#
# MKAIV-214 Phase-up (4K) 1934
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py PKS 1934-63 | J1939-6342, radec bfcal single_accumulation, 19:39:25.03, -63:42:45.7, (200.0 12000.0 -11.11 7.777 -1.231) -t 64 -n off --description=MKAIV-214 Phase-up (4K) 1934 --proposal-id=MKAIV-330 --program-block-id=MKAIV-214 --issue-id=MKAIV-214 --sb-id-code=20170616-0041 --description=MKAIV-214 Phase-up (4K) 1934 --observer=Sarah --config-label=ac5315b,067e267
# ==========
#
# MKAIV-449 Three calibrator Imaging
# /home/kat/katsdpscripts/AR1/observations/track.py /home/kat/katsdpscripts/AR1/catalogues/three_calib.csv --horizon=20 -t 300 -n off -m 25200 --repeat --description=MKAIV-449 Three calibrator Imaging --proposal-id=20170313LM-01 --program-block-id=45ob742487746 --issue-id=MKAIV-449 --sb-id-code=20170616-0043 --description=MKAIV-449 Three calibrator Imaging --observer=Lindsay --config-label=ac5315b,067e267
# ==========
#
# MKAIV-388 CBF J1939 2134
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-388 --backend=digifits --backend-args -t 0.0001531 -p 4 -B 856 -F 1284 -t 600 J1939 2134 --horizon 20 --sb-id-code=20170616-0034 --description=MKAIV-388 CBF J1939 2134 --observer=sarah --config-label=ac5315b,067e267
# ==========
#
# MKAIV-388 CBF J1909-3744
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-388 --backend=digifits --backend-args -t 0.0001531 -p 4 -B 856 -F 1284 -t 600 J1909-3744 --horizon 20 --sb-id-code=20170616-0033 --description=MKAIV-388 CBF J1909-3744 --observer=sarah --config-label=ac5315b,067e267
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170616-0032 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,067e267
# ==========
#
# MKAIV-388 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-388 --backend=digifits --backend-args -t 0.0001531 -p 4 -B 856 -F 1284 -t 600 J1644-4559 --horizon 20 --sb-id-code=20170616-0031 --description=MKAIV-388 CBF J1644-4559 --observer=sarah --config-label=ac5315b,067e267
# ==========
#
# MKAIV-388  CBF J1559-4438
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-388 --backend=digifits --backend-args -t 0.0001531 -p 4 -B 856 -F 1284 -t 600  J1559-4438 --horizon 20 --sb-id-code=20170616-0030 --description=MKAIV-388  CBF J1559-4438 --observer=sarah --config-label=ac5315b,067e267
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170616-0029 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,067e267
# ==========
#
# MKAIV-388 CBF J1909-3744
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-388 --backend=digifits --backend-args -t 0.0001531 -p 4 -B 856 -F 1284 -t 600 J1909-3744 --horizon 20 --sb-id-code=20170616-0028 --description=MKAIV-388 CBF J1909-3744 --observer=sarah --config-label=ac5315b,067e267
# ==========
#
# MKAIV-388 CBF J1327-6222
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-388 --backend=digifits --backend-args -t 0.0001531 -p 4 -B 856 -F 1284 -t 600 J1327-6222 --horizon 20 --sb-id-code=20170616-0027 --description=MKAIV-388 CBF J1327-6222 --observer=sarah --config-label=ac5315b,067e267
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170616-0026 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,067e267
# ==========
#
# MKAIV-388 CBF J1909-3744
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-388 --backend=digifits --backend-args -t 0.0001531 -p 4 -B 856 -F 1284 -t 3600 J1909-3744 --horizon 20 --sb-id-code=20170616-0045 --description=MKAIV-388 CBF J1909-3744 --observer=sarah --config-label=ac5315b,067e267
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170616-0044 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,067e267
# ==========
#
# COMM-185 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 1200 J1622-4950 --horizon 10 --sb-id-code=20170616-0025 --description=COMM-185 CBF J1622-4950 --observer=Maciej --config-label=ac5315b,067e267
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170616-0024 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,067e267
# ==========
#
# COMM-185 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 300 J1644-4559 --horizon 10 --sb-id-code=20170616-0023 --description=COMM-185 CBF J1644-4559 --observer=Maciej --config-label=ac5315b,067e267
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170616-0022 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,067e267
# ==========
#
# COMM-185 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 1200 J1622-4950 --horizon 10 --sb-id-code=20170616-0021 --description=COMM-185 CBF J1622-4950 --observer=Maciej Serylak --config-label=ac5315b,067e267
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170616-0020 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,067e267
# ==========
#
# COMM-185 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-185 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 300 J1644-4559 --horizon 10 --sb-id-code=20170616-0019 --description=COMM-185 CBF J1644-4559 --observer=Maciej Serylak --config-label=ac5315b,067e267
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170616-0018 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,067e267
# ==========
#
# COMM-185 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-185 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 1200 J1622-4950 --horizon 10 --sb-id-code=20170616-0017 --description=COMM-185 CBF J1622-4950 --observer=Maciej Serylak --config-label=ac5315b,067e267
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170616-0016 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,067e267
# ==========
#
# COMM-185 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-185 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 300 J1644-4559 --horizon 10 --sb-id-code=20170616-0015 --description=COMM-185 CBF J1644-4559 --observer=Maciej Serylak --config-label=ac5315b,067e267
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170616-0014 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,067e267
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170616-0013 --description=MKAIV-405 Generic AR1 Phaseup --observer=Audrey --config-label=ac5315b,067e267
# ==========
#
# MKAIV-393 Imaging observation DEEP2
# /home/kat/katsdpscripts/AR1/observations/image.py /home/kat/katsdpscripts/AR1/catalogues/DEEP2.csv --horizon=20 -t 600 -g 120 -b 900 -i 20000 -m 46800 --description=MKAIV-393 Imaging observation DEEP2 --proposal-id=OPUS-131 --program-block-id=MKAIV-393 --issue-id=MKAIV-393 --sb-id-code=20170615-0031 --description=MKAIV-393 Imaging observation DEEP2 --observer=Tom --config-label=ac5315b,303903e
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170615-0032 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,303903e
# ==========
#
# COMM-185 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 1200 J1622-4950 --horizon 10 --sb-id-code=20170615-0030 --description=COMM-185 CBF J1622-4950 --observer=Maciej --config-label=ac5315b,303903e
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170615-0029 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,303903e
# ==========
#
# COMM-185 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 300 J1644-4559 --horizon 10 --sb-id-code=20170615-0028 --description=COMM-185 CBF J1644-4559 --observer=Maciej --config-label=ac5315b,303903e
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170615-0027 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,303903e
# ==========
#
# COMM-185 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 1200 J1622-4950 --horizon 10 --sb-id-code=20170615-0026 --description=COMM-185 CBF J1622-4950 --observer=Maciej Serylak --config-label=ac5315b,303903e
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170615-0025 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,303903e
# ==========
#
# COMM-185 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-185 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 300 J1644-4559 --horizon 10 --sb-id-code=20170615-0024 --description=COMM-185 CBF J1644-4559 --observer=Maciej Serylak --config-label=ac5315b,303903e
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 64 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --issue-id=MKAIV-405 --sb-id-code=20170615-0023 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=ac5315b,303903e
# ==========
#
# COMM-185 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-185 --backend=digifits --backend-args=-t 0.000153 -p 4 -B 856 -F 1284 -t 1200 J1622-4950 --horizon 10 --sb-id-code=20170615-0022 --description=COMM-185 CBF J1622-4950 --observer=Maciej Serylak --config-label=ac5315b,303903e
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# ...
# /home/kat/katsdpscripts/AR1/observations/calibrate_delays.py /home/kat/katsdpscripts/AR1/catalogues/three_calib.csv --horizon=20 -t 30 -n off --description=MKAIV-584 Generic AR1 delaycal --proposal-id=MKAIV-584 --program-block-id=MKAIV-584 --sb-id-code=20170516-0004 --description=MKAIV-584 Generic AR1 delaycal --observer=Moloko --config-label=a1e1bb0,2a56665
# ==========
#
# MKAIV-186 phase stability/Spectral_Baseline
# /home/kat/katsdpscripts/AR1/observations/image.py PKS1934-63, radec bpcal delaycal gaincal , 19:39:25.03, -63:42:45.7, (200.0 12000.0 -11.11 7.777 -1.231 --horizon=20 -t 120 -n off -m 18000 --description=MKAIV-186 phase stability/Spectral_Baseline --proposal-id=20170312TA-03 --program-block-id=44ob183148308 --sb-id-code=20170515-0030 --description=MKAIV-186 phase stability/Spectral_Baseline --observer=Thomas --config-label=a1e1bb0,2a56665
# ==========
#
# MKAIV-584 Generic AR1 delaycal
# /home/kat/katsdpscripts/AR1/observations/calibrate_delays.py /home/kat/katsdpscripts/AR1/catalogues/three_calib.csv --horizon=20 -t 30 -n off --description=MKAIV-584 Generic AR1 delaycal --proposal-id=MKAIV-584 --program-block-id=MKAIV-584 --sb-id-code=20170515-0031 --description=MKAIV-584 Generic AR1 delaycal --observer=Lindsay --config-label=a1e1bb0,2a56665
# ==========
#
# COMM-AR1 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=dspsr -B 856 -F 1284 -t 1200 J1622-4950 --horizon 20 --sb-id-code=20170515-0028 --description=COMM-AR1 CBF J1622-4950 --observer=Maciej Serylak --config-label=a1e1bb0,dc5161d
# ==========
#
# MKAIV 215: Phase-up (4K) PKS 1934-63
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py PKS 1934-63 | J1939-6342, radec bpcal single_accumulation, 19:39:25.03, -63:42:45.7, (200.0 12000.0 -11.11 7.777 -1.231) -t 60 -n off --description=MKAIV-215 Phase-up (4K) PKS 1934-63 --sb-id-code=20170515-0027 --description=MKAIV 215: Phase-up (4K) PKS 1934-63 --observer=Maciej Serylak --config-label=a1e1bb0,dc5161d
# ==========
#
# COMM-AR1 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=dspsr -B 856 -F 1284 -t 300 J1644-4559 --horizon 20 --sb-id-code=20170515-0026 --description=COMM-AR1 CBF J1644-4559 --observer=Maciej Serylak --config-label=a1e1bb0,dc5161d
# ==========
#
# MKAIV 215: Phase-up (4K) PKS 1934-63
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py PKS 1934-63 | J1939-6342, radec bpcal single_accumulation, 19:39:25.03, -63:42:45.7, (200.0 12000.0 -11.11 7.777 -1.231) -t 60 -n off --description=MKAIV-215 Phase-up (4K) PKS 1934-63 --sb-id-code=20170515-0025 --description=MKAIV 215: Phase-up (4K) PKS 1934-63 --observer=Maciej Serylak --config-label=a1e1bb0,dc5161d
# ==========
#
# COMM-AR1 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=dspsr -B 856 -F 1284 -t 1200 J1622-4950 --horizon 20 --sb-id-code=20170515-0024 --description=COMM-AR1 CBF J1622-4950 --observer=Maciej Serylak --config-label=a1e1bb0,dc5161d
# ==========
#
# MKAIV 215: Phase-up (4K) PKS 1934-63
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py PKS 1934-63 | J1939-6342, radec bpcal single_accumulation, 19:39:25.03, -63:42:45.7, (200.0 12000.0 -11.11 7.777 -1.231) -t 60 -n off --description=MKAIV-215 Phase-up (4K) PKS 1934-63 --sb-id-code=20170515-0023 --description=MKAIV 215: Phase-up (4K) PKS 1934-63 --observer=Maciej Serylak --config-label=a1e1bb0,dc5161d
# ==========
#
# COMM-AR1 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=dspsr -B 856 -F 1284 -t 300 J1644-4559 --horizon 20 --sb-id-code=20170515-0022 --description=COMM-AR1 CBF J1644-4559 --observer=Maciej Serylak --config-label=a1e1bb0,dc5161d
# ==========
#
# MKAIV 215: Phase-up (4K) PKS 1934-63
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py PKS 1934-63 | J1939-6342, radec bpcal single_accumulation, 19:39:25.03, -63:42:45.7, (200.0 12000.0 -11.11 7.777 -1.231) -t 60 -n off --description=MKAIV-215 Phase-up (4K) PKS 1934-63 --sb-id-code=20170515-0021 --description=MKAIV 215: Phase-up (4K) PKS 1934-63 --observer=Maciej Serylak --config-label=a1e1bb0,dc5161d
# ==========
#
# COMM-AR1 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=dspsr -B 856 -F 1284 -t 1200 J1622-4950 --horizon 20 --sb-id-code=20170515-0020 --description=COMM-AR1 CBF J1622-4950 --observer=Maciej Serylak --config-label=a1e1bb0,dc5161d
# ==========
#
# MKAIV 215: Phase-up (4K) PKS 1934-63
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py PKS 1934-63 | J1939-6342, radec bpcal single_accumulation, 19:39:25.03, -63:42:45.7, (200.0 12000.0 -11.11 7.777 -1.231) -t 60 -n off --description=MKAIV-215 Phase-up (4K) PKS 1934-63 --sb-id-code=20170515-0019 --description=MKAIV 215: Phase-up (4K) PKS 1934-63 --observer=Maciej Serylak --config-label=a1e1bb0,dc5161d
# ==========
#
# COMM-AR1 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=dspsr -B 856 -F 1284 -t 300 J1644-4559 --horizon 20 --sb-id-code=20170515-0018 --description=COMM-AR1 CBF J1644-4559 --observer=Maciej Serylak --config-label=a1e1bb0,dc5161d
# ==========
#
# MKAIV 215: Phase-up (4K) PKS 1934-63
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py PKS 1934-63 | J1939-6342, radec bpcal single_accumulation, 19:39:25.03, -63:42:45.7, (200.0 12000.0 -11.11 7.777 -1.231) -t 60 -n off --description=MKAIV-215 Phase-up (4K) PKS 1934-63 --sb-id-code=20170515-0017 --description=MKAIV 215: Phase-up (4K) PKS 1934-63 --observer=Maciej Serylak --config-label=a1e1bb0,dc5161d
# ==========
#
# MKAIV-584 Generic AR1 delaycal
# /home/kat/katsdpscripts/AR1/observations/calibrate_delays.py /home/kat/katsdpscripts/AR1/catalogues/three_calib.csv --horizon=20 -t 30 -n off --description=MKAIV-584 Generic AR1 delaycal --proposal-id=MKAIV-584 --program-block-id=MKAIV-584 --sb-id-code=20170515-0016 --description=MKAIV-584 Generic AR1 delaycal --observer=Lindsay --config-label=a1e1bb0,dc5161d
# ==========
#
# MKAIV-111 AR1 pointing
# /home/kat/katsdpscripts/AR1/observations/point_source_scan.py /home/kat/katsdpscripts/RTS/sources_pnt_L.csv --horizon=20 -n coupler,10,10,180 -m 39600 -f 1284 --description=MKAIV-111 AR1 pointing --proposal-id=20170312RV-03 --program-block-id=38ob109217327 --sb-id-code=20170515-0015 --description=MKAIV-111 AR1 pointing --observer=Ruby --config-label=a1e1bb0,dc5161d
# ==========
#
# MKAIV-584 Generic AR1 delaycal
# /home/kat/katsdpscripts/AR1/observations/calibrate_delays.py /home/kat/katsdpscripts/AR1/catalogues/three_calib.csv --horizon=20 -t 30 -n off --description=MKAIV-584 Generic AR1 delaycal --proposal-id=MKAIV-584 --program-block-id=MKAIV-584 --sb-id-code=20170515-0013 --description=MKAIV-584 Generic AR1 delaycal --observer=Moloko --config-label=a1e1bb0,dc5161d
# ==========
#
#
# No metadata
# ==========
#
# MKAIV-308 Basic health
# /home/kat/katsdpscripts/AR1/observations/basic_health.py --description=MKAIV-308 Basic health --proposal-id=20170312LM-01 --program-block-id=41ob733529946 --sb-id-code=20170515-0012 --description=MKAIV-308 Basic health --observer=Moloko --config-label=a1e1bb0,dc5161d
# ==========
#
# MKAIV-584 Generic AR1 delaycal
# /home/kat/katsdpscripts/AR1/observations/calibrate_delays.py /home/kat/katsdpscripts/AR1/catalogues/three_calib.csv --horizon=20 -t 30 -n off --description=MKAIV-584 Generic AR1 delaycal --proposal-id=MKAIV-584 --program-block-id=MKAIV-584 --sb-id-code=20170515-0010 --description=MKAIV-584 Generic AR1 delaycal --observer=Moloko --config-label=a1e1bb0,dc5161d
# ==========
#
# MKAIV-584 Generic AR1 delaycal
# /home/kat/katsdpscripts/AR1/observations/calibrate_delays.py /home/kat/katsdpscripts/AR1/catalogues/three_calib.csv --horizon=20 -t 30 -n off --description=MKAIV-584 Generic AR1 delaycal --proposal-id=MKAIV-584 --program-block-id=MKAIV-584 --sb-id-code=20170515-0011 --description=MKAIV-584 Generic AR1 delaycal --observer=Moloko --config-label=a1e1bb0,dc5161d
# ==========
#
# MKAIV-584 Generic AR1 delaycal
# /home/kat/katsdpscripts/AR1/observations/calibrate_delays.py /home/kat/katsdpscripts/AR1/catalogues/three_calib.csv --horizon=20 -t 30 -n off --description=MKAIV-584 Generic AR1 delaycal --proposal-id=MKAIV-584 --program-block-id=MKAIV-584 --sb-id-code=20170515-0009 --description=MKAIV-584 Generic AR1 delaycal --observer=Moloko --config-label=a1e1bb0,dc5161d
# ==========
#
#
# No metadata
# ==========
#
# MKAIV-308 Basic health
# /home/kat/katsdpscripts/AR1/observations/basic_health.py --description=MKAIV-308 Basic health --proposal-id=20170312LM-01 --program-block-id=41ob733529946 --sb-id-code=20170515-0002 --description=MKAIV-308 Basic health --observer=Moloko --config-label=a1e1bb0,39fa9ba
# ==========
#
# MKAIV-584 Generic AR1 delaycal
# /home/kat/katsdpscripts/AR1/observations/calibrate_delays.py /home/kat/katsdpscripts/AR1/catalogues/three_calib.csv --horizon=20 -t 30 -n off --description=MKAIV-584 Generic AR1 delaycal --proposal-id=MKAIV-584 --program-block-id=MKAIV-584 --sb-id-code=20170515-0001 --description=MKAIV-584 Generic AR1 delaycal --observer=Moloko --config-label=a1e1bb0,39fa9ba
# ==========
#
# MKAIV-386D AR1 Bandpass Calibrators LST 18-24
# /home/kat/katsdpscripts/AR1/observations/image.py /home/kat/katsdpscripts/AR1/catalogues/bpcals.csv --horizon=20 -t 300 -g 300 -b 300 -m 21600 --description=MKAIV-386D AR1 Bandpass Calibrators LST 18-24 --proposal-id=OPUS-131 --program-block-id=MKAIV-386D --sb-id-code=20170514-0071 --description=MKAIV-386D AR1 Bandpass Calibrators LST 18-24 --observer=Tony --config-label=a1e1bb0,39fa9ba
# ==========
#
# MKAIV-388 CBF J1909-3744
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-388 --backend=dspsr -B 856 -F 1284 -t 600 J1909-3744 --horizon 20 --sb-id-code=20170514-0070 --description=MKAIV-388 CBF J1909-3744 --observer=sarah --config-label=a1e1bb0,39fa9ba
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 30 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --sb-id-code=20170514-0069 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=a1e1bb0,39fa9ba
# ==========
#
# MKAIV-388  CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-388 --backend=dspsr -B 856 -F 1284 -t 900  J1622-4950 --horizon 20 --sb-id-code=20170514-0068 --description=MKAIV-388  CBF J1622-4950 --observer=sarah --config-label=a1e1bb0,39fa9ba
# ==========
#
# MKAIV-388 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-388 --backend=dspsr -B 856 -F 1284 -t 600 J1644-4559 --horizon 20 --sb-id-code=20170514-0067 --description=MKAIV-388 CBF J1644-4559 --observer=sarah --config-label=a1e1bb0,39fa9ba
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 30 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --sb-id-code=20170514-0066 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=a1e1bb0,39fa9ba
# ==========
#
# MKAIV-388  CBF J1559-4438
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-388 --backend=dspsr -B 856 -F 1284 -t 600  J1559-4438 --horizon 20 --sb-id-code=20170514-0065 --description=MKAIV-388  CBF J1559-4438 --observer=sarah --config-label=a1e1bb0,39fa9ba
# ==========
#
# MKAIV-388 CBF J1327-6222
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=FST-TRNS --program-block-id=MKAIV-388 --backend=dspsr -B 856 -F 1284 -t 600 J1327-6222 --horizon 20 --sb-id-code=20170514-0064 --description=MKAIV-388 CBF J1327-6222 --observer=sarah --config-label=a1e1bb0,39fa9ba
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 30 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --sb-id-code=20170514-0063 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=a1e1bb0,39fa9ba
# ==========
#
# COMM-AR1 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=dspsr -B 856 -F 1284 -t 1200 J1622-4950 --horizon 20 --sb-id-code=20170514-0042 --description=COMM-AR1 CBF J1622-4950 --observer=Maciej Serylak --config-label=a1e1bb0,39fa9ba
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 30 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --sb-id-code=20170514-0054 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=a1e1bb0,39fa9ba
# ==========
#
# COMM-AR1 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=dspsr -B 856 -F 1284 -t 300 J1644-4559 --horizon 20 --sb-id-code=20170514-0040 --description=COMM-AR1 CBF J1644-4559 --observer=Maciej Serylak --config-label=a1e1bb0,39fa9ba
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 30 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --sb-id-code=20170514-0053 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=a1e1bb0,39fa9ba
# ==========
#
# COMM-AR1 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=dspsr -B 856 -F 1284 -t 1200 J1622-4950 --horizon 20 --sb-id-code=20170514-0038 --description=COMM-AR1 CBF J1622-4950 --observer=Maciej Serylak --config-label=a1e1bb0,39fa9ba
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 30 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --sb-id-code=20170514-0052 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=a1e1bb0,39fa9ba
# ==========
#
# COMM-AR1 CBF J1644-4559
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=dspsr -B 856 -F 1284 -t 300 J1644-4559 --horizon 20 --sb-id-code=20170514-0036 --description=COMM-AR1 CBF J1644-4559 --observer=Maciej Serylak --config-label=a1e1bb0,39fa9ba
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 30 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --sb-id-code=20170514-0051 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=a1e1bb0,39fa9ba
# ==========
#
# COMM-AR1 CBF J1622-4950
# /home/kat/usersnfs/katusescripts/ptuse/beamform_single_pulsar.py --proposal-id=COMM-AR1 --program-block-id=COMM-AR1 --backend=dspsr -B 856 -F 1284 -t 1200 J1622-4950 --horizon 20 --sb-id-code=20170514-0034 --description=COMM-AR1 CBF J1622-4950 --observer=Maciej Serylak --config-label=a1e1bb0,39fa9ba
# ==========
#
# MKAIV-405 Generic AR1 Phaseup
# /home/kat/katsdpscripts/AR1/observations/bf_phaseup_AR1.py --horizon=20 -t 30 -n off --description=MKAIV-405 Generic AR1 Phaseup --proposal-id=MKAIV-330 --program-block-id=MKAIV-405 --sb-id-code=20170514-0050 --description=MKAIV-405 Generic AR1 Phaseup --observer=Lindsay --config-label=a1e1bb0,39fa9ba
# ==========

# %%
print fi.metadata.Details
# Out:
# ===============================================================================
# Name: /var/kat/archive2/data/ftp/staging/1494799521.h5 (version 3.0)
# ===============================================================================
# Observer: Lindsay  Experiment ID: 20170514-0050
# Description: 'MKAIV-405 Generic AR1 Phaseup'
# Observed from 2017-05-14 22:05:22.629 UTC to 2017-05-14 22:09:42.769 UTC
# Dump rate / period: 0.12505 Hz / 7.997 s
# Subarrays: 1
#   ID  Antennas                            Inputs  Corrprods
#    0  m000,m003,m005,m006,m007,m008,m010,m012,m014,m015,m020,m021,m031,m034,m049,m058  32      544
# Spectral Windows: 1
#   ID Band Product  CentreFreq(MHz)  Bandwidth(MHz)  Channels  ChannelWidth(kHz)
#    0 L    bc856M4k   1284.000         856.000           4096       208.984
# -------------------------------------------------------------------------------
# Data selected according to the following criteria:
#   subarray=0
#   ants=['m008', 'm003', 'm007', 'm012', 'm000', 'm014', 'm006', 'm005', 'm015', 'm021', 'm020', 'm034', 'm010', 'm049', 'm031', 'm058']
#   spw=0
# -------------------------------------------------------------------------------
# Shape: (33 dumps, 4096 channels, 544 correlation products) => Size: 588.251 MB
# Antennas: m000,m003,m005,m006,m007,*m008,m010,m012,m014,m015,m020,m021,m031,m034,m049,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes
# Channels: 4096 (index 0 - 4095,  856.000 MHz - 1711.791 MHz), each 208.984 kHz wide
# Targets: 2 selected out of 2 in catalogue
#   ID  Name         Type      RA(J2000)     DEC(J2000)  Tags                       Dumps  ModelFlux(Jy)
#    0  PKS 1934-63  radec     19:39:25.03  -63:42:45.7  bfcal single_accumulation      9      14.46
#    1  Nothing      special             -            -                                24
# Scans: 3 selected out of 3 total       Compscans: 1 selected out of 1 total
#   Date        Timerange(UTC)       ScanState  CompScanLabel  Dumps  Target
#   14-May-2017/22:05:26 - 22:06:06    0:slew     0:un_corrected      6    0:PKS 1934-63
#               22:06:14 - 22:06:30    1:track    0:un_corrected      3    0:PKS 1934-63
#               22:06:38 - 22:09:38    2:stop     0:un_corrected     24    1:Nothing

# %%
det=fi.metadata.Details
for line in det.splitlines():
    print line
# Out:
# ===============================================================================
# Name: /var/kat/archive2/data/ftp/staging/1494799521.h5 (version 3.0)
# ===============================================================================
# Observer: Lindsay  Experiment ID: 20170514-0050
# Description: 'MKAIV-405 Generic AR1 Phaseup'
# Observed from 2017-05-14 22:05:22.629 UTC to 2017-05-14 22:09:42.769 UTC
# Dump rate / period: 0.12505 Hz / 7.997 s
# Subarrays: 1
#   ID  Antennas                            Inputs  Corrprods
#    0  m000,m003,m005,m006,m007,m008,m010,m012,m014,m015,m020,m021,m031,m034,m049,m058  32      544
# Spectral Windows: 1
#   ID Band Product  CentreFreq(MHz)  Bandwidth(MHz)  Channels  ChannelWidth(kHz)
#    0 L    bc856M4k   1284.000         856.000           4096       208.984
# -------------------------------------------------------------------------------
# Data selected according to the following criteria:
#   subarray=0
#   ants=['m008', 'm003', 'm007', 'm012', 'm000', 'm014', 'm006', 'm005', 'm015', 'm021', 'm020', 'm034', 'm010', 'm049', 'm031', 'm058']
#   spw=0
# -------------------------------------------------------------------------------
# Shape: (33 dumps, 4096 channels, 544 correlation products) => Size: 588.251 MB
# Antennas: m000,m003,m005,m006,m007,*m008,m010,m012,m014,m015,m020,m021,m031,m034,m049,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes
# Channels: 4096 (index 0 - 4095,  856.000 MHz - 1711.791 MHz), each 208.984 kHz wide
# Targets: 2 selected out of 2 in catalogue
#   ID  Name         Type      RA(J2000)     DEC(J2000)  Tags                       Dumps  ModelFlux(Jy)
#    0  PKS 1934-63  radec     19:39:25.03  -63:42:45.7  bfcal single_accumulation      9      14.46
#    1  Nothing      special             -            -                                24
# Scans: 3 selected out of 3 total       Compscans: 1 selected out of 1 total
#   Date        Timerange(UTC)       ScanState  CompScanLabel  Dumps  Target
#   14-May-2017/22:05:26 - 22:06:06    0:slew     0:un_corrected      6    0:PKS 1934-63
#               22:06:14 - 22:06:30    1:track    0:un_corrected      3    0:PKS 1934-63
#               22:06:38 - 22:09:38    2:stop     0:un_corrected     24    1:Nothing

# %%
ls=det.splitlines()
print ls[20]
# Out:
# Antennas: m000,m003,m005,m006,m007,*m008,m010,m012,m014,m015,m020,m021,m031,m034,m049,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes

# %%
print fi.metadata.FileSize/(1024*1024*1024.0)
# Out:
# 0.896242096089

# %%
GB=1024*1024*1024.0
for fi in f:
    if fi.metadata.FileSize/GB > 1:
        det=fi.metadata.Details
        ls=det.splitlines()
        if ls[20].count(tel) >0 :
            print fi.metadata.Description,"\n",ls[1],"\n",ls[20],"\n"
# Out:
# AR1: MKAIV-387 CBF J0953 0755
# Name: /var/kat/archive2/data/ftp/staging/1497540257.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0437-4715
# Name: /var/kat/archive2/data/ftp/staging/1497539556.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497539110.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0835-4510
# Name: /var/kat/archive2/data/ftp/staging/1497538402.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0742-2822
# Name: /var/kat/archive2/data/ftp/staging/1497537680.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497537243.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0738-4042
# Name: /var/kat/archive2/data/ftp/staging/1497536533.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0437-4715
# Name: /var/kat/archive2/data/ftp/staging/1497535829.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-584 Generic AR1 delaycal
# Name: /var/kat/archive2/data/ftp/staging/1497534160.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-393 Imaging observation DEEP1
# Name: /var/kat/archive2/data/ftp/staging/1497488408.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388 CBF J1939 2134
# Name: /var/kat/archive2/data/ftp/staging/1497487515.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388 CBF J1909-3744
# Name: /var/kat/archive2/data/ftp/staging/1497486614.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-382 Phase-up PKS 1934-63
# Name: /var/kat/archive2/data/ftp/staging/1497486008.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388 CBF J1644-4559
# Name: /var/kat/archive2/data/ftp/staging/1497485114.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388  CBF J1559-4438
# Name: /var/kat/archive2/data/ftp/staging/1497484215.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-382 Phase-up PKS 1934-63
# Name: /var/kat/archive2/data/ftp/staging/1497483609.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388 CBF J1909-3744
# Name: /var/kat/archive2/data/ftp/staging/1497482718.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388 CBF J1327-6222
# Name: /var/kat/archive2/data/ftp/staging/1497481820.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-382 Phase-up PKS 1934-63
# Name: /var/kat/archive2/data/ftp/staging/1497481271.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-449 Three calibrator Imaging
# Name: /var/kat/archive2/data/ftp/staging/1497470409.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497468006.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-185 CBF J1644-4559
# Name: /var/kat/archive2/data/ftp/staging/1497467419.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497466812.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-185 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1497465018.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497464410.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497463210.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-185 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1497461415.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497460862.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497459892.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-308 Basic health
# Name: /var/kat/archive2/data/ftp/staging/1497453751.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m008,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-308 Basic health
# Name: /var/kat/archive2/data/ftp/staging/1497438139.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m011,m014,*m015,m021,m031,m042,m057,m059,m060,m061,m062  Inputs: 30  Autocorr: yes  Crosscorr: yes
#
# MKAIV-393 Imaging observation DEEP4
# Name: /var/kat/archive2/data/ftp/staging/1497402006.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m010,m011,m014,m015,m042,m049,*m057,m060,m061,m062  Inputs: 28  Autocorr: yes  Crosscorr: yes
#
# MKAIV-449 Three calibrator Imaging
# Name: /var/kat/archive2/data/ftp/staging/1497384008.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m010,m011,m014,m015,m042,m049,*m057,m060,m061,m062  Inputs: 28  Autocorr: yes  Crosscorr: yes
#
# COMM-185 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1497382222.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m010,m011,m014,m015,m042,m049,*m057,m060,m061,m062  Inputs: 28  Autocorr: yes  Crosscorr: yes
#
# COMM-185 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1497378622.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m010,m011,m014,m015,m042,m049,*m057,m060,m061,m062  Inputs: 28  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1497375023.h5 (version 3.0)
# Antennas: m000,m001,m006,m007,m010,m011,m014,m015,m042,m049,*m057,m060,m061,m062  Inputs: 28  Autocorr: yes  Crosscorr: yes
#
# MKAIV-599 Interferometric Offset Pointing
# Name: /var/kat/archive2/data/ftp/staging/1497370274.h5 (version 3.0)
# Antennas: m000,m001,m006,m010,m011,m014,m015,m042,m049,*m057,m060,m061,m062  Inputs: 26  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0953 0755
# Name: /var/kat/archive2/data/ftp/staging/1497368856.h5 (version 3.0)
# Antennas: m000,m001,m006,m010,m011,m014,m015,m042,m049,*m057,m060,m061,m062  Inputs: 26  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0437-4715
# Name: /var/kat/archive2/data/ftp/staging/1497368148.h5 (version 3.0)
# Antennas: m000,m001,m006,m010,m011,m014,m015,m042,m049,*m057,m060,m061,m062  Inputs: 26  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0835-4510
# Name: /var/kat/archive2/data/ftp/staging/1497363831.h5 (version 3.0)
# Antennas: m000,m001,m006,m010,m011,m014,m015,m042,m049,*m057,m060,m061,m062  Inputs: 26  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0742-2822
# Name: /var/kat/archive2/data/ftp/staging/1497363095.h5 (version 3.0)
# Antennas: m000,m001,m006,m010,m011,m014,m015,m042,m049,*m057,m060,m061,m062  Inputs: 26  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0738-4042
# Name: /var/kat/archive2/data/ftp/staging/1497361937.h5 (version 3.0)
# Antennas: m000,m001,m006,m010,m011,m014,m015,m042,m049,*m057,m060,m061,m062  Inputs: 26  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0437-4715
# Name: /var/kat/archive2/data/ftp/staging/1497361227.h5 (version 3.0)
# Antennas: m000,m001,m006,m010,m011,m014,m015,m042,m049,*m057,m060,m061,m062  Inputs: 26  Autocorr: yes  Crosscorr: yes
#
# MKAIV-393 Imaging observation DEEP8
# Name: /var/kat/archive2/data/ftp/staging/1497336924.h5 (version 3.0)
# Antennas: m000,m001,m006,m010,m011,m014,m015,m042,m049,*m057,m060,m061,m062  Inputs: 26  Autocorr: yes  Crosscorr: yes
#
# MKAIV-393 Imaging observation DEEP8
# Name: /var/kat/archive2/data/ftp/staging/1497334483.h5 (version 3.0)
# Antennas: m000,m001,m006,m010,m011,m014,m015,m042,m049,*m057,m060,m061,m062  Inputs: 26  Autocorr: yes  Crosscorr: yes
#
# MKAIV-393 Imaging observation DEEP8
# Name: /var/kat/archive2/data/ftp/staging/1497315609.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388 CBF J1939 2134
# Name: /var/kat/archive2/data/ftp/staging/1497314726.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388 CBF J1909-3744
# Name: /var/kat/archive2/data/ftp/staging/1497313826.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-382 Phase-up PKS 1934-63
# Name: /var/kat/archive2/data/ftp/staging/1497313207.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388 CBF J1644-4559
# Name: /var/kat/archive2/data/ftp/staging/1497312322.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388  CBF J1559-4438
# Name: /var/kat/archive2/data/ftp/staging/1497311423.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-382 Phase-up PKS 1934-63
# Name: /var/kat/archive2/data/ftp/staging/1497310809.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388 CBF J1909-3744
# Name: /var/kat/archive2/data/ftp/staging/1497309925.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388 CBF J1327-6222
# Name: /var/kat/archive2/data/ftp/staging/1497309024.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-382 Phase-up PKS 1934-63
# Name: /var/kat/archive2/data/ftp/staging/1497308410.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-214 Phase-up (4K) 1934
# Name: /var/kat/archive2/data/ftp/staging/1497306609.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-214 Phase-up (4K) 1934
# Name: /var/kat/archive2/data/ftp/staging/1497304809.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-173 drift scan 1934-63
# Name: /var/kat/archive2/data/ftp/staging/1497303923.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-214 Phase-up (4K) 1934
# Name: /var/kat/archive2/data/ftp/staging/1497303069.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-214 Phase-up (4K) 1934
# Name: /var/kat/archive2/data/ftp/staging/1497302544.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497301203.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497299427.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-185 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1497295815.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497295210.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-185 CBF J1644-4559
# Name: /var/kat/archive2/data/ftp/staging/1497294618.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497294008.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-185 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1497292219.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497291606.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1644-4559
# Name: /var/kat/archive2/data/ftp/staging/1497291022.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497290412.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1497288788.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497288309.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1644-4559
# Name: /var/kat/archive2/data/ftp/staging/1497287858.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497287443.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497286809.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-449 Three calibrator Imaging
# Name: /var/kat/archive2/data/ftp/staging/1497277166.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-393 Imaging observation DEEP7
# Name: /var/kat/archive2/data/ftp/staging/1497258520.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m010,m011,m014,m015,m021,m042,m049,*m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-393 Imaging observation DEEP7
# Name: /var/kat/archive2/data/ftp/staging/1497229280.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-449 Three calibrator Imaging
# Name: /var/kat/archive2/data/ftp/staging/1497211211.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-185 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1497209412.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497208807.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-185 CBF J1644-4559
# Name: /var/kat/archive2/data/ftp/staging/1497208253.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497207611.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-185 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1497205971.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497205208.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1644-4559
# Name: /var/kat/archive2/data/ftp/staging/1497204697.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497204007.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1497202369.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497201608.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1644-4559
# Name: /var/kat/archive2/data/ftp/staging/1497201013.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497200411.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497199811.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-449 Three calibrator Imaging
# Name: /var/kat/archive2/data/ftp/staging/1497194259.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0953 0755
# Name: /var/kat/archive2/data/ftp/staging/1497193442.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0437-4715
# Name: /var/kat/archive2/data/ftp/staging/1497192738.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0835-4510
# Name: /var/kat/archive2/data/ftp/staging/1497191707.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0742-2822
# Name: /var/kat/archive2/data/ftp/staging/1497190981.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0738-4042
# Name: /var/kat/archive2/data/ftp/staging/1497189870.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0437-4715
# Name: /var/kat/archive2/data/ftp/staging/1497188530.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-393 Imaging observation DEEP6
# Name: /var/kat/archive2/data/ftp/staging/1497167111.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-185 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1497123012.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497122406.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-185 CBF J1644-4559
# Name: /var/kat/archive2/data/ftp/staging/1497121814.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497121210.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-185 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1497119414.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497118811.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1644-4559
# Name: /var/kat/archive2/data/ftp/staging/1497118212.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497117610.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1497115815.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497115209.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1644-4559
# Name: /var/kat/archive2/data/ftp/staging/1497114617.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497114009.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-393 Imaging observation DEEP5
# Name: /var/kat/archive2/data/ftp/staging/1497056411.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388 CBF J1939 2134
# Name: /var/kat/archive2/data/ftp/staging/1497055514.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388 CBF J1909-3744
# Name: /var/kat/archive2/data/ftp/staging/1497054617.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388 CBF J1644-4559
# Name: /var/kat/archive2/data/ftp/staging/1497053110.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388  CBF J1559-4438
# Name: /var/kat/archive2/data/ftp/staging/1497052213.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388 CBF J1909-3744
# Name: /var/kat/archive2/data/ftp/staging/1497050712.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388 CBF J1327-6222
# Name: /var/kat/archive2/data/ftp/staging/1497049814.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-599 Interferometric Offset Pointing
# Name: /var/kat/archive2/data/ftp/staging/1497038988.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# Offset CBF pointing test with different catalogue
# Name: /var/kat/archive2/data/ftp/staging/1497034809.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-185 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1497033012.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497031210.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1497029543.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m049,*m057,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497028823.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m048,m049,*m057,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1644-4559
# Name: /var/kat/archive2/data/ftp/staging/1497028365.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m048,m049,*m057,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1497027949.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m048,m049,*m057,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-584 Generic AR1 delaycal
# Name: /var/kat/archive2/data/ftp/staging/1497027609.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m048,m049,*m057,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-599 Interferometric Offset Pointing
# Name: /var/kat/archive2/data/ftp/staging/1497021624.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m048,m049,*m057,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-599 Interferometric Offset Pointing
# Name: /var/kat/archive2/data/ftp/staging/1497018034.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m048,m049,*m057,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-599 Interferometric Offset Pointing
# Name: /var/kat/archive2/data/ftp/staging/1497017096.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,m011,m014,m015,m021,m042,m048,m049,*m057,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-449 Three calibrator Imaging
# Name: /var/kat/archive2/data/ftp/staging/1497005655.h5 (version 3.0)
# Antennas: m006,m015,m042,*m057,m060,m061,m062  Inputs: 14  Autocorr: yes  Crosscorr: yes
#
# Offset CBF pointing test
# Name: /var/kat/archive2/data/ftp/staging/1497001312.h5 (version 3.0)
# Antennas: m006,m015,m042,*m057,m060,m061,m062  Inputs: 14  Autocorr: yes  Crosscorr: yes
#
# MKAIV-202 Interferometric Pointing Calibration
# Name: /var/kat/archive2/data/ftp/staging/1496925501.h5 (version 3.0)
# Antennas: m001,m002,m006,m015,m021,m031,m042,m048,m049,*m057,m059,m060,m061,m062  Inputs: 28  Autocorr: yes  Crosscorr: yes
#
# COMM-161 Image faint, extended HI (IC 5264)
# Name: /var/kat/archive2/data/ftp/staging/1496924209.h5 (version 3.0)
# Antennas: m001,m002,m006,m015,m021,m031,m042,m048,m049,*m057,m059,m060,m061,m062  Inputs: 28  Autocorr: yes  Crosscorr: yes
#
# COMM-161 Image faint, extended HI (IC 5264)
# Name: /var/kat/archive2/data/ftp/staging/1496923391.h5 (version 3.0)
# Antennas: m001,m002,m006,m015,m021,m031,m042,m048,m049,*m057,m059,m060,m061,m062  Inputs: 28  Autocorr: yes  Crosscorr: yes
#
# MKAIV-584 Generic AR1 delaycal
# Name: /var/kat/archive2/data/ftp/staging/1496922564.h5 (version 3.0)
# Antennas: m001,m002,m006,m015,m021,m031,m042,m048,m049,*m057,m059,m060,m061,m062  Inputs: 28  Autocorr: yes  Crosscorr: yes
#
# MKAIV-584 Generic AR1 delaycal
# Name: /var/kat/archive2/data/ftp/staging/1496921972.h5 (version 3.0)
# Antennas: m001,m002,m006,m015,m021,m031,m042,m048,m049,*m057,m059,m060,m061,m062  Inputs: 28  Autocorr: yes  Crosscorr: yes
#
# MKAIV-308 Basic health
# Name: /var/kat/archive2/data/ftp/staging/1496916876.h5 (version 3.0)
# Antennas: m001,m002,m006,m015,m021,m031,m042,m048,m049,*m057,m059,m060,m061,m062  Inputs: 28  Autocorr: yes  Crosscorr: yes
#
# MKAIV-584 Generic AR1 delaycal
# Name: /var/kat/archive2/data/ftp/staging/1496908176.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m011,m014,m021,m042,m048,m049,*m057,m058,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-584 Generic AR1 delaycal
# Name: /var/kat/archive2/data/ftp/staging/1496907208.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m011,m014,m021,m042,m048,m049,*m057,m058,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-202 Interferometric Pointing Calibration
# Name: /var/kat/archive2/data/ftp/staging/1496734893.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m006,m007,m015,m031,m042,m049,*m057,m058,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-387 CBF J0738-4042
# Name: /var/kat/archive2/data/ftp/staging/1496658770.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m007,*m008,m011,m014,m015,m021,m031,m042,m049,m057,m058,m059  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-387 CBF J0437-4715
# Name: /var/kat/archive2/data/ftp/staging/1496657604.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m007,*m008,m011,m014,m015,m021,m031,m042,m049,m057,m058,m059  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-308 Basic health
# Name: /var/kat/archive2/data/ftp/staging/1496647087.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m007,m011,m014,m015,m021,m031,m057,*m058,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-202 Interferometric Pointing Calibration
# Name: /var/kat/archive2/data/ftp/staging/1496617213.h5 (version 3.0)
# Antennas: *m057,m058,m059,m060  Inputs: 8  Autocorr: yes  Crosscorr: yes
#
# MKAIV-232 Baseline Calibration (Delay model calculation)
# Name: /var/kat/archive2/data/ftp/staging/1496594409.h5 (version 3.0)
# Antennas: *m057,m058,m059,m060  Inputs: 8  Autocorr: yes  Crosscorr: yes
#
# MKAIV-393 Imaging observation DEEP3
# Name: /var/kat/archive2/data/ftp/staging/1496538011.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m006,m007,m011,m031,m042,m049,*m057,m058,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-449 Three calibrator Imaging
# Name: /var/kat/archive2/data/ftp/staging/1496522583.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m006,m007,m011,m031,m042,m049,*m057,m058,m059,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-161 Image faint, extended HI (IC 5264)
# Name: /var/kat/archive2/data/ftp/staging/1496476396.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m006,m007,*m008,m011,m014,m015,m049,m057,m058,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-161 Image faint, extended HI (IC 5264)
# Name: /var/kat/archive2/data/ftp/staging/1496461621.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m006,m007,*m008,m011,m014,m015,m049,m057,m058,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-161 Image faint, extended HI (IC 5264)
# Name: /var/kat/archive2/data/ftp/staging/1496446210.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m006,m007,*m008,m011,m014,m015,m049,m057,m058,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-584 Generic AR1 delaycal
# Name: /var/kat/archive2/data/ftp/staging/1496435411.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m006,m007,*m008,m011,m014,m015,m049,m057,m058,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1496431813.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m006,m007,*m008,m011,m014,m015,m049,m057,m058,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1496431211.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m006,m007,*m008,m011,m014,m015,m049,m057,m058,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1644-4559
# Name: /var/kat/archive2/data/ftp/staging/1496430616.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m006,m007,*m008,m011,m014,m015,m049,m057,m058,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1496430008.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m006,m007,*m008,m011,m014,m015,m049,m057,m058,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1496428212.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m006,m007,*m008,m011,m014,m015,m049,m057,m058,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1496427610.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m006,m007,*m008,m011,m014,m015,m049,m057,m058,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1644-4559
# Name: /var/kat/archive2/data/ftp/staging/1496427016.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m006,m007,*m008,m011,m014,m015,m049,m057,m058,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1496426410.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m006,m007,*m008,m011,m014,m015,m049,m057,m058,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1496424613.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m006,m007,*m008,m011,m014,m015,m049,m057,m058,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1496424010.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m006,m007,*m008,m011,m014,m015,m049,m057,m058,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1496422813.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m006,m007,*m008,m011,m014,m015,m049,m057,m058,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-232 Baseline Calibration (Delay model calculation)
# Name: /var/kat/archive2/data/ftp/staging/1496415611.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m006,m007,*m008,m011,m014,m015,m049,m057,m058,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-308 Basic health
# Name: /var/kat/archive2/data/ftp/staging/1496413159.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m006,m007,*m008,m011,m014,m015,m049,m057,m058,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-449 Three calibrator Imaging
# Name: /var/kat/archive2/data/ftp/staging/1496407183.h5 (version 3.0)
# Antennas: m005,m008,m011,m049,*m057,m058,m059,m060,m061  Inputs: 18  Autocorr: yes  Crosscorr: yes
#
# MKAIV-449 Three calibrator Imaging
# Name: /var/kat/archive2/data/ftp/staging/1496400882.h5 (version 3.0)
# Antennas: m005,m008,m011,m049,*m057,m058,m059,m060,m061  Inputs: 18  Autocorr: yes  Crosscorr: yes
#
# MKAIV-308 Basic health
# Name: /var/kat/archive2/data/ftp/staging/1496399204.h5 (version 3.0)
# Antennas: m005,m008,m011,m049,*m057,m058,m059,m060,m061  Inputs: 18  Autocorr: yes  Crosscorr: yes
#
# MKAIV-449 Three calibrator Imaging
# Name: /var/kat/archive2/data/ftp/staging/1496395285.h5 (version 3.0)
# Antennas: m005,m008,m011,m049,*m057,m058,m059,m060,m061  Inputs: 18  Autocorr: yes  Crosscorr: yes
#
# MKAIV-229 Imaging full beam correction
# Name: /var/kat/archive2/data/ftp/staging/1496349008.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,m008,m011,m014,m015,m021,m031,m042,m057,*m058,m059,m060  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1496345415.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,m008,m011,m014,m015,m021,m031,m042,m057,*m058,m059,m060  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1496344810.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,m008,m011,m014,m015,m021,m031,m042,m057,*m058,m059,m060  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1496341811.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,m008,m011,m014,m015,m021,m031,m042,m057,*m058,m059,m060  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1496341213.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,m008,m011,m014,m015,m021,m031,m042,m057,*m058,m059,m060  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1496340011.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,m008,m011,m014,m015,m021,m031,m042,m057,*m058,m059,m060  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1496338212.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,m008,m011,m014,m015,m021,m031,m042,m057,*m058,m059,m060  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-393 Imaging observation DEEP3
# Name: /var/kat/archive2/data/ftp/staging/1496315541.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m031,m042,m057,m058,m059  Inputs: 26  Autocorr: yes  Crosscorr: yes
#
# MKAIV-393 Imaging observation DEEP3
# Name: /var/kat/archive2/data/ftp/staging/1496301228.h5 (version 3.0)
# Antennas: m002,m005,m006,m007,*m008,m011,m014,m031,m042,m057,m058,m059  Inputs: 24  Autocorr: yes  Crosscorr: yes
#
# MKAIV-308 Basic health
# Name: /var/kat/archive2/data/ftp/staging/1496298638.h5 (version 3.0)
# Antennas: m002,m005,m006,m007,*m008,m011,m014,m031,m042,m057,m058,m059  Inputs: 24  Autocorr: yes  Crosscorr: yes
#
# MKAIV-214 Phase-up (4K) 1934
# Name: /var/kat/archive2/data/ftp/staging/1496287812.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m015,m021,m031,m042,m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-214 Phase-up (4K) 1934
# Name: /var/kat/archive2/data/ftp/staging/1496286010.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m015,m021,m031,m042,m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-214 Phase-up (4K) 1934
# Name: /var/kat/archive2/data/ftp/staging/1496284210.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m015,m021,m031,m042,m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-214 Phase-up (4K) 1934
# Name: /var/kat/archive2/data/ftp/staging/1496282425.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m015,m021,m031,m042,m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-214 Phase-up (4K) 1934
# Name: /var/kat/archive2/data/ftp/staging/1496280610.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m015,m021,m031,m042,m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-214 Phase-up (4K) 1934
# Name: /var/kat/archive2/data/ftp/staging/1496278813.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m015,m021,m031,m042,m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-173 drift scan 1934-63
# Name: /var/kat/archive2/data/ftp/staging/1496274323.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m015,m021,m031,m042,m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-214 Phase-up (4K) 1934
# Name: /var/kat/archive2/data/ftp/staging/1496273414.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m015,m021,m031,m042,m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1496269828.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m015,m021,m031,m042,m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1496268930.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m015,m021,m031,m042,m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1496267128.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m015,m021,m031,m042,m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1496266232.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m015,m021,m031,m042,m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1496264437.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m015,m021,m031,m042,m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1496263529.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m015,m021,m031,m042,m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1496259025.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m015,m021,m031,m042,m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1496257829.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m015,m021,m031,m042,m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1496255426.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m015,m021,m031,m042,m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1496254810.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m015,m021,m031,m042,m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1496253610.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m015,m021,m031,m042,m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1496252188.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m015,m021,m031,m042,m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1496251765.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m015,m021,m031,m042,m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-449 Three calibrator Imaging
# Name: /var/kat/archive2/data/ftp/staging/1496246550.h5 (version 3.0)
# Antennas: m001,m002,m005,m006,m007,*m008,m011,m014,m015,m021,m031,m042,m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-308 Basic health
# Name: /var/kat/archive2/data/ftp/staging/1496226522.h5 (version 3.0)
# Antennas: m000,m001,m002,m005,m006,m007,*m008,m011,m015,m031,m042,m057,m058  Inputs: 26  Autocorr: yes  Crosscorr: yes
#
# COMM-161 Image faint, extended HI (IC 5264)
# Name: /var/kat/archive2/data/ftp/staging/1496109612.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,*m008,m010,m011,m014,m015,m031,m042,m057,m058  Inputs: 28  Autocorr: yes  Crosscorr: yes
#
# MKAIV-405 Generic AR1 Phaseup
# Name: /var/kat/archive2/data/ftp/staging/1496109007.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,*m008,m010,m011,m014,m015,m031,m042,m057,m058  Inputs: 28  Autocorr: yes  Crosscorr: yes
#
# MKAIV-232 Baseline Calibration (Delay model calculation)
# Name: /var/kat/archive2/data/ftp/staging/1496089080.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,*m008,m010,m011,m014,m015,m031,m042,m057,m058  Inputs: 28  Autocorr: yes  Crosscorr: yes
#
# Generic AR1 delaycal
# Name: /var/kat/archive2/data/ftp/staging/1496088903.h5 (version 3.0)
# ...
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1495404075.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV 215: Phase-up (4K) PKS 1934-63
# Name: /var/kat/archive2/data/ftp/staging/1495403623.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1644-4559
# Name: /var/kat/archive2/data/ftp/staging/1495403180.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV 215: Phase-up (4K) PKS 1934-63
# Name: /var/kat/archive2/data/ftp/staging/1495402732.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1495401390.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV 215: Phase-up (4K) PKS 1934-63
# Name: /var/kat/archive2/data/ftp/staging/1495400940.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1644-4559
# Name: /var/kat/archive2/data/ftp/staging/1495400504.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV 215: Phase-up (4K) PKS 1934-63
# Name: /var/kat/archive2/data/ftp/staging/1495400054.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1495398716.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV 215: Phase-up (4K) PKS 1934-63
# Name: /var/kat/archive2/data/ftp/staging/1495398272.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1644-4559
# Name: /var/kat/archive2/data/ftp/staging/1495397838.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV 215: Phase-up (4K) PKS 1934-63
# Name: /var/kat/archive2/data/ftp/staging/1495397423.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV 215: Phase-up (4K) PKS 1934-63
# Name: /var/kat/archive2/data/ftp/staging/1495396751.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-166 AR1 Imaging Calibrator LST 06-12
# Name: /var/kat/archive2/data/ftp/staging/1495381510.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0953 0755
# Name: /var/kat/archive2/data/ftp/staging/1495380063.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0437-4715
# Name: /var/kat/archive2/data/ftp/staging/1495379347.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0835-4510
# Name: /var/kat/archive2/data/ftp/staging/1495378190.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0742-2822
# Name: /var/kat/archive2/data/ftp/staging/1495377339.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0738-4042
# Name: /var/kat/archive2/data/ftp/staging/1495376285.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# AR1: MKAIV-387 CBF J0437-4715
# Name: /var/kat/archive2/data/ftp/staging/1495375572.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-396 Gain Stability
# Name: /var/kat/archive2/data/ftp/staging/1495356162.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m057,m060,m061,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388 CBF J1909-3744
# Name: /var/kat/archive2/data/ftp/staging/1495331112.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m049,m057,m058,m060  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388  CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1495329312.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m049,m057,m058,m060  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388 CBF J1644-4559
# Name: /var/kat/archive2/data/ftp/staging/1495328413.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m049,m057,m058,m060  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388  CBF J1559-4438
# Name: /var/kat/archive2/data/ftp/staging/1495326614.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m049,m057,m058,m060  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-388 CBF J1327-6222
# Name: /var/kat/archive2/data/ftp/staging/1495325711.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m049,m057,m058,m060  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1495323610.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m049,m057,m058,m060  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1644-4559
# Name: /var/kat/archive2/data/ftp/staging/1495322410.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m049,m057,m058,m060  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1495320012.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m049,m057,m058,m060  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1495316410.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m049,m057,m058,m060  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-386 Bandpass calibrators with 10 min track
# Name: /var/kat/archive2/data/ftp/staging/1495291661.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m015,m021,m031,m049,m057,m058,m060  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-202 Interferometric Pointing Calibration
# Name: /var/kat/archive2/data/ftp/staging/1495271762.h5 (version 3.0)
# Antennas: m002,m003,m005,m012,m015,m031,*m057,m058  Inputs: 16  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1495240523.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m014,m015,m021,m031,m049,m057,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1495237224.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m014,m015,m021,m031,m049,m057,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1495236622.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m014,m015,m021,m031,m049,m057,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1495236025.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m014,m015,m021,m031,m049,m057,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1495235426.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m014,m015,m021,m031,m049,m057,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1495233629.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m014,m015,m021,m031,m049,m057,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1495233024.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m014,m015,m021,m031,m049,m057,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1495232433.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m014,m015,m021,m031,m049,m057,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1495231824.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m014,m015,m021,m031,m049,m057,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1495230039.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m014,m015,m021,m031,m049,m057,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1495229424.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m014,m015,m021,m031,m049,m057,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1495228825.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m014,m015,m021,m031,m049,m057,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1495228226.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m014,m015,m021,m031,m049,m057,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1495211425.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m014,m015,m021,m031,m049,m057,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1495210165.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m014,m015,m021,m031,m049,m057,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1495209180.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m014,m015,m021,m031,m049,m057,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1495208113.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m014,m015,m021,m031,m049,m057,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1495207272.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m014,m015,m021,m031,m049,m057,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1495206228.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m014,m015,m021,m031,m049,m057,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1495205355.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,*m008,m010,m012,m014,m015,m021,m031,m049,m057,m058  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1495151416.h5 (version 3.0)
# Antennas: m000,m005,m006,m007,*m008,m010,m012,m015,m022,m057,m058  Inputs: 22  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1495148114.h5 (version 3.0)
# Antennas: m000,m005,m006,m007,*m008,m010,m012,m015,m022,m057,m058  Inputs: 22  Autocorr: yes  Crosscorr: yes
#
# COMM-AR1 CBF J1622-4950
# Name: /var/kat/archive2/data/ftp/staging/1495144816.h5 (version 3.0)
# Antennas: m000,m005,m006,m007,*m008,m010,m012,m015,m022,m057,m058  Inputs: 22  Autocorr: yes  Crosscorr: yes
#
# MKAIV-295B AR1 Imaging Calibrator LST 06-12
# Name: /var/kat/archive2/data/ftp/staging/1495127750.h5 (version 3.0)
# Antennas: m000,m005,m006,m007,*m008,m010,m012,m015,m022,m057,m058  Inputs: 22  Autocorr: yes  Crosscorr: yes
#
# MKAIV-308 Basic health
# Name: /var/kat/archive2/data/ftp/staging/1495126206.h5 (version 3.0)
# Antennas: m000,m005,m006,m007,*m008,m010,m012,m015,m022,m057,m058  Inputs: 22  Autocorr: yes  Crosscorr: yes
#
# Hotload and Coldload observation:MKAIV-209 Tsys and Tnd
# Name: /var/kat/archive2/data/ftp/staging/1495111661.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,*m008,m021,m022,m031,m034,m049,m057,m058,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-386 Bandpass calibrators with 10 min track
# Name: /var/kat/archive2/data/ftp/staging/1495090072.h5 (version 3.0)
# Antennas: m000,m001,m002,m006,m007,*m008,m021,m022,m031,m034,m049,m057,m058,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-386 Bandpass calibrators with 10 min track
# Name: /var/kat/archive2/data/ftp/staging/1495087372.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,m007,*m008,m022,m034,m049,m057,m058,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-308 Basic health
# Name: /var/kat/archive2/data/ftp/staging/1495084282.h5 (version 3.0)
# Antennas: m000,m001,m002,m003,m005,m006,m007,*m008,m022,m034,m049,m057,m058,m059,m060,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-386A AR1 Bandpass Calibrators LST 00-06
# Name: /var/kat/archive2/data/ftp/staging/1495001957.h5 (version 3.0)
# Antennas: m000,m003,m005,m010,m012,m015,m020,m021,m022,m031,m034,m049,*m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-308 Basic health
# Name: /var/kat/archive2/data/ftp/staging/1495000206.h5 (version 3.0)
# Antennas: m000,m003,m005,m010,m012,m015,m020,m021,m022,m031,m034,m049,*m057,m058,m059,m061  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
#
# Name: /var/kat/archive2/data/ftp/staging/1494934167.h5 (version 3.0)
# Antennas: m003,m005,m006,*m008,m010,m012,m014,m015,m020,m021,m031,m034,m049,m057,m058,m059  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV 215: Phase-up (4K) PKS 0408-65
# Name: /var/kat/archive2/data/ftp/staging/1494933761.h5 (version 3.0)
# Antennas: m003,m005,m006,*m008,m010,m012,m014,m015,m020,m021,m031,m034,m049,m057,m058,m059  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-584 Generic AR1 delaycal
# Name: /var/kat/archive2/data/ftp/staging/1494933580.h5 (version 3.0)
# Antennas: m003,m005,m006,*m008,m010,m012,m014,m015,m020,m021,m031,m034,m049,m057,m058,m059  Inputs: 32  Autocorr: yes  Crosscorr: yes
#
# MKAIV-386A AR1 Bandpass Calibrators LST 00-06
# Name: /var/kat/archive2/data/ftp/staging/1494922314.h5 (version 3.0)
# Antennas: m000,m001,m003,m005,m006,m007,*m008,m010,m012,m014,m049,m057,m058,m059  Inputs: 28  Autocorr: yes  Crosscorr: yes
#
# MKAIV-308 Basic health
# Name: /var/kat/archive2/data/ftp/staging/1494920506.h5 (version 3.0)
# Antennas: m000,m001,m003,m005,m006,m007,*m008,m010,m012,m014,m049,m057,m058,m059  Inputs: 28  Autocorr: yes  Crosscorr: yes
#
# MKAIV-111 AR1 pointing
# Name: /var/kat/archive2/data/ftp/staging/1494847551.h5 (version 3.0)
# Antennas: m000,m003,m005,m006,m007,*m008,m010,m012,m015,m020,m021,m022,m031,m057,m059  Inputs: 30  Autocorr: yes  Crosscorr: yes
#
# MKAIV-308 Basic health
# Name: /var/kat/archive2/data/ftp/staging/1494840327.h5 (version 3.0)
# Antennas: m000,m003,m005,m006,m007,m008,m010,m012,*m015,m020,m021,m022,m031,m057,m059,m062  Inputs: 32  Autocorr: yes  Crosscorr: yes
