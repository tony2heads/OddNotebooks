# %% [markdown]
# # 4. Basic Transforms

# %% [markdown]
# In this notebook we will look at some basic Fourier transform pairs.
#
# First import the necessary modules:

# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
pi=np.pi
sinc=np.sinc

# %% [markdown]
# There are some basic Fourier transfom pairs that are worth knowing, because you'll see them all over the place (including later in this course!) and they can be used to create more complex functions, as we will see later.
# <br/>
# First lets make a couple of convenience functions using the fourier transform provided by numpy:

# %%
def ft(y):
    return np.fft.fftshift(np.fft.fft(np.fft.fftshift(y)))

def ftfreqs(N,dt):
    return np.fft.fftshift(np.fft.fftfreq(N,dt))

# %% [markdown]
# Now lets define some of these functions here, then we can play with taking their Fourier transforms.

# %%
# constant function
def constant(t,A):
    return A*np.ones(len(t))

# %%
# spike of amplitude A at given value of t
def spike(t,t0,A):
    output = np.zeros(len(t))
    output[t==t0] = A
    print sum(t==t0)
    return output

# %%
# top-hat function
def tophat(t,width,A):
    output = np.zeros(len(t))
    output[abs(t)<width/2.0] = A
    return output

# %%
# sinc function
def sincfunc(t,scale):
    return sinc(t/scale)

# %%
# gaussian function
def gaussian(t,sigma):
    return (1./(2.*np.pi*sigma))*np.exp(-t**2.0/(sigma**2.0))

# %%
# shah 
def shah(t,t_space,A):
    output = np.zeros(len(t))
    mod_array = np.array([int(i)%t_space for i in t])
    output[mod_array==0] = A
    return output

# %% [markdown]
# Now lets play with these functions and their Fourier transforms. First lets do a single cosine, just to check all is well:

# %%
delta_t = 1.0
t = np.arange(-200,200,delta_t)     # set x-axis values

# %%
y=5.0*np.cos(2.*pi*t/50.)          # create function
Y = ft(y)                           # Fourier transform
freqs = ftfreqs(len(y),delta_t)

# %%
f, ax = plt.subplots(1,2,figsize=[13,3])     # create plot

ax[0].plot(t,y)
ax[0].set_xlabel('Time')
ax[0].set_ylabel('Amplitude')
ax[0].set_title('y(t)')

ax[1].plot(freqs,Y,'o-')
ax[1].set_xlabel('Frequency')
ax[1].set_ylabel('Amplitude')
ax[1].set_title('Y(f)')

# try setting the x limits to zoom in to the Fourier transform:
ax[1].set_xlim(-0.05,0.05)
# Out:
# /usr/local/lib/python2.7/dist-packages/numpy/core/numeric.py:462: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (-0.05, 0.05)

# %% [markdown]
# Does that look like what you expect?
# <br/>
# Now lets try the functions we've defined above:

# %%
delta_t = 1.0
t = np.arange(-200,200,delta_t)     # set x-axis values

# %%
y=tophat(t,30.,10.)                 # create function
Y = ft(y)                           # Fourier transform
freqs = ftfreqs(len(y),delta_t)

# %%
f, ax = plt.subplots(1,2,figsize=[13,3])     # create plot

ax[0].plot(t,y)
ax[0].set_xlabel('Time')
ax[0].set_ylabel('Amplitude')
ax[0].set_title('y(t)')

#ax[1].plot(freqs,Y,'o')
ax[1].plot(freqs,Y,'o-')
ax[1].set_xlabel('Frequency')
ax[1].set_ylabel('Amplitude')
ax[1].set_title('Y(f)')

# try setting the x limits to zoom in to the Fourier transform:
ax[1].set_xlim(-0.5,0.5)
# Out:
# (-0.5, 0.5)

# %% [markdown]
# You can fiddle, but some suggested functions and parameters are:
#
# * constant(t,10.)
# * spike(t,0.0,10.)
# * tophat(t,30.,10.)
# * sincfunc(t,10.)
# * gaussian(t,10.)
# * shah(t,20.,10.)
#
# Try making the parameters larger and smaller, and see what the effect is in the Fourier domain.

# %% [markdown]
# We can also combine functions. For example:

# %%
y = sincfunc(t,20.)*sincfunc(t,20.)   # create function
Y = ft(y)                             # Fourier transform
freqs = ftfreqs(len(y),delta_t)

# %%
f, ax = plt.subplots(1,2,figsize=[13,3])     # create plot

ax[0].plot(t,y)
ax[0].set_xlabel('Time')
ax[0].set_ylabel('Amplitude')
ax[0].set_title('y(t)')

ax[1].plot(freqs,Y)
ax[1].set_xlabel('Frequency')
ax[1].set_ylabel('Amplitude')
ax[1].set_title('Y(f)')

# try setting the x limits to zoom in to the Fourier transform:
ax[1].set_xlim(-0.3,0.3)
# Out:
# (-0.3, 0.3)

# %%
plt.show()
