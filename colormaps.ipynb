# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm

# %% [markdown]
# Sequential2
# -----------
#
# Many of the $L^*$ values from the Sequential2 plots are monotonically
# increasing, but some (autumn, cool, spring, and winter) plateau or even go both
# up and down in $L^*$ space. Others (afmhot, copper, gist_heat, and hot)
# have kinks in the $L^*$ functions. Data that is being represented in a
# region of the colormap that is at a plateau or kink will lead to a perception of
# banding of the data in those values in the colormap (see [mycarta-banding]_ for
# an excellent example of this).

# %%
mpl.rcParams['figure.figsize']=(12.0,12.0)

# %%
for tel in range(64):
    x=np.linspace(0,6.3,22)
    plt.plot(x,tel*np.sin(x),color=cm.viridis.colors[4*tel])
plt.show()

# %%
for tel in range(64):
    x=np.linspace(0,6.3,22)
    plt.plot(x,tel*np.sin(x),color=cm.inferno.colors[4*tel])
plt.show()

# %%
for tel in range(64):
    x=np.linspace(0,6.3,22)
    plt.plot(x,tel*np.sin(x),color=cm.plasma.colors[4*tel])
plt.show()

# %%
for tel in range(64):
    x=np.linspace(0,6.3,22)
    plt.plot(x,tel*np.sin(x),color=cm.magma.colors[4*tel])
plt.show()

# %%
for tel in range(64):
    x=np.linspace(0,6.3,22)
    plt.plot(x,tel*np.sin(x),color=cm.viridis_r.colors[4*tel])
plt.show()

# %%
cm2=cm.viridis_r.colors+cm.plasma.colors
print len(cm2)
# Out:
# 512

# %%
for tel in range(64):
    x=np.linspace(0,6.3,100)
    plt.plot(x,tel*np.sin(x),color=cm2[8*tel],label=str(tel))
    plt.legend()
plt.show()

# %%
cm3=cm.viridis.colors+cm.plasma_r.colors
for tel in range(64):
    x=np.linspace(0,6.3,100)
    plt.plot(x,tel*np.sin(x),color=cm3[8*tel],label=str(tel))
    plt.legend()
plt.show()
