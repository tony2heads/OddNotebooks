# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def gaussian(x, mu, sig):
    """
    mu is the mean
    sig is standard devaiation
    """
    return np.exp(-np.power((x - mu)/sig, 2.)/2)

# %%
x=np.linspace(-3,3,50)
amp=gaussian(x,0,2.0)

# %%
plt.figure(figsize=(10,10))
plt.minorticks_on()
plt.plot(x,amp)
plt.grid()

# %%
print gaussian(1.1775,0,1)
hwhm=1.1775
# Out:
# 0.49994703058592965

# %%
# FWHM in sigma =2*1.1775=2.355

# %%
def where(amp):
    """
    valid in the range 0 to 1.
    """
    x=np.sqrt(2*np.log(1/amp))
    return x

# %%
print where(0.5), where(0.9)
# Out:
# 1.1774100225154747 0.4590436050264209

# %%
fwhm=2*where(0.5)
print "FWHM =twice HWHM = ",fwhm , "in units of Sigma"
# Out:
# FWHM =twice HWHM =  2.3548200450309493 in units of Sigma
