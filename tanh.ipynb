# %%
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x=np.linspace(-3,3,201)

# %%
print x
# Out:
# [-3.   -2.97 -2.94 -2.91 -2.88 -2.85 -2.82 -2.79 -2.76 -2.73 -2.7  -2.67
#  -2.64 -2.61 -2.58 -2.55 -2.52 -2.49 -2.46 -2.43 -2.4  -2.37 -2.34 -2.31
#  -2.28 -2.25 -2.22 -2.19 -2.16 -2.13 -2.1  -2.07 -2.04 -2.01 -1.98 -1.95
#  -1.92 -1.89 -1.86 -1.83 -1.8  -1.77 -1.74 -1.71 -1.68 -1.65 -1.62 -1.59
#  -1.56 -1.53 -1.5  -1.47 -1.44 -1.41 -1.38 -1.35 -1.32 -1.29 -1.26 -1.23
#  -1.2  -1.17 -1.14 -1.11 -1.08 -1.05 -1.02 -0.99 -0.96 -0.93 -0.9  -0.87
#  -0.84 -0.81 -0.78 -0.75 -0.72 -0.69 -0.66 -0.63 -0.6  -0.57 -0.54 -0.51
#  -0.48 -0.45 -0.42 -0.39 -0.36 -0.33 -0.3  -0.27 -0.24 -0.21 -0.18 -0.15
#  -0.12 -0.09 -0.06 -0.03  0.    0.03  0.06  0.09  0.12  0.15  0.18  0.21
#   0.24  0.27  0.3   0.33  0.36  0.39  0.42  0.45  0.48  0.51  0.54  0.57
#   0.6   0.63  0.66  0.69  0.72  0.75  0.78  0.81  0.84  0.87  0.9   0.93
#   0.96  0.99  1.02  1.05  1.08  1.11  1.14  1.17  1.2   1.23  1.26  1.29
#   1.32  1.35  1.38  1.41  1.44  1.47  1.5   1.53  1.56  1.59  1.62  1.65
# ...

# %%
y=np.tanh(x)

# %%
pylab.figure(figsize=(12,12))
pylab.plot(x,y)
pylab.ylim(-1,1)
y2=x
pylab.plot(x,y2,label="Ideal")
pylab.xlabel("Signal in")
pylab.ylabel("Signal out")
pylab.grid()
pylab.legend()
