# %%
n="/var/kat/archive/data/RTS/telescope_products/2015/12/03/1449140896.h5"

# %%
# %matplotlib inline
import scape
import katpoint
# Out:
# /usr/local/lib/python2.7/dist-packages/pkg_resources/__init__.py:187: RuntimeWarning: You have iterated over the result of pkg_resources.parse_version. This is a legacy behavior which is inconsistent with the new version class introduced in setuptools 8.0. In most cases, conversion to a tuple is unnecessary. For comparison of versions, sort the Version instances directly. If you have another use case requiring the tuple, please file a bug with the setuptools project describing that need.
#   stacklevel=1,

# %%
from katsdpscripts.reduction.analyse_point_source_scans import analyse_point_source_scans

# %%
class my_opts:
    def __init__(self, **kwds):
        self.__dict__.update(kwds)

# %%
opts = my_opts(outfilebase=None, keepfilename=None, baseline='m062', \
        mc_iterations=1, time_offset=0.0, pointing_model=None, freq_chans=None, old_loader=None, nd_models=None, \
        ku_band=True, channel_mask=None,keep_all=None,remove_spikes=False,batch=False,plot_spectrum=True)

# %%
analyse_point_source_scans(n,opts)
# Out:
# INFO:root:Loading dataset '/var/kat/archive/data/RTS/telescope_products/2015/12/03/1449140896.h5'
# INFO:scape.kathdf5:Loading baseline 'm062,m062'
# DEBUG:katpoint.catalogue:Added '1253-055' [radec] (and 1 aliases)
# DEBUG:katpoint.catalogue:Added '1921-293' [radec] (and 1 aliases)
# INFO:scape.kathdf5:Defaulting to 'coupler' noise diode (either no or both diodes are firing)
# WARNING:scape.kathdf5:Cannot find coupler noise diode H polarisation model for antenna m062 - using default.
# WARNING:scape.kathdf5:Cannot find coupler noise diode V polarisation model for antenna m062 - using default.
# INFO:root:==== Processing compound scan 1 of 1: 'm062 1449140896 1253-055 2015-12-03 11:17:34.337' ====
# WARNING:scape.dataset:No noise diode model found in data set - gain calibration not done
# WARNING:scape.dataset:No noise diode model found in data set - gain calibration not done
# DEBUG:scape.compoundscan:Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target '1253-055':
# DEBUG:scape.beam_baseline:Iteration 0: residual = inf, beam height = 5.188, width = 0.087 deg, inner region = 155/360
# DEBUG:scape.beam_baseline:Iteration 1: residual = 1.49, beam height = 6.571, width = 0.122 deg, inner region = 155/360
# DEBUG:scape.beam_baseline:Iteration 2: residual = 0.00, beam height = 6.571, width = 0.122 deg, inner region = 155/360
# DEBUG:scape.beam_baseline:Refinement: beam height = 6.330, width = 0.120 deg, first null = 0.146 deg, based on 6 of 6 scans
# DEBUG:scape.compoundscan:Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target '1253-055':
# DEBUG:scape.beam_baseline:Iteration 0: residual = inf, beam height = 3.150, width = 0.087 deg, inner region = 155/360
# DEBUG:scape.beam_baseline:Iteration 1: residual = 6.05, beam height = 4.034, width = 0.119 deg, inner region = 153/360
# DEBUG:scape.beam_baseline:Iteration 2: residual = 0.00, beam height = 4.033, width = 0.119 deg, inner region = 153/360
# DEBUG:scape.beam_baseline:Iteration 3: residual = 0.00, beam height = 4.033, width = 0.119 deg, inner region = 153/360
# DEBUG:scape.beam_baseline:Refinement: beam height = 4.102, width = 0.123 deg, first null = 0.185 deg, based on 6 of 6 scans
# DEBUG:scape.compoundscan:Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target '1253-055':
# DEBUG:scape.beam_baseline:Iteration 0: residual = inf, beam height = 8.313, width = 0.087 deg, inner region = 154/360
# DEBUG:scape.beam_baseline:Iteration 1: residual = 4.03, beam height = 10.601, width = 0.121 deg, inner region = 154/360
# DEBUG:scape.beam_baseline:Iteration 2: residual = 0.00, beam height = 10.601, width = 0.121 deg, inner region = 154/360
# DEBUG:scape.beam_baseline:Refinement: beam height = 10.334, width = 0.120 deg, first null = 0.169 deg, based on 6 of 6 scans
# WARNING:scape.dataset:No noise diode model found in data set - gain calibration not done
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':
# INFO:root:==== Processing compound scan 2 of 1: 'm062 1449140896 1921-293 2015-12-03 11:27:32.584' ====
# WARNING:scape.dataset:No noise diode model found in data set - gain calibration not done
# WARNING:scape.dataset:No noise diode model found in data set - gain calibration not done
# DEBUG:scape.compoundscan:Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target '1921-293':
# DEBUG:scape.beam_baseline:Iteration 0: residual = inf, beam height = 2.682, width = 0.085 deg, inner region = 151/359
# DEBUG:scape.beam_baseline:Iteration 1: residual = 0.21, beam height = 2.678, width = 0.147 deg, inner region = 152/359
# DEBUG:scape.beam_baseline:Iteration 2: residual = 0.00, beam height = 2.671, width = 0.149 deg, inner region = 151/359
# DEBUG:scape.beam_baseline:Iteration 3: residual = 0.00, beam height = 2.668, width = 0.149 deg, inner region = 151/359
# DEBUG:scape.beam_baseline:Iteration 4: residual = 0.00, beam height = 2.668, width = 0.149 deg, inner region = 151/359
# DEBUG:scape.beam_baseline:Refinement: beam height = 2.674, width = 0.112 deg, first null = 0.178 deg, based on 6 of 6 scans
# DEBUG:scape.compoundscan:Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target '1921-293':
# DEBUG:scape.beam_baseline:Iteration 0: residual = inf, beam height = 10.228, width = 0.074 deg, inner region = 136/359
# DEBUG:scape.beam_baseline:Iteration 1: residual = 0.02, beam height = 8.953, width = 0.154 deg, inner region = 52/359
# DEBUG:scape.beam_baseline:Iteration 2: residual = 0.08, beam height = 12.906, width = 0.200 deg, inner region = 47/359
# DEBUG:scape.beam_baseline:Iteration 3: residual = 0.00, beam height = 12.677, width = 0.198 deg, inner region = 48/359
# DEBUG:scape.beam_baseline:Iteration 4: residual = -0.00, beam height = 12.662, width = 0.197 deg, inner region = 48/359
# DEBUG:scape.compoundscan:Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target '1921-293':
# DEBUG:scape.beam_baseline:Iteration 0: residual = inf, beam height = 10.599, width = 0.063 deg, inner region = 146/359
# DEBUG:scape.beam_baseline:Iteration 1: residual = 0.01, beam height = 10.588, width = 0.069 deg, inner region = 146/359
# DEBUG:scape.beam_baseline:Iteration 2: residual = -0.00, beam height = 10.590, width = 0.069 deg, inner region = 146/359
# DEBUG:scape.beam_baseline:Refinement: beam height = 4.923, width = 0.088 deg, first null = 0.124 deg, based on 2 of 6 scans
# WARNING:scape.dataset:No noise diode model found in data set - gain calibration not done
# keep_all=None,main_compscan.beam.is_valid=True , keep=False
# keep_all=None,main_compscan.beam.is_valid=False , keep=False

# %%
opts = my_opts(outfilebase=None, keepfilename=None, baseline='m062,m063',\
        mc_iterations=1, time_offset=0.0, pointing_model=None, freq_chans=None, old_loader=None, nd_models=None, \
        ku_band=True, channel_mask=None,keep_all=None,remove_spikes=False,batch=True,plot_spectrum=False)

# %%
analyse_point_source_scans(n,opts)
# Out:
# INFO:root:Loading dataset '/var/kat/archive/data/RTS/telescope_products/2015/12/03/1449140896.h5'
# INFO:scape.kathdf5:Loading baseline 'm062,m063'
# DEBUG:katpoint.catalogue:Added '1253-055' [radec] (and 1 aliases)
# DEBUG:katpoint.catalogue:Added '1921-293' [radec] (and 1 aliases)
# INFO:scape.kathdf5:Defaulting to 'coupler' noise diode (either no or both diodes are firing)
# WARNING:scape.kathdf5:Cannot find coupler noise diode H polarisation model for antenna m062 - using default.
# WARNING:scape.kathdf5:Cannot find coupler noise diode V polarisation model for antenna m062 - using default.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-5ee7979f173b> in <module>()
# ----> 1 analyse_point_source_scans(n,opts)
#
# /usr/local/lib/python2.7/dist-packages/katsdpscripts/reduction/analyse_point_source_scans.pyc in analyse_point_source_scans(filename, opts)
#     381         dataset.nd_v_model=None
#     382         for i in range(len(dataset.scans)):
# --> 383             dataset.scans[i].data = scape.stats.remove_spikes(dataset.scans[i].data,axis=1,spike_width=3,outlier_sigma=5.)
#     384
#     385     # Initialise the output data cache (None indicates the compscan has not been processed yet)
#
# /usr/local/lib/python2.7/dist-packages/scape/stats.pyc in remove_spikes(data, axis, spike_width, outlier_sigma)
#     220     kernel[axis] = kernel_size
#     221     # Medfilt now seems to upcast 32-bit floats to doubles - convert it back to floats...
# --> 222     filtered_data = np.asarray(signal.medfilt(data, kernel), data.dtype)
#     223     # The deviation is measured relative to the local median in the signal
#     224     abs_dev = np.abs(data - filtered_data)
#
# /usr/lib/python2.7/dist-packages/scipy/signal/signaltools.pyc in medfilt(volume, kernel_size)
#     376     numels = product(kernel_size, axis=0)
#     377     order = numels // 2
# --> 378     return sigtools._order_filterND(volume, domain, order)
#     379
#     380
#
# ValueError: order_filterND not available for this type
