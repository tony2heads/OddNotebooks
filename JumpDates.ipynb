# %%
from datetime import  datetime
#
def ts_date(ts):
    dt=datetime.fromtimestamp(ts)
    date=dt.strftime("%Y-%b-%d %H:%M")
    return date

# %%
ts=1528797322 
print ts_date(ts) #LOCAL
# Out:
# 2018-Jun-12 11:55

# %%
f=open('/home/tony/Desktop/katsdpscripts_OLD/reduction/Interferometric/RDB/dates.txt','r')
f2=open('/home/tony/Desktop/katsdpscripts_OLD/reduction/Interferometric/RDB/dates+times.txt','w+')
for line in f:
    ts=int(line)
    print line[:-1], ts_date(ts)
    f2.write("%s  %s\n" %(line[:-1], ts_date(ts)))
f.close()
# Out:
# 1527267438 2018-May-25 18:57
# 1527274909 2018-May-25 21:01
# 1527282685 2018-May-25 23:11
# 1527291452 2018-May-26 01:37
# 1527299014 2018-May-26 03:43
# 1528458436 2018-Jun-08 13:47
# 1528620394 2018-Jun-10 10:46
# 1528793511 2018-Jun-12 10:51
# 1529568791 2018-Jun-21 10:13
# 1531862098 2018-Jul-17 23:14
# 1532397670 2018-Jul-24 04:01
# 1532538109 2018-Jul-25 19:01
# 1532709498 2018-Jul-27 18:38
# 1533000338 2018-Jul-31 03:25
# 1533361580 2018-Aug-04 07:46
# 1534359661 2018-Aug-15 21:01
# 1534546856 2018-Aug-18 01:00
# 1534561951 2018-Aug-18 05:12
# 1534876817 2018-Aug-21 20:40
# 1535238760 2018-Aug-26 01:12
# 1535362286 2018-Aug-27 11:31
# 1535927888 2018-Sep-03 00:38
# 1538395976 2018-Oct-01 14:12
# 1538480138 2018-Oct-02 13:35
# 1538669095 2018-Oct-04 18:04
# 1538675667 2018-Oct-04 19:54
# 1541021466 2018-Oct-31 23:31
# 1541177285 2018-Nov-02 18:48
# 1541953576 2018-Nov-11 18:26
# 1544111434 2018-Dec-06 17:50
# 1545014672 2018-Dec-17 04:44
# 1545253441 2018-Dec-19 23:04
# ...
