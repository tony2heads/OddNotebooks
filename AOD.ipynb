# %%
import pysolr
from IPython.core.display import display, HTML
archive = pysolr.Solr('http://192.168.1.50:8983/solr/kat_core')
search_str = []
search_str.append('CAS.ProductTypeName:MeerKATAR1TelescopeProduct')
search_str.append('StartTime:[2017-05-17T00:00:00Z TO 2017-05-24T00:00:00Z]')
search_string = ' AND '.join(search_str)
ar_res = archive.search( search_string ,rows=10000,**{'sort':'StartTime desc'})
h = '<table>'
h += "<tr><th>Owner<th>UT Start<th>Schedule block<th>Description<th>chan<th>ants<th>size<th>Archive</tr>"			
for r in ar_res.docs[::-1]:
    if 'ScheduleBlockIdCode' not in r:
        r['ScheduleBlockIdCode']=""
    if len(r['Description'])<1 :
        r['Description']='Beamformer?'
    link = 'http://kat-archive.kat.ac.za:8080/archive_search/#\
    {"ei":"%s","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}\
    '%(r['ScheduleBlockIdCode'])
    h += '<tr> <td> %s <td> %s <td> <a href=\'%s\'>%s</a>\
    <td> %s <td> %d <td> %d <td> %5.2f <td> %s  </tr>'\
    %(r['Observer'],r['StartTime'],link,r['ScheduleBlockIdCode'],r['Description'],\
      r['NumFreqChannels'],len(r['Antennas']),r['FileSize'][0]/1024.0**3\
      ,r['CAS.ReferenceDatastore'][0][5:])
h += "</table>"
display(HTML(h))
h += "<tr><th>Owner<th>UT Start<th>Schedule block<th>Description<th>\
chan<th>ants<th>size<th>Archive</tr>"
from BeautifulSoup import BeautifulSoup
soup = BeautifulSoup(h)
with open("output.html", "wb") as file:
    file.write("<html>\n")
    file.write(soup.prettify("utf-8"))
    file.write("\n<\html>\n")
# Out:
# <table><tr><th>Owner<th>UT Start<th>Schedule block<th>Description<th>chan<th>ants<th>size<th>Archive</tr><tr> <td> Lindsay <td> 2017-05-17T05:50:08Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20170517-0003","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20170517-0003</a>    <td> MKAIV-308 Basic health <td> 4096 <td> 16 <td>  3.67 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/05/17/1495000206.h5  </tr><tr> <td> Lindsay <td> 2017-05-17T06:13:54Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20170517-0005","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20170517-0005</a>    <td> MKAIV-405 Generic AR1 Phaseup <td> 4096 <td> 16 <td>  0.81 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/05/17/1495001633.h5  </tr><tr> <td> Tony <td> 2017-05-17T06:19:18Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20170517-0006","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20170517-0006</a>    <td> MKAIV-386A AR1 Bandpass Calibrators LST 00-06 <td> 4096 <td> 16 <td> 14.64 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/05/17/1495001957.h5  </tr><tr> <td> ruby <td> 2017-05-17T06:38:33Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20170517-0007","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20170517-0007</a>    <td> 'Power detected search mode single pol' <td> 4096 <td> 1 <td>  0.00 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/05/17/1495003067.h5  </tr><tr> <td> ruby <td> 2017-05-17T06:49:13Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20170517-0008","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20170517-0008</a>    <td> Semi-stokes search mode four pol <td> 4096 <td> 1 <td>  0.00 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/05/17/1495003734.h5  </tr><tr> <td> ruby <td> 2017-05-17T07:05:29Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20170517-0009","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20170517-0009</a>    <td> AR1: beamformer Dev driftscan (halfband) <td> 4096 <td> 1 <td>  0.01 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/05/17/1495004693.h5  </tr><tr> <td> CAM <td> 2017-05-17T07:13:32Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20170517-0010","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20170517-0010</a>    <td> AR1: beamformer Dev driftscan (halfband) <td> 4096 <td> 1 <td>  0.01 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/05/17/1495005190.h5  </tr><tr> <td> ruby <td> 2017-05-17T07:30:40Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20170517-0011","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20170517-0011</a>    <td> COMM-173: Beamformer <td> 4096 <td> 1 <td>  0.01 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/05/17/1495006204.h5  </tr><tr> <td> ruby <td> 2017-05-17T07:39:21Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20170517-0012","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20170517-0012</a>    <td> COMM-173: Beamformer <td> 4096 <td> 1 <td>  0.00 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/05/17/1495006560.h5  </tr><tr> <td> lance <td> 2017-05-17T09:51:56Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20170517-0013","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20170517-0013</a>    <td> Spiral Holography test correction on <td> 4096 <td> 2 <td>  0.12 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/05/17/1495014714.h5  </tr><tr> <td> lance <td> 2017-05-17T10:27:55Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"201705 ...
