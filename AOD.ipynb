# %%
import pysolr
from IPython.core.display import display, HTML
archive = pysolr.Solr('http://192.168.1.50:8983/solr/kat_core')
search_str = []
search_str.append('CAS.ProductTypeName:MeerKATAR1TelescopeProduct')
search_str.append('StartTime:[2017-10-17T00:00:00Z TO 2017-10-25T00:00:00Z]')
search_string = ' AND '.join(search_str)
ar_res = archive.search( search_string ,rows=10000,**{'sort':'StartTime desc'})
h = '<table>'
h += "<tr><th>Owner<th>UT Start<th>Schedule block<th>Description<th>chan<th>ants<th>size<th>Archive</tr>"			
for r in ar_res.docs[::-1]:
    if 'ScheduleBlockIdCode' not in r:
        r['ScheduleBlockIdCode']=""
    if len(r['Description'])<1 :
        r['Description']='Beamformer?'
    link = 'http://kat-archive.kat.ac.za:8080/archive_search/#\
    {"ei":"%s","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}\
    '%(r['ScheduleBlockIdCode'])
    h += '<tr> <td> %s <td> %s <td> <a href=\'%s\'>%s</a>\
    <td> %s <td> %d <td> %d <td> %5.2f <td> %s  </tr>'\
    %(r['Observer'],r['StartTime'],link,r['ScheduleBlockIdCode'],r['Description'],\
      r['NumFreqChannels'],len(r['Antennas']),r['FileSize'][0]/1024.0**3\
      ,r['CAS.ReferenceDatastore'][0][5:])
h += "</table>"
display(HTML(h))
h += "<tr><th>Owner<th>UT Start<th>Schedule block<th>Description<th>\
chan<th>ants<th>size<th>Archive</tr>"
from BeautifulSoup import BeautifulSoup
soup = BeautifulSoup(h)
with open("output.html", "wb") as file:
    file.write("<html>\n")
    file.write(soup.prettify("utf-8"))
    file.write("\n<\html>\n")
# Out:
# <table><tr><th>Owner<th>UT Start<th>Schedule block<th>Description<th>chan<th>ants<th>size<th>Archive</tr><tr> <td> Lindsay <td> 2017-10-17T05:47:31Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20171017-0004","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20171017-0004</a>    <td> MKAIV-584 Generic AR1 delaycal <td> 4096 <td> 11 <td>  0.58 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/10/17/1508219246.h5  </tr><tr> <td> Lindsay <td> 2017-10-17T05:58:09Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20171017-0005","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20171017-0005</a>    <td> MKAIV-405 Generic AR1 Phaseup <td> 4096 <td> 11 <td>  0.50 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/10/17/1508219888.h5  </tr><tr> <td> Lindsay <td> 2017-10-17T06:10:24Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20171017-0010","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20171017-0010</a>    <td> MKAIV-405 Generic AR1 Phaseup <td> 4096 <td> 10 <td>  0.23 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/10/17/1508220622.h5  </tr><tr> <td> Maciej Serylak <td> 2017-10-17T08:20:40Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20171017-0011","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20171017-0011</a>    <td> SKARAB tests - Vela - ROACH2 test observation 1 sec dump <td> 4096 <td> 4 <td>  0.26 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/10/17/1508228437.h5  </tr><tr> <td> Maciej Serylak <td> 2017-10-17T08:59:46Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20171017-0017","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20171017-0017</a>    <td> SKARAB tests - Vela - SKARAB test observation 1 sec dump <td> 4096 <td> 4 <td>  0.21 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/10/17/1508230786.h5  </tr><tr> <td> Maciej Serylak <td> 2017-10-17T08:59:46Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20171017-0018","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20171017-0018</a>    <td> SKARAB tests - Vela - ROACH2 test observation 1 sec dump <td> 4096 <td> 4 <td>  0.22 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/10/17/1508230785.h5  </tr><tr> <td> Maciej Serylak <td> 2017-10-17T09:09:55Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20171017-0019","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20171017-0019</a>    <td> SKARAB tests - Vela - ROACH2 capture partition 8 <td> 4096 <td> 4 <td>  0.22 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/10/17/1508231394.h5  </tr><tr> <td> Maciej Serylak <td> 2017-10-17T09:16:29Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20171017-0022","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20171017-0022</a>    <td> SKARAB tests - Vela - ROACH2 capture partition 9 <td> 4096 <td> 4 <td>  0.21 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/10/17/1508231789.h5  </tr><tr> <td> Maciej Serylak <td> 2017-10-17T09:16:35Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20171017-0021","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20171017-0021</a>    <td> SKARAB tests - Vela - SKARAB capture partition 9 <td> 4096 <td> 4 <td>  0.21 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/10/17/1508231794.h5  </tr><tr> <td> Maciej Serylak <td> 2017-10-17T09:21:10Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20171017-0023","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20171017-0023</a>    <td> SKARAB tests - Vela - ROACH2 capture partition 10 <td> 4096 <td> 4 <td>  0.21 <td> /var/kat ...
