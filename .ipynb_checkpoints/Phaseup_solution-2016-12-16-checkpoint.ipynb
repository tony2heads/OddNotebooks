# %%
import katdal
import matplotlib.pylab as plt
# %matplotlib inline
import numpy as np
import pickle

# %%
filename='/var/kat/archive2/data/MeerKATAR1/telescope_products/2016/12/17/1481976006.h5'

# %%
h = katdal.open(filename)

# %%
print h
# Out:
# ===============================================================================
# Name: /var/kat/archive2/data/MeerKATAR1/telescope_products/2016/12/17/1481976006.h5 (version 3.0)
# ===============================================================================
# Observer: Simphiwe  Experiment ID: 20161215-0067
# Description: 'Generic Phaseup for all targets'
# Observed from 2016-12-17 14:00:08.761 SAST to 2016-12-17 14:05:20.629 SAST
# Dump rate / period: 0.25011 Hz / 3.998 s
# Subarrays: 1
#   ID  Antennas                            Inputs  Corrprods
#    0  m006,m007,m008,m010,m014,m015,m021,m022,m025,m031,m062,m063  24      312
# Spectral Windows: 1
#   ID Band Product  CentreFreq(MHz)  Bandwidth(MHz)  Channels  ChannelWidth(kHz)
#    0 L    bc856M4k   1284.000         856.000           4096       208.984
# -------------------------------------------------------------------------------
# Data selected according to the following criteria:
#   subarray=0
#   ants=['m008', 'm010', 'm007', 'm014', 'm006', 'm063', 'm015', 'm021', 'm022', 'm025', 'm031', 'm062']
#   spw=0
# -------------------------------------------------------------------------------
# Shape: (78 dumps, 4096 channels, 312 correlation products) => Size: 797.442 MB
# Antennas: m006,m007,*m008,m010,m014,m015,m021,m022,m025,m031,m062,m063  Inputs: 24  Autocorr: yes  Crosscorr: yes
# Channels: 4096 (index 0 - 4095,  856.000 MHz - 1711.791 MHz), each 208.984 kHz wide
# Targets: 1 selected out of 1 in catalogue
#   ID  Name     Type      RA(J2000)     DEC(J2000)  Tags  Dumps  ModelFlux(Jy)
#    0  Nothing  special             -            -           78
# Scans: 3 selected out of 3 total       Compscans: 3 selected out of 3 total
#   Date        Timerange(UTC)       ScanState  CompScanLabel  Dumps  Target
#   17-Dec-2016/12:00:10 - 12:00:18    0:stop     0:track          3    0:Nothing
#               12:00:22 - 12:04:26    1:stop     1:un_corrected     62    0:Nothing
#               12:04:30 - 12:05:18    2:stop     2:corrected     13    0:Nothing

# %%
# check what cal products we have
print 'Solutions:'
print '    Product             Number of solutions'
for k in h.file['TelescopeState'].keys():
    if 'cal_product' in k:
        print '   ', k, ' --- ' , len(h.file['TelescopeState'][k])
# Out:
# Solutions:
#     Product             Number of solutions
#     cal_product_B  ---  7
#     cal_product_K  ---  7
#     cal_product_G  ---  14

# %%
np.set_printoptions(precision=4,suppress=True)

# %%
# check antenna ordering
print h.file['TelescopeState']['cal_antlist']
a_list=[]
aa=h.file['TelescopeState']['cal_antlist']
for i,ai in enumerate(aa):
    a_list.append(pickle.loads(ai[1]))
a_array=np.array(a_list)
print a_list
print a_array[0]
labels=a_array[0]
# Out:
# <HDF5 dataset "cal_antlist": shape (1,), type "|V162">
# [['m006', 'm007', 'm008', 'm010', 'm014', 'm015', 'm021', 'm022', 'm025', 'm031', 'm062', 'm063']]
# ['m006' 'm007' 'm008' 'm010' 'm014' 'm015' 'm021' 'm022' 'm025' 'm031'
#  'm062' 'm063']

# %% [markdown]
# # Delays

# %%
k = h.file['TelescopeState']['cal_product_K']
k_list = []
for i, ki in enumerate(k):
    k_list.append(pickle.loads(ki[1]))
k_array = np.array(k_list)

k_0 = k_array[:,0,:]*1e9
k_1 = k_array[:,1,:]*1e9

# %%
k_array.shape #Times,Pols,Antennas
# Out:
# (7, 2, 12)

# %%
# print delays (if there are few delays)
print 'POL 0: \n', k_0[0], "\n",k_0[-1]
print 'POL 1: \n', k_1[0],"\n" ,k_1[-1]
# Out:
# POL 0:
# [ 129.841    70.1441  107.6273   19.5937   44.5095  127.2658  486.1175
#   519.7897   -0.      -65.7929  106.6967  104.1939]
# [ 0.0131 -0.0211 -0.0241  0.0078 -0.0217 -0.0565 -0.0321  0.0121 -0.
#   0.0614 -0.0219 -0.7904]
# POL 1:
# [ 131.7816   68.3944  106.6554  111.8852   44.6594  125.544   483.84
#   517.4891   -0.      -65.9241  101.4197   98.6889]
# [ 0.0052 -0.0137 -0.0309 -0.0061 -0.0228 -0.0747 -0.0458  0.0202 -0.
#   0.0234 -0.0115 -0.1677]

# %%
print labels
# Out:
# ['m006' 'm007' 'm008' 'm010' 'm014' 'm015' 'm021' 'm022' 'm025' 'm031'
#  'm062' 'm063']

# %%
colors=['r','g','b','c','m','k','darkorange','darkgreen','maroon','darkviolet','olive','saddlebrown','darkorchid']

# %%
#plot delays (if there are many delays)
fig, ax = plt.subplots(2,1,figsize=(20, 10))
for i in range(len(labels)):
    ax[0].plot(k_0[:,i],'-x',markersize=8,label=labels[i],color=colors[i]);
#ax[0].set_ylim([-0.2,0.2]);
    ax[1].plot(k_1[:,i],'-x',markersize=8,label=labels[i],color=colors[i]);
#ax[1].set_ylim([-0.2,0.2]);
plt.legend(loc='upper center')

# %% [markdown]
# # Gains

# %%
g = h.file['TelescopeState']['cal_product_G']
g_list = []
for i, gi in enumerate(g):
    g_list.append(pickle.loads(gi[1]))
g_array = np.array(g_list)
print g_array.shape

g_0 = g_array[:,0,:]
g_1 = g_array[:,1,:]
# Out:
# (14, 2, 12)

# %%
#First
print np.abs(g_0)[0]
print np.abs(g_1)[0]
# Out:
# [ 1.0005  0.9996  0.9993  0.9998  1.0017  1.0022  0.9994  0.9998  1.0013
#   1.0007  1.0005  0.9999]
# [ 1.0008  1.0001  1.0001  1.0008  1.0002  1.0005  1.0001  1.0005  1.0004
#   1.0013  0.9999  1.0016]

# %%
#Last
print np.abs(g_0)[-1]
print np.abs(g_1)[-1]
# Out:
# [ 0.9988  0.9936  1.0008  1.0013  1.0006  0.9956  0.9985  0.9999  1.0026
#   1.002   0.9974  0.9942]
# [ 1.0026  0.9976  0.9995  1.0005  0.9946  0.998   1.0042  1.0033  1.0024
#   0.9996  0.9958  1.0046]

# %%
#Ratio
print np.abs(g_0)[-1]/np.abs(g_0)[0]
print np.abs(g_1)[-1]/np.abs(g_1)[0]
# Out:
# [ 0.9983  0.994   1.0015  1.0015  0.999   0.9934  0.9991  1.      1.0013
#   1.0013  0.9969  0.9943]
# [ 1.0019  0.9975  0.9994  0.9997  0.9944  0.9975  1.0041  1.0028  1.002
#   0.9983  0.9959  1.003 ]

# %%
#Before
print np.rad2deg(np.angle(g_0)[0])
print np.rad2deg(np.angle(g_1)[0])
# Out:
# [  65.7901   80.1277  140.8249   80.3179  143.1093   79.9864  127.4786
#    76.8676    0.       -7.5898  135.1778  -36.5728]
# [  39.0339   98.7905  104.0512   94.4213   76.4657   60.607   117.1581
#    60.8776    0.       46.8733   67.7817   84.5578]

# %%
#After
print np.rad2deg(np.angle(g_0)[-1])
print np.rad2deg(np.angle(g_1)[-1])
# Out:
# [  -1.6691   13.4643    9.1952   -1.783    14.5433   17.8655   18.2752
#     3.621    -0.      -21.7476   14.5382 -112.41  ]
# [  2.0136  10.1039  12.2729   4.8682  14.7775  27.0048  24.8358   0.3559
#    0.      -3.637    9.5765 -70.8425]

# %%
#Differences
print np.rad2deg(np.angle(g_0)[-1])-np.rad2deg(np.angle(g_0)[0])
print np.rad2deg(np.angle(g_1)[-1])-np.rad2deg(np.angle(g_1)[0])
# Out:
# [ -67.4592  -66.6634 -131.6297  -82.1009 -128.566   -62.1209 -109.2034
#   -73.2466   -0.      -14.1579 -120.6397  -75.8372]
# [ -37.0202  -88.6866  -91.7783  -89.553   -61.6882  -33.6022  -92.3223
#   -60.5217   -0.      -50.5103  -58.2052 -155.4004]

# %%
#plot gains - amplitude
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].plot(np.abs(g_0),'-x');
#ax[0].set_ylim([0,5.0]);
ax[1].plot(np.abs(g_1),'-x');
#ax[1].set_ylim([0,5.0]);
plt.xlabel('Dump')
plt.ylabel('Gain')
plt.legend()
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/axes.py:4747: UserWarning: No labeled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labeled objects found. "

# %%
#plot gains - phase
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].plot(np.rad2deg(np.angle(g_0)),'-x');
ax[0].set_ylim([-180,180]);
ax[1].plot(np.rad2deg(np.angle(g_1)),'-x');
ax[1].set_ylim([-180,180]);

# %% [markdown]
# # Bandpasses

# %%
b = h.file['TelescopeState']['cal_product_B']
b_list = []
for i, bi in enumerate(b):
    b_list.append(pickle.loads(bi[-1]))
b_array = np.array(b_list)
print b_array.shape
# bandpass shape is ntimes x channels x pol x antenna 
# where ntimes is the number of bandpasses

# just look at LAST bandpass for now
b_0_0 = b_array[-1,:,0,:]
b_1_0 = b_array[-1,:,1,:]
# Out:
# (7, 4096, 2, 12)

# %%
#plot bandpass - amplitude
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].plot(np.abs(b_0_0),'.');
ax[0].set_ylim([0,10]);
ax[0].set_xlabel('gains')
ax[1].plot(np.abs(b_1_0),'.');
ax[1].set_ylim([0,10]);
ax[1].set_xlabel('gains')
#plt.xlabel('channel')
#plt.ylabel('gains')

# %%
""""
for i in range(len(labels)):
    ax[0].plot(k_0[:,i],'-x',markersize=8,label=labels[i],color=colors[i]);
#ax[0].set_ylim([-0.2,0.2]);
    ax[1].plot(k_1[:,i],'-x',markersize=8,label=labels[i],color=colors[i]);
#ax[1].set_ylim([-0.2,0.2]);
plt.legend(loc='upper center')
"""

# %%
#plot bandpass - phase
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].set_ylim([-70,70]);
ax[1].set_ylim([-70,70]);
ax[0].plot(np.rad2deg(np.angle(b_0_0)),'.');
ax[1].plot(np.rad2deg(np.angle(b_1_0)),'.');
plt.legend()

# %%
len(labels)
# Out:
# 12

# %%
b_array.shape
# Time,channels,pols,antennas
# Out:
# (7, 4096, 2, 12)

# %%
#One bandpass at the END
antn=11
b_0_1 = b_array[-1,:,0,antn]
b_1_1 = b_array[-1,:,1,antn]
print b_1_1.shape
print a_array[:,antn]
# Out:
# (4096,)
# ['m063']

# %%
#plot bandpass - amplitude
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].plot(np.abs(b_0_1),'.');
ax[0].set_ylim([0,10]);
ax[0].set_xlabel('gains')
ax[1].plot(np.abs(b_1_1),'.');
ax[1].set_ylim([0,10]);
ax[1].set_xlabel('gains')
#plt.xlabel('channel')
#plt.ylabel('gains')

# %%
#plot bandpass - phase
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].plot(np.rad2deg(np.angle(b_0_1)),'.');
ax[0].set_ylim([-70,70]);
ax[1].plot(np.rad2deg(np.angle(b_1_1)),'.');
ax[1].set_ylim([-70,70]);

# %%
str(h.catalogue.targets[0])
# Out:
# 'Nothing, tags=special, no flux info'

# %% [markdown]
# # M063 crazy solutions
