# %%
# %matplotlib inline
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import katarchive

import datetime

import logging
logging.root.setLevel(logging.ERROR)

# %%
def findproj(text):
    found='Unknown'        # default
    chx=text.find('prop')
    if chx >0  :
        pr2=text[chx+11:chx+38].split()
        code=pr2[0]
        found=code.replace("=","")
    else:
        if text.find('maser') >0:
            found="Maser monitoring"
            #print text
    return found

# %%
today=datetime.datetime.today()
ago=datetime.timedelta(-7)
lastweek=today+ago
print today,lastweek
begin=lastweek.strftime(format="%d/%m/%Y")
end=today.strftime(format="%d/%m/%Y")
# Out:
# 2016-08-01 14:09:52.321493 2016-07-25 14:09:52.321493

# %%
print katarchive.search_archive(startdate=begin,enddate=end)
# Out:
# Searched using: CAS.ProductTypeName:(KatFile) AND CAS.ProductTransferStatus:RECEIVED AND StartTime:[2016-07-24T22:00:00Z TO 2016-08-01T21:59:59Z]
# Returning 75 results
# [['1', '2016-08-01 13:32:08 SAST', 'operator', [90727556]], ['1', '2016-08-01 12:45:40 SAST', 'Lindsay', [1530722528]], ['1', '2016-08-01 12:41:49 SAST', 'operator', [91503604]], ['1', '2016-08-01 09:35:31 SAST', 'Nadeem', [612421560]], ['1', '2016-08-01 09:32:52 SAST', 'operator', [91462126]], ['1', '2016-08-01 00:56:17 SAST', 'Nadeem', [2373230888]], ['1', '2016-08-01 00:52:15 SAST', 'operator', [119632047]], ['1', '2016-07-31 22:45:17 SAST', 'Lindsay', [5852949992]], ['1', '2016-07-31 22:41:11 SAST', 'operator', [132861000]], ['1', '2016-07-31 15:30:22 SAST', 'Nadeem', [1291641508]], ['1', '2016-07-31 15:26:14 SAST', 'operator', [95424567]], ['1', '2016-07-31 09:22:02 SAST', 'Tony', [1776560805]], ['1', '2016-07-31 09:16:19 SAST', 'operator', [236718122]], ['1', '2016-07-31 03:00:19 SAST', 'Nadeem', [1782814499]], ['1', '2016-07-31 02:56:13 SAST', 'operator', [90705402]], ['1', '2016-07-30 21:57:20 SAST', 'Nadeem', [1220571654]], ['1', '2016-07-30 21:53:13 SAST', 'operator', [91467751]], ['1', '2016-07-30 14:45:19 SAST', 'Tony', [1515608459]], ['1', '2016-07-30 14:41:14 SAST', 'operator', [94634694]], ['1', '2016-07-30 09:20:23 SAST', 'Tony', [1476533302]], ['1', '2016-07-30 09:16:18 SAST', 'operator', [92265279]], ['1', '2016-07-30 03:08:03 SAST', 'Nadeem', [1772182483]], ['1', '2016-07-30 03:05:11 SAST', 'operator', [102429960]], ['1', '2016-07-30 02:00:16 SAST', 'Lindsay', [3021388869]], ['1', '2016-07-30 01:56:18 SAST', 'operator', [90725386]], ['1', '2016-07-29 21:45:19 SAST', 'Nadeem', [1182174726]], ['1', '2016-07-29 21:41:11 SAST', 'operator', [91475154]], ['1', '2016-07-29 12:15:22 SAST', 'Nadeem', [1229650072]], ['1', '2016-07-29 12:11:13 SAST', 'operator', [91508419]], ['1', '2016-07-29 03:07:20 SAST', 'Nadeem', [1792625331]], ['1', '2016-07-29 03:03:18 SAST', 'operator', [90712602]], ['1', '2016-07-29 01:00:21 SAST', 'Tony', [591178996]], ['1', '2016-07-29 00:56:15 SAST', 'operator', [119597367]], ['1', '2016-07-28 20:40:21 SAST', 'Nadeem', [1187094272]], ['1', '2016-07-28 20:36:14 SAST', 'operator', [130564219]], ['1', '2016-07-28 15:32:13 SAST', 'Nadeem', [1478955085]], ['1', '2016-07-28 15:25:14 SAST', 'operator', [91511698]], ['1', '2016-07-28 11:15:04 SAST', 'Sean', [4766306559]], ['1', '2016-07-28 11:10:40 SAST', 'operator', [387833177]], ['1', '2016-07-28 07:00:21 SAST', 'Tony', [1192861602]], ['1', '2016-07-28 06:56:16 SAST', 'operator', [121143579]], ['1', '2016-07-28 02:50:20 SAST', 'Nadeem', [1182587407]], ['1', '2016-07-28 02:46:15 SAST', 'operator', [85219279]], ['1', '2016-07-27 19:25:15 SAST', 'Nadeem', [162728672]], ['1', '2016-07-27 19:21:12 SAST', 'operator', [91481636]], ['1', '2016-07-27 17:42:14 SAST', 'sarah', [314033456]], ['1', '2016-07-27 17:04:47 SAST', 'Lindsay', [1561172439]], ['1', '2016-07-27 17:02:36 SAST', 'operator', [39184473]], ['1', '2016-07-27 16:57:40 SAST', 'operator', [90690479]], ['1', '2016-07-27 12:51:32 SAST', 'Nadeem', [860777105]], ['1', '2016-07-27 12:43:52 SAST', 'operator', [64715093]], ['1', '2016-07-27 09:03:11 SAST', 'Nadeem', [673505161]], ['1', '2016-07-27 08:55:43 SAST', 'operator', [61328214]], ['1', '2016-07-27 08:39:25 SAST', 'operator', [63595494]], ['1', '2016-07-27 01:16:17 SAST', 'Nadeem', [1313191016]], ['1', '2016-07-27 01:12:15 SAST', 'operator', [61381839]], ['1', '2016-07-26 21:00:22 SAST', 'Lindsay', [895257732]], ['1', '2016-07-26 20:56:15 SAST', 'operator', [93255561]], ['1', '2016-07-26 15:53:11 SAST', 'Nadeem', [951256799]], ['1', '2016-07-26 15:50:40 SAST', 'operator', [61384498]], ['1', '2016-07-26 11:40:07 SAST', 'Nadeem', [888780138]], ['1', '2016-07-26 11:37:39 SAST', 'operator', [62475664]], ['1', '2016-07-26 09:40:22 SAST', 'Sean', [3345170145]], ['1', '2016-07-26 09:37:12 SAST', 'operator', [61908410]], ['1', '2016-07-25 20:30:19 SAST', 'Nadeem', [2623361075]], ['1', '2016-07-25 20:26:16 SAST', 'operator', [61913200]], ['1', '2016-07-25 15:10:15 SAST', 'Nadeem', [1078427526]], ['1', '2016-07-25 15:07:53 SAST', 'operator', [44549477]] ...

# %%
f = katarchive.search_archive(startdate=begin)
start = datetime.datetime.strptime(f[-1].__str__().split('\'')[3],'%Y-%m-%d %H:%M:%S %Z')
end = datetime.datetime.strptime(f[0].__str__().split('\'')[3],'%Y-%m-%d %H:%M:%S %Z')
# Out:
# Searched using: CAS.ProductTypeName:(KatFile) AND CAS.ProductTransferStatus:RECEIVED AND StartTime:[2016-07-24T22:00:00Z TO 2016-08-01T21:59:59Z]
# Returning 75 results

# %%
#print 'First file in run: ' , start.isoformat()
#print 'Last file in run: ' , end.isoformat()

# %%
for fi in f:
    txts=fi.metadata.InstructionSet
    p=findproj(txts)
    print fi.metadata.ExperimentID, p, fi.metadata.Duration, fi.metadata.Description, len(fi.metadata.Antennas)
# Out:
# 2 COMM_Atten 115.01 Auto atten 6
# 2 COMM_Point_LM 1959.16 Pointing Observation 6
# 2 COMM_Atten 116.01 Auto atten 6
# 2 COMM_Image_NO 7480.1 Imaging Calibration 6
# 2 COMM_Atten 116.01 Auto atten 6
# 2 20150210SS-01 29010.4 Field11Feb_Low 6
# 2 COMM_Atten 152.01 Auto atten 6
# 2 COMM_Point_LM 7494.59 Pointing Observation 6
# 2 COMM_Atten 169.01 Auto atten 6
# 2 20141125NO-01 15790.22 ATEL6733 6
# 2 COMM_Atten 121.01 Auto atten 6
# 2 COMM_Bandpass_TF 21720.3 Bandpass Calibrators 6
# 2 COMM_Atten 302.02 Auto atten 6
# 2 20150217RT-01 21790.3 NGC_1808 - 1350MHz 6
# 2 COMM_Atten 115.01 Auto atten 6
# 2 20141219SS-01 14920.21 W2332 Low 6
# 2 COMM_Atten 116.01 Auto atten 6
# 2 20150619TF-01 18530.26 3C279 6
# 2 COMM_Atten 120.01 Auto atten 6
# 2 COMM_Bandpass_TF 18050.25 Bandpass Calibrators 6
# 2 COMM_Atten 117.01 Auto atten 6
# 2 20150217RT-01 21660.3 NGC_1808 - 1600MHz 6
# 2 COMM_Atten 130.01 Auto atten 6
# 2 COMM_Point_LM 3868.31 Pointing Observation 6
# 2 COMM_Atten 115.01 Auto atten 6
# 2 20130822NO-01 14450.2 W2332_5056 6
# 2 COMM_Atten 116.01 Auto atten 6
# 2 COMM_Image_NO 15030.21 Imaging Calibration 6
# 2 COMM_Atten 116.01 Auto atten 6
# 2 20150217RT-01 21910.3 NGC_1808 - 1850MHz 6
# 2 COMM_Atten 115.01 Auto atten 6
# 2 COMM_Bandpass_TF 7220.1 Bandpass Calibrators 6
# 2 COMM_Atten 152.01 Auto atten 6
# 2 20141002MB-01 14510.2 SS433 6
# 2 COMM_Atten 166.01 Auto atten 6
# 2 20131211NO-01 18080.25 PKS1510-089 6
# 2 COMM_Atten 116.01 Auto atten 6
# 2 20160516YL-01 14524.96 Pointing1 6
# 2 COMM_Atten 119.79 Auto atten 6
# 2 COMM_Bandpass_TF 14580.2 Bandpass Calibrators 6
# 2 COMM_Atten 154.01 Auto atten 6
# 2 20150210SS-01 14450.2 Field11Feb_High 6
# 2 COMM_Atten 108.01 Auto atten 6
# 2 20140729RT-01 1015.01 N4_Observe_2_1822Mhz 6
# 2 COMM_Atten 116.01 Auto atten 6
# 2 Unknown 401.03 Beamformer observation 6
# 2 COMM_Point_LM 1998.16 Pointing Observation 6
# 2 COMM_Atten 49.0 Auto atten 6
# 2 COMM_Atten 115.01 Auto atten 6
# 2 COMM_Image_NO 14420.2 Imaging Calibration 5
# 2 COMM_Atten 114.01 Auto atten 5
# 2 COMM_Image_NO 11280.16 Imaging Calibration 5
# 2 COMM_Atten 108.01 Auto atten 5
# 2 COMM_Atten 112.01 Auto atten 5
# 2 20150210SS-01 22000.3 Field11Feb_Low 5
# 2 COMM_Atten 108.01 Auto atten 5
# 2 20141111IM-01 15000.21 LS5039_2 5
# 2 COMM_Atten 165.01 Auto atten 5
# 2 20141125NO-01 15940.22 ATEL6733 5
# 2 COMM_Atten 108.01 Auto atten 5
# 2 COMM_Image_NO 14890.21 Imaging Calibration 5
# 2 COMM_Atten 110.01 Auto atten 5
# 2 COMM_RFI_SP 5976.47 Basic RFI Scan: RFI SCAN 5
# 2 COMM_Atten 109.01 Auto atten 5
# 2 COMM_Image_NO 43980.61 Imaging Calibration 5
# 2 COMM_Atten 109.01 Auto atten 5
# 2 COMM_Image_NO 18070.25 Imaging Calibration 5
# 2 COMM_Atten 78.01 Auto atten 5
# 2 Unknown 595.05 Beamformer observation 5
# 2 Unknown 567.04 Beamformer observation 5
# 2 COMM_Image_NO 6530.09 Imaging Calibration 5
# 2 COMM_Atten 42.0 Auto atten 5
# 2 COMM_Atten 108.01 Auto atten 5
# 2 COMM_RFI_SP 5976.47 Basic RFI Scan: RFI SCAN 5
# 2 COMM_Atten 108.01 Auto atten 5

# %% [markdown]
# Only select observations that are longer than 1 hrs then extract the project id from the script parameters. If there is no project id then allocated No_project_id

# %%
sbd = [] #Experiment ID
pid = [] #project ID
fnd = [] #Filename
dud = [] #Duration
antsd = [] #number of antennas
scrd = [] #script  -NOT USED NOW

for fi in f:
    if fi.metadata.Duration < 3600: #only pick hour long or greater observations for analysis
        continue
    # now try extract the project-id from the instruction-set string
    """
    script = fi.metadata.InstructionSet
    scrd.append(script)
    spl = script.split()
    """
    txts=fi.metadata.InstructionSet
    p=findproj(txts)
    if p == "Unknown":
        p="Maser Monitoring"
    sbd.append(fi.metadata.ExperimentID)
    pid.append(p)
    fnd.append(fi.metadata.Filename)
    dud.append(fi.metadata.Duration)
    antsd.append(len(fi.metadata.Antennas))

# %%
pi = np.array(pid)
sb = np.array(sbd)
du = np.array(dud)
ants = np.array(antsd)

p_cent = (sum(du)/((end.toordinal()-start.toordinal())*24*3600))*100

print 'Percentage system usage: ', np.floor(p_cent),'%'
# Out:
# Percentage system usage:  80.0 %

# %%
a_id = []
a_time = []
for p in set(pi):
    ind = pi == p
    print p,round(sum(du[ind])/3600,2)
    a_id.append(p)
    a_time.append(round(sum(du[ind])/3600,2))
# Out:
# 20141111IM-01 4.17
# 20150217RT-01 18.16
# 20130822NO-01 4.01
# 20141125NO-01 8.81
# 20160516YL-01 4.03
# 20141002MB-01 4.03
# 20131211NO-01 5.02
# 20150619TF-01 5.15
# 20141219SS-01 4.14
# COMM_RFI_SP 3.32
# 20150210SS-01 18.18
# COMM_Image_NO 36.58
# COMM_Point_LM 3.16
# COMM_Bandpass_TF 17.1

# %%
ind = np.argsort(a_id)
for i in ind:
    print ("%-16s %5.1f %d") %(a_id[i],a_time[i],ants[i])
# Out:
# 20130822NO-01      4.0 6
# 20131211NO-01      5.0 6
# 20141002MB-01      4.0 6
# 20141111IM-01      4.2 6
# 20141125NO-01      8.8 6
# 20141219SS-01      4.1 6
# 20150210SS-01     18.2 6
# 20150217RT-01     18.2 6
# 20150619TF-01      5.2 6
# 20160516YL-01      4.0 6
# COMM_Bandpass_TF  17.1 6
# COMM_Image_NO     36.6 6
# COMM_Point_LM      3.2 6
# COMM_RFI_SP        3.3 6

# %% [markdown]
# Find the unique project ids and determine the total observation duration.

# %% [markdown]
# Sort ID and time for display

# %% [markdown]
# Plot as pie-chart

# %%
cmap = plt.cm.prism
colors = cmap(np.linspace(0., 1., 7))

# %%
plt.figure(figsize=(15,15))
plt.pie(a_time,labels=a_id,colors=colors,autopct='%1.1f%%');

# %%
plt.show()

# %%
fi.metadata.InstructionSet
# Out:
# u'/home/kat/scripts/observation/auto_attenuate.py -t radec,0,-90 --mode=bc16n400M1k -f 1822 --proposal-id COMM_Atten program-block-id=00ob3000000 --sb-id-code=20160725-0001 --description= AutoAttenuation for 00ob3000000  --observer=operator --config-label=Auto2016-06-29T14h25m13.0Z'
