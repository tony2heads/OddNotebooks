# %%
# %matplotlib notebook
from Tkinter import *
# %gui inline

# %%
from katsdpscripts.reduction.analyse_point_source_scans import analyse_point_source_scans

# %%
class my_opts:
    def __init__(self, **kwds):
        self.__dict__.update(kwds)

# %% [markdown]
# # Antennas used
# ## m036, with 1 second dump time

# %%
h5name='/var/kat/archive3/data/MeerKATAR1/telescope_products/2017/11/19/1511081630.h5'
cleanchans="2703,2914"

# %%
baseline='m036'
opts = my_opts(outfilebase='1511081630_m036', keepfilename=None, baseline=baseline, mc_iterations=1, freq_centre=1284.0, \
time_offset=0.0, pointing_model=None, freq_chans=cleanchans, old_loader=None, nd_models=None, \
ku_band=False, channel_mask=None,keep_all=True,remove_spikes=False,batch=False,plot_spectrum=True)

analyse_point_source_scans(h5name,opts)
print "Done",baseline
# Out:
# INFO: Loading dataset '/var/kat/archive3/data/MeerKATAR1/telescope_products/2017/11/19/1511081630.h5'
# INFO: Loading baseline 'm036,m036'
# DEBUG: Added 'Hyd A' [radec] (and 4 aliases)
# DEBUG: Added '3C 273' [radec] (and 2 aliases)
# DEBUG: Added 'Vir A' [radec] (and 5 aliases)
# DEBUG: Added 'PKS 1610-60' [radec] (and 2 aliases)
# DEBUG: Added 'Her A' [radec] (and 4 aliases)
# DEBUG: Added '3C 353' [radec] (and 2 aliases)
# DEBUG: Added 'PKS 2153-69' [radec] (and 2 aliases)
# DEBUG: Added 'PKS 0410-75' [radec] (and 1 aliases)
# DEBUG: Added '3C 279' [radec] (and 2 aliases)
# DEBUG: Added '3C 286' [radec] (and 1 aliases)
# DEBUG: Added '3C 358' [radec] (and 2 aliases)
# DEBUG: Added 'PKS 1814-63' [radec] (and 1 aliases)
# DEBUG: Added 'PKS 1934-63' [radec] (and 1 aliases)
# DEBUG: Added 'PKS 2104-25' [radec] (and 2 aliases)
# DEBUG: Added '3C 409' [radec] (and 2 aliases)
# DEBUG: Added 'Cyg A' [radec] (and 3 aliases)
# DEBUG: Added '3C 433' [radec] (and 1 aliases)
# ...
