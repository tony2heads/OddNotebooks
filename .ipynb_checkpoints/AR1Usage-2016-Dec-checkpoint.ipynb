# %%
# %matplotlib inline
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import katarchive

import datetime

import logging
logging.root.setLevel(logging.ERROR)

# %%
katarchive.product_filter.only_ar1()

begin="01/12/2016"
end="31/12/2016"  # Last run on 14th Nov

# %%
def channels(details):
    ch32k="32768"
    mode="4k" # default
    if ch32k in details:
        mode="32k"
    return mode

# %%
print katarchive.search_archive(startdate=begin,enddate=end)
# Out:
# Searched using: CAS.ProductTypeName:(MeerKATAR1TelescopeProduct) AND CAS.ProductTransferStatus:RECEIVED AND StartTime:[2016-11-30T22:00:00Z TO 2016-12-31T21:59:59Z]
# Returning 429 results
# [['1483193704.h5', '2016-12-31 16:15:06 SAST', 'AR1', 79390338508], ['1483192805.h5', '2016-12-31 16:00:07 SAST', 'AR1', 1223970389], ['1483188318.h5', '2016-12-31 14:46:51 SAST', 'sarah', 1932150437], ['1483187407.h5', '2016-12-31 14:30:08 SAST', 'sarah', 1405240730], ['1483186514.h5', '2016-12-31 14:15:44 SAST', 'sarah', 1922752280], ['1483185618.h5', '2016-12-31 14:01:04 SAST', 'sarah', 1918024369], ['1483184706.h5', '2016-12-31 13:45:08 SAST', 'sarah', 1565179259], ['1483183815.h5', '2016-12-31 13:32:19 SAST', 'sarah', 1909085678], ['1483182918.h5', '2016-12-31 13:16:09 SAST', 'sarah', 1898128128], ['1483182007.h5', '2016-12-31 13:00:07 SAST', 'sarah', 1317171166], ['1483176604.h5', '2016-12-31 11:30:05 SAST', 'AR1', 3794881726], ['1483174806.h5', '2016-12-31 11:00:08 SAST', 'AR1', 4027114766], ['1483150036.h5', '2016-12-31 04:09:34 SAST', 'sarah', 1837011455], ['1483148714.h5', '2016-12-31 03:46:13 SAST', 'sarah', 3459333405], ['1483147805.h5', '2016-12-31 03:30:06 SAST', 'sarah', 1280453587], ['1483146915.h5', '2016-12-31 03:16:05 SAST', 'AR1', 1819865575], ['1483146014.h5', '2016-12-31 03:01:12 SAST', 'sarah', 1815199751], ['1483145106.h5', '2016-12-31 02:45:07 SAST', 'sarah', 1288590809], ['1483144216.h5', '2016-12-31 02:31:10 SAST', 'sarah', 1806266800], ['1483143321.h5', '2016-12-31 02:16:10 SAST', 'sarah', 1801564617], ['1483142408.h5', '2016-12-31 02:00:09 SAST', 'sarah', 1340089682], ['1483105631.h5', '2016-12-30 15:47:13 SAST', 'AR1', 79381480732], ['1483104972.h5', '2016-12-30 15:36:13 SAST', 'Moloko', 783692394], ['1483104488.h5', '2016-12-30 15:28:09 SAST', 'Moloko', 755699894], ['1483103709.h5', '2016-12-30 15:17:21 SAST', 'Moloko', 457273047], ['1483100249.h5', '2016-12-30 14:17:31 SAST', 'Lindsay', 8390064721], ['1483099342.h5', '2016-12-30 14:02:23 SAST', 'Moloko', 927736397], ['1483097843.h5', '2016-12-30 13:38:08 SAST', 'Moloko', 4193345147], ['1483080306.h5', '2016-12-30 08:45:17 SAST', 'AR1', 262284613872], ['1483064108.h5', '2016-12-30 04:15:20 SAST', 'AR1', 263441204241], ['1483063207.h5', '2016-12-30 04:00:15 SAST', 'AR1', 8051683225], ['1483045207.h5', '2016-12-29 23:00:19 SAST', 'AR1', 262329772103], ['1483029005.h5', '2016-12-29 18:30:16 SAST', 'AR1', 272637523310], ['1483028409.h5', '2016-12-29 18:20:20 SAST', 'AR1', 8077404322], ['1483014070.h5', '2016-12-29 14:21:21 SAST', 'AR1', 229381243638], ['1483013569.h5', '2016-12-29 14:12:57 SAST', 'AR1', 7012744302], ['1483012987.h5', '2016-12-29 14:03:18 SAST', 'Moloko', 6920079572], ['1483012433.h5', '2016-12-29 13:55:00 SAST', 'Moloko', 5360002573], ['1482972008.h5', '2016-12-29 02:40:09 SAST', 'Tom', 85319691870], ['1482971407.h5', '2016-12-29 02:30:09 SAST', 'AR1', 1148001631], ['1482968714.h5', '2016-12-29 01:46:35 SAST', 'AR1', 1805289798], ['1482967816.h5', '2016-12-29 01:31:48 SAST', 'sarah', 1800970873], ['1482967098.h5', '2016-12-29 01:18:19 SAST', 'sarah', 1397633831], ['1482966383.h5', '2016-12-29 01:07:21 SAST', 'sarah', 1785300716], ['1482965682.h5', '2016-12-29 00:55:17 SAST', 'sarah', 1781160364], ['1482965213.h5', '2016-12-29 00:46:55 SAST', 'sarah', 1329164717], ['1482963318.h5', '2016-12-29 00:15:55 SAST', 'sarah', 4483312303], ['1482962408.h5', '2016-12-29 00:00:10 SAST', 'sarah', 1283440176], ['1482927011.h5', '2016-12-28 14:10:13 SAST', 'AR1', 65582748279], ['1482926692.h5', '2016-12-28 14:04:53 SAST', 'Fannie', 651220494], ['1482925295.h5', '2016-12-28 13:41:36 SAST', 'Fannie', 2983627890], ['1482918749.h5', '2016-12-28 11:52:29 SAST', 'Moloko', 554943130], ['1482914986.h5', '2016-12-28 10:49:47 SAST', 'AR1', 556830733], ['1482736677.h5', '2016-12-26 09:18:02 SAST', 'AR1', 138568252064], ['1482722106.h5', '2016-12-26 05:15:11 SAST', 'AR1', 134687413998], ['1482701892.h5', '2016-12-25 23:38:18 SAST', 'AR1', 3488201837], ['1482687420.h5', '2016-12-25 19:37:07 SAST', 'AR1', 133667006833], ['1482672634.h5', '2016-12-25 15:30:39 SAST', 'AR1', 136546346474], ['1482672276.h5', '2016-12-25 15:24:36 SAST', 'AR1', 2999894830], ['14826285 ...

# %%
f = katarchive.search_archive(startdate=begin,enddate=end)
start = datetime.datetime.strptime(f[-1].__str__().split('\'')[3],'%Y-%m-%d %H:%M:%S %Z')
end = datetime.datetime.strptime(f[0].__str__().split('\'')[3],'%Y-%m-%d %H:%M:%S %Z')
# Out:
# Searched using: CAS.ProductTypeName:(MeerKATAR1TelescopeProduct) AND CAS.ProductTransferStatus:RECEIVED AND StartTime:[2016-11-30T22:00:00Z TO 2016-12-31T21:59:59Z]
# Returning 429 results

# %%
#print 'First file in run: ' , start.isoformat()
#print 'Last file in run: ' , end.isoformat()

# %%
f.sort(key=lambda k: k.metadata.StartTime)

# %%
for fi in f:
    txts=fi.metadata.InstructionSet
    #p=findproj(txts)
    print fi.metadata.ExperimentID, np.round(fi.metadata.Duration/3600.,2),"hrs",\
    len(fi.metadata.Antennas),channels(fi.metadata.Details),fi.metadata.Description
    
    #print("%13s %6.2fhrs %2dants %3s %s") %(fi.metadata.ExperimentID, np.round(fi.metadata.Duration/3600.,2),\
    #len(fi.metadata.Antennas),channels(fi.metadata.Details),fi.metadata.Description)
# Out:
# 20161201-0001 0.14 hrs 10 4k Generic Phaseup for all targets
# 20161201-0002 0.38 hrs 8 4k AR1: Basic functionality test
# 20161201-0003 0.36 hrs 8 4k AR1: Basic functionality test
# 20161201-0004 0.06 hrs 8 32k AR1: Basic functionality test
# 20161201-0005 0.38 hrs 8 32k AR1: Basic functionality test
# 20161201-0006 0.08 hrs 8 4k Generic Phaseup for all targets
# 20161201-0010 11.88 hrs 8 4k AR1: Calibrator Switching Imaging observation
# 20161201-0020 0.1 hrs 9 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161201-0029 0.12 hrs 7 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161201-0028 0.17 hrs 7 4k AR1: MKAIV-231 CBF J0437-4715
# 20161201-0022 0.17 hrs 7 4k AR1: MKAIV-224 CBF J0738-4042
# 20161201-0023 0.11 hrs 7 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161201-0024 0.17 hrs 7 4k AR1: MKAIV-224 CBF J0742-2822
# 20161201-0025 0.17 hrs 7 4k AR1: MKAIV-224 CBF J0835-4510
# 20161201-0026 0.11 hrs 7 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161201-0027 0.5 hrs 7 4k AR1: MKAIV-231 CBF J0437-4715
# 20161201-0015 0.08 hrs 7 4k Generic Phaseup for all targets
# 20161201-0016 3.02 hrs 7 4k Image extended HI source (M83)
# 20161201-0017 3.01 hrs 7 4k Image extended HI source (M83)
# 20161201-0018 0.37 hrs 7 4k Image extended HI source (M83)
# 20161202-0001 0.13 hrs 10 32k Generic Phaseup for all targets
# 20161202-0002 3.06 hrs 10 32k Image extended HI source (M83)
# 20161202-0005 0.61 hrs 10 32k AR1: Basic functionality test
# 20161202-0006 0.08 hrs 9 4k Generic Phaseup for all targets
# 20161202-0007 0.08 hrs 9 4k Generic Phaseup for all targets
# 20161202-0008 10.02 hrs 9 4k Mosaicing
# 20161202-0009 6.03 hrs 9 4k Interferometric Pointing Calibration
# 20161203-0001 0.38 hrs 11 4k AR1: Basic functionality test
# 20161203-0002 0.04 hrs 11 4k Generic Phaseup for all targets
# 20161203-0003 0.08 hrs 11 4k Generic Phaseup for all targets
# 20161203-0004 0.11 hrs 11 4k AR1: MKAIV-214 Phase-up 1934
# 20161203-0005 0.17 hrs 11 4k AR1: MKAIV-388 CBF J1327-6222
# 20161203-0007 0.02 hrs 11 4k AR1: MKAIV-388 CBF J1327-6222
# 20161203-0008 0.02 hrs 11 4k AR1: MKAIV-388 CBF J1327-6222
# 20161203-0009 0.01 hrs 11 4k AR1: MKAIV-388 CBF J1327-6222
# 20161203-0010 0.02 hrs 11 4k AR1: MKAIV-388 CBF J1327-6222
# 20161203-0013 0.12 hrs 11 4k AR1: MKAIV-214 Phase-up 1934
# 20161203-0014 0.07 hrs 11 4k AR1: MKAIV-388 CBF J1327-6222
# 20161203-0015 0.17 hrs 11 4k AR1: MKAIV-388 CBF J1939 2134
# 20161203-0016 0.13 hrs 11 4k AR1: MKAIV-214 Phase-up 1934
# 20161203-0021 0.17 hrs 11 4k AR1: MKAIV-388 CBF J1644-4559
# 20161203-0020 0.17 hrs 11 4k AR1: MKAIV-388 CBF J1559-4438
# 20161203-0022 0.12 hrs 11 4k AR1: MKAIV-214 Phase-up 1934
# 20161203-0023 0.17 hrs 11 4k AR1: MKAIV-388 CBF J1939 2134
# 20161203-0024 0.17 hrs 11 4k AR1: MKAIV-388 CBF J1909-3744
# 20161203-0025 0.12 hrs 11 4k AR1: MKAIV-214 Phase-up 1934
# 20161203-0027 0.17 hrs 11 4k AR1: MKAIV-388 CBF J1909-3744
# 20161203-0028 0.17 hrs 11 4k AR1: MKAIV-388 CBF J1327-6222
# 20161203-0029 0.09 hrs 11 4k Generic Phaseup for all targets
# 20161203-0030 11.81 hrs 11 4k Imaging observation DEEP2
# 20161204-0001 0.03 hrs 11 4k AR1: Basic functionality test
# 20161204-0002 0.36 hrs 11 4k AR1: Basic functionality test
# 20161204-0005 0.08 hrs 11 4k Generic Phaseup for all targets
# 20161204-0006 0.1 hrs 11 32k Generic Phaseup for all targets
# 20161204-0007 0.06 hrs 11 4k Phase-down
# 20161204-0008 0.43 hrs 11 4k Baseline Calibration (Delay model calculation)
# 20161204-0009 0.06 hrs 11 4k Phase-down
# 20161204-0010 0.45 hrs 11 4k Baseline Calibration (Delay model calculation)
# 20161204-0012 0.07 hrs 11 4k Phase-down
# 20161204-0011 0.51 hrs 11 4k Baseline Calibration (Delay model calculation)
# 20161204-0015 0.1 hrs 11 4k Generic Phaseup for all targets
# 20161204-0016 6.01 hrs 11 4k AR1: MKAIV-295 Calibrator Imaging observation
# 20161204-0017 0.14 hrs 11 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161204-0019 0.17 hrs 11 4k AR1: MKAIV-224 CBF J0738-4042
# 20161204-0018 0.17 hrs 11 4k AR1: MKAIV-231 CBF J0437-4715
# 20161204-0020 0.12 hrs 11 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161204-0021 0.17 hrs 11 4k AR1: MKAIV-224 CBF J0742-2822
# 20161204-0022 0.17 hrs 11 4k AR1: MKAIV-224 CBF J0835-4510
# 20161204-0023 0.11 hrs 11 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161204-0024 0.5 hrs 11 4k AR1: MKAIV-231 CBF J0437-4715
# 20161205-0001 0.38 hrs 11 4k AR1: Basic functionality test
# 20161205-0002 0.09 hrs 11 4k AR1: MKAIV-216 Phase-down
# 20161205-0003 0.1 hrs 11 32k Generic Phaseup for all targets
# 20161205-0004 0.1 hrs 11 4k Generic Phaseup for all targets
# 20161205-0005 0.45 hrs 11 4k AR1: Basic functionality test
# 20161205-0008 0.36 hrs 11 4k AR1: Basic functionality test
# 20161205-0011 0.08 hrs 10 4k Generic Phaseup for all targets
# 20161205-0012 0.07 hrs 10 4k Hotload and Coldload observation:Tsys and Tnd
# 20161205-0015 0.09 hrs 10 4k Generic Phaseup for all targets
# 20161205-0014 0.58 hrs 10 4k Imaging full beam correction
# 20161205-0018 0.09 hrs 10 4k Generic Phaseup for all targets
# 20161205-0019 0.08 hrs 10 4k Hotload and Coldload observation:T_sys_T_nd
# 20161205-0022 0.03 hrs 10 4k Generic Phaseup for all targets
# 20161205-0023 0.08 hrs 10 4k Generic Phaseup for all targets
# 20161205-0025 0.36 hrs 10 4k AR1: Basic functionality test
# 20161205-0026 0.08 hrs 10 4k Generic Phaseup for all targets
# 20161205-0027 0.08 hrs 10 4k Generic Phaseup for all targets
# 20161205-0024 0.17 hrs 10 4k MKAIV-394: Laura - Polarization purity and leakage (BP pol)
# 20161205-0028 0.35 hrs 10 4k Polarization purity and leakage (BP pol)
# 20161205-0029 0.09 hrs 10 32k Generic Phaseup for all targets
# 20161205-0031 0.11 hrs 10 32k Generic Phaseup for all targets
# 20161205-0032 0.11 hrs 10 32k Generic Phaseup for all targets
# 20161205-0030 3.03 hrs 10 32k AR1: Two calib Imaging
# 20161205-0041 0.27 hrs 10 32k Generic Phaseup for all targets
# 20161205-0033 3.07 hrs 10 32k AR1: Two calib Imaging
# 20161205-0046 0.27 hrs 10 32k Generic Phaseup for all targets
# 20161206-0002 0.11 hrs 8 32k Generic Phaseup for all targets
# 20161206-0003 3.08 hrs 8 32k Spectral dynamic range (G330.89-0.36)
# 20161206-0004 0.1 hrs 8 32k Generic Phaseup for all targets
# 20161206-0005 3.06 hrs 8 32k Spectral dynamic range (G330.89-0.36)
# 20161206-0006 0.1 hrs 8 32k Generic Phaseup for all targets
# 20161206-0007 2.01 hrs 8 32k Spectral dynamic range (G330.89-0.36)
# 20161206-0009 0.12 hrs 8 4k AR1: MKAIV-214 Phase-up 1934
# 20161206-0010 0.05 hrs 8 4k AR1: CBF J1644-4559
# 20161206-0013 0.03 hrs 9 4k Generic Phaseup for all targets
# 20161206-0015 0.08 hrs 9 4k Generic Phaseup for all targets
# 20161206-0012 0.36 hrs 9 4k AR1: Basic functionality test
# 20161206-0025 0.08 hrs 9 4k Generic Phaseup for all targets
# 20161206-0026 1.08 hrs 9 4k AR1: MKAIV-295 Calibrator Imaging observation
# 20161206-0017 0.17 hrs 9 4k AR1: MKAIV-231 CBF J0437-4715
# 20161206-0018 0.17 hrs 9 4k AR1: MKAIV-224 CBF J0738-4042
# 20161206-0019 0.11 hrs 9 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161206-0020 0.17 hrs 9 4k AR1: MKAIV-224 CBF J0742-2822
# 20161206-0021 0.25 hrs 9 4k AR1: MKAIV-224 CBF J0835-4510
# 20161206-0022 0.27 hrs 9 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161206-0024 0.59 hrs 9 4k AR1: MKAIV-231 CBF J0437-4715
# 20161206-0032 0.14 hrs 9 32k Generic Phaseup for all targets
# 20161207-0002 0.09 hrs 8 32k Generic Phaseup for all targets
# 20161207-0003 0.09 hrs 8 32k Generic Phaseup for all targets
# 20161207-0004 0.09 hrs 8 32k Generic Phaseup for all targets
# 20161207-0005 0.09 hrs 8 32k Generic Phaseup for all targets
# 20161206-0031 3.02 hrs 8 32k Image extended HI source (M83)
# 20161207-0006 0.05 hrs 8 32k Image extended HI source (M83)
# 20161207-0007 0.08 hrs 9 32k Generic Phaseup for all targets
# 20161207-0010 0.1 hrs 9 32k Generic Phaseup for all targets
# 20161207-0009 0.1 hrs 9 32k Generic Phaseup for all targets
# 20161207-0011 0.1 hrs 9 32k Generic Phaseup for all targets
# 20161207-0012 0.1 hrs 9 32k Generic Phaseup for all targets
# 20161207-0016 0.09 hrs 9 32k Generic Phaseup for all targets
# 20161207-0019 0.4 hrs 9 32k AR1: Basic functionality test
# 20161207-0018 0.39 hrs 9 32k AR1: Basic functionality test
# 20161207-0020 0.36 hrs 8 4k AR1: Basic functionality test
# 20161207-0023 0.09 hrs 9 32k Generic Phaseup for all targets
# 20161205-0043 1.19 hrs 9 32k Spectral dynamic range (G330.89-0.36)
# 20161207-0013 0.36 hrs 9 32k Image extended HI source (M83)
# 20161207-0024 0.05 hrs 9 4k Generic Phaseup for all targets
# 20161207-0025 0.08 hrs 9 4k Generic Phaseup for all targets
# 20161207-0026 0.01 hrs 9 4k AR1: MKAIV-295 Calibrator Imaging observation
# 20161207-0027 1.54 hrs 9 4k AR1: MKAIV-295 Calibrator Imaging observation
# 20161207-0028 0.09 hrs 9 4k Generic Phaseup for all targets
# 20161207-0030 12.0 hrs 9 4k Polarization purity and leakage (k-cross)
# 20161208-0001 0.09 hrs 10 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161208-0002 0.05 hrs 10 4k AR1: MKAIV-388 CBF J1327-6222
# 20161208-0003 1.0 hrs 10 4k AR1: MKAIV-388 CBF J1939 2134
# 20161208-0004 0.13 hrs 10 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161208-0005 0.17 hrs 10 4k AR1: MKAIV-388 CBF J1559-4438
# 20161208-0006 0.17 hrs 10 4k AR1: MKAIV-388 CBF J1644-4559
# 20161208-0010 0.07 hrs 10 4k AR1: MKAIV-216 Phase-down
# 20161208-0011 6.02 hrs 10 4k AR1: MKAIV-232 Baseline calibration
# 20161208-0009 0.13 hrs 10 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161208-0023 0.09 hrs 9 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161208-0022 0.17 hrs 9 4k AR1: MKAIV-231 CBF J0437-4715
# 20161208-0015 0.17 hrs 9 4k AR1: MKAIV-224 CBF J0738-4042
# 20161208-0016 0.11 hrs 9 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161208-0017 0.17 hrs 9 4k AR1: MKAIV-224 CBF J0742-2822
# 20161208-0018 0.16 hrs 9 4k AR1: MKAIV-224 CBF J0835-4510
# 20161208-0027 0.17 hrs 9 4k AR1: MKAIV-224 CBF J0742-2822
# 20161208-0024 0.09 hrs 9 4k Generic Phaseup for all targets
# 20161208-0025 6.02 hrs 9 4k Interferometric Pointing Calibration
# 20161208-0026 0.41 hrs 9 4k AR1: Basic functionality test
# 20161209-0004 0.08 hrs 9 32k Generic Phaseup for all targets
# 20161209-0001 0.13 hrs 9 32k Generic Phaseup for all targets
# 20161209-0002 0.67 hrs 9 32k AR1: COMM-154 Spectral line modes sensitivity
# 20161212-0011 0.08 hrs 9 4k AR1: MKAIV-214 Phase-up 1934
# 20161212-0012 0.08 hrs 9 4k AR1: MKAIV-224 CBF J1644-4559
# 20161212-0013 0.08 hrs 9 4k AR1: MKAIV-224 CBF J1644-4559
# 20161212-0014 0.1 hrs 9 32k AR1: MKAIV-382 Phase-up 1934 32K
# 20161212-0016 0.36 hrs 8 4k AR1: Basic functionality test
# 20161212-0018 0.14 hrs 9 4k Generic Phaseup for all targets
# 20161212-0020 0.07 hrs 8 4k Generic Phaseup for all targets
# 20161212-0019 6.03 hrs 8 4k AR1: checking calibrators
# 20161212-0036 0.14 hrs 3 4k AR1: MKAIV-78 Quick Check Point Source Scan
# 20161212-0037 0.04 hrs 3 4k AR1: MKAIV-79 Basic Tracking of a Source
# 20161212-0024 0.14 hrs 8 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161212-0025 0.17 hrs 8 4k AR1: MKAIV-224 CBF J0742-2822
# 20161212-0026 0.17 hrs 8 4k AR1: MKAIV-224 CBF J0835-4510
# 20161212-0027 0.11 hrs 8 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161212-0038 0.33 hrs 8 4k AR1: MKAIV-224 CBF J0835-4510
# 20161212-0040 0.11 hrs 8 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161212-0041 0.33 hrs 8 4k AR1: MKAIV-224 CBF J0835-4510
# 20161212-0042 0.33 hrs 8 4k AR1: MKAIV-224 CBF J0835-4510
# 20161212-0029 0.08 hrs 8 4k Hotload and Coldload observation:AR1: Tsys and Tnd
# 20161212-0032 0.38 hrs 8 4k AR1: Basic functionality test
# 20161212-0031 6.02 hrs 8 4k AR1: Baseline Calibration (Delay model calculation)
# 20161213-0002 0.14 hrs 7 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161213-0003 0.17 hrs 7 4k AR1: MKAIV-224 CBF J0835-4510
# 20161213-0004 0.0 hrs 7 4k AR1: MKAIV-224 CBF J0835-4510
# 20161213-0005 0.17 hrs 7 4k AR1: MKAIV-224 CBF J0835-4510
# 20161213-0006 0.36 hrs 9 4k AR1: Basic functionality test
# 20161213-0008 0.05 hrs 9 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161213-0010 0.17 hrs 9 4k AR1: MKAIV-388 CBF J1939 2134
# 20161213-0014 0.02 hrs 9 4k AR1: Beamformer functionality test
# 20161213-0016 0.02 hrs 9 4k AR1: Beamformer functionality test
# 20161213-0015 0.02 hrs 9 4k AR1: Beamformer functionality test
# 20161213-0018 0.02 hrs 9 4k AR1: Beamformer functionality test
# 20161213-0017 0.02 hrs 9 4k AR1: Beamformer functionality test
# 20161213-0019 0.17 hrs 9 4k AR1: MKAIV-388 CBF J1939 2134
# 20161213-0020 0.02 hrs 9 4k AR1: Beamformer functionality test
# 20161213-0021 0.02 hrs 9 4k AR1: Beamformer functionality test
# 20161213-0022 0.01 hrs 9 4k AR1: Beamformer functionality test
# 20161213-0023 0.02 hrs 9 4k AR1: Beamformer functionality test
# 20161213-0026 0.02 hrs 9 4k AR1: Beamformer functionality test
# 20161213-0028 0.02 hrs 9 4k AR1: Beamformer functionality test
# 20161213-0027 0.02 hrs 9 4k AR1: Beamformer functionality test
# 20161213-0029 0.07 hrs 10 4k Generic Phaseup for all targets
# 20161213-0030 0.14 hrs 10 4k Generic Phaseup for all targets
# 20161213-0031 0.08 hrs 9 4k Generic Phaseup for all targets
# 20161213-0024 6.01 hrs 9 4k MKAIV-348: TomM - Equatorial test field imaging obs
# 20161213-0032 0.04 hrs 12 32k Generic Phaseup for all targets
# 20161213-0035 0.1 hrs 12 32k Generic Phaseup for all targets
# 20161214-0004 0.36 hrs 12 4k AR1: Basic functionality test
# 20161214-0005 0.08 hrs 12 4k Generic Phaseup for all targets
# 20161214-0006 0.07 hrs 12 4k AR1: MKAIV-85 Tipping Curve
# 20161214-0007 0.72 hrs 12 4k AR1: MKAIV-85 Tipping Curve
# 20161214-0008 0.09 hrs 12 32k Generic Phaseup for all targets
# 20161214-0012 0.12 hrs 12 32k Generic Phaseup for all targets
# 20161214-0009 0.01 hrs 12 32k Image bright HI source (NGC 3621) p1
# 20161214-0014 0.12 hrs 12 32k Generic Phaseup for all targets
# 20161215-0002 0.04 hrs 12 4k AR1: Basic functionality test
# 20161215-0003 0.36 hrs 12 4k AR1: Basic functionality test
# 20161215-0004 0.02 hrs 12 4k Generic Phaseup for all targets
# 20161215-0005 0.08 hrs 12 4k Generic Phaseup for all targets
# 20161214-0003 0.06 hrs 12 32k AR1: Basic functionality test
# 20161215-0007 0.1 hrs 12 32k Generic Phaseup for all targets
# 20161215-0008 0.12 hrs 12 32k Generic Phaseup for all targets
# 20161215-0009 0.11 hrs 12 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161215-0010 0.01 hrs 12 4k AR1: BF obs of 1934-638
# 20161215-0011 0.08 hrs 12 4k AR1: BF obs of 1934-638
# 20161215-0012 0.11 hrs 12 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161215-0013 0.08 hrs 12 4k AR1: MKAIV-231 CBF J1939 2134
# 20161215-0014 0.02 hrs 12 4k AR1: MKAIV-231 CBF J1939 2134 SP
# 20161215-0015 0.08 hrs 12 4k AR1: MKAIV-231 CBF J1939 2134
# 20161215-0016 0.17 hrs 12 4k AR1: MKAIV-231 CBF J1939 2134
# 20161215-0019 0.13 hrs 12 4k AR1: MKAIV-214 Phase-up 1934
# 20161215-0027 0.17 hrs 12 4k AR1: MKAIV-388 CBF J1909-3744
# 20161215-0059 0.07 hrs 12 4k Generic Phaseup for all targets
# 20161215-0062 5.84 hrs 12 4k Calibrator Switching Effects
# 20161215-0078 0.15 hrs 12 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161215-0079 0.17 hrs 12 4k AR1: MKAIV-231 CBF J0437-4715
# 20161215-0080 0.17 hrs 12 4k AR1: MKAIV-224 CBF J0738-4042
# 20161215-0081 0.12 hrs 12 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161215-0083 0.17 hrs 12 4k AR1: MKAIV-224 CBF J0742-2822
# 20161215-0084 0.17 hrs 12 4k AR1: MKAIV-224 CBF J0835-4510
# 20161215-0085 0.11 hrs 12 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161215-0086 0.34 hrs 12 4k AR1: MKAIV-231 CBF J0437-4715
# 20161215-0087 0.17 hrs 12 4k AR1: MKAIV-231 CBF J0953 0755
# 20161215-0061 0.1 hrs 12 4k Generic Phaseup for all targets
# 20161215-0039 6.14 hrs 12 4k Interferometric Pointing Calibration
# 20161215-0006 0.04 hrs 12 4k AR1: Basic functionality test
# 20161216-0001 0.37 hrs 12 4k AR1: Basic functionality test
# 20161215-0060 0.08 hrs 12 4k Generic Phaseup for all targets
# 20161215-0063 11.05 hrs 12 4k Mosaicing
# 20161217-0001 0.11 hrs 12 4k AR1: Basic functionality test
# 20161217-0002 0.4 hrs 12 4k AR1: Basic functionality test
# 20161217-0003 0.25 hrs 12 4k Hotload and Coldload observation:Tsys and Tnd
# 20161217-0004 0.13 hrs 12 4k AR1: MKAIV-78 Quick Check Point Source Scan
# 20161217-0005 0.02 hrs 12 4k Hotload and Coldload observation:T_sys_T_nd
# 20161217-0006 0.33 hrs 12 4k AR1: MKAIV-85 Tipping_Curve
# 20161215-0089 0.27 hrs 12 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161215-0090 0.17 hrs 12 4k AR1: MKAIV-388 CBF J1327-6222
# 20161215-0091 0.17 hrs 12 4k AR1: MKAIV-388 CBF J1939 2134
# 20161215-0092 0.13 hrs 12 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161215-0093 0.17 hrs 12 4k AR1: MKAIV-388 CBF J1559-4438
# 20161215-0094 0.17 hrs 12 4k AR1: MKAIV-388 CBF J1644-4559
# 20161215-0095 0.12 hrs 12 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161215-0096 0.17 hrs 12 4k AR1: MKAIV-388 CBF J1939 2134
# 20161215-0097 0.17 hrs 12 4k AR1: MKAIV-388 CBF J1909-3744
# 20161215-0067 0.09 hrs 12 4k Generic Phaseup for all targets
# 20161215-0066 11.95 hrs 12 4k Imaging observation SCP
# 20161215-0068 1.34 hrs 12 4k Baseline Calibration (Delay model calculation)
# 20161215-0071 0.24 hrs 12 4k Generic Phaseup for all targets
# 20161215-0073 0.24 hrs 12 4k Generic Phaseup for all targets
# 20161219-0001 0.03 hrs 10 4k Generic Phaseup for all targets
# 20161219-0002 0.36 hrs 10 4k AR1: Basic functionality test
# 20161219-0008 0.14 hrs 11 32k Generic Phaseup for all targets
# 20161219-0004 4.03 hrs 11 32k Spectral dynamic range (G330.89-0.36)
# 20161219-0011 0.09 hrs 10 4k AR1: MKAIV-214 Phase-up 0408-65
# 20161219-0013 0.17 hrs 10 4k AR1: MKAIV-224 CBF J0738-4042
# 20161219-0012 0.17 hrs 10 4k AR1: MKAIV-231 CBF J0437-4715
# 20161219-0014 0.12 hrs 10 4k AR1: MKAIV-214 Phase-up 0408-65
# 20161219-0016 0.17 hrs 10 4k AR1: MKAIV-224 CBF J0835-4510
# 20161219-0015 0.17 hrs 10 4k AR1: MKAIV-224 CBF J0742-2822
# 20161219-0017 0.13 hrs 10 4k AR1: MKAIV-214 Phase-up 0408-65
# 20161219-0018 0.17 hrs 10 4k AR1: MKAIV-231 CBF J0437-4715
# 20161219-0019 0.17 hrs 10 4k AR1: MKAIV-231 CBF J0953 0755
# 20161219-0020 8.02 hrs 10 4k Three calibrator imaging
# 20161220-0001 0.39 hrs 10 4k AR1: Basic functionality test
# 20161219-0009 0.37 hrs 10 4k AR1: Basic functionality test
# 20161220-0002 0.06 hrs 10 4k AR1: Basic functionality test
# 20161220-0006 0.09 hrs 9 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161220-0005 0.02 hrs 9 4k AR1: MKAIV-231 CBF J1909-3744
# 20161220-0007 0.02 hrs 9 4k AR1: MKAIV-231 CBF J1909-3744
# 20161220-0008 0.12 hrs 10 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161220-0009 0.02 hrs 10 4k AR1: MKAIV-231 CBF J1909-3744
# 20161220-0011 0.02 hrs 10 4k AR1: MKAIV-388 CBF J1939 2134
# 20161220-0014 0.01 hrs 10 4k AR1: MKAIV-231 CBF J1909-3744 digifits
# 20161215-0088 0.12 hrs 10 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161220-0018 0.11 hrs 10 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161220-0016 0.02 hrs 10 4k AR1: MKAIV-231 CBF J1909-3744 digifits
# 20161220-0019 0.02 hrs 10 4k AR1: MKAIV-231 CBF J1909-3744
# 20161220-0020 0.02 hrs 10 4k AR1: MKAIV-231 CBF J1909-3744 digifits
# 20161220-0021 0.02 hrs 10 4k AR1: MKAIV-231 CBF J1909-3744 digifits halfband
# 20161220-0022 0.02 hrs 10 4k AR1: MKAIV-231 CBF J1909-3744 dspsr fullband
# 20161220-0023 0.02 hrs 10 4k AR1: MKAIV-231 CBF J1909-3744 dspsr fullband
# 20161220-0024 0.12 hrs 10 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161220-0025 0.02 hrs 10 4k AR1: MKAIV-231 CBF J1909-3744 digifits
# 20161220-0027 0.12 hrs 12 32k Generic Phaseup for all targets
# 20161220-0028 0.6 hrs 12 32k Imaging observation SCP
# 20161220-0031 0.13 hrs 12 32k Generic Phaseup for all targets
# 20161220-0029 4.11 hrs 12 32k Imaging observation SCP
# 20161220-0035 0.12 hrs 12 4k Generic Phaseup for all targets
# 20161221-0001 1.01 hrs 12 4k Imaging observation SCP
# 20161221-0002 0.04 hrs 13 4k Generic Phaseup for all targets
# 20161221-0003 0.37 hrs 12 4k AR1: Basic functionality test
# 20161221-0007 0.11 hrs 8 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161221-0009 0.02 hrs 8 4k AR1: MKAIV-231 CBF J1644-4559
# 20161221-0010 0.02 hrs 8 4k AR1: MKAIV-231 CBF J1644-4559
# 20161221-0013 0.11 hrs 8 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161221-0012 0.02 hrs 8 4k AR1: MKAIV-231 CBF J1644-4559
# 20161221-0014 0.03 hrs 8 4k AR1: MKAIV-231 CBF J1644-4559
# 20161221-0015 0.03 hrs 8 4k AR1: MKAIV-231 CBF J1644-4559 offset beam
# 20161221-0004 0.05 hrs 12 4k Generic Phaseup for all targets
# 20161221-0016 0.08 hrs 12 4k Generic Phaseup for all targets
# 20161221-0017 0.08 hrs 12 4k Generic Phaseup for all targets
# 20161221-0005 8.0 hrs 12 4k Three calibrator imaging
# 20161221-0027 0.08 hrs 12 4k Generic Phaseup for all targets
# 20161221-0028 8.1 hrs 12 4k Imaging observation SCP
# 20161221-0021 0.12 hrs 12 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161221-0023 0.17 hrs 12 4k AR1: MKAIV-224 CBF J0835-4510
# 20161222-0001 0.41 hrs 12 4k AR1: Basic functionality test
# 20161222-0002 0.08 hrs 12 4k Generic Phaseup for all targets
# 20161222-0005 0.36 hrs 12 4k AR1: Basic functionality test
# 20161222-0006 0.05 hrs 12 32k Generic Phaseup for all targets
# 20161222-0009 0.1 hrs 12 32k Generic Phaseup for all targets
# 20161222-0007 0.11 hrs 12 32k Three calibrator imaging
# 20161222-0010 0.1 hrs 11 32k Generic Phaseup for all targets
# 20161222-0008 4.01 hrs 11 32k Three calibrator imaging
# 20161222-0012 4.01 hrs 11 32k Three calibrator imaging
# 20161222-0013 0.12 hrs 11 32k Generic Phaseup for all targets
# 20161222-0015 3.96 hrs 11 32k Imaging observation SCP
# 20161222-0016 0.02 hrs 12 4k AR1: MKAIV-216 Phase-down
# 20161223-0002 0.41 hrs 12 4k AR1: Basic functionality test
# 20161223-0009 0.11 hrs 12 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161223-0013 0.11 hrs 12 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161223-0010 0.17 hrs 12 4k AR1: MKAIV-388 CBF J1327-6222
# 20161223-0020 0.08 hrs 12 4k Generic Phaseup for all targets
# 20161223-0027 0.08 hrs 12 4k Generic Phaseup for all targets
# 20161223-0029 0.08 hrs 9 4k Generic Phaseup for all targets
# 20161223-0034 0.08 hrs 9 4k Generic Phaseup for all targets
# 20161223-0035 6.16 hrs 9 4k AR1: MKAIV-295 Calibrator Imaging observation
# 20161223-0042 1.59 hrs 9 4k AR1: Basic functionality test
# 20161223-0043 0.27 hrs 9 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161223-0044 0.25 hrs 9 4k AR1: MKAIV-231 CBF J0437-4715
# 20161223-0045 0.25 hrs 9 4k AR1: MKAIV-224 CBF J0738-4042
# 20161223-0046 0.27 hrs 9 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161223-0047 0.25 hrs 9 4k AR1: MKAIV-224 CBF J0742-2822
# 20161223-0048 0.25 hrs 9 4k AR1: MKAIV-224 CBF J0835-4510
# 20161223-0049 0.27 hrs 9 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161223-0050 0.42 hrs 9 4k AR1: MKAIV-231 CBF J0437-4715
# 20161223-0051 0.25 hrs 9 4k AR1: MKAIV-231 CBF J0953 0755
# 20161223-0037 8.2 hrs 9 4k Imaging observation SCP
# 20161223-0038 0.24 hrs 9 4k Generic Phaseup for all targets
# 20161223-0040 0.24 hrs 9 4k Generic Phaseup for all targets
# 20161224-0001 0.27 hrs 9 4k AR1: MKAIV-214 Phase-up 0408-65
# 20161224-0005 0.17 hrs 9 4k AR1: MKAIV-231 CBF J0437-4715
# 20161224-0010 0.17 hrs 9 4k AR1: MKAIV-224 CBF J0738-4042
# 20161224-0011 0.12 hrs 9 4k AR1: MKAIV-214 Phase-up 0408-65
# 20161224-0015 0.17 hrs 9 4k AR1: MKAIV-231 CBF J0437-4715
# 20161223-0052 0.09 hrs 9 4k Generic Phaseup for all targets
# 20161223-0053 8.0 hrs 9 4k Three calibrator imaging
# 20161223-0063 0.09 hrs 7 32k Generic Phaseup for all targets
# 20161223-0064 4.09 hrs 7 32k Imaging observation SCP
# 20161223-0065 4.0 hrs 7 32k Imaging observation SCP
# 20161223-0066 0.1 hrs 7 32k Generic Phaseup for all targets
# 20161223-0068 4.02 hrs 7 32k Three calibrator imaging
# 20161223-0070 4.14 hrs 7 32k Imaging observation SCP
# 20161228-0004 0.35 hrs 4 4k AR1: Basic functionality test
# 20161228-0008 0.35 hrs 4 4k AR1: Basic functionality test
# 20161228-0015 0.36 hrs 10 4k AR1: Basic functionality test
# 20161228-0016 0.08 hrs 10 4k Generic Phaseup for all targets
# 20161228-0017 8.0 hrs 10 4k Three calibrator imaging
# 20161228-0018 0.11 hrs 10 4k AR1: MKAIV-214 Phase-up 0408-65
# 20161228-0019 0.5 hrs 10 4k AR1: MKAIV-231 CBF J0437-4715
# 20161228-0020 0.12 hrs 10 4k AR1: MKAIV-214 Phase-up 0408-65
# 20161228-0021 0.17 hrs 10 4k AR1: MKAIV-231 CBF J0437-4715
# 20161228-0022 0.17 hrs 10 4k AR1: MKAIV-224 CBF J0738-4042
# 20161228-0023 0.12 hrs 10 4k AR1: MKAIV-214 Phase-up 0408-65
# 20161228-0024 0.17 hrs 10 4k AR1: MKAIV-224 CBF J0742-2822
# 20161228-0025 0.17 hrs 10 4k AR1: MKAIV-224 CBF J0835-4510
# 20161228-0026 0.09 hrs 10 4k Generic Phaseup for all targets
# 20161228-0027 10.4 hrs 10 4k Imaging observation SCP
# 20161229-0005 0.08 hrs 10 32k Generic Phaseup for all targets
# 20161229-0006 0.11 hrs 10 32k Generic Phaseup for all targets
# 20161229-0003 0.11 hrs 10 32k Generic Phaseup for all targets
# 20161229-0007 3.51 hrs 10 32k Three calibrator imaging
# 20161229-0011 0.11 hrs 10 32k Generic Phaseup for all targets
# 20161229-0009 4.17 hrs 10 32k Imaging observation SCP
# 20161229-0010 4.01 hrs 10 32k Imaging observation SCP
# 20161229-0015 0.11 hrs 10 32k Generic Phaseup for all targets
# 20161229-0016 4.02 hrs 10 32k Three calibrator imaging
# 20161229-0017 4.0 hrs 10 32k Three calibrator imaging
# 20161230-0004 0.36 hrs 12 4k AR1: Basic functionality test
# 20161230-0005 0.08 hrs 12 4k Generic Phaseup for all targets
# 20161230-0008 0.72 hrs 12 4k Baseline Calibration (Delay model calculation)
# 20161230-0010 0.05 hrs 11 4k AR1: Basic functionality test
# 20161230-0011 0.08 hrs 11 4k Generic Phaseup for all targets
# 20161230-0012 0.08 hrs 11 4k Generic Phaseup for all targets
# 20161230-0009 8.11 hrs 11 4k Imaging observation SCP
# 20161230-0013 0.12 hrs 11 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161230-0014 0.17 hrs 11 4k AR1: MKAIV-231 CBF J0437-4715
# 20161230-0015 0.17 hrs 11 4k AR1: MKAIV-224 CBF J0738-4042
# 20161230-0016 0.12 hrs 11 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161230-0017 0.17 hrs 11 4k AR1: MKAIV-224 CBF J0742-2822
# 20161230-0018 0.17 hrs 11 4k AR1: MKAIV-224 CBF J0835-4510
# 20161230-0019 0.11 hrs 11 4k AR1: MKAIV-214 Phase-up 0823-500
# 20161230-0022 0.34 hrs 11 4k AR1: MKAIV-231 CBF J0437-4715
# 20161230-0021 0.17 hrs 11 4k AR1: MKAIV-231 CBF J0953 0755
# 20161230-0023 0.39 hrs 11 4k AR1: Basic functionality test
# 20161230-0024 0.37 hrs 11 4k AR1: Basic functionality test
# 20161230-0025 0.11 hrs 11 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161230-0026 0.17 hrs 11 4k AR1: MKAIV-388 CBF J1327-6222
# 20161230-0027 0.17 hrs 11 4k AR1: MKAIV-388 CBF J1939 2134
# 20161230-0028 0.13 hrs 11 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161230-0029 0.17 hrs 11 4k AR1: MKAIV-388 CBF J1559-4438
# 20161230-0030 0.17 hrs 11 4k AR1: MKAIV-388 CBF J1644-4559
# 20161230-0031 0.12 hrs 11 4k AR1: MKAIV-214 Phase-up PKS 1934-638
# 20161230-0032 0.17 hrs 11 4k AR1: MKAIV-388 CBF J1939 2134
# 20161230-0047 0.1 hrs 11 4k Generic Phaseup for all targets
# 20161230-0048 8.08 hrs 11 4k Three calibrator imaging

# %% [markdown]
# Only select observations that are longer than 1 hrs then extract the project id from the script parameters. If there is no project id then allocated No_project_id

# %%
sbd = [] #Experiment ID
pid = [] #project ID
fnd = [] #Filename
dud = [] #Duration
antsd = [] #number of antennas
scrd = [] #script  -NOT USED NOW

for fi in f:
    if fi.metadata.Duration < 3600: #only pick hour long or greater observations for analysis
        continue
    # now try extract the project-id from the instruction-set string
    """
    script = fi.metadata.InstructionSet
    scrd.append(script)
    spl = script.split()
    """
    txts=fi.metadata.InstructionSet
    #p=findproj(txts)
    p=fi.metadata.Description# ignore "AR1...
    sbd.append(fi.metadata.ExperimentID) 
    pid.append(p)
    fnd.append(fi.metadata.Filename)
    dud.append(fi.metadata.Duration)
    antsd.append(len(fi.metadata.Antennas))
    #print p

# %%
pi = np.array(pid)
sb = np.array(sbd)
du = np.array(dud)
ants = np.array(antsd)

p_cent = (sum(du)/((end.toordinal()-start.toordinal())*24*3600))*100

print 'Percentage system usage: ', np.floor(p_cent),'%'
# Out:
# Percentage system usage:  40.0 %

# %%
a_id = []
a_time = []
for p in set(pi):
    ind = pi == p
    #print p,round(sum(du[ind])/3600,2)
    a_id.append(p)
    a_time.append(round(sum(du[ind])/3600,2))

# %%
ind = np.argsort(a_id)
for i in ind:
    print ("%-16s %5.1fhrs with %d ants") %(a_id[i],a_time[i],ants[i])
# Out:
# AR1: Baseline Calibration (Delay model calculation)   6.0hrs with 11 ants
# AR1: Basic functionality test   1.6hrs with 8 ants
# AR1: Calibrator Switching Imaging observation  11.9hrs with 10 ants
# AR1: MKAIV-232 Baseline calibration   6.0hrs with 9 ants
# AR1: MKAIV-295 Calibrator Imaging observation  14.8hrs with 8 ants
# AR1: MKAIV-388 CBF J1939 2134    1.0hrs with 9 ants
# AR1: Two calib Imaging   6.1hrs with 10 ants
# AR1: checking calibrators   6.0hrs with 8 ants
# Baseline Calibration (Delay model calculation)   1.3hrs with 9 ants
# Calibrator Switching Effects   5.8hrs with 8 ants
# Image extended HI source (M83)  12.1hrs with 7 ants
# Imaging observation DEEP2  11.8hrs with 9 ants
# Imaging observation SCP  76.3hrs with 8 ants
# Interferometric Pointing Calibration  18.2hrs with 7 ants
# MKAIV-348: TomM - Equatorial test field imaging obs   6.0hrs with 10 ants
# Mosaicing         21.1hrs with 11 ants
# Polarization purity and leakage (k-cross)  12.0hrs with 9 ants
# Spectral dynamic range (G330.89-0.36)  13.4hrs with 9 ants
# Three calibrator imaging  63.7hrs with 10 ants

# %% [markdown]
# Find the unique project ids and determine the total observation duration.

# %% [markdown]
# Sort ID and time for display

# %% [markdown]
# Plot as pie-chart

# %%
cmap = plt.cm.prism
colors = cmap(np.linspace(0., 1., 7))

# %%
plt.figure(figsize=(20,20))
plt.pie(a_time,labels=a_id,colors=colors,autopct='%1.1f%%');

# %%
plt.show()
