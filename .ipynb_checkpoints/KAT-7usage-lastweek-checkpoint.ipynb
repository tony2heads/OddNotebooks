# %%
# %matplotlib inline
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import katarchive

import datetime

import logging
logging.root.setLevel(logging.ERROR)

# %%
def findproj(text):
    found='Unknown'        # default
    chx=text.find('prop')
    if chx >0  :
        pr2=text[chx+11:chx+38].split()
        code=pr2[0]
        found=code.replace("=","")
    else:
        if text.find('maser') >0:
            found="Maser monitoring"
            #print text
    return found

# %%
today=datetime.datetime.today()
ago=datetime.timedelta(-7)
lastweek=today+ago
print today,lastweek
begin=lastweek.strftime(format="%d/%m/%Y")
end=today.strftime(format="%d/%m/%Y")
# Out:
# 2016-05-13 14:04:30.259905 2016-05-06 14:04:30.259905

# %%
print katarchive.search_archive(startdate=begin,enddate=end)
# Out:
# Searched using: CAS.ProductTypeName:(KatFile) AND CAS.ProductTransferStatus:RECEIVED AND StartTime:[2016-05-05T22:00:00Z TO 2016-05-13T21:59:59Z]
# Returning 70 results
# [['1', '2016-05-13 13:49:41 SAST', 'operator', [368368919]], ['1', '2016-05-13 09:00:27 SAST', 'Nadeem', [1264711409]], ['1', '2016-05-13 08:57:55 SAST', 'operator', [88362660]], ['1', '2016-05-12 23:38:20 SAST', 'Nadeem', [2651177904]], ['1', '2016-05-12 23:34:15 SAST', 'operator', [88367838]], ['1', '2016-05-12 16:45:58 SAST', 'Nadeem', [1672648995]], ['1', '2016-05-12 16:43:36 SAST', 'operator', [35274170]], ['1', '2016-05-12 16:39:11 SAST', 'operator', [35267170]], ['1', '2016-05-12 14:44:53 SAST', 'operator', [59490325]], ['1', '2016-05-12 14:36:59 SAST', 'operator', [7758637]], ['1', '2016-05-12 12:57:51 SAST', 'operator', [8095993]], ['1', '2016-05-12 11:42:18 SAST', 'operator', [7281534]], ['1', '2016-05-12 11:29:04 SAST', 'operator', [13549604]], ['1', '2016-05-12 11:22:41 SAST', 'operator', [13599589]], ['1', '2016-05-12 09:24:25 SAST', 'Nadeem', [287048454]], ['1', '2016-05-12 09:21:06 SAST', 'operator', [87595519]], ['1', '2016-05-12 03:45:23 SAST', 'Nadeem', [1221389901]], ['1', '2016-05-12 03:41:12 SAST', 'operator', [88392640]], ['1', '2016-05-11 22:30:19 SAST', 'Nadeem', [1497753834]], ['1', '2016-05-11 22:26:11 SAST', 'operator', [113345277]], ['1', '2016-05-11 17:14:19 SAST', 'Tony', [1477196885]], ['1', '2016-05-11 17:11:32 SAST', 'operator', [35258707]], ['1', '2016-05-11 16:38:53 SAST', 'operator', [71954960]], ['1', '2016-05-11 06:40:18 SAST', 'Nadeem', [1624162460]], ['1', '2016-05-11 06:36:15 SAST', 'operator', [59508114]], ['1', '2016-05-10 21:17:14 SAST', 'Richard', [5278806708]], ['1', '2016-05-10 21:13:11 SAST', 'operator', [87614409]], ['1', '2016-05-10 17:08:46 SAST', 'Lindsay', [11343494462]], ['1', '2016-05-10 17:07:26 SAST', 'operator', [34491342]], ['1', '2016-05-10 17:02:08 SAST', 'operator', [114129209]], ['1', '2016-05-10 08:43:52 SAST', 'Nadeem', [1183796502]], ['1', '2016-05-10 08:40:27 SAST', 'operator', [87575441]], ['1', '2016-
# 2 20141219SS-01 15460.21 W2332 Low 6
# 2 COMM_Atten 112.01 Auto atten 6
# 2 20141002MB-01 32420.45 SS433 6
# 2 COMM_Atten 112.01 Auto atten 6
# 2 COMM_Image_NO 20450.28 Imaging Calibration 6
# 2 COMM_Atten 44.0 Auto atten 6
# 2 COMM_Atten 44.0 Auto atten 6
# 2 COMM_Atten 75.01 Auto atten 6
# 2 COMM_Atten 59.0 Auto atten 2
# 2 COMM_Atten 62.0 Auto atten 2
# 2 COMM_Atten 55.0 Auto atten 2
# 2 COMM_Atten 306.02 Auto atten 1
# 2 COMM_Atten 307.02 Auto atten 1
# 2 20130822NO-01 3500.05 W2332_5056 6
# 2 COMM_Atten 111.01 Auto atten 6
# 2 20141219SS-01 14930.21 W2332 Low 6
# 2 COMM_Atten 112.01 Auto atten 6
# 2 20131211NO-01 18310.25 PKS1510-089 6
# 2 COMM_Atten 144.01 Auto atten 6
# 2 20150619TF-01 18060.25 3C279 6
# 2 COMM_Atten 44.0 Auto atten 6
# 2 COMM_Atten 91.01 Auto atten 6
# 2 20150210SS-01 19850.27 Field11Feb_Low 6
# 2 COMM_Atten 75.01 Auto atten 6
# 2 20140513DL-01 33105.46 GC Night 15 6
# 2 COMM_Atten 111.01 Auto atten 6
# 2 COMM_Point_LM 14526.15 Pointing Observation 6
# 2 COMM_Atten 43.0 Auto atten 6
# 2 COMM_Atten 145.01 Auto atten 6
# 2 COMM_Image_NO 14470.2 Imaging Calibration 6
# 2 COMM_Atten 111.01 Auto atten 6
# 2 COMM_RFI_SP 5885.47 Basic RFI Scan: RFI SCAN 6
# 2 COMM_Atten 74.01 Auto atten 6
# 2 20140513DL-01 32890.45 GC Night 14 6
# 2 COMM_Atten 79.01 Auto atten 6
# 2 COMM_Image_NO 14760.2 Imaging Calibration 6
# 2 COMM_Atten 44.0 Auto atten 6
# 2 COMM_Atten 111.01 Auto atten 6
# 2 COMM_Bandpass_TF 11010.15 Bandpass Calibrators 6
# 2 COMM_Atten 142.01 Auto atten 6
# 2 COMM_Bandpass_TF 5530.08 Bandpass Calibrators 6
# 2 COMM_Atten 74.01 Auto atten 6
# 2 20140513DL-01 32650.45 GC Night 12 6
# 2 COMM_Atten 144.01 Auto atten 6
# 2 COMM_RFI_SP 324.03 Basic RFI Scan: RFI SCAN 6
# 2 COMM_Atten 111.01 Auto atten 6
# 2 20150825LR-01 9530.13 reticulum2 6
# 2 COMM_Atten 42.0 Auto atten 6
# 2 COMM_Image_NO 12460.17 Imaging Calibration 6
# 2 COMM_Atten 75.01 Auto atten 6
# 2 20140513DL-01 32780.45 GC Night 10 6
# 2 COMM_Atten 303.02 Auto atten 6
# 2 COMM_Point_LM 324.03 Pointing Observation 6
# 2 COMM_Atten 302.02 Auto atten 6
# 2 20150825LR-01 310.0 reticulum2 6
# 2 COMM_Atten 41.0 Auto atten 6
# 2 20141219SS-01 14920.21 W2332 Low 6
# 2 COMM_Atten 113.01 Auto atten 6
# 2 20140729RT-01 22015.3 S2_Observe_2 6
# 2 COMM_Atten 96.01 Auto atten 6
# 2 COMM_Image_NO 20400.28 Imaging Calibration 6
# 2 COMM_Atten 44.0 Auto atten 6
# 2 COMM_Atten 45.0 Auto atten 6
# 2 COMM_Atten 145.01 Auto atten 6
# 2 COMM_RFI_SP 5976.47 Basic RFI Scan: RFI SCAN 6
# 2 COMM_Atten 44.0 Auto atten 6
# 2 COMM_Atten 93.01 Auto atten 6
# 2 20130822NO-01 13950.19 W2332_5056 6
# 2 COMM_Atten 118.01 Auto atten 6

# %% [markdown]
# Only select observations that are longer than 1 hrs then extract the project id from the script parameters. If there is no project id then allocated No_project_id

# %%
sbd = [] #Experiment ID
pid = [] #project ID
fnd = [] #Filename
dud = [] #Duration
antsd = [] #number of antennas
scrd = [] #script  -NOT USED NOW

for fi in f:
    if fi.metadata.Duration < 3600: #only pick hour long or greater observations for analysis
        continue
    # now try extract the project-id from the instruction-set string
    """
    script = fi.metadata.InstructionSet
    scrd.append(script)
    spl = script.split()
    """
    txts=fi.metadata.InstructionSet
    p=findproj(txts)
    if p == "Unknown":
        p="Maser Monitoring"
    sbd.append(fi.metadata.ExperimentID)
    pid.append(p)
    fnd.append(fi.metadata.Filename)
    dud.append(fi.metadata.Duration)
    antsd.append(len(fi.metadata.Antennas))

# %%
pi = np.array(pid)
sb = np.array(sbd)
du = np.array(dud)
ants = np.array(antsd)

p_cent = (sum(du)/((end.toordinal()-start.toordinal())*24*3600))*100

print 'Percentage system usage: ', np.floor(p_cent),'%'
# Out:
# Percentage system usage:  72.0 %

# %%
a_id = []
a_time = []
for p in set(pi):
    ind = pi == p
    print p,round(sum(du[ind])/3600,2)
    a_id.append(p)
    a_time.append(round(sum(du[ind])/3600,2))
# Out:
# 20140729RT-01 6.12
# COMM_Bandpass_TF 4.59
# COMM_RFI_SP 3.29
# 20141002MB-01 9.01
# 20130822NO-01 3.88
# 20150825LR-01 2.65
# 20150619TF-01 5.02
# 20141219SS-01 12.59
# 20140513DL-01 36.51
# 20150210SS-01 5.51
# COMM_Image_NO 22.93
# COMM_Point_LM 4.04
# 20131211NO-01 5.09

# %%
ind = np.argsort(a_id)
for i in ind:
    print ("%-16s %5.1f %d") %(a_id[i],a_time[i],ants[i])
# Out:
# 20130822NO-01      3.9 6
# 20131211NO-01      5.1 6
# 20140513DL-01     36.5 6
# 20140729RT-01      6.1 6
# 20141002MB-01      9.0 6
# 20141219SS-01     12.6 6
# 20150210SS-01      5.5 6
# 20150619TF-01      5.0 6
# 20150825LR-01      2.6 6
# COMM_Bandpass_TF   4.6 6
# COMM_Image_NO     22.9 6
# COMM_Point_LM      4.0 6
# COMM_RFI_SP        3.3 6

# %% [markdown]
# Find the unique project ids and determine the total observation duration.

# %% [markdown]
# Sort ID and time for display

# %% [markdown]
# Plot as pie-chart

# %%
cmap = plt.cm.prism
colors = cmap(np.linspace(0., 1., 7))

# %%
plt.figure(figsize=(15,15))
plt.pie(a_time,labels=a_id,colors=colors,autopct='%1.1f%%');

# %%
plt.show()

# %%
fi.metadata.InstructionSet
# Out:
# u'/home/kat/scripts/observation/auto_attenuate.py -f 1822 -t radec,0,-90 --mode=bc16n400M1k --proposal-id COMM_Atten program-block-id=25ob00900351 --sb-id-code=20160505-0015 --description= AutoAttenuation for 25ob00900351  --observer=operator --config-label=Auto2016-03-01T11h45m26.0Z'
