# %% [markdown]
# # AR1 Observation report

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import katdal
import pickle
import katpoint
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from katdal.chunkstore_s3 import S3ChunkStore
from katdal.datasources import TelstateDataSource
from katdal.visdatav4 import VisibilityDataV4

# %% [markdown]
# ## File to be processed

# %%
filename='1529567823_sdp_l0.full.rdb'

# %% [markdown]
# ## Set up environment

# %% [markdown]
# ## Load data

# %%
# !pwd
# Out:
# /home/tony/Desktop/PythonScripts/Notebooks

# %%
data = katdal.open(filename)
# Out:
# Accessing http://archive-gw-1.kat.ac.za:7480//auth.html
# /usr/local/lib/python2.7/dist-packages/dask/array/core.py:673: UserWarning: The token= keyword to map_blocks has been moved to name=
#   warnings.warn("The token= keyword to map_blocks has been moved to name=")

# %%
print data
# Out:
# ===============================================================================
# Name: file:///1529567823_sdp_l0.full.rdb | 1529567823_sdp_l0 (version 4.0)
# ===============================================================================
# Observer: Lindsay  Experiment ID: 20180621-0026
# Description: 'MKAIV-202 Interferometric Pointing Calibration'
# Observed from 2018-06-21 09:57:06.438 SAST to 2018-06-21 10:08:02.160 SAST
# Dump rate / period: 0.12505 Hz / 7.997 s
# Subarrays: 1
#   ID  Antennas                            Inputs  Corrprods
#    0  m000,m009,m017,m027,m031,m047,m052,m056  16      144
# Spectral Windows: 1
#   ID Band Product  CentreFreq(MHz)  Bandwidth(MHz)  Channels  ChannelWidth(kHz)
#    0 L    c856M4k    1284.000         856.000           4096       208.984
# -------------------------------------------------------------------------------
# Data selected according to the following criteria:
#   subarray=0
#   ants=['m047', 'm009', 'm052', 'm000', 'm056', 'm017', 'm027', 'm031']
#   spw=0
# -------------------------------------------------------------------------------
# Shape: (82 dumps, 4096 channels, 144 correlation products) => Size: 386.925 MB
# Antennas: m000,m009,m017,m027,m031,*m047,m052,m056  Inputs: 16  Autocorr: yes  Crosscorr: yes
# Channels: 4096 (index 0 - 4095,  856.000 MHz - 1711.791 MHz), each 208.984 kHz wide
# Targets: 2 selected out of 2 in catalogue
#   ID  Name          Type      RA(J2000)     DEC(J2000)  Tags     Dumps  ModelFlux(Jy)
#    0  Nothing       special             -            -               1
#    1  PKS 0023-263  radec      0:25:49.16  -26:02:12.6  gaincal     81
# Scans: 20 selected out of 20 total       Compscans: 1 selected out of 1 total
#   Date        Timerange(UTC)       ScanState  CompScanLabel  Dumps  Target
#   21-Jun-2018/07:57:10 - 07:57:18    0:stop     0:interferometric_pointing      2    1:PKS 0023-263
#               07:57:26 - 07:57:58    1:slew     0:interferometric_pointing      5    1:PKS 0023-263
#               07:58:06 - 07:59:02    2:track    0:interferometric_pointing      8    1:PKS 0023-263
#               07:59:10 - 07:59:18    3:slew     0:interferometric_pointing      2    1:PKS 0023-263
#               07:59:26 - 08:00:06    4:track    0:interferometric_pointing      6    1:PKS 0023-263
#               08:00:14 - 08:00:22    5:slew     0:interferometric_pointing      2    1:PKS 0023-263
#               08:00:30 - 08:01:10    6:track    0:interferometric_pointing      6    1:PKS 0023-263
#               08:01:18 - 08:01:26    7:slew     0:interferometric_pointing      2    1:PKS 0023-263
#               08:01:34 - 08:02:38    8:track    0:interferometric_pointing      9    1:PKS 0023-263
#               08:02:46 - 08:02:54    9:slew     0:interferometric_pointing      2    1:PKS 0023-263
#               08:03:02 - 08:03:42   10:track    0:interferometric_pointing      6    1:PKS 0023-263
#               08:03:50 - 08:03:58   11:slew     0:interferometric_pointing      2    1:PKS 0023-263
#               08:04:06 - 08:04:46   12:track    0:interferometric_pointing      6    1:PKS 0023-263
#               08:04:54 - 08:05:02   13:slew     0:interferometric_pointing      2    1:PKS 0023-263
#               08:05:10 - 08:06:06   14:track    0:interferometric_pointing      8    1:PKS 0023-263
#               08:06:14 - 08:06:22   15:slew     0:interferometric_pointing      2    1:PKS 0023-263
#               08:06:30 - 08:07:10   16:track    0:interferometric_pointing      6    1:PKS 0023-263
#               08:07:18 - 08:07:26   17:slew     0:interferometric_pointing      2    1:PKS 0023-263
#               08:07:34 - 08:07:50   18:track    0:interferometric_pointing      3    1:PKS 0023-263
#               08:07:58 - 08:07:58   19:stop     0:interferometric_pointing      1    0:Nothing

# %%
N = data.shape[0]
ext = 930
step = max(int(floor(N/ext)),1)
print step
# Out:
# 1

# %%
data.obs_params
# Out:
# {'capture_block_id': '1529567823',
#  'centre_freq': 1284.0,
#  'config_label': '8fec874,0334842',
#  'dbe_centre_freq': None,
#  'description': 'MKAIV-202 Interferometric Pointing Calibration',
#  'dry_run': False,
#  'experiment_id': '20180621-0026',
#  'horizon': 21.0,
#  'issue_id': 'MKAIV-202',
#  'max_duration': 21600.0,
#  'max_extent': 1.0,
#  'mode': None,
#  'nd_params': {'diode': 'coupler', 'off': 10, 'on': 10, 'period': 180},
#  'no_capture': False,
#  'no_mask': False,
#  'number_of_steps': 10,
#  'observer': 'Lindsay',
#  'product': 'c856M4k',
#  'program_block_id': 'MKAIV-202',
#  'projection': 'zenithal-equidistant',
#  'proposal_description': '',
#  'proposal_id': 'MKAIV-202',
#  'quorum': 0.9,
#  'reduction_label': None,
#  'sb_id_code': '20180621-0026',
#  'script_arguments': '/home/kat/katsdpcatalogues/gaincal_l_5jy.csv --horizon=20 -t 64 -m 21600 --description=MKAIV-202 Interferometric Pointing Calibration --proposal-id=MKAIV-202 --program-block-id=MKAIV-202 --issue-id=MKAIV-202 --sb-id-code=20180621-0026 --description=MKAIV-202 Interferometric Pointing Calibration --observer=Lindsay --config-label=8fec874,0334842',
#  'script_name': '/home/kat/katsdpscripts/observation/interferometric_pointing.py',
#  'start_time': None,
#  'stow_when_done': False,
#  'track_duration': 64.0}

# %%
import scape

# %% [markdown]
# ## Load static flags

# %%
#pickle_file = open('/var/kat/katsdpscripts/RTS/rfi_mask.pickle')
pickle_file = open('../katsdppipelines/katsdpcal/katsdpcal/conf/rfi_masks/rfi_mask.pickle')
rfi_static_flags = pickle.load(pickle_file)
pickle_file.close()
edge = np.tile(True,4096)
edge[slice(211,3896)] = False
static_flags = np.logical_or(edge,rfi_static_flags)

# %% [markdown]
# ## Plot timeseries, spectrograph and spectrum for each antenna

# %%
data.select()
ants = data.ants
for ant in ants:
    for active_pol in ['H','V']:
        ts_start = data.timestamps[0]
        ts_end = data.timestamps[-1]
        data.select(ants=ant.name,corrprods='auto',\
                    channels=~static_flags,pol=active_pol,dumps=slice(0,N,step),scans=['scan','track'])
        d = scape.DataSet(data)
        ts = data.timestamps - data.timestamps[0]
        figure(figsize=[15,10])
        subplot(221)
        scape.plot_xyz(d,'time','amp')
        title('Time series - Ant: %s Pol: %s'%(ant.name,active_pol))
        #yscale('log')
        #ylim(1,2000)
        subplot(222)
        scape.plot_xyz(d,'time','freq','amp')
        title('Spectrogram - Ant: %s Pol: %s'%(ant.name,active_pol))
        subplot(223)
        scape.plot_xyz(d,'freq','amp',label='Average')
        title('Spectrum - Ant: %s Pol: %s'%(ant.name,active_pol))
        #ylim(0,2000)
        subplot(224)
        scape.plot_xyz(d,'az','el')
        title('Pointing - Ant: %s Pol: %s'%(ant.name,active_pol))
# Out:
# INFO: Loading single-dish baseline 'm000,m000'
# INFO: Using 'coupler' noise diode as it is the only one firing in data set
# WARNING: Cannot find coupler noise diode H polarisation model for antenna m000 - using default.
# WARNING: Cannot find coupler noise diode V polarisation model for antenna m000 - using default.
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7fb497c74140>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7fb497c74140>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7fb497c74140>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7fb497c74140>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7fb497c74140>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7fb497c740c8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7fb497c74140>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7fb497c74140>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7fb497c74140>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7fb497c740c8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7fb497c740c8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7fb497c740c8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7fb497c740c8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7fb497c740c8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7fb497c740c8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7fb497c740c8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7fb497c6fcf8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7fb497c6fcf8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7fb497c6fcf8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7fb497c6fcf8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7fb497c6fcf8>
# DEBUG: Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7fb497c74500>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7fb497c6fcf8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7fb497c6fcf8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7fb497c6fcf8>
# DEBUG: Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7fb497c74500>
# DEBUG: Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7fb497c74500>
# DEBUG: Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7fb497c74500>
# DEBUG: Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7fb497c74500>
# DEBUG: Event before-call.s3.GetObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7fb497c74500>
# DEBUG: Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7fb497c74500>
# DEBUG: Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7fb497c74500>
# DEBUG: Event before-call.s3.GetObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-call.s3.GetObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-call.s3.GetObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-call.s3.GetObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Making request for OperationModel(name=GetObject) (verify_ssl=True) with params: {'body': '', 'url': u'http://archive-gw-1.kat.ac.za:7480/1529567823_sdp_l0/correlator_data/00007_00000_00000.npy', 'headers': {'User-Agent': 'Botocore/1.10.10 Python/2.7.6 Linux/4.4.0-128-generic'}, 'context': {'auth_type': None, 'client_region': 'default', 'signing': {'bucket': u'1529567823_sdp_l0'}, 'has_streaming_input': False, 'client_config': <botocore.config.Config object at 0x7fb49105d8d0>}, 'query_string': {}, 'url_path': u'/1529567823_sdp_l0/correlator_data/00007_00000_00000.npy', 'method': u'GET'}
# DEBUG: Event before-call.s3.GetObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-call.s3.GetObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-call.s3.GetObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Making request for OperationModel(name=GetObject) (verify_ssl=True) with params: {'body': '', 'url': u'http://archive-gw-1.kat.ac.za:7480/1529567823_sdp_l0/correlator_data/00007_01024_00000.npy', 'headers': {'User-Agent': 'Botocore/1.10.10 Python/2.7.6 Linux/4.4.0-128-generic'}, 'context': {'auth_type': None, 'client_region': 'default', 'signing': {'bucket': u'1529567823_sdp_l0'}, 'has_streaming_input': False, 'client_config': <botocore.config.Config object at 0x7fb49105d8d0>}, 'query_string': {}, 'url_path': u'/1529567823_sdp_l0/correlator_data/00007_01024_00000.npy', 'method': u'GET'}
# DEBUG: Making request for OperationModel(name=GetObject) (verify_ssl=True) with params: {'body': '', 'url': u'http://archive-gw-1.kat.ac.za:7480/1529567823_sdp_l0/correlator_data/00007_02048_00000.npy', 'headers': {'User-Agent': 'Botocore/1.10.10 Python/2.7.6 Linux/4.4.0-128-generic'}, 'context': {'auth_type': None, 'client_region': 'default', 'signing': {'bucket': u'1529567823_sdp_l0'}, 'has_streaming_input': False, 'client_config': <botocore.config.Config object at 0x7fb49105d8d0>}, 'query_string': {}, 'url_path': u'/1529567823_sdp_l0/correlator_data/00007_02048_00000.npy', 'method': u'GET'}
# DEBUG: Making request for OperationModel(name=GetObject) (verify_ssl=True) with params: {'body': '', 'url': u'http://archive-gw-1.kat.ac.za:7480/1529567823_sdp_l0/correlator_data/00007_03072_00000.npy', 'headers': {'User-Agent': 'Botocore/1.10.10 Python/2.7.6 Linux/4.4.0-128-generic'}, 'context': {'auth_type': None, 'client_region': 'default', 'signing': {'bucket': u'1529567823_sdp_l0'}, 'has_streaming_input': False, 'client_config': <botocore.config.Config object at 0x7fb49105d8d0>}, 'query_string': {}, 'url_path': u'/1529567823_sdp_l0/correlator_data/00007_03072_00000.npy', 'method': u'GET'}
# DEBUG: Making request for OperationModel(name=GetObject) (verify_ssl=True) with params: {'body': '', 'url': u'http://archive-gw-1.kat.ac.za:7480/1529567823_sdp_l0/correlator_data/00008_00000_00000.npy', 'headers': {'User-Agent': 'Botocore/1.10.10 Python/2.7.6 Linux/4.4.0-128-generic'}, 'context': {'auth_type': None, 'client_region': 'default', 'signing': {'bucket': u'1529567823_sdp_l0'}, 'has_streaming_input': False, 'client_config': <botocore.config.Config object at 0x7fb49105d8d0>}, 'query_string': {}, 'url_path': u'/1529567823_sdp_l0/correlator_data/00008_00000_00000.npy', 'method': u'GET'}
# DEBUG: Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fb49105d7d0>>
# DEBUG: Making request for OperationModel(name=GetObject) (verify_ssl=True) with params: {'body': '', 'url': u'http://archive-gw-1.kat.ac.za:7480/1529567823_sdp_l0/correlator_data/00008_01024_00000.npy', 'headers': {'User-Agent': 'Botocore/1.10.10 Python/2.7.6 Linux/4.4.0-128-generic'}, 'context': {'auth_type': None, 'client_region': 'default', 'signing': {'bucket': u'1529567823_sdp_l0'}, 'has_streaming_input': False, 'client_config': <botocore.config.Config object at 0x7fb49105d8d0>}, 'query_string': {}, 'url_path': u'/1529567823_sdp_l0/correlator_data/00008_01024_00000.npy', 'method': u'GET'}
# DEBUG: Making request for OperationModel(name=GetObject) (verify_ssl=True) with params: {'body': '', 'url': u'http://archive-gw-1.kat.ac.za:7480/1529567823_sdp_l0/correlator_data/00008_02048_00000.npy', 'headers': {'User-Agent': 'Botocore/1.10.10 Python/2.7.6 Linux/4.4.0-128-generic'}, 'context': {'auth_type': None, 'client_region': 'default', 'signing': {'bucket': u'1529567823_sdp_l0'}, 'has_streaming_input': False, 'client_config': <botocore.config.Config object at 0x7fb49105d8d0>}, 'query_string': {}, 'url_path': u'/1529567823_sdp_l0/correlator_data/00008_02048_00000.npy', 'method': u'GET'}
# DEBUG: Making request for OperationModel(name=GetObject) (verify_ssl=True) with params: {'body': '', 'url': u'http://archive-gw-1.kat.ac.za:7480/1529567823_sdp_l0/correlator_data/00008_03072_00000.npy', 'headers': {'User-Agent': 'Botocore/1.10.10 Python/2.7.6 Linux/4.4.0-128-generic'}, 'context': {'auth_type': None, 'client_region': 'default', 'signing': {'bucket': u'1529567823_sdp_l0'}, 'has_streaming_input': False, 'client_config': <botocore.config.Config object at 0x7fb49105d8d0>}, 'query_string': {}, 'url_path': u'/1529567823_sdp_l0/correlator_data/00008_03072_00000.npy', 'method': u'GET'}
# DEBUG: Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fb49105d7d0>>
# DEBUG: Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fb49105d7d0>>
# DEBUG: Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fb49105d7d0>>
# DEBUG: Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fb49105d7d0>>
# DEBUG: Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fb497c6fc08>
# DEBUG: Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fb49105d7d0>>
# DEBUG: Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fb49105d7d0>>
# DEBUG: Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fb49105d7d0>>
# DEBUG: Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fb497c6fc08>
# DEBUG: Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fb497c6fc08>
# DEBUG: Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fb497c6fc08>
# DEBUG: Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fb497c6fc08>
# DEBUG: Calculating signature using v4 auth.
# DEBUG: Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fb497c6fc08>
# DEBUG: Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fb497c6fc08>
# DEBUG: Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fb497c6fc08>
# DEBUG: Calculating signature using v4 auth.
# DEBUG: Calculating signature using v4 auth.
# DEBUG: Calculating signature using v4 auth.
# DEBUG: Calculating signature using v4 auth.
# DEBUG: CanonicalRequest:
# GET
# /1529567823_sdp_l0/correlator_data/00007_00000_00000.npy
#
# host:archive-gw-1.kat.ac.za:7480
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20180622T122646Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG: Calculating signature using v4 auth.
# DEBUG: Calculating signature using v4 auth.
# DEBUG: Calculating signature using v4 auth.
# DEBUG: CanonicalRequest:
# GET
# /1529567823_sdp_l0/correlator_data/00007_01024_00000.npy
#
# host:archive-gw-1.kat.ac.za:7480
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20180622T122646Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG: CanonicalRequest:
# GET
# /1529567823_sdp_l0/correlator_data/00007_02048_00000.npy
#
# host:archive-gw-1.kat.ac.za:7480
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20180622T122646Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG: CanonicalRequest:
# GET
# /1529567823_sdp_l0/correlator_data/00007_03072_00000.npy
#
# host:archive-gw-1.kat.ac.za:7480
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20180622T122646Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG: CanonicalRequest:
# GET
# /1529567823_sdp_l0/correlator_data/00008_00000_00000.npy
#
# host:archive-gw-1.kat.ac.za:7480
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20180622T122646Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122646Z
# 20180622/default/s3/aws4_request
# 6f84da413125720cf28ad36c523feb725283542020860621e5dca88a9a1358da
# DEBUG: CanonicalRequest:
# GET
# /1529567823_sdp_l0/correlator_data/00008_01024_00000.npy
#
# host:archive-gw-1.kat.ac.za:7480
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20180622T122646Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG: CanonicalRequest:
# GET
# /1529567823_sdp_l0/correlator_data/00008_02048_00000.npy
#
# host:archive-gw-1.kat.ac.za:7480
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20180622T122646Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG: CanonicalRequest:
# GET
# /1529567823_sdp_l0/correlator_data/00008_03072_00000.npy
#
# host:archive-gw-1.kat.ac.za:7480
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20180622T122646Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122646Z
# 20180622/default/s3/aws4_request
# e28ee90492ce9d0a58cf91e2c3bd6b13b7019033dcfd30d4153f17b723abb9bb
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122646Z
# 20180622/default/s3/aws4_request
# 9e246f9867b563d06cdf37745a95deb06dab0c5c422075552aa09d6859a75380
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122646Z
# 20180622/default/s3/aws4_request
# 5a174b99940759cbafcd72e1b953c3057a11389d806fbe08d1571942b706d064
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122646Z
# 20180622/default/s3/aws4_request
# c4de5f8576f493385a51d23f294109f225d04d138885a16a35125f75ca249c98
# DEBUG: Signature:
# 730c7517154854944c7cd4444a1c81ed7e280c389e2a254210bab216eb450c20
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122646Z
# 20180622/default/s3/aws4_request
# 6ae6c2f08d5a157a33b486ac6bc57f47807bdfd631586156bedb1dee3c9f78d8
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122646Z
# 20180622/default/s3/aws4_request
# b3b82e187489b75994c6dc3746352ca2b9ac194d96f9eed31bb25ab58dc8b43b
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122646Z
# 20180622/default/s3/aws4_request
# 276ff69221012ddaafec95ec7f59db8a92ff27ed3b783822e2f4cb185ee1d69a
# DEBUG: Signature:
# d52af416d5873bada15d23302cc36b11be46fac77be084cca78214d5561e9cb2
# DEBUG: Signature:
# 4afddcebb3e6384e72654fb55c26be5d7eb1cd6e7cdb7ad731a4c475e0317f33
# DEBUG: Signature:
# 8bf95184c982ff265cb62ea6ffcbe3818a3170c2b47a578083a7a6758b3467fc
# DEBUG: Signature:
# 9805e426c751875d85d1337ca26a1501cb7c2c46ec281706740ee7551158c570
# DEBUG: Sending http request: <PreparedRequest [GET]>
# DEBUG: Signature:
# 66ef69724a19ee33c4b388ed12560ddc100cc3a483fb8ebc369d4db080ebe9a6
# DEBUG: Signature:
# e945578aee7d5ac82c62f0b455188c49c70b8a78d2173da9a99aa2ef0718a6c9
# DEBUG: Signature:
# b39ec2c4fd95ecd24cdbfdab5041ddb14ecff7761145df8de4eb77bb94f3b800
# DEBUG: Sending http request: <PreparedRequest [GET]>
# DEBUG: Sending http request: <PreparedRequest [GET]>
# DEBUG: Sending http request: <PreparedRequest [GET]>
# DEBUG: Sending http request: <PreparedRequest [GET]>
# INFO: Resetting dropped connection: archive-gw-1.kat.ac.za
# DEBUG: Sending http request: <PreparedRequest [GET]>
# DEBUG: Sending http request: <PreparedRequest [GET]>
# DEBUG: Sending http request: <PreparedRequest [GET]>
# INFO: Starting new HTTP connection (2): archive-gw-1.kat.ac.za
# INFO: Starting new HTTP connection (3): archive-gw-1.kat.ac.za
# INFO: Starting new HTTP connection (4): archive-gw-1.kat.ac.za
# INFO: Starting new HTTP connection (5): archive-gw-1.kat.ac.za
# INFO: Starting new HTTP connection (6): archive-gw-1.kat.ac.za
# INFO: Starting new HTTP connection (7): archive-gw-1.kat.ac.za
# INFO: Starting new HTTP connection (8): archive-gw-1.kat.ac.za
# DEBUG: "GET /1529567823_sdp_l0/correlator_data/00007_00000_00000.npy HTTP/1.1" 200 1179728
# DEBUG: Response headers: {'content-length': '1179728', 'accept-ranges': 'bytes', 'last-modified': 'Thu, 21 Jun 2018 07:58:34 GMT', 'etag': '"02c96e01ac153ca2fa0ed4dd3daf03da"', 'x-amz-request-id': 'tx00000000000000003c819-005b2ceb06-8c099-default', 'date': 'Fri, 22 Jun 2018 12:26:46 GMT', 'content-type': 'application/octet-stream'}
# DEBUG: Response body:
# <botocore.response.StreamingBody object at 0x7fb48a75f910>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fb49108bb50>
# DEBUG: No retry needed.
# DEBUG: Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: "GET /1529567823_sdp_l0/correlator_data/00007_03072_00000.npy HTTP/1.1" 200 1179728
# DEBUG: "GET /1529567823_sdp_l0/correlator_data/00007_02048_00000.npy HTTP/1.1" 200 1179728
# DEBUG: "GET /1529567823_sdp_l0/correlator_data/00008_03072_00000.npy HTTP/1.1" 200 1179728
# DEBUG: "GET /1529567823_sdp_l0/correlator_data/00008_02048_00000.npy HTTP/1.1" 200 1179728
# DEBUG: "GET /1529567823_sdp_l0/correlator_data/00008_01024_00000.npy HTTP/1.1" 200 1179728
# DEBUG: Response headers: {'content-length': '1179728', 'accept-ranges': 'bytes', 'last-modified': 'Thu, 21 Jun 2018 07:58:34 GMT', 'etag': '"2dbb3f583d8ca39f269f1258490b5ce5"', 'x-amz-request-id': 'tx00000000000000003c81a-005b2ceb06-8c099-default', 'date': 'Fri, 22 Jun 2018 12:26:46 GMT', 'content-type': 'application/octet-stream'}
# DEBUG: Response headers: {'content-length': '1179728', 'accept-ranges': 'bytes', 'last-modified': 'Thu, 21 Jun 2018 07:58:35 GMT', 'etag': '"28b2eb46a1ca7e2f95d1d23e8e9968de"', 'x-amz-request-id': 'tx00000000000000003c81a-005b2ceb06-8666e-default', 'date': 'Fri, 22 Jun 2018 12:26:46 GMT', 'content-type': 'application/octet-stream'}
# DEBUG: Response headers: {'content-length': '1179728', 'accept-ranges': 'bytes', 'last-modified': 'Thu, 21 Jun 2018 07:58:34 GMT', 'etag': '"1756df26dc8adb35b913c08e9234115b"', 'x-amz-request-id': 'tx00000000000000003c81b-005b2ceb06-8c0e1-default', 'date': 'Fri, 22 Jun 2018 12:26:46 GMT', 'content-type': 'application/octet-stream'}
# DEBUG: Response headers: {'content-length': '1179728', 'accept-ranges': 'bytes', 'last-modified': 'Thu, 21 Jun 2018 07:58:34 GMT', 'etag': '"af6dff8fbc4be0593612f8783c0448a6"', 'x-amz-request-id': 'tx00000000000000003c81b-005b2ceb06-8c099-default', 'date': 'Fri, 22 Jun 2018 12:26:46 GMT', 'content-type': 'application/octet-stream'}
# DEBUG: Response headers: {'content-length': '1179728', 'accept-ranges': 'bytes', 'last-modified': 'Thu, 21 Jun 2018 07:58:34 GMT', 'etag': '"d9f3e706f31581edc05d0602be3ee6a5"', 'x-amz-request-id': 'tx00000000000000003c81b-005b2ceb06-8666e-default', 'date': 'Fri, 22 Jun 2018 12:26:46 GMT', 'content-type': 'application/octet-stream'}
# DEBUG: Response body:
# <botocore.response.StreamingBody object at 0x7fb48a669f50>
# DEBUG: Response body:
# <botocore.response.StreamingBody object at 0x7fb48a75fe50>
# DEBUG: "GET /1529567823_sdp_l0/correlator_data/00008_00000_00000.npy HTTP/1.1" 200 1179728
# DEBUG: Response body:
# <botocore.response.StreamingBody object at 0x7fb48a75fbd0>
# DEBUG: Response body:
# <botocore.response.StreamingBody object at 0x7fb48a75fb10>
# DEBUG: Response body:
# <botocore.response.StreamingBody object at 0x7fb48a75fa90>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fb49108bb50>
# DEBUG: "GET /1529567823_sdp_l0/correlator_data/00007_01024_00000.npy HTTP/1.1" 200 1179728
# DEBUG: Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fb49108bb50>
# DEBUG: Response headers: {'content-length': '1179728', 'accept-ranges': 'bytes', 'last-modified': 'Thu, 21 Jun 2018 07:58:34 GMT', 'etag': '"ab8bdd3b998e6dc605d903b482fc0428"', 'x-amz-request-id': 'tx00000000000000003c81a-005b2ceb06-8c0e1-default', 'date': 'Fri, 22 Jun 2018 12:26:46 GMT', 'content-type': 'application/octet-stream'}
# DEBUG: Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fb49108bb50>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fb49108bb50>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fb49108bb50>
# DEBUG: No retry needed.
# DEBUG: Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: No retry needed.
# DEBUG: Response body:
# <botocore.response.StreamingBody object at 0x7fb48a675050>
# DEBUG: No retry needed.
# DEBUG: No retry needed.
# DEBUG: No retry needed.
# DEBUG: Response headers: {'content-length': '1179728', 'accept-ranges': 'bytes', 'last-modified': 'Thu, 21 Jun 2018 07:58:34 GMT', 'etag': '"fe05e0308fd35e16b1beda0fa80152b5"', 'x-amz-request-id': 'tx00000000000000003c819-005b2ceb06-8c0e1-default', 'date': 'Fri, 22 Jun 2018 12:26:46 GMT', 'content-type': 'application/octet-stream'}
# DEBUG: Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fb49108bb50>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7fb497c74140>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Response body:
# <botocore.response.StreamingBody object at 0x7fb48a6ece10>
# DEBUG: No retry needed.
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7fb497c740c8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7fb497c74140>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fb49108bb50>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7fb497c740c8>
# DEBUG: No retry needed.
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7fb497c6fcf8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7fb497c74500>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7fb497c74140>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7fb497c6fcf8>
# DEBUG: Event before-call.s3.GetObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7fb497c740c8>
# DEBUG: Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7fb497c74500>
# DEBUG: Making request for OperationModel(name=GetObject) (verify_ssl=True) with params: {'body': '', 'url': u'http://archive-gw-1.kat.ac.za:7480/1529567823_sdp_l0/correlator_data/00009_00000_00000.npy', 'headers': {'User-Agent': 'Botocore/1.10.10 Python/2.7.6 Linux/4.4.0-128-generic'}, 'context': {'auth_type': None, 'client_region': 'default', 'signing': {'bucket': u'1529567823_sdp_l0'}, 'has_streaming_input': False, 'client_config': <botocore.config.Config object at 0x7fb49105d8d0>}, 'query_string': {}, 'url_path': u'/1529567823_sdp_l0/correlator_data/00009_00000_00000.npy', 'method': u'GET'}
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-call.s3.GetObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fb49105d7d0>>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7fb497c6fcf8>
# DEBUG: Making request for OperationModel(name=GetObject) (verify_ssl=True) with params: {'body': '', 'url': u'http://archive-gw-1.kat.ac.za:7480/1529567823_sdp_l0/correlator_data/00009_01024_00000.npy', 'headers': {'User-Agent': 'Botocore/1.10.10 Python/2.7.6 Linux/4.4.0-128-generic'}, 'context': {'auth_type': None, 'client_region': 'default', 'signing': {'bucket': u'1529567823_sdp_l0'}, 'has_streaming_input': False, 'client_config': <botocore.config.Config object at 0x7fb49105d8d0>}, 'query_string': {}, 'url_path': u'/1529567823_sdp_l0/correlator_data/00009_01024_00000.npy', 'method': u'GET'}
# DEBUG: Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fb497c6fc08>
# DEBUG: Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7fb497c74500>
# DEBUG: Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fb49105d7d0>>
# DEBUG: Calculating signature using v4 auth.
# DEBUG: Event before-call.s3.GetObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fb497c6fc08>
# DEBUG: CanonicalRequest:
# GET
# /1529567823_sdp_l0/correlator_data/00009_00000_00000.npy
#
# host:archive-gw-1.kat.ac.za:7480
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20180622T122646Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG: Making request for OperationModel(name=GetObject) (verify_ssl=True) with params: {'body': '', 'url': u'http://archive-gw-1.kat.ac.za:7480/1529567823_sdp_l0/correlator_data/00009_02048_00000.npy', 'headers': {'User-Agent': 'Botocore/1.10.10 Python/2.7.6 Linux/4.4.0-128-generic'}, 'context': {'auth_type': None, 'client_region': 'default', 'signing': {'bucket': u'1529567823_sdp_l0'}, 'has_streaming_input': False, 'client_config': <botocore.config.Config object at 0x7fb49105d8d0>}, 'query_string': {}, 'url_path': u'/1529567823_sdp_l0/correlator_data/00009_02048_00000.npy', 'method': u'GET'}
# DEBUG: Calculating signature using v4 auth.
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122646Z
# 20180622/default/s3/aws4_request
# 6412a9265e89a55e60c3e3f3a26af25573d5c0d736eceaafbf633711d9206df6
# DEBUG: Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fb49105d7d0>>
# DEBUG: CanonicalRequest:
# GET
# /1529567823_sdp_l0/correlator_data/00009_01024_00000.npy
#
# host:archive-gw-1.kat.ac.za:7480
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20180622T122646Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG: Signature:
# 05aaf48d9cf03295f4839c20c1854da06775bdecb1698116235793408fd676ff
# DEBUG: Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fb497c6fc08>
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122646Z
# 20180622/default/s3/aws4_request
# 2590f1034b1af25b3b5224c1bc949aed1e8053fb2abf10e9e2d2485768a68ba5
# DEBUG: Sending http request: <PreparedRequest [GET]>
# DEBUG: Calculating signature using v4 auth.
# DEBUG: Signature:
# a035b81b33397a8ac1df0c26d7b8684a903a7a3fe0f735731c094714782fd2ae
# DEBUG: CanonicalRequest:
# GET
# /1529567823_sdp_l0/correlator_data/00009_02048_00000.npy
#
# host:archive-gw-1.kat.ac.za:7480
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20180622T122646Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7fb497c74140>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7fb497c74140>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7fb497c74140>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7fb497c74140>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x7fb497c74140>
# DEBUG: Sending http request: <PreparedRequest [GET]>
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122646Z
# 20180622/default/s3/aws4_request
# 342770e877859e3a9335e14349e646aa387c348e091fa04742af5428ac898eb4
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7fb497c740c8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7fb497c740c8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7fb497c740c8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7fb497c740c8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x7fb497c740c8>
# DEBUG: Signature:
# 091f4edd4a6c80c9326459d15f1d5f8afc09df89105cce8e755f51c049f58152
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_cache of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Sending http request: <PreparedRequest [GET]>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7fb497c6fcf8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7fb497c6fcf8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7fb497c6fcf8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7fb497c6fcf8>
# DEBUG: Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x7fb497c6fcf8>
# DEBUG: Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7fb497c74500>
# DEBUG: Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7fb497c74500>
# DEBUG: Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7fb497c74500>
# DEBUG: Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7fb497c74500>
# DEBUG: Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x7fb497c74500>
# DEBUG: Event before-call.s3.GetObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-call.s3.GetObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-call.s3.GetObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-call.s3.GetObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event before-call.s3.GetObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Making request for OperationModel(name=GetObject) (verify_ssl=True) with params: {'body': '', 'url': u'http://archive-gw-1.kat.ac.za:7480/1529567823_sdp_l0/correlator_data/00009_03072_00000.npy', 'headers': {'User-Agent': 'Botocore/1.10.10 Python/2.7.6 Linux/4.4.0-128-generic'}, 'context': {'auth_type': None, 'client_region': 'default', 'signing': {'bucket': u'1529567823_sdp_l0'}, 'has_streaming_input': False, 'client_config': <botocore.config.Config object at 0x7fb49105d8d0>}, 'query_string': {}, 'url_path': u'/1529567823_sdp_l0/correlator_data/00009_03072_00000.npy', 'method': u'GET'}
# DEBUG: Making request for OperationModel(name=GetObject) (verify_ssl=True) with params: {'body': '', 'url': u'http://archive-gw-1.kat.ac.za:7480/1529567823_sdp_l0/correlator_data/00010_00000_00000.npy', 'headers': {'User-Agent': 'Botocore/1.10.10 Python/2.7.6 Linux/4.4.0-128-generic'}, 'context': {'auth_type': None, 'client_region': 'default', 'signing': {'bucket': u'1529567823_sdp_l0'}, 'has_streaming_input': False, 'client_config': <botocore.config.Config object at 0x7fb49105d8d0>}, 'query_string': {}, 'url_path': u'/1529567823_sdp_l0/correlator_data/00010_00000_00000.npy', 'method': u'GET'}
# DEBUG: Making request for OperationModel(name=GetObject) (verify_ssl=True) with params: {'body': '', 'url': u'http://archive-gw-1.kat.ac.za:7480/1529567823_sdp_l0/correlator_data/00010_01024_00000.npy', 'headers': {'User-Agent': 'Botocore/1.10.10 Python/2.7.6 Linux/4.4.0-128-generic'}, 'context': {'auth_type': None, 'client_region': 'default', 'signing': {'bucket': u'1529567823_sdp_l0'}, 'has_streaming_input': False, 'client_config': <botocore.config.Config object at 0x7fb49105d8d0>}, 'query_string': {}, 'url_path': u'/1529567823_sdp_l0/correlator_data/00010_01024_00000.npy', 'method': u'GET'}
# DEBUG: Making request for OperationModel(name=GetObject) (verify_ssl=True) with params: {'body': '', 'url': u'http://archive-gw-1.kat.ac.za:7480/1529567823_sdp_l0/correlator_data/00010_02048_00000.npy', 'headers': {'User-Agent': 'Botocore/1.10.10 Python/2.7.6 Linux/4.4.0-128-generic'}, 'context': {'auth_type': None, 'client_region': 'default', 'signing': {'bucket': u'1529567823_sdp_l0'}, 'has_streaming_input': False, 'client_config': <botocore.config.Config object at 0x7fb49105d8d0>}, 'query_string': {}, 'url_path': u'/1529567823_sdp_l0/correlator_data/00010_02048_00000.npy', 'method': u'GET'}
# DEBUG: Making request for OperationModel(name=GetObject) (verify_ssl=True) with params: {'body': '', 'url': u'http://archive-gw-1.kat.ac.za:7480/1529567823_sdp_l0/correlator_data/00010_03072_00000.npy', 'headers': {'User-Agent': 'Botocore/1.10.10 Python/2.7.6 Linux/4.4.0-128-generic'}, 'context': {'auth_type': None, 'client_region': 'default', 'signing': {'bucket': u'1529567823_sdp_l0'}, 'has_streaming_input': False, 'client_config': <botocore.config.Config object at 0x7fb49105d8d0>}, 'query_string': {}, 'url_path': u'/1529567823_sdp_l0/correlator_data/00010_03072_00000.npy', 'method': u'GET'}
# DEBUG: Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fb49105d7d0>>
# DEBUG: Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fb49105d7d0>>
# DEBUG: Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fb49105d7d0>>
# DEBUG: Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fb49105d7d0>>
# DEBUG: Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fb49105d7d0>>
# DEBUG: Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fb497c6fc08>
# DEBUG: Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fb497c6fc08>
# DEBUG: Calculating signature using v4 auth.
# DEBUG: Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fb497c6fc08>
# DEBUG: Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fb497c6fc08>
# DEBUG: Calculating signature using v4 auth.
# DEBUG: Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fb497c6fc08>
# DEBUG: CanonicalRequest:
# GET
# /1529567823_sdp_l0/correlator_data/00010_00000_00000.npy
#
# host:archive-gw-1.kat.ac.za:7480
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20180622T122647Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG: Calculating signature using v4 auth.
# DEBUG: Calculating signature using v4 auth.
# DEBUG: CanonicalRequest:
# GET
# /1529567823_sdp_l0/correlator_data/00009_03072_00000.npy
#
# host:archive-gw-1.kat.ac.za:7480
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20180622T122647Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG: Calculating signature using v4 auth.
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122647Z
# 20180622/default/s3/aws4_request
# 04645f21585668b30b6f432dd316f8dc30fbddde29e869aaa6ec86af13863415
# DEBUG: CanonicalRequest:
# GET
# /1529567823_sdp_l0/correlator_data/00010_02048_00000.npy
#
# host:archive-gw-1.kat.ac.za:7480
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20180622T122647Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG: CanonicalRequest:
# GET
# /1529567823_sdp_l0/correlator_data/00010_03072_00000.npy
#
# host:archive-gw-1.kat.ac.za:7480
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20180622T122647Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG: "GET /1529567823_sdp_l0/correlator_data/00009_00000_00000.npy HTTP/1.1" 200 1179728
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122647Z
# 20180622/default/s3/aws4_request
# 92f015c1a0be6707d17041b2790600bf8bbc00c2d66735de18b846a33333ad04
# DEBUG: CanonicalRequest:
# GET
# /1529567823_sdp_l0/correlator_data/00010_01024_00000.npy
#
# host:archive-gw-1.kat.ac.za:7480
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20180622T122647Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG: Signature:
# 60fbab26c858ded29c94582ad3e5d1b1852c6ee32bc3c679ff86e9f9e663ae0c
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122647Z
# 20180622/default/s3/aws4_request
# fc02f6f1d880c543aa0c434d1ce98f22f5bd263eed4cc120d7c166d5791a58cc
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122647Z
# 20180622/default/s3/aws4_request
# 27bce4b46396b061d4b6f073fcff1795194c681e3a50d39077e16d06105def07
# DEBUG: "GET /1529567823_sdp_l0/correlator_data/00009_01024_00000.npy HTTP/1.1" 200 1179728
# DEBUG: Response headers: {'content-length': '1179728', 'accept-ranges': 'bytes', 'last-modified': 'Thu, 21 Jun 2018 07:58:36 GMT', 'etag': '"d3724c51ad9c49a0be7719a54d07664a"', 'x-amz-request-id': 'tx00000000000000003c81d-005b2ceb07-8c0e1-default', 'date': 'Fri, 22 Jun 2018 12:26:47 GMT', 'content-type': 'application/octet-stream'}
# DEBUG: Signature:
# 6802dccaf5977c3bce90c335d861283c03351b963b8a19c1fc51b90eaecb53c3
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122647Z
# 20180622/default/s3/aws4_request
# 81dc9b5a30100fdb198c5880790d11170c650eaf55dd1ac335199b8ff8ca4c13
# DEBUG: Sending http request: <PreparedRequest [GET]>
# DEBUG: Signature:
# b8dd90a43dd3ff4811ba43fe7e64497197b4d5c6b621fd311db0d220fd0f6e98
# DEBUG: Signature:
# f5e97fddcba5c97a2849d2792b40dfb8dcc6d9c5a5a45e2b0299cac4edca31e3
# DEBUG: Response headers: {'content-length': '1179728', 'accept-ranges': 'bytes', 'last-modified': 'Thu, 21 Jun 2018 07:58:36 GMT', 'etag': '"8818cba10b4fd4dd4f084b4ece65e8b5"', 'x-amz-request-id': 'tx00000000000000003c81e-005b2ceb07-8c099-default', 'date': 'Fri, 22 Jun 2018 12:26:47 GMT', 'content-type': 'application/octet-stream'}
# DEBUG: Response body:
# <botocore.response.StreamingBody object at 0x7fb48a650ad0>
# DEBUG: "GET /1529567823_sdp_l0/correlator_data/00009_02048_00000.npy HTTP/1.1" 200 1179728
# DEBUG: Sending http request: <PreparedRequest [GET]>
# DEBUG: Signature:
# a35540607fcc0f8827ca81d10c0645d12b1fc1eb108e84f5bea25950bc7ae129
# DEBUG: Sending http request: <PreparedRequest [GET]>
# DEBUG: Sending http request: <PreparedRequest [GET]>
# DEBUG: Response body:
# <botocore.response.StreamingBody object at 0x7fb48a75fd90>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fb49108bb50>
# DEBUG: Response headers: {'content-length': '1179728', 'accept-ranges': 'bytes', 'last-modified': 'Thu, 21 Jun 2018 07:58:36 GMT', 'etag': '"c6eab685b2cfdc1f1805f6b42fa97b46"', 'x-amz-request-id': 'tx00000000000000003c81e-005b2ceb07-8c0e1-default', 'date': 'Fri, 22 Jun 2018 12:26:47 GMT', 'content-type': 'application/octet-stream'}
# DEBUG: Sending http request: <PreparedRequest [GET]>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fb49108bb50>
# DEBUG: No retry needed.
# DEBUG: Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: No retry needed.
# DEBUG: Response body:
# <botocore.response.StreamingBody object at 0x7fb48a75fc50>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fb49108bb50>
# DEBUG: No retry needed.
# DEBUG: Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: "GET /1529567823_sdp_l0/correlator_data/00010_02048_00000.npy HTTP/1.1" 200 1179728
# DEBUG: Response headers: {'content-length': '1179728', 'accept-ranges': 'bytes', 'last-modified': 'Thu, 21 Jun 2018 07:58:58 GMT', 'etag': '"e86b08cc3919154c719ba8714eb62b32"', 'x-amz-request-id': 'tx00000000000000003c820-005b2ceb07-8666e-default', 'date': 'Fri, 22 Jun 2018 12:26:47 GMT', 'content-type': 'application/octet-stream'}
# DEBUG: "GET /1529567823_sdp_l0/correlator_data/00010_00000_00000.npy HTTP/1.1" 200 1179728
# DEBUG: Response body:
# <botocore.response.StreamingBody object at 0x7fb48a75f150>
# ...
# DEBUG: Making request for OperationModel(name=GetObject) (verify_ssl=True) with params: {'body': '', 'url': u'http://archive-gw-1.kat.ac.za:7480/1529567823_sdp_l0/correlator_data/00014_02048_00000.npy', 'headers': {'User-Agent': 'Botocore/1.10.10 Python/2.7.6 Linux/4.4.0-128-generic'}, 'context': {'auth_type': None, 'client_region': 'default', 'signing': {'bucket': u'1529567823_sdp_l0'}, 'has_streaming_input': False, 'client_config': <botocore.config.Config object at 0x7fb49105d8d0>}, 'query_string': {}, 'url_path': u'/1529567823_sdp_l0/correlator_data/00014_02048_00000.npy', 'method': u'GET'}
# DEBUG: Calculating signature using v4 auth.
# DEBUG: CanonicalRequest:
# GET
# /1529567823_sdp_l0/correlator_data/00013_03072_00000.npy
#
# host:archive-gw-1.kat.ac.za:7480
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20180622T122647Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG: Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fb49105d7d0>>
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122647Z
# 20180622/default/s3/aws4_request
# cbea867720b8cba0b5dbfea65a34f9ea812d4e690682b24845f241c346a5bd18
# DEBUG: Signature:
# 1f087159b1d669753b7990e071e821008897c9625960e65e0e3e7b4ff37ed5ea
# DEBUG: Event before-call.s3.GetObject: calling handler <bound method S3RegionRedirector.set_request_url of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fb497c6fc08>
# DEBUG: Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fb49105d7d0>>
# DEBUG: CanonicalRequest:
# GET
# /1529567823_sdp_l0/correlator_data/00013_02048_00000.npy
#
# host:archive-gw-1.kat.ac.za:7480
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20180622T122647Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122647Z
# 20180622/default/s3/aws4_request
# 404b4690095f3d7d906efa954d934ffb9a866a5c6845360c7475d27be0c79486
# DEBUG: Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fb497c6fc08>
# DEBUG: Signature:
# 520e88a713c9c0d3802f61323ef8d5e1dd8d943509a6dcebebe703913532d032
# DEBUG: Sending http request: <PreparedRequest [GET]>
# DEBUG: Making request for OperationModel(name=GetObject) (verify_ssl=True) with params: {'body': '', 'url': u'http://archive-gw-1.kat.ac.za:7480/1529567823_sdp_l0/correlator_data/00014_03072_00000.npy', 'headers': {'User-Agent': 'Botocore/1.10.10 Python/2.7.6 Linux/4.4.0-128-generic'}, 'context': {'auth_type': None, 'client_region': 'default', 'signing': {'bucket': u'1529567823_sdp_l0'}, 'has_streaming_input': False, 'client_config': <botocore.config.Config object at 0x7fb49105d8d0>}, 'query_string': {}, 'url_path': u'/1529567823_sdp_l0/correlator_data/00014_03072_00000.npy', 'method': u'GET'}
# DEBUG: Calculating signature using v4 auth.
# DEBUG: Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fb497c6fc08>
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122647Z
# 20180622/default/s3/aws4_request
# ac42089430d76cee0c0cbb05b8cf0cbf615f6d85feb8bb0ee1b6d6e78e4e4cd6
# DEBUG: Signature:
# a635f7711e300c60bcf6d29471e4d2a6357e39aaa07139cd30d1f735bbe41a09
# DEBUG: Calculating signature using v4 auth.
# DEBUG: Sending http request: <PreparedRequest [GET]>
# DEBUG: Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x7fb49105d7d0>>
# DEBUG: CanonicalRequest:
# GET
# /1529567823_sdp_l0/correlator_data/00014_00000_00000.npy
#
# host:archive-gw-1.kat.ac.za:7480
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20180622T122647Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG: Calculating signature using v4 auth.
# DEBUG: Signature:
# 4d299ad4fd3915a292fae12e85d5501125c93d17096fd558c03a5c1f6139f8aa
# DEBUG: Sending http request: <PreparedRequest [GET]>
# DEBUG: CanonicalRequest:
# GET
# /1529567823_sdp_l0/correlator_data/00014_01024_00000.npy
#
# host:archive-gw-1.kat.ac.za:7480
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20180622T122647Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG: Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x7fb497c6fc08>
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122647Z
# 20180622/default/s3/aws4_request
# f074441d890d822fb5a460d2aeac2dae49785eea296f4f098826c21565b1ed77
# DEBUG: CanonicalRequest:
# GET
# /1529567823_sdp_l0/correlator_data/00014_02048_00000.npy
#
# host:archive-gw-1.kat.ac.za:7480
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20180622T122647Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG: Sending http request: <PreparedRequest [GET]>
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122647Z
# 20180622/default/s3/aws4_request
# 3f997b773af3d6b86af9dcb2b194e3b9adca0212e4e3a7b46efc5c66b30dc8e9
# DEBUG: Calculating signature using v4 auth.
# DEBUG: Signature:
# dcb74ad10cabc4a04454c5a6000c8905b7ec8e61d34c54734cd191a8299a906d
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122647Z
# 20180622/default/s3/aws4_request
# 2f940f5950127a433a68f835f1cfba588bb54bd44d823c6aff450c048a9e2aab
# DEBUG: Signature:
# 15bfb1bd59c42150069cbcd3ce5eb3531b77c1ef40bd33c529dc187f88d047e6
# DEBUG: CanonicalRequest:
# GET
# /1529567823_sdp_l0/correlator_data/00014_03072_00000.npy
#
# host:archive-gw-1.kat.ac.za:7480
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20180622T122647Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# DEBUG: Sending http request: <PreparedRequest [GET]>
# DEBUG: Signature:
# b14ed94364eb7da750c11f19a025dabb796b58dff712f0e3a1aa82b354532986
# DEBUG: Sending http request: <PreparedRequest [GET]>
# DEBUG: StringToSign:
# AWS4-HMAC-SHA256
# 20180622T122647Z
# 20180622/default/s3/aws4_request
# b001f1199019b02c4bb4db7770021a3a76e05b267a05b9a3f44cd74e5b209350
# DEBUG: Sending http request: <PreparedRequest [GET]>
# DEBUG: "GET /1529567823_sdp_l0/correlator_data/00013_00000_00000.npy HTTP/1.1" 200 1179728
# DEBUG: Signature:
# e2b7e239ced37d72afc43c179c2e3bf6739ff302c552b877c5c535d6d3d38073
# DEBUG: Response headers: {'content-length': '1179728', 'accept-ranges': 'bytes', 'last-modified': 'Thu, 21 Jun 2018 07:59:19 GMT', 'etag': '"e3f5183973ae12aee036bc0528b062e7"', 'x-amz-request-id': 'tx00000000000000003c824-005b2ceb07-8c099-default', 'date': 'Fri, 22 Jun 2018 12:26:47 GMT', 'content-type': 'application/octet-stream'}
# DEBUG: Sending http request: <PreparedRequest [GET]>
# DEBUG: Response body:
# <botocore.response.StreamingBody object at 0x7fb48a686410>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fb49108bb50>
# DEBUG: No retry needed.
# DEBUG: "GET /1529567823_sdp_l0/correlator_data/00013_02048_00000.npy HTTP/1.1" 200 1179728
# DEBUG: Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Response headers: {'content-length': '1179728', 'accept-ranges': 'bytes', 'last-modified': 'Thu, 21 Jun 2018 07:59:20 GMT', 'etag': '"d42e947f7ac6f5118eacdf9456391213"', 'x-amz-request-id': 'tx00000000000000003c825-005b2ceb07-8c099-default', 'date': 'Fri, 22 Jun 2018 12:26:47 GMT', 'content-type': 'application/octet-stream'}
# DEBUG: Response body:
# <botocore.response.StreamingBody object at 0x7fb48a686850>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fb49108bb50>
# DEBUG: No retry needed.
# DEBUG: Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: "GET /1529567823_sdp_l0/correlator_data/00014_00000_00000.npy HTTP/1.1" 200 1179728
# DEBUG: "GET /1529567823_sdp_l0/correlator_data/00013_01024_00000.npy HTTP/1.1" 200 1179728
# DEBUG: Response headers: {'content-length': '1179728', 'accept-ranges': 'bytes', 'last-modified': 'Thu, 21 Jun 2018 07:59:20 GMT', 'etag': '"aa1f43c8df30e644588dece73a756412"', 'x-amz-request-id': 'tx00000000000000003c824-005b2ceb07-8c0e1-default', 'date': 'Fri, 22 Jun 2018 12:26:47 GMT', 'content-type': 'application/octet-stream'}
# DEBUG: Response headers: {'content-length': '1179728', 'accept-ranges': 'bytes', 'last-modified': 'Thu, 21 Jun 2018 07:59:20 GMT', 'etag': '"4b4c2a99d74a32e8acbc85e7e49527ff"', 'x-amz-request-id': 'tx00000000000000003c825-005b2ceb07-8c0e1-default', 'date': 'Fri, 22 Jun 2018 12:26:47 GMT', 'content-type': 'application/octet-stream'}
# DEBUG: Response body:
# <botocore.response.StreamingBody object at 0x7fb48a75fd50>
# DEBUG: Response body:
# <botocore.response.StreamingBody object at 0x7fb48a75fa90>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fb49108bb50>
# DEBUG: No retry needed.
# DEBUG: "GET /1529567823_sdp_l0/correlator_data/00014_02048_00000.npy HTTP/1.1" 200 1179728
# DEBUG: Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fb49108bb50>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Response headers: {'content-length': '1179728', 'accept-ranges': 'bytes', 'last-modified': 'Thu, 21 Jun 2018 07:59:20 GMT', 'etag': '"7162053dc8e074087bf8daf0e1b35870"', 'x-amz-request-id': 'tx00000000000000003c826-005b2ceb07-8c099-default', 'date': 'Fri, 22 Jun 2018 12:26:47 GMT', 'content-type': 'application/octet-stream'}
# DEBUG: No retry needed.
# DEBUG: Response body:
# <botocore.response.StreamingBody object at 0x7fb48a686450>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fb49108bb50>
# DEBUG: No retry needed.
# DEBUG: Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: "GET /1529567823_sdp_l0/correlator_data/00014_03072_00000.npy HTTP/1.1" 200 1179728
# DEBUG: Response headers: {'content-length': '1179728', 'accept-ranges': 'bytes', 'last-modified': 'Thu, 21 Jun 2018 07:59:20 GMT', 'etag': '"4d40a55636769796957282e0809ef0a7"', 'x-amz-request-id': 'tx00000000000000003c826-005b2ceb07-8c0e1-default', 'date': 'Fri, 22 Jun 2018 12:26:47 GMT', 'content-type': 'application/octet-stream'}
# DEBUG: "GET /1529567823_sdp_l0/correlator_data/00013_03072_00000.npy HTTP/1.1" 200 1179728
# DEBUG: Response body:
# <botocore.response.StreamingBody object at 0x7fb48a6860d0>
# DEBUG: Response headers: {'content-length': '1179728', 'accept-ranges': 'bytes', 'last-modified': 'Thu, 21 Jun 2018 07:59:20 GMT', 'etag': '"99c7fe6fb9dd6b4dec577564b6ea738d"', 'x-amz-request-id': 'tx00000000000000003c825-005b2ceb07-8666e-default', 'date': 'Fri, 22 Jun 2018 12:26:47 GMT', 'content-type': 'application/octet-stream'}
# DEBUG: Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fb49108bb50>
# DEBUG: Response body:
# <botocore.response.StreamingBody object at 0x7fb48a686d50>
# DEBUG: No retry needed.
# DEBUG: Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fb49108bb50>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: No retry needed.
# DEBUG: Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# DEBUG: "GET /1529567823_sdp_l0/correlator_data/00014_01024_00000.npy HTTP/1.1" 200 1179728
# DEBUG: Response headers: {'content-length': '1179728', 'accept-ranges': 'bytes', 'last-modified': 'Thu, 21 Jun 2018 07:59:20 GMT', 'etag': '"4b71c2d90806602228ff8b2bc3862613"', 'x-amz-request-id': 'tx00000000000000003c826-005b2ceb07-8666e-default', 'date': 'Fri, 22 Jun 2018 12:26:47 GMT', 'content-type': 'application/octet-stream'}
# DEBUG: Response body:
# <botocore.response.StreamingBody object at 0x7fb48a75f8d0>
# DEBUG: Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x7fb49108bb50>
# DEBUG: No retry needed.
# DEBUG: Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirector.redirect_from_error of <botocore.utils.S3RegionRedirector object at 0x7fb49108bbd0>>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-12a9a7eef029> in <module>()
#       6         ts_end = data.timestamps[-1]
#       7         data.select(ants=ant.name,corrprods='auto',                    channels=~static_flags,pol=active_pol,dumps=slice(0,N,step),scans=['scan','track'])
# ----> 8         d = scape.DataSet(data)
#       9         ts = data.timestamps - data.timestamps[0]
#      10         figure(figsize=[15,10])
#
# /usr/local/lib/python2.7/dist-packages/scape/dataset.py in __init__(self, filename, compscanlist, experiment_id, observer, description, data_unit, corrconf, antenna, antenna2, nd_h_model, nd_v_model, enviro, **kwargs)
#     127                 if kwargs.get('katdal', True):
#     128                     compscanlist, experiment_id, observer, description, data_unit, \
# --> 129                         corrconf, antenna, antenna2, nd_h_model, nd_v_model, enviro = hdf5_load(filename, **kwargs)
#     130                 else:
#     131                     compscanlist, experiment_id, observer, description, data_unit, \
#
# /usr/local/lib/python2.7/dist-packages/scape/kathdf5.py in load_dataset(filename, baseline, selected_pointing, noise_diode, nd_models, time_offset, **kwargs)
#     277                              np.zeros((num_times, num_chans), np.complex64) for cid in corr_id]
#     278                 scan_data = np.dstack(scan_data).astype(np.complex64)
# --> 279             scan_pointing = np.rec.fromarrays([d.sensor[az_sensor].astype(np.float32) * np.float32(np.pi / 180.0),
#     280                                                d.sensor[el_sensor].astype(np.float32) * np.float32(np.pi / 180.0)],
#     281                                               names=('az', 'el'))
#
# /usr/local/lib/python2.7/dist-packages/katdal/sensordata.pyc in __getitem__(self, name)
#     624
#     625         """
# --> 626         return self.get(name, select=True)
#     627
#     628     def _set_keep(self, keep=None):
#
# /usr/local/lib/python2.7/dist-packages/katdal/sensordata.pyc in get(self, name, select, extract, **kwargs)
#     717                     break
#     718             else:
# --> 719                 raise KeyError("Unknown sensor '%s' (does not match actual name or virtual template)" % (name,))
#     720         # If this is the first time this sensor is accessed, extract its data and store it in cache, if enabled
#     721         if isinstance(sensor_data, SensorData) and extract:
#
# KeyError: "Unknown sensor 'Antennas/m000/pos_actual_scan_azim' (does not match actual name or virtual template)"

# %%
data.timestamps[1] - data.timestamps[0]

# %%
for ant in ants:
    print ant.description

# %%
for active_pol in ['H','V']:
    print "Doing pol",active_pol
    data.select()
    data.select(corrprods='cross', channels=slice(2200,2800),pol=active_pol,scans=['scan','track'])
    baseline_names = [('%s - %s' % (inpA[:-1], inpB[:-1])) for inpA, inpB in data.corr_products]
    num_bls = data.shape[2]
    #num_bls=0
    num_chans, sample_period = len(data.channel_freqs), data.dump_period
    scan_targets, scan_mid_az, scan_mid_el, scan_timestamps, scan_phase = [], [], [], [], []
    for scan_ind, state, target in data.scans():
        num_ts = data.shape[0]
        ts = data.timestamps[0::step]
        vis = data.vis[0::step,:,:]
        scan_phase.append(np.angle(vis).T.reshape(-1, vis.shape[0]))
        scan_timestamps.append(ts - data.start_time.secs)
    scan_freqinds = [np.arange(num_bls * num_chans)] * len(scan_timestamps)
    print "Debug", num_bls,num_chans,len(scan_timestamps),"\nxxxxxxxxxxxxxxxxxxx"
    figure(figsize=(15,200))
    segms, labels, lines = scape.plots_basic.plot_segments(scan_timestamps, scan_freqinds,\
                                scan_phase, labels=scan_targets)
    for label in labels:
        label.set_rotation('vertical')
    plt.xlabel('Time (s), since %s' % (katpoint.Timestamp(data.start_time).local(),))
    plt.yticks(np.arange(num_chans // 2, num_bls * num_chans, num_chans), baseline_names,ha='right',y=1.0,fontsize=7)
    for yval in range(0, num_bls * num_chans, num_chans):
        plt.axhline(yval, color='k', lw=1, alpha=0.1)
        #plt.axvline(yval, color='y', lw=1, alpha=0.1)
    plt.title('Raw visibility phase per baseline, Pol %s'%active_pol)

# %%
print 'Report generated:'
# !date
