# %% [markdown]
# # Demo of mpld3

# %% [markdown]
# This notebook gives a brief overview of [mpld3](http://mpld3.github.io), a package which allows seamless visualization of matplotlib plots using HTML, Javascript, and the [D3js](http://d3js.org/) package.
#
# One of the nicest parts of the IPython notebook is the ability to embed figures inline with code.  For example, we can quickly create a scatter plot as so:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
# Scatter points
fig, ax = plt.subplots()
np.random.seed(0)
x, y = np.random.normal(size=(2, 200))
color, size = np.random.random((2, 200))

ax.scatter(x, y, c=color, s=500 * size, alpha=0.3)
ax.grid(color='lightgray', alpha=0.7)

# %% [markdown]
# A weakness quickly becomes clear, however: the embedded figure is a simple static PNG image.
#
# This is where mpld3 comes in. Using the simple ``mpld3.display()`` command, we can create a fully interactive visualization of the same plot:

# %%
import mpld3
mpld3.display(fig)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-9b78a551750a> in <module>()
#       1 import mpld3
# ----> 2 mpld3.display(fig)
#
# /usr/local/lib/python2.7/dist-packages/mpld3/_display.pyc in display(fig, closefig, **kwargs)
#     250     if closefig:
#     251         plt.close(fig)
# --> 252     return HTML(fig_to_html(fig, **kwargs))
#     253
#     254
#
# /usr/local/lib/python2.7/dist-packages/mpld3/_display.pyc in fig_to_html(fig, d3_url, mpld3_url, no_extras, template_type, **kwargs)
#     204     figid = get_id(fig) + str(int(random.random() * 1E10))
#     205     renderer = MPLD3Renderer()
# --> 206     Exporter(renderer, close_mpl=False, **kwargs).run(fig)
#     207
#     208     fig, figure_json, extra_css, extra_js = renderer.finished_figures[0]
#
# /usr/local/lib/python2.7/dist-packages/mpld3/mplexporter/exporter.pyc in run(self, fig)
#      47             import matplotlib.pyplot as plt
#      48             plt.close(fig)
# ---> 49         self.crawl_fig(fig)
#      50
#      51     @staticmethod
#
# /usr/local/lib/python2.7/dist-packages/mpld3/mplexporter/exporter.pyc in crawl_fig(self, fig)
#     114                                        props=utils.get_figure_properties(fig)):
#     115             for ax in fig.axes:
# --> 116                 self.crawl_ax(ax)
#     117
#     118     def crawl_ax(self, ax):
#
# /usr/local/lib/python2.7/dist-packages/mpld3/mplexporter/exporter.pyc in crawl_ax(self, ax)
#     136                 self.draw_patch(ax, patch)
#     137             for collection in ax.collections:
# --> 138                 self.draw_collection(ax, collection)
#     139             for image in ax.images:
#     140                 self.draw_image(ax, image)
#
# /usr/local/lib/python2.7/dist-packages/mpld3/mplexporter/exporter.pyc in draw_collection(self, ax, collection, force_pathtrans, force_offsettrans)
#     214
#     215         offset_coords, offsets = self.process_transform(
# --> 216             transOffset, ax, offsets, force_trans=force_offsettrans)
#     217
#     218         processed_paths = [utils.SVG_path(path) for path in paths]
#
# /usr/local/lib/python2.7/dist-packages/mpld3/mplexporter/exporter.pyc in process_transform(transform, ax, data, return_trans, force_trans)
#      79             Returned only if data is specified
#      80         """
# ---> 81         if transform.contains_branch(transforms.BlendedGenericTransform):
#      82             warnings.warn("Blended transforms not yet supported. "
#      83                           "Zoom behavior may not work as expected.")
#
# AttributeError: 'CompositeAffine2D' object has no attribute 'contains_branch'

# %% [markdown]
# Notice that as you hover over the plot, a toolbar appears in the lower left. This has tools to enable panning and zooming, and a button to reset the view once you've explored the plot.
#
# If you'd like to use mpld3 by default for every figure you generate, you can call the following command:

# %%
mpld3.enable_notebook()

# %% [markdown]
# ## Other Plot Types

# %% [markdown]
# Nearly any type of plot matplotlib can do, mpld3 can visualize as well. Below are some examples:

# %% [markdown]
# ### A Histogram

# %%
# Histogram with modified axes/grid
fig = plt.figure()

ax = fig.add_subplot(111, axisbg='#EEEEEE')
ax.grid(color='white', linestyle='solid')

x = np.random.normal(size=1000)
ax.hist(x, 30, histtype='stepfilled', fc='lightblue', alpha=0.5);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python2.7/dist-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     333                 pass
#     334             else:
# --> 335                 return printer(obj)
#     336             # Finally look for special method names
#     337             method = _safe_get_formatter_method(obj, self.print_method)
#
# /usr/local/lib/python2.7/dist-packages/mpld3/_display.pyc in <lambda>(fig, kwds)
#     330     formatter = ip.display_formatter.formatters['text/html']
#     331     formatter.for_type(Figure,
# --> 332                        lambda fig, kwds=kwargs: fig_to_html(fig, **kwds))
#     333
#     334
#
# /usr/local/lib/python2.7/dist-packages/mpld3/_display.pyc in fig_to_html(fig, d3_url, mpld3_url, no_extras, template_type, **kwargs)
#     204     figid = get_id(fig) + str(int(random.random() * 1E10))
#     205     renderer = MPLD3Renderer()
# --> 206     Exporter(renderer, close_mpl=False, **kwargs).run(fig)
#     207
#     208     fig, figure_json, extra_css, extra_js = renderer.finished_figures[0]
#
# /usr/local/lib/python2.7/dist-packages/mpld3/mplexporter/exporter.pyc in run(self, fig)
#      47             import matplotlib.pyplot as plt
#      48             plt.close(fig)
# ---> 49         self.crawl_fig(fig)
#      50
#      51     @staticmethod
#
# /usr/local/lib/python2.7/dist-packages/mpld3/mplexporter/exporter.pyc in crawl_fig(self, fig)
#     114                                        props=utils.get_figure_properties(fig)):
#     115             for ax in fig.axes:
# --> 116                 self.crawl_ax(ax)
#     117
#     118     def crawl_ax(self, ax):
#
# /usr/local/lib/python2.7/dist-packages/mpld3/mplexporter/exporter.pyc in crawl_ax(self, ax)
#     134                     self.draw_text(ax, artist)
#     135             for patch in ax.patches:
# --> 136                 self.draw_patch(ax, patch)
#     137             for collection in ax.collections:
#     138                 self.draw_collection(ax, collection)
#
# /usr/local/lib/python2.7/dist-packages/mpld3/mplexporter/exporter.pyc in draw_patch(self, ax, patch, force_trans)
#     198         coordinates, vertices = self.process_transform(transform,
#     199                                                        ax, vertices,
# --> 200                                                        force_trans=force_trans)
#     201         linestyle = utils.get_path_style(patch, fill=patch.get_fill())
#     202         self.renderer.draw_path(data=vertices,
#
# /usr/local/lib/python2.7/dist-packages/mpld3/mplexporter/exporter.pyc in process_transform(transform, ax, data, return_trans, force_trans)
#      79             Returned only if data is specified
#      80         """
# ---> 81         if transform.contains_branch(transforms.BlendedGenericTransform):
#      82             warnings.warn("Blended transforms not yet supported. "
#      83                           "Zoom behavior may not work as expected.")
#
# AttributeError: 'CompositeGenericTransform' object has no attribute 'contains_branch'

# %% [markdown]
# ### Line Plots with Legend

# %%
# Draw lines
fig, ax = plt.subplots()
x = np.linspace(-5, 15, 1000)
for offset in np.linspace(0, 3, 4):
    ax.plot(x, 0.9 * np.sin(x - offset), lw=5, alpha=0.4,
            label="Offset: {0}".format(offset))
ax.set_xlim(0, 10)
ax.set_ylim(-1.2, 1.0)
ax.text(5, -1.1, "Here are some curves", size=18, ha='center')
ax.grid(color='lightgray', alpha=0.7)
ax.legend()

# %% [markdown]
# ### Multiple Subplots with linked axes

# %%
# multiple subplots, shared axes
fig, ax = plt.subplots(2, 2, figsize=(8, 6),sharex='col', sharey='row')
fig.subplots_adjust(hspace=0.3)

np.random.seed(0)

for axi in ax.flat:
    color = np.random.random(3)
    axi.plot(np.random.random(30), lw=2, c=color)
    axi.set_title("RGB = ({0:.2f}, {1:.2f}, {2:.2f})".format(*color),
                  size=14)
    axi.grid(color='lightgray', alpha=0.7)

# %% [markdown]
# ## Plugins

# %% [markdown]
# One of the key features of mpld3 is the plugin framework. Plugins are a way to specify additional interactivity for your plots. A number of plugins are built-in, and it is also possible to define new, custom plugins for nearly limitless interactive behaviors. For example, here is the built-in Linked Brushing plugin that allows exploration of multi-dimensional datasets:

# %%
from mpld3 import plugins

fig, ax = plt.subplots(3, 3, figsize=(6, 6))
fig.subplots_adjust(hspace=0.1, wspace=0.1)
ax = ax[::-1]

X = np.random.normal(size=(3, 100))
for i in range(3):
    for j in range(3):
        ax[i, j].xaxis.set_major_formatter(plt.NullFormatter())
        ax[i, j].yaxis.set_major_formatter(plt.NullFormatter())
        points = ax[i, j].scatter(X[j], X[i])
        
plugins.connect(fig, plugins.LinkedBrush(points))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-1035b6e1e7b3> in <module>()
#      12         points = ax[i, j].scatter(X[j], X[i])
#      13
# ---> 14 plugins.connect(fig, plugins.LinkedBrush(points))
#
# AttributeError: 'module' object has no attribute 'LinkedBrush'

# %% [markdown]
# Selecting points with the brush lets you quickly explore the relationships between the points.

# %% [markdown]
# ## For More Information

# %% [markdown]
# More examples, documentation, and information can be found on the [mpld3 website](http://mpld3.github.io).  See especially the [Example Gallery](http://mpld3.github.io/examples/index.html) and the [Notebook Gallery](http://mpld3.github.io/notebooks/index.html).  If you are interested in contributing, the source of mpld3 can be found on [GitHub](http://github.com/jakevdp/mpld3).
