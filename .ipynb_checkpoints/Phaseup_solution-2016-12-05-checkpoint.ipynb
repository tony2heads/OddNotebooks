# %%
import katdal
import matplotlib.pylab as plt
# %matplotlib inline
import numpy as np
import pickle

# %%
filename='/var/kat/archive2/data/MeerKATAR1/telescope_products/2016/12/05/1480934843.h5'

# %%
h = katdal.open(filename)

# %%
print h
# Out:
# ===============================================================================
# Name: /var/kat/archive2/data/MeerKATAR1/telescope_products/2016/12/05/1480934843.h5 (version 3.0)
# ===============================================================================
# Observer: Lindsay  Experiment ID: 20161205-0011
# Description: 'Generic Phaseup for all targets'
# Observed from 2016-12-05 12:47:25.703 SAST to 2016-12-05 12:52:01.586 SAST
# Dump rate / period: 0.25011 Hz / 3.998 s
# Subarrays: 1
#   ID  Antennas                            Inputs  Corrprods
#    0  m006,m007,m008,m010,m014,m015,m025,m031,m062,m063  20      220
# Spectral Windows: 1
#   ID Band Product  CentreFreq(MHz)  Bandwidth(MHz)  Channels  ChannelWidth(kHz)
#    0 L    bc856M4k   1284.000         856.000           4096       208.984
# -------------------------------------------------------------------------------
# Data selected according to the following criteria:
#   subarray=0
#   ants=['m008', 'm010', 'm007', 'm014', 'm006', 'm063', 'm015', 'm025', 'm031', 'm062']
#   spw=0
# -------------------------------------------------------------------------------
# Shape: (69 dumps, 4096 channels, 220 correlation products) => Size: 497.418 MB
# Antennas: m006,m007,*m008,m010,m014,m015,m025,m031,m062,m063  Inputs: 20  Autocorr: yes  Crosscorr: yes
# Channels: 4096 (index 0 - 4095,  856.000 MHz - 1711.791 MHz), each 208.984 kHz wide
# Targets: 2 selected out of 2 in catalogue
#   ID  Name         Type      RA(J2000)     DEC(J2000)  Tags                       Dumps  ModelFlux(Jy)
#    0  PKS 1934-63  radec     19:39:25.03  -63:42:45.7  bfcal single_accumulation     21      14.46
#    1  Nothing      special             -            -                                48
# Scans: 6 selected out of 6 total       Compscans: 2 selected out of 2 total
#   Date        Timerange(UTC)       ScanState  CompScanLabel  Dumps  Target
#   05-Dec-2016/10:47:27 - 10:47:39    0:slew     0:un_corrected      4    0:PKS 1934-63
#               10:47:43 - 10:48:11    1:track    0:un_corrected      8    0:PKS 1934-63
#               10:48:15 - 10:51:11    2:stop     0:un_corrected     45    1:Nothing
#               10:51:15 - 10:51:23    3:stop     1:corrected      3    1:Nothing
#               10:51:27 - 10:51:35    4:slew     1:corrected      3    0:PKS 1934-63
#               10:51:39 - 10:51:59    5:track    1:corrected      6    0:PKS 1934-63

# %%
# check what cal products we have
print 'Solutions:'
print '    Product             Number of solutions'
for k in h.file['TelescopeState'].keys():
    if 'cal_product' in k:
        print '   ', k, ' --- ' , len(h.file['TelescopeState'][k])
# Out:
# Solutions:
#     Product             Number of solutions
#     cal_product_B  ---  1
#     cal_product_K  ---  1
#     cal_product_G  ---  2

# %%
np.set_printoptions(precision=4,suppress=True)

# %%
# check antenna ordering
print h.file['TelescopeState']['cal_antlist']
a_list=[]
aa=h.file['TelescopeState']['cal_antlist']
for i,ai in enumerate(aa):
    a_list.append(pickle.loads(ai[1]))
a_array=np.array(a_list)
print a_list
print a_array[0]
labels=a_array[0]
# Out:
# <HDF5 dataset "cal_antlist": shape (1,), type "|V136">
# [['m006', 'm007', 'm008', 'm010', 'm014', 'm015', 'm025', 'm031', 'm062', 'm063']]
# ['m006' 'm007' 'm008' 'm010' 'm014' 'm015' 'm025' 'm031' 'm062' 'm063']

# %% [markdown]
# # Delays

# %%
k = h.file['TelescopeState']['cal_product_K']
k_list = []
for i, ki in enumerate(k):
    k_list.append(pickle.loads(ki[1]))
k_array = np.array(k_list)

k_0 = k_array[:,0,:]*1e9
k_1 = k_array[:,1,:]*1e9

# %%
k_array.shape #Times,Pols,Antennas
# Out:
# (1, 2, 10)

# %%
# print delays (if there are few delays)
print 'POL 0: \n', k_0[0], "\n",k_0[-1]
print 'POL 1: \n', k_1[0],"\n" ,k_1[-1]
# Out:
# POL 0:
# [-386.1823 -407.8168 -378.2989 -389.2626 -385.8648 -385.8244    0.
#   234.1866 -376.5317 -383.1955]
# [-386.1823 -407.8168 -378.2989 -389.2626 -385.8648 -385.8244    0.
#   234.1866 -376.5317 -383.1955]
# POL 1:
# [-383.0795 -404.8667 -374.5329 -382.8159 -381.0252 -382.8547    0.
#   238.1867 -377.1153 -380.2651]
# [-383.0795 -404.8667 -374.5329 -382.8159 -381.0252 -382.8547    0.
#   238.1867 -377.1153 -380.2651]

# %%
print labels
# Out:
# ['m006' 'm007' 'm008' 'm010' 'm014' 'm015' 'm025' 'm031' 'm062' 'm063']

# %%
colors=['r','g','b','c','m','k','darkorange','darkgreen','maroon','darkviolet','olive','saddlebrown','darkorchid']

# %%
#plot delays (if there are many delays)
fig, ax = plt.subplots(2,1,figsize=(20, 10))
for i in range(len(labels)):
    ax[0].plot(k_0[:,i],'-x',markersize=8,label=labels[i],color=colors[i]);
#ax[0].set_ylim([-0.2,0.2]);
    ax[1].plot(k_1[:,i],'-x',markersize=8,label=labels[i],color=colors[i]);
#ax[1].set_ylim([-0.2,0.2]);
plt.legend(loc='upper center')

# %% [markdown]
# # Gains

# %%
g = h.file['TelescopeState']['cal_product_G']
g_list = []
for i, gi in enumerate(g):
    g_list.append(pickle.loads(gi[1]))
g_array = np.array(g_list)
print g_array.shape

g_0 = g_array[:,0,:]
g_1 = g_array[:,1,:]
# Out:
# (2, 2, 10)

# %%
#First
print np.abs(g_0)[0]
print np.abs(g_1)[0]
# Out:
# [ 0.9993  0.997   0.9997  1.0011  1.      1.0008  1.0001  1.0011  0.9997
#   1.0006]
# [ 0.9992  0.998   1.0004  1.0005  1.002   1.0004  0.9982  0.9999  1.0001
#   1.0013]

# %%
#Last
print np.abs(g_0)[-1]
print np.abs(g_1)[-1]
# Out:
# [ 0.998   1.001   0.996   1.0014  1.0001  1.      1.0009  1.003   1.0011
#   1.0002]
# [ 0.9979  1.0008  0.9981  1.0039  1.0008  0.9983  0.9973  1.0023  1.0005
#   1.0001]

# %%
#Ratio
print np.abs(g_0)[-1]/np.abs(g_0)[0]
print np.abs(g_1)[-1]/np.abs(g_1)[0]
# Out:
# [ 0.9987  1.004   0.9964  1.0003  1.0001  0.9992  1.0007  1.002   1.0014
#   0.9996]
# [ 0.9987  1.0027  0.9977  1.0034  0.9988  0.9979  0.9991  1.0024  1.0003
#   0.9988]

# %%
#Before
print np.rad2deg(np.angle(g_0)[0])
print np.rad2deg(np.angle(g_1)[0])
# Out:
# [  57.3925   71.5961  120.0439   69.2529  144.2304   69.3078    0.
#   -15.9946  136.3778   99.1341]
# [  33.9374   82.1952   62.4975   77.0956   75.5732   45.9398   -0.
#    22.2833   65.6602  104.9874]

# %%
#After
print np.rad2deg(np.angle(g_0)[-1])
print np.rad2deg(np.angle(g_1)[-1])
# Out:
# [  56.9876   70.4964  121.035    68.8373  144.5245   69.3653    0.
#   -15.8451  137.1003   99.9036]
# [  33.4761   81.001    63.5622   76.7016   75.7887   45.9994    0.
#    22.3678   66.264   105.65  ]

# %%
#Differences
print np.rad2deg(np.angle(g_0)[-1])-np.rad2deg(np.angle(g_0)[0])
print np.rad2deg(np.angle(g_1)[-1])-np.rad2deg(np.angle(g_1)[0])
# Out:
# [-0.4048 -1.0998  0.9911 -0.4156  0.2941  0.0574  0.      0.1495  0.7224
#   0.7695]
# [-0.4614 -1.1942  1.0647 -0.394   0.2155  0.0596  0.      0.0845  0.6038
#   0.6626]

# %%
#plot gains - amplitude
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].plot(np.abs(g_0),'-x');
#ax[0].set_ylim([0,5.0]);
ax[1].plot(np.abs(g_1),'-x');
#ax[1].set_ylim([0,5.0]);
plt.xlabel('Dump')
plt.ylabel('Gain')
plt.legend()
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/axes.py:4747: UserWarning: No labeled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labeled objects found. "

# %%
#plot gains - phase
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].plot(np.rad2deg(np.angle(g_0)),'-x');
ax[0].set_ylim([-180,180]);
ax[1].plot(np.rad2deg(np.angle(g_1)),'-x');
ax[1].set_ylim([-180,180]);

# %% [markdown]
# # Bandpasses

# %%
b = h.file['TelescopeState']['cal_product_B']
b_list = []
for i, bi in enumerate(b):
    b_list.append(pickle.loads(bi[-1]))
b_array = np.array(b_list)
print b_array.shape
# bandpass shape is ntimes x channels x pol x antenna 
# where ntimes is the number of bandpasses

# just look at LAST bandpass for now
b_0_0 = b_array[-1,:,0,:]
b_1_0 = b_array[-1,:,1,:]
# Out:
# (1, 4096, 2, 10)

# %%
#plot bandpass - amplitude
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].plot(np.abs(b_0_0),'.');
ax[0].set_ylim([0,10]);
ax[0].set_xlabel('gains')
ax[1].plot(np.abs(b_1_0),'.');
ax[1].set_ylim([0,10]);
ax[1].set_xlabel('gains')
#plt.xlabel('channel')
#plt.ylabel('gains')

# %%
""""
for i in range(len(labels)):
    ax[0].plot(k_0[:,i],'-x',markersize=8,label=labels[i],color=colors[i]);
#ax[0].set_ylim([-0.2,0.2]);
    ax[1].plot(k_1[:,i],'-x',markersize=8,label=labels[i],color=colors[i]);
#ax[1].set_ylim([-0.2,0.2]);
plt.legend(loc='upper center')
"""
# Out:
# '"\nfor i in range(len(labels)):\n    ax[0].plot(k_0[:,i],\'-x\',markersize=8,label=labels[i],color=colors[i]);\n#ax[0].set_ylim([-0.2,0.2]);\n    ax[1].plot(k_1[:,i],\'-x\',markersize=8,label=labels[i],color=colors[i]);\n#ax[1].set_ylim([-0.2,0.2]);\nplt.legend(loc=\'upper center\')\n'

# %%
#plot bandpass - phase
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].set_ylim([-70,70]);
ax[1].set_ylim([-70,70]);
ax[0].plot(np.rad2deg(np.angle(b_0_0)),'.');
ax[1].plot(np.rad2deg(np.angle(b_1_0)),'.');
plt.legend()

# %%
len(labels)
# Out:
# 10

# %%
b_array.shape
# Time,channels,pols,antennas
# Out:
# (1, 4096, 2, 10)

# %%
#One bandpass at the END
antn=9
b_0_1 = b_array[-1,:,0,antn]
b_1_1 = b_array[-1,:,1,antn]
print b_1_1.shape
print a_array[:,antn]
# Out:
# (4096,)
# ['m063']

# %%
#plot bandpass - amplitude
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].plot(np.abs(b_0_1),'.');
ax[0].set_ylim([0,10]);
ax[0].set_xlabel('gains')
ax[1].plot(np.abs(b_1_1),'.');
ax[1].set_ylim([0,10]);
ax[1].set_xlabel('gains')
#plt.xlabel('channel')
#plt.ylabel('gains')

# %%
#plot bandpass - phase
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].plot(np.rad2deg(np.angle(b_0_1)),'.');
ax[0].set_ylim([-70,70]);
ax[1].plot(np.rad2deg(np.angle(b_1_1)),'.');
ax[1].set_ylim([-70,70]);
