# %%
import pysolr
from IPython.core.display import display, HTML
archive = pysolr.Solr('http://192.168.1.50:8983/solr/kat_core')
search_str = []
search_str.append('CAS.ProductTypeName:MeerKATAR1TelescopeProduct')
search_str.append('StartTime:[2017-12-01T00:00:00Z TO 2017-12-05T00:00:00Z]')
search_string = ' AND '.join(search_str)
ar_res = archive.search( search_string ,rows=10000,**{'sort':'StartTime desc'})
h = '<table>'
h += "<tr><th>Owner<th>UT Start<th>Schedule block<th>Description<th>chan<th>ants<th>size<th>Archive</tr>"			
for r in ar_res.docs[::-1]:
    if 'ScheduleBlockIdCode' not in r:
        r['ScheduleBlockIdCode']=""
    if len(r['Description'])<1 :
        r['Description']='Beamformer?'
    link = 'http://kat-archive.kat.ac.za:8080/archive_search/#\
    {"ei":"%s","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}\
    '%(r['ScheduleBlockIdCode'])
    h += '<tr> <td> %s <td> %s <td> <a href=\'%s\'>%s</a>\
    <td> %s <td> %d <td> %d <td> %5.2f <td> %s  </tr>'\
    %(r['Observer'],r['StartTime'],link,r['ScheduleBlockIdCode'],r['Description'],\
      r['NumFreqChannels'],len(r['Antennas']),r['FileSize'][0]/1024.0**3\
      ,r['CAS.ReferenceDatastore'][0][5:])
h += "</table>"
display(HTML(h))
h += "<tr><th>Owner<th>UT Start<th>Schedule block<th>Description<th>\
chan<th>ants<th>size<th>Archive</tr>"
from BeautifulSoup import BeautifulSoup
soup = BeautifulSoup(h)
with open("output.html", "wb") as file:
    file.write("<html>\n")
    file.write(soup.prettify("utf-8"))
    file.write("\n<\html>\n")
# Out:
# <table><tr><th>Owner<th>UT Start<th>Schedule block<th>Description<th>chan<th>ants<th>size<th>Archive</tr><tr> <td> Mattieu <td> 2017-12-01T02:27:36Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20171201-0001","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20171201-0001</a>    <td> MKAIV-916: L-band holography array performance <td> 32 <td> 16 <td>  0.92 <td> /var/kat/archive3/data/MeerKATAR1/telescope_products/2017/12/01/1512095242.h5  </tr><tr> <td> Mattieu <td> 2017-12-01T03:30:59Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20171201-0002","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20171201-0002</a>    <td> MKAIV-916: L-band holography array performance <td> 4096 <td> 16 <td>  1.47 <td> /var/kat/archive3/data/MeerKATAR1/telescope_products/2017/12/01/1512099045.h5  </tr><tr> <td> Observer <td> 2017-12-01T06:25:12Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20171201-0003","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20171201-0003</a>    <td> Observation script no-delay track without beams <td> 4096 <td> 3 <td>  0.04 <td> /var/kat/archive3/data/MeerKATAR1/telescope_products/2017/12/01/1512109518.h5  </tr><tr> <td> Observer <td> 2017-12-01T06:35:12Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20171201-0005","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20171201-0005</a>    <td> Observation script no-delay track without beams <td> 4096 <td> 3 <td>  0.05 <td> /var/kat/archive3/data/MeerKATAR1/telescope_products/2017/12/01/1512110115.h5  </tr><tr> <td> Observer <td> 2017-12-01T06:46:16Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20171201-0006","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20171201-0006</a>    <td> Observation script no-delay track without beams <td> 4096 <td> 3 <td>  0.04 <td> /var/kat/archive3/data/MeerKATAR1/telescope_products/2017/12/01/1512110777.h5  </tr><tr> <td> Observer <td> 2017-12-01T06:52:40Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20171201-0004","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20171201-0004</a>    <td> Observation script  with delay track without beams <td> 4096 <td> 3 <td>  0.04 <td> /var/kat/archive3/data/MeerKATAR1/telescope_products/2017/12/01/1512111161.h5  </tr><tr> <td> Lindsay <td> 2017-12-01T14:33:46Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20171201-0026","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20171201-0026</a>    <td> MKAIV-308 Basic health <td> 4096 <td> 16 <td>  1.14 <td> /var/kat/archive3/data/MeerKATAR1/telescope_products/2017/12/01/1512138821.h5  </tr><tr> <td> Mattieu <td> 2017-12-01T16:42:05Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20171201-0042","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20171201-0042</a>    <td> MKAIV-916: L-band holography array performance <td> 32 <td> 16 <td>  0.95 <td> /var/kat/archive3/data/MeerKATAR1/telescope_products/2017/12/01/1512146522.h5  </tr><tr> <td> Tony <td> 2017-12-01T18:04:58Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20171201-0043","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20171201-0043</a>    <td> MKAIV-111 AR1 pointing <td> 4096 <td> 16 <td> 265.24 <td> /var/kat/archive3/data/MeerKATAR1/telescope_products/2017/12/01/1512151498.h5  </tr><tr> <td> Lindsay <td> 2017-12-02T01:30:29Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#    {"ei":"20171201-0044","so":true,"r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}    '>20171201-0044</a>    <td> MKAIV-584 Generic AR1 delaycal <td> 4096 <td> 16 <td>  2.38 <td> /var/kat/archive3/data/MeerKATAR1/telescope_products/2017/12/02/1512178226.h5  </tr><tr> <td> SMakhath ...
