# %%
import katdal
import matplotlib.pylab as plt
# %matplotlib inline
import numpy as np
import pickle

# %%
#filename="/var/kat/archive2/data/MeerKATAR1/telescope_products/2016/11/24/1480013885.h5"
#filename="/var/kat/archive2/data/MeerKATAR1/telescope_products/2016/11/25/1480052041.h5"
#filename='/var/kat/archive2/data/MeerKATAR1/telescope_products/2016/11/25/1480052823.h5'
filename='/var/kat/archive2/data/MeerKATAR1/telescope_products/2016/11/25/1480053177.h5'

# %%
h = katdal.open(filename)

# %%
print h
# Out:
# ===============================================================================
# Name: /var/kat/archive2/data/MeerKATAR1/telescope_products/2016/11/25/1480053177.h5 (version 3.0)
# ===============================================================================
# Observer: Fannie  Experiment ID: 20161125-0003
# Description: 'Generic Phaseup for all targets'
# Observed from 2016-11-25 07:53:01.095 SAST to 2016-11-25 07:57:20.985 SAST
# Dump rate / period: 0.25011 Hz / 3.998 s
# Subarrays: 1
#   ID  Antennas                            Inputs  Corrprods
#    0  m006,m007,m008,m010,m014,m015,m025,m031  16      144
# Spectral Windows: 1
#   ID Band Product  CentreFreq(MHz)  Bandwidth(MHz)  Channels  ChannelWidth(kHz)
#    0 L    bc856M4k   1284.000         856.000           4096       208.984
# -------------------------------------------------------------------------------
# Data selected according to the following criteria:
#   subarray=0
#   ants=['m008', 'm010', 'm007', 'm014', 'm006', 'm015', 'm025', 'm031']
#   spw=0
# -------------------------------------------------------------------------------
# Shape: (65 dumps, 4096 channels, 144 correlation products) => Size: 306.708 MB
# Antennas: m006,m007,*m008,m010,m014,m015,m025,m031  Inputs: 16  Autocorr: yes  Crosscorr: yes
# Channels: 4096 (index 0 - 4095,  856.000 MHz - 1711.791 MHz), each 208.984 kHz wide
# Targets: 2 selected out of 2 in catalogue
#   ID  Name     Type      RA(J2000)     DEC(J2000)  Tags                       Dumps  ModelFlux(Jy)
#    0  Nothing  special             -            -                                47
#    1  3C286    radec     13:31:08.29   30:30:33.0  bfcal single_accumulation     18      15.37
# Scans: 6 selected out of 6 total       Compscans: 2 selected out of 2 total
#   Date        Timerange(UTC)       ScanState  CompScanLabel  Dumps  Target
#   25-Nov-2016/05:53:03 - 05:53:11    0:slew     0:un_corrected      3    1:3C286
#               05:53:15 - 05:53:39    1:track    0:un_corrected      7    1:3C286
#               05:53:43 - 05:56:39    2:stop     0:un_corrected     45    0:Nothing
#               05:56:43 - 05:56:46    3:stop     1:corrected      2    0:Nothing
#               05:56:50 - 05:56:54    4:slew     1:corrected      2    1:3C286
#               05:56:58 - 05:57:18    5:track    1:corrected      6    1:3C286

# %%
# check what cal products we have
print 'Solutions:'
print '    Product             Number of solutions'
for k in h.file['TelescopeState'].keys():
    if 'cal_product' in k:
        print '   ', k, ' --- ' , len(h.file['TelescopeState'][k])
# Out:
# Solutions:
#     Product             Number of solutions
#     cal_product_B  ---  20
#     cal_product_K  ---  21
#     cal_product_G  ---  40

# %%
np.set_printoptions(precision=4,suppress=True)

# %%
# check antenna ordering
print h.file['TelescopeState']['cal_antlist']
a_list=[]
aa=h.file['TelescopeState']['cal_antlist']
for i,ai in enumerate(aa):
    a_list.append(pickle.loads(ai[1]))
a_array=np.array(a_list)
print a_list
print a_array[0]
labels=a_array[0]
# Out:
# <HDF5 dataset "cal_antlist": shape (1,), type "|V110">
# [['m006', 'm007', 'm008', 'm010', 'm014', 'm015', 'm025', 'm031']]
# ['m006' 'm007' 'm008' 'm010' 'm014' 'm015' 'm025' 'm031']

# %% [markdown]
# # Delays

# %%
k = h.file['TelescopeState']['cal_product_K']
k_list = []
for i, ki in enumerate(k):
    k_list.append(pickle.loads(ki[1]))
k_array = np.array(k_list)

k_0 = k_array[:,0,:]*1e9
k_1 = k_array[:,1,:]*1e9

# %%
k_array.shape #Times,Pols,Antennas
# Out:
# (21, 2, 8)

# %%
# print delays (if there are few delays)
print 'POL 0: \n', k_0[0], "\n",k_0[-1]
print 'POL 1: \n', k_1[0],"\n" ,k_1[-1]
# Out:
# POL 0:
# [-288.1658 -314.4214 -298.8877 -295.8282 -292.5184 -287.8406    0.
#   327.4976]
# [-0.0157  0.0025 -0.0289 -0.028  -0.0157 -0.0209  0.     -0.0044]
# POL 1:
# [-285.0346 -311.4965 -295.1827 -289.3639 -287.6753 -284.8566    0.
#   331.4784]
# [-0.0133 -0.007  -0.0335 -0.0397 -0.0111 -0.0169 -0.     -0.0185]

# %%
print labels
# Out:
# ['m006' 'm007' 'm008' 'm010' 'm014' 'm015' 'm025' 'm031']

# %%
colors=['r','g','b','c','m','k','darkorange','darkgreen','maroon','darkviolet','olive','saddlebrown','darkorchid']

# %%
#plot delays (if there are many delays)
fig, ax = plt.subplots(2,1,figsize=(20, 10))
for i in range(len(labels)):
    ax[0].plot(k_0[:,i],'-x',markersize=8,label=labels[i],color=colors[i]);
#ax[0].set_ylim([-0.2,0.2]);
    ax[1].plot(k_1[:,i],'-x',markersize=8,label=labels[i],color=colors[i]);
#ax[1].set_ylim([-0.2,0.2]);
plt.legend(loc='upper center')

# %% [markdown]
# # Gains

# %%
g = h.file['TelescopeState']['cal_product_G']
g_list = []
for i, gi in enumerate(g):
    g_list.append(pickle.loads(gi[1]))
g_array = np.array(g_list)
print g_array.shape

g_0 = g_array[:,0,:]
g_1 = g_array[:,1,:]
# Out:
# (40, 2, 8)

# %%
#First
print np.abs(g_0)[0]
print np.abs(g_1)[0]
# Out:
# [ 0.9992  0.9988  0.9988  0.9977  1.0039  1.001   1.0012  1.0006]
# [ 1.0008  0.9988  1.0012  1.0007  0.9978  1.0014  0.9992  1.0011]

# %%
#Last
print np.abs(g_0)[-1]
print np.abs(g_1)[-1]
# Out:
# [ 0.9969  1.0001  0.9973  1.0016  0.9984  0.9968  1.0017  0.9961]
# [ 0.9975  1.0004  1.0004  1.0018  0.9975  0.9958  0.9988  0.9957]

# %%
#Ratio
print np.abs(g_0)[-1]/np.abs(g_0)[0]
print np.abs(g_1)[-1]/np.abs(g_1)[0]
# Out:
# [ 0.9977  1.0013  0.9984  1.0039  0.9945  0.9958  1.0006  0.9955]
# [ 0.9967  1.0016  0.9992  1.0011  0.9997  0.9943  0.9996  0.9946]

# %%
#Before
print np.rad2deg(np.angle(g_0)[0])
print np.rad2deg(np.angle(g_1)[0])
# Out:
# [ 115.0916  101.0942  135.9494  101.3964  -28.9063  123.7688    0.
#    27.8946]
# [  78.8691  118.9876  119.0926   98.5681  104.3389   92.4305   -0.
#    77.9584]

# %%
#After
print np.rad2deg(np.angle(g_0)[-1])
print np.rad2deg(np.angle(g_1)[-1])
# Out:
# [ 125.474   112.958   140.0853  124.7259 -120.2123  139.0344    0.
#    55.2662]
# [  87.5711  127.1096  132.9778  126.5862  126.2453  102.8556    0.
#    96.4793]

# %%
#Differences
print np.rad2deg(np.angle(g_0)[-1])-np.rad2deg(np.angle(g_0)[0])
print np.rad2deg(np.angle(g_1)[-1])-np.rad2deg(np.angle(g_1)[0])
# Out:
# [ 10.3824  11.8638   4.1359  23.3295 -91.306   15.2657  -0.      27.3717]
# [  8.702    8.122   13.8853  28.0181  21.9064  10.4251   0.      18.5208]

# %%
#plot gains - amplitude
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].plot(np.abs(g_0),'-x');
#ax[0].set_ylim([0,5.0]);
ax[1].plot(np.abs(g_1),'-x');
#ax[1].set_ylim([0,5.0]);
plt.xlabel('Dump')
plt.ylabel('Gain')
plt.legend()
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/axes.py:4747: UserWarning: No labeled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labeled objects found. "

# %%
#plot gains - phase
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].plot(np.rad2deg(np.angle(g_0)),'-x');
ax[0].set_ylim([-180,180]);
ax[1].plot(np.rad2deg(np.angle(g_1)),'-x');
ax[1].set_ylim([-180,180]);

# %% [markdown]
# # Bandpasses

# %%
b = h.file['TelescopeState']['cal_product_B']
b_list = []
for i, bi in enumerate(b):
    b_list.append(pickle.loads(bi[-1]))
b_array = np.array(b_list)
print b_array.shape
# bandpass shape is ntimes x channels x pol x antenna 
# where ntimes is the number of bandpasses

# just look at LAST bandpass for now
b_0_0 = b_array[-1,:,0,:]
b_1_0 = b_array[-1,:,1,:]
# Out:
# (20, 4096, 2, 8)

# %%
#plot bandpass - amplitude
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].plot(np.abs(b_0_0),'.');
ax[0].set_ylim([0,10]);
ax[0].set_xlabel('gains')
ax[1].plot(np.abs(b_1_0),'.');
ax[1].set_ylim([0,10]);
ax[1].set_xlabel('gains')
#plt.xlabel('channel')
#plt.ylabel('gains')

# %%
#plot bandpass - phase
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].set_ylim([-70,70]);
ax[1].set_ylim([-70,70]);
ax[0].plot(np.rad2deg(np.angle(b_0_0)),'.');
ax[1].plot(np.rad2deg(np.angle(b_1_0)),'.');

# %%
b_array.shape
# Time,channels,pols,antennas
# Out:
# (20, 4096, 2, 8)

# %%
#One bandpass at the END
antn=7
b_0_1 = b_array[-1,:,0,antn]
b_1_1 = b_array[-1,:,1,antn]
print b_1_1.shape
print a_array[:,antn]
# Out:
# (4096,)
# ['m031']

# %%
#plot bandpass - amplitude
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].plot(np.abs(b_0_1),'.');
ax[0].set_ylim([0,10]);
ax[0].set_xlabel('gains')
ax[1].plot(np.abs(b_1_1),'.');
ax[1].set_ylim([0,10]);
ax[1].set_xlabel('gains')
#plt.xlabel('channel')
#plt.ylabel('gains')

# %%
#plot bandpass - phase
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].plot(np.rad2deg(np.angle(b_0_1)),'.');
ax[0].set_ylim([-70,70]);
ax[1].plot(np.rad2deg(np.angle(b_1_1)),'.');
ax[1].set_ylim([-70,70]);

# %%
str(h.catalogue.targets[1])
# Out:
# '3C286 (J1331+3030), tags=radec bfcal single_accumulation, 13:31:08.29 30:30:33.0, flux defined for 800 - 43200 MHz'
