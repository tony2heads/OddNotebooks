# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# pylab import has clobbered these variables: ['sample', 'f', 'sort']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
import scape
import katdal
import katpoint
import katsdpscripts
import glob
import re
import pandas as pd 

import csv
import operator

# %%
from os import system

# %%
print "Scape version: %s"%scape.__version__
print "katdal version: %s"%katdal.__version__
print "katpoint version: %s"%katpoint.__version__
print "katsdpscripts version: %s"%katsdpscripts.__version__
# Out:
# Scape version: 0.1.dev609+master.e0e7c8c
# katdal version: 0.7.2.dev386+master.ec7699d
# katpoint version: 0.7.dev318+master.6f21089
# katsdpscripts version: 0.1.dev2656+master.0a88762

# %%
# !ls /var/kat/archive3
# Out:
# comm-data  data

# %%
h5_filename ='/var/kat/archive3/data/MeerKATAR1/telescope_products/2017/11/19/1511125197.h5'
# %set_env h5_filename = $h5_filename
# Out:
# env: h5_filename=/var/kat/archive3/data/MeerKATAR1/telescope_products/2017/11/19/1511125197.h5

# %%
d = katdal.open(h5_filename);
ant_list,ants = [],[]
[ant_list.append(ant.name) for ant in d.ants]
print(ant_list)
ants = ",".join(ants)
print ants
# Out:
# DEBUG: Added '0008-421' [radec] (and 1 aliases)
# DEBUG: Added '0023-263' [radec] (and 1 aliases)
# DEBUG: Added '0056-001' [radec] (and 1 aliases)
# DEBUG: Added '3C48' [radec] (and 1 aliases)
# DEBUG: Added '0237-233' [radec] (and 1 aliases)
# DEBUG: Added '0252-712' [radec] (and 1 aliases)
# DEBUG: Added 'CTA21' [radec] (and 1 aliases)
# DEBUG: Added '0408-658' [radec] (and 1 aliases)
# DEBUG: Added '0428+205' [radec] (and 1 aliases)
# DEBUG: Added '3C138' [radec] (and 1 aliases)
# DEBUG: Added '0537-441' [radec] (and 1 aliases)
# DEBUG: Added '0614-349' [radec] (and 1 aliases)
# DEBUG: Added '0723-008' [radec] (and 1 aliases)
# DEBUG: Added '0733-174' [radec] (and 1 aliases)
# DEBUG: Added '0823-500' [radec] (and 1 aliases)
# DEBUG: Added '3C237' [radec] (and 1 aliases)
# DEBUG: Added '1127-145' [radec] (and 1 aliases)
# ['m020', 'm021', 'm023', 'm036']

# %%
#ant_list.remove('m028') # had low signal power
ant_list.remove('m036') # no signal part way through
#ant_list.remove('m045') # Not tracking
#print ant_list
ants=','.join(ant_list)
print ants
# %set_env ants=$ants
# Out:
# m020,m021,m023
# env: ants=m020,m021,m023

# %%
ref_ant='m021'
# %set_env ref_ant=$ref_ant
# Out:
# env: ref_ant=m021

# %%
figure(1,figsize=(15,15))
figure(2,figsize=(15,15))
figure(3,figsize=(15,15))
figure(4,figsize=(15,15))
# %run /home/tony/Desktop/katsdpscripts/reduction/baseline_cal_reduction.py -f 2200,2800 -p 'H' -r $ref_ant \
 -a $ants  $h5_filename
# Out:
# Loading and processing data...
#
# antennas (3): m020, m021 (*ref*), m023 [pol H]
# baselines (3): 0-1 0-2 1-2
# scan   0 (   2 samples) skipped 'stop'
# scan   1 (  48 samples) skipped 'slew'
# scan   2 ( 129 samples) 0.094 0.096 0.098 '0008-421'
# scan   3 (  25 samples) skipped 'slew'
# scan   4 ( 127 samples) 0.049 0.051 0.050 '0023-263'
# scan   5 (  32 samples) skipped 'slew'
# scan   6 ( 128 samples) 0.167 0.165 0.179 '0056-001'
# scan   7 (  35 samples) skipped 'slew'
# scan   8 ( 128 samples) 0.030 0.030 0.030 '3C48'
# scan   9 (  65 samples) skipped 'slew'
# scan  10 ( 127 samples) 0.073 0.074 0.074 '0237-233'
# scan  11 (  93 samples) skipped 'slew'
# scan  12 ( 127 samples) 0.073 0.075 0.078 '0252-712'
# scan  13 (  91 samples) skipped 'slew'
# scan  14 ( 127 samples) 0.055 0.058 0.059 'CTA21'
# scan  15 (  85 samples) skipped 'slew'
# scan  16 ( 128 samples) 0.028 0.028 0.028 '0408-658'
# scan  17 (  76 samples) skipped 'slew'
# scan  18 ( 127 samples) 0.118 0.122 0.126 '0428+205'
# scan  19 (  15 samples) skipped 'slew'
# scan  20 ( 128 samples) 0.052 0.054 0.053 '3C138'
# scan  21 (  48 samples) skipped 'slew'
# scan  22 ( 128 samples) 0.099 0.099 0.101 '0537-441'
# scan  23 (  15 samples) skipped 'slew'
# scan  24 ( 127 samples) 0.150 0.150 0.150 '0614-349'
# scan  25 (  36 samples) skipped 'slew'
# scan  26 ( 128 samples) 0.096 0.097 0.095 '0723-008'
# scan  27 (  16 samples) skipped 'slew'
# scan  28 ( 127 samples) 0.194 0.202 0.203 '0733-174'
# scan  29 (  27 samples) skipped 'slew'
# scan  30 ( 128 samples) 0.086 0.088 0.086 '0823-500'
# scan  31 (  61 samples) skipped 'slew'
# scan  32 ( 127 samples) 0.095 0.095 0.095 '0008-421'
# scan  33 (  21 samples) skipped 'slew'
# scan  34 ( 128 samples) 0.050 0.050 0.052 '0023-263'
# scan  35 ( 167 samples) skipped 'slew'
# scan  36 ( 129 samples) 0.177 0.173 0.167 '0056-001'
# scan  37 (  31 samples) skipped 'slew'
# scan  38 ( 127 samples) 0.031 0.031 0.031 '3C48'
# scan  39 (  64 samples) skipped 'slew'
# scan  40 ( 128 samples) 0.073 0.074 0.075 '0237-233'
# scan  41 (  70 samples) skipped 'slew'
# scan  42 ( 127 samples) 0.073 0.074 0.073 '0252-712'
# scan  43 (  95 samples) skipped 'slew'
# scan  44 ( 127 samples) 0.058 0.056 0.060 'CTA21'
# scan  45 (  96 samples) skipped 'slew'
# scan  46 ( 127 samples) 0.028 0.028 0.029 '0408-658'
# scan  47 (  86 samples) skipped 'slew'
# scan  48 ( 128 samples) 0.121 0.120 0.122 '0428+205'
# scan  49 (  16 samples) skipped 'slew'
# scan  50 ( 127 samples) 0.052 0.054 0.052 '3C138'
# scan  51 (  56 samples) skipped 'slew'
# scan  52 ( 127 samples) 0.099 0.099 0.101 '0537-441'
# scan  53 (  18 samples) skipped 'slew'
# scan  54 ( 127 samples) 0.148 0.147 0.151 '0614-349'
# scan  55 (  36 samples) skipped 'slew'
# scan  56 ( 127 samples) 0.096 0.101 0.096 '0723-008'
# scan  57 (  17 samples) skipped 'slew'
# scan  58 ( 128 samples) 0.217 0.214 0.204 '0733-174'
# scan  59 (  29 samples) skipped 'slew'
# scan  60 ( 127 samples) 0.083 0.083 0.082 '0823-500'
# scan  61 (  62 samples) skipped 'slew'
# scan  62 ( 127 samples) 0.093 0.095 0.096 '0008-421'
# scan  63 (  19 samples) skipped 'slew'
# scan  64 ( 127 samples) 0.051 0.051 0.051 '0023-263'
# scan  65 ( 171 samples) skipped 'slew'
# scan  66 ( 129 samples) 0.175 0.180 0.179 '0056-001'
# scan  67 (  27 samples) skipped 'slew'
# scan  68 ( 127 samples) 0.033 0.033 0.033 '3C48'
# scan  69 (  60 samples) skipped 'slew'
# scan  70 ( 128 samples) 0.072 0.072 0.073 '0237-233'
# scan  71 (  56 samples) skipped 'slew'
# scan  72 ( 127 samples) 0.076 0.079 0.075 '0252-712'
# scan  73 (  85 samples) skipped 'slew'
# scan  74 ( 128 samples) 0.057 0.056 0.059 'CTA21'
# scan  75 (  88 samples) skipped 'slew'
# scan  76 ( 127 samples) 0.028 0.028 0.028 '0408-658'
# scan  77 (  99 samples) skipped 'slew'
# scan  78 ( 127 samples) 0.116 0.119 0.118 '0428+205'
# scan  79 (  16 samples) skipped 'slew'
# scan  80 ( 127 samples) 0.053 0.055 0.054 '3C138'
# scan  81 (  68 samples) skipped 'slew'
# scan  82 ( 128 samples) 0.098 0.098 0.099 '0537-441'
# scan  83 (  23 samples) skipped 'slew'
# scan  84 ( 127 samples) 0.145 0.150 0.151 '0614-349'
# scan  85 (  36 samples) skipped 'slew'
# scan  86 ( 128 samples) 0.085 0.085 0.084 '0723-008'
# scan  87 (  18 samples) skipped 'slew'
# scan  88 ( 127 samples) 0.182 0.183 0.186 '0733-174'
# scan  89 (  32 samples) skipped 'slew'
# scan  90 ( 128 samples) 0.080 0.082 0.081 '0823-500'
# scan  91 (  60 samples) skipped 'slew'
# scan  92 ( 128 samples) 0.098 0.097 0.099 '0008-421'
# scan  93 (  18 samples) skipped 'slew'
# scan  94 ( 127 samples) 0.053 0.051 0.052 '0023-263'
# scan  95 ( 172 samples) skipped 'slew'
# scan  96 ( 130 samples) 0.187 0.187 0.176 '0056-001'
# scan  97 (  40 samples) skipped 'slew'
# scan  98 ( 127 samples) 0.071 0.073 0.074 '0237-233'
# scan  99 (  50 samples) skipped 'slew'
# scan 100 ( 127 samples) 0.074 0.075 0.072 '0252-712'
# scan 101 (  76 samples) skipped 'slew'
# scan 102 ( 128 samples) 0.055 0.060 0.060 'CTA21'
# scan 103 (  78 samples) skipped 'slew'
# scan 104 ( 127 samples) 0.028 0.029 0.029 '0408-658'
# scan 105 (  89 samples) skipped 'slew'
# scan 106 ( 127 samples) 0.117 0.116 0.124 '0428+205'
# scan 107 (  15 samples) skipped 'slew'
# scan 108 ( 128 samples) 0.056 0.057 0.055 '3C138'
# scan 109 (  84 samples) skipped 'slew'
# scan 110 ( 128 samples) 0.100 0.100 0.102 '0537-441'
# scan 111 (  31 samples) skipped 'slew'
# scan 112 ( 127 samples) 0.148 0.152 0.155 '0614-349'
# scan 113 (  38 samples) skipped 'slew'
# scan 114 ( 127 samples) 0.083 0.083 0.083 '0723-008'
# scan 115 (  20 samples) skipped 'slew'
# scan 116 ( 127 samples) 0.180 0.182 0.191 '0733-174'
# scan 117 (  37 samples) skipped 'slew'
# scan 118 ( 127 samples) 0.079 0.079 0.082 '0823-500'
# scan 119 (  59 samples) skipped 'slew'
# scan 120 ( 128 samples) 0.098 0.101 0.102 '0008-421'
# scan 121 (  17 samples) skipped 'slew'
# scan 122 ( 127 samples) 0.054 0.055 0.054 '0023-263'
# scan 123 ( 175 samples) skipped 'slew'
# scan 124 ( 127 samples) 0.206 0.214 0.210 '0056-001'
# scan 125 (  40 samples) skipped 'slew'
# scan 126 ( 128 samples) 0.072 0.071 0.074 '0237-233'
# scan 127 (  44 samples) skipped 'slew'
# scan 128 ( 127 samples) 0.073 0.074 0.079 '0252-712'
# scan 129 (  69 samples) skipped 'slew'
# scan 130 ( 128 samples) 0.061 0.060 0.059 'CTA21'
# scan 131 (  70 samples) skipped 'slew'
# scan 132 ( 127 samples) 0.028 0.028 0.029 '0408-658'
# scan 133 (  79 samples) skipped 'slew'
# scan 134 ( 128 samples) 0.118 0.122 0.120 '0428+205'
# scan 135 (  14 samples) skipped 'slew'
# scan 136 ( 127 samples) 0.056 0.058 0.056 '3C138'
# scan 137 (  88 samples) skipped 'slew'
# scan 138 ( 128 samples) 0.100 0.100 0.101 '0537-441'
# scan 139 ( 162 samples) skipped 'slew'
# scan 140 ( 127 samples) 0.158 0.153 0.153 '0614-349'
# scan 141 (  58 samples) skipped 'slew'
# scan 142 ( 128 samples) 0.086 0.083 0.085 '0723-008'
# scan 143 (  21 samples) skipped 'slew'
# scan 144 ( 127 samples) 0.185 0.187 0.184 '0733-174'
# scan 145 (  44 samples) skipped 'slew'
# scan 146 ( 128 samples) 0.087 0.092 0.092 '0823-500'
# scan 147 (  44 samples) skipped 'slew'
# scan 148 ( 128 samples) 0.076 0.075 0.079 '3C237'
# scan 149 (  23 samples) skipped 'slew'
# scan 150 ( 127 samples) 0.114 0.111 0.107 '1127-145'
# scan 151 (  75 samples) skipped 'slew'
# scan 152 ( 129 samples) 0.108 0.108 0.110 '0008-421'
# scan 153 (  30 samples) skipped 'slew'
# scan 154 ( 127 samples) 0.073 0.073 0.074 '0237-233'
# scan 155 (  41 samples) skipped 'slew'
# scan 156 ( 127 samples) 0.074 0.076 0.076 '0252-712'
# scan 157 ( 132 samples) skipped 'slew'
# scan 158 ( 128 samples) 0.063 0.062 0.060 'CTA21'
# scan 159 (  62 samples) skipped 'slew'
# scan 160 ( 127 samples) 0.028 0.028 0.029 '0408-658'
# scan 161 (  72 samples) skipped 'slew'
# scan 162 ( 127 samples) 0.117 0.123 0.116 '0428+205'
# scan 163 (  16 samples) skipped 'slew'
# scan 164 ( 128 samples) 0.056 0.056 0.057 '3C138'
# scan 165 (  68 samples) skipped 'slew'
# scan 166 ( 128 samples) 0.100 0.100 0.101 '0537-441'
# scan 167 (  19 samples) skipped 'slew'
# scan 168 ( 127 samples) 0.150 0.152 0.150 '0614-349'
# scan 169 (  84 samples) skipped 'slew'
# scan 170 ( 128 samples) 0.086 0.083 0.085 '0723-008'
# scan 171 (  21 samples) skipped 'slew'
# scan 172 ( 128 samples) 0.182 0.187 0.180 '0733-174'
# scan 173 (  57 samples) skipped 'slew'
# scan 174 ( 128 samples) 0.078 0.077 0.079 '0823-500'
# scan 175 (  50 samples) skipped 'slew'
# scan 176 ( 127 samples) 0.092 0.091 0.089 '3C237'
# scan 177 (  25 samples) skipped 'slew'
# scan 178 ( 127 samples) 0.100 0.100 0.097 '1127-145'
# scan 179 (  92 samples) skipped 'slew'
# scan 180 ( 128 samples) 0.074 0.076 0.078 '0237-233'
# scan 181 (  37 samples) skipped 'slew'
# scan 182 ( 127 samples) 0.076 0.075 0.074 '0252-712'
# scan 183 ( 137 samples) skipped 'slew'
# scan 184 ( 129 samples) 0.066 0.065 0.063 'CTA21'
# scan 185 (  57 samples) skipped 'slew'
# scan 186 ( 127 samples) 0.028 0.029 0.029 '0408-658'
# scan 187 (  65 samples) skipped 'slew'
# scan 188 ( 127 samples) 0.127 0.124 0.139 '0428+205'
# scan 189 (  17 samples) skipped 'slew'
# scan 190 ( 128 samples) 0.057 0.056 0.057 '3C138'
# scan 191 (  56 samples) skipped 'slew'
# scan 192 ( 128 samples) 0.098 0.099 0.100 '0537-441'
# scan 193 (  17 samples) skipped 'slew'
# scan 194 ( 128 samples) 0.144 0.151 0.151 '0614-349'
# scan 195 (  65 samples) skipped 'slew'
# scan 196 ( 127 samples) 0.084 0.082 0.085 '0723-008'
# scan 197 (  24 samples) skipped 'slew'
# scan 198 ( 128 samples) 0.182 0.184 0.187 '0733-174'
# scan 199 (  79 samples) skipped 'slew'
# scan 200 ( 128 samples) 0.078 0.081 0.079 '0823-500'
# scan 201 (  59 samples) skipped 'slew'
# scan 202 ( 128 samples) 0.069 0.073 0.070 '3C237'
# scan 203 (  26 samples) skipped 'slew'
# scan 204 ( 127 samples) 0.092 0.092 0.094 '1127-145'
# scan 205 (  93 samples) skipped 'slew'
# scan 206 ( 127 samples) 0.080 0.078 0.080 '0237-233'
# scan 207 (  35 samples) skipped 'slew'
# scan 208 ( 127 samples) 0.075 0.075 0.075 '0252-712'
# scan 209 (  15 samples) skipped 'slew'
# scan 210 ( 127 samples) 0.029 0.028 0.029 '0408-658'
# scan 211 ( 136 samples) skipped 'slew'
# scan 212 ( 129 samples) 0.138 0.135 0.133 '0428+205'
# scan 213 (  18 samples) skipped 'slew'
# scan 214 ( 127 samples) 0.056 0.057 0.057 '3C138'
# scan 215 (  50 samples) skipped 'slew'
# scan 216 ( 128 samples) 0.097 0.100 0.099 '0537-441'
# scan 217 (  16 samples) skipped 'slew'
# scan 218 ( 127 samples) 0.144 0.147 0.148 '0614-349'
# scan 219 (  55 samples) skipped 'slew'
# scan 220 ( 127 samples) 0.082 0.081 0.083 '0723-008'
# scan 221 (  24 samples) skipped 'slew'
# scan 222 ( 128 samples) 0.182 0.185 0.182 '0733-174'
# scan 223 ( 104 samples) skipped 'slew'
# scan 224 ( 128 samples) 0.080 0.081 0.080 '0823-500'
# scan 225 (  71 samples) skipped 'slew'
# scan 226 ( 128 samples) 0.065 0.066 0.067 '3C237'
# scan 227 (  28 samples) skipped 'slew'
# scan 228 ( 127 samples) 0.091 0.090 0.092 '1127-145'
# scan 229 (  93 samples) skipped 'slew'
# scan 230 ( 127 samples) 0.086 0.089 0.088 '0237-233'
# scan 231 (  34 samples) skipped 'slew'
# scan 232 ( 127 samples) 0.076 0.077 0.078 '0252-712'
# scan 233 (  15 samples) skipped 'slew'
# scan 234 ( 127 samples) 0.028 0.029 0.029 '0408-658'
# scan 235 ( 136 samples) skipped 'slew'
# scan 236 ( 128 samples) 0.056 0.059 0.057 '3C138'
#
# Fitting 8 parameters to 44270 data points (discarded 871)...
# Condition number = 1056.358
#
# Antenna m020
# ------------
# E (m):               128.781 +- 0.01562 (was  97.025) *
# N (m):               -311.875 +- 0.01371 (was -299.636) *
# U (m):                43.972 +- 0.04814 (was   2.452) *
# Cable length (m):    5844.501 +- 0.02291 (was 5852.260) *
# Receiver delay (ns): 27850.224 +- 0.109   (was 27887.197) *
#
# Antenna m021  (*REFERENCE*)
# ------------
# E (m):               -295.948 +- 0.00000 (was -295.948)
# N (m):               -327.235 +- 0.00000 (was -327.235)
# U (m):                 0.692 +- 0.00000 (was   0.692)
# Cable length (m):    5870.283 +- 0.00000 (was 5870.283)
# Receiver delay (ns): 27973.081 +- 0.000   (was 27973.081)
#
# Antenna m023
# ------------
# E (m):               -305.993 +- 0.01571 (was -322.296) *
# N (m):               -148.477 +- 0.01385 (was -142.181) *
# U (m):                20.722 +- 0.04848 (was  -0.589) *
# Cable length (m):    5867.804 +- 0.02305 (was 5871.794) *
# Receiver delay (ns): 27961.267 +- 0.110   (was 27980.281) *

# %%
figure(1,figsize=(15,15))
figure(2,figsize=(15,15))
figure(3,figsize=(15,15))
figure(4,figsize=(15,15))
# %run -e /home/tony/Desktop/katsdpscripts/reduction/baseline_cal_reduction.py -f 2200,2800 -p 'V' -r $ref_ant \
 -a $ants  $h5_filename
# Out:
# Loading and processing data...
#
# antennas (3): m020, m021 (*ref*), m023 [pol V]
# baselines (3): 0-1 0-2 1-2
# scan   0 (   2 samples) skipped 'stop'
# scan   1 (  48 samples) skipped 'slew'
# scan   2 ( 129 samples) 0.107 0.111 0.111 '0008-421'
# scan   3 (  25 samples) skipped 'slew'
# scan   4 ( 127 samples) 0.061 0.062 0.060 '0023-263'
# scan   5 (  32 samples) skipped 'slew'
# scan   6 ( 128 samples) 0.209 0.211 0.228 '0056-001'
# scan   7 (  35 samples) skipped 'slew'
# scan   8 ( 128 samples) 0.034 0.034 0.034 '3C48'
# scan   9 (  65 samples) skipped 'slew'
# scan  10 ( 127 samples) 0.083 0.084 0.083 '0237-233'
# scan  11 (  93 samples) skipped 'slew'
# scan  12 ( 127 samples) 0.084 0.087 0.087 '0252-712'
# scan  13 (  91 samples) skipped 'slew'
# scan  14 ( 127 samples) 0.064 0.067 0.067 'CTA21'
# scan  15 (  85 samples) skipped 'slew'
# scan  16 ( 128 samples) 0.032 0.032 0.032 '0408-658'
# scan  17 (  76 samples) skipped 'slew'
# scan  18 ( 127 samples) 0.134 0.142 0.144 '0428+205'
# scan  19 (  15 samples) skipped 'slew'
# scan  20 ( 128 samples) 0.061 0.064 0.062 '3C138'
# scan  21 (  48 samples) skipped 'slew'
# scan  22 ( 128 samples) 0.113 0.114 0.113 '0537-441'
# scan  23 (  15 samples) skipped 'slew'
# scan  24 ( 127 samples) 0.174 0.176 0.170 '0614-349'
# scan  25 (  36 samples) skipped 'slew'
# scan  26 ( 128 samples) 0.105 0.108 0.104 '0723-008'
# scan  27 (  16 samples) skipped 'slew'
# scan  28 ( 127 samples) 0.218 0.231 0.226 '0733-174'
# scan  29 (  27 samples) skipped 'slew'
# scan  30 ( 128 samples) 0.097 0.101 0.097 '0823-500'
# scan  31 (  61 samples) skipped 'slew'
# scan  32 ( 127 samples) 0.109 0.110 0.108 '0008-421'
# scan  33 (  21 samples) skipped 'slew'
# scan  34 ( 128 samples) 0.057 0.058 0.058 '0023-263'
# scan  35 ( 167 samples) skipped 'slew'
# scan  36 ( 129 samples) 0.221 0.216 0.205 '0056-001'
# scan  37 (  31 samples) skipped 'slew'
# scan  38 ( 127 samples) 0.034 0.035 0.035 '3C48'
# scan  39 (  64 samples) skipped 'slew'
# scan  40 ( 128 samples) 0.080 0.083 0.082 '0237-233'
# scan  41 (  70 samples) skipped 'slew'
# scan  42 ( 127 samples) 0.084 0.086 0.084 '0252-712'
# scan  43 (  95 samples) skipped 'slew'
# scan  44 ( 127 samples) 0.066 0.065 0.068 'CTA21'
# scan  45 (  96 samples) skipped 'slew'
# scan  46 ( 127 samples) 0.032 0.032 0.033 '0408-658'
# scan  47 (  86 samples) skipped 'slew'
# scan  48 ( 128 samples) 0.140 0.140 0.139 '0428+205'
# scan  49 (  16 samples) skipped 'slew'
# scan  50 ( 127 samples) 0.059 0.061 0.059 '3C138'
# scan  51 (  56 samples) skipped 'slew'
# scan  52 ( 127 samples) 0.112 0.116 0.114 '0537-441'
# scan  53 (  18 samples) skipped 'slew'
# scan  54 ( 127 samples) 0.172 0.173 0.173 '0614-349'
# scan  55 (  36 samples) skipped 'slew'
# scan  56 ( 127 samples) 0.109 0.114 0.101 '0723-008'
# scan  57 (  17 samples) skipped 'slew'
# scan  58 ( 128 samples) 0.240 0.238 0.224 '0733-174'
# scan  59 (  29 samples) skipped 'slew'
# scan  60 ( 127 samples) 0.094 0.095 0.093 '0823-500'
# scan  61 (  62 samples) skipped 'slew'
# scan  62 ( 127 samples) 0.107 0.110 0.109 '0008-421'
# scan  63 (  19 samples) skipped 'slew'
# scan  64 ( 127 samples) 0.057 0.059 0.057 '0023-263'
# scan  65 ( 171 samples) skipped 'slew'
# scan  66 ( 129 samples) 0.216 0.227 0.218 '0056-001'
# scan  67 (  27 samples) skipped 'slew'
# scan  68 ( 127 samples) 0.036 0.037 0.036 '3C48'
# scan  69 (  60 samples) skipped 'slew'
# scan  70 ( 128 samples) 0.080 0.082 0.081 '0237-233'
# scan  71 (  56 samples) skipped 'slew'
# scan  72 ( 127 samples) 0.089 0.093 0.085 '0252-712'
# scan  73 (  85 samples) skipped 'slew'
# scan  74 ( 128 samples) 0.066 0.066 0.068 'CTA21'
# scan  75 (  88 samples) skipped 'slew'
# scan  76 ( 127 samples) 0.031 0.032 0.031 '0408-658'
# scan  77 (  99 samples) skipped 'slew'
# scan  78 ( 127 samples) 0.134 0.139 0.137 '0428+205'
# scan  79 (  16 samples) skipped 'slew'
# scan  80 ( 127 samples) 0.057 0.060 0.057 '3C138'
# scan  81 (  68 samples) skipped 'slew'
# scan  82 ( 128 samples) 0.112 0.115 0.113 '0537-441'
# scan  83 (  23 samples) skipped 'slew'
# scan  84 ( 127 samples) 0.165 0.173 0.172 '0614-349'
# scan  85 (  36 samples) skipped 'slew'
# scan  86 ( 128 samples) 0.094 0.095 0.093 '0723-008'
# scan  87 (  18 samples) skipped 'slew'
# scan  88 ( 127 samples) 0.209 0.212 0.210 '0733-174'
# scan  89 (  32 samples) skipped 'slew'
# scan  90 ( 128 samples) 0.091 0.094 0.090 '0823-500'
# scan  91 (  60 samples) skipped 'slew'
# scan  92 ( 128 samples) 0.112 0.112 0.112 '0008-421'
# scan  93 (  18 samples) skipped 'slew'
# scan  94 ( 127 samples) 0.060 0.058 0.059 '0023-263'
# scan  95 ( 172 samples) skipped 'slew'
# scan  96 ( 130 samples) 0.229 0.227 0.208 '0056-001'
# scan  97 (  40 samples) skipped 'slew'
# scan  98 ( 127 samples) 0.080 0.084 0.083 '0237-233'
# scan  99 (  50 samples) skipped 'slew'
# scan 100 ( 127 samples) 0.085 0.087 0.083 '0252-712'
# scan 101 (  76 samples) skipped 'slew'
# scan 102 ( 128 samples) 0.064 0.070 0.068 'CTA21'
# scan 103 (  78 samples) skipped 'slew'
# scan 104 ( 127 samples) 0.032 0.033 0.033 '0408-658'
# scan 105 (  89 samples) skipped 'slew'
# scan 106 ( 127 samples) 0.135 0.135 0.143 '0428+205'
# scan 107 (  15 samples) skipped 'slew'
# scan 108 ( 128 samples) 0.057 0.059 0.055 '3C138'
# scan 109 (  84 samples) skipped 'slew'
# scan 110 ( 128 samples) 0.115 0.116 0.115 '0537-441'
# scan 111 (  31 samples) skipped 'slew'
# scan 112 ( 127 samples) 0.168 0.174 0.176 '0614-349'
# scan 113 (  38 samples) skipped 'slew'
# scan 114 ( 127 samples) 0.091 0.092 0.090 '0723-008'
# scan 115 (  20 samples) skipped 'slew'
# scan 116 ( 127 samples) 0.206 0.210 0.216 '0733-174'
# scan 117 (  37 samples) skipped 'slew'
# scan 118 ( 127 samples) 0.091 0.091 0.092 '0823-500'
# scan 119 (  59 samples) skipped 'slew'
# scan 120 ( 128 samples) 0.111 0.116 0.114 '0008-421'
# scan 121 (  17 samples) skipped 'slew'
# scan 122 ( 127 samples) 0.061 0.063 0.060 '0023-263'
# scan 123 ( 175 samples) skipped 'slew'
# scan 124 ( 127 samples) 0.245 0.260 0.246 '0056-001'
# scan 125 (  40 samples) skipped 'slew'
# scan 126 ( 128 samples) 0.095 0.100 0.097 '0237-233'
# scan 127 (  44 samples) skipped 'slew'
# scan 128 ( 127 samples) 0.085 0.087 0.090 '0252-712'
# scan 129 (  69 samples) skipped 'slew'
# scan 130 ( 128 samples) 0.070 0.070 0.067 'CTA21'
# scan 131 (  70 samples) skipped 'slew'
# scan 132 ( 127 samples) 0.032 0.033 0.032 '0408-658'
# scan 133 (  79 samples) skipped 'slew'
# scan 134 ( 128 samples) 0.137 0.142 0.139 '0428+205'
# scan 135 (  14 samples) skipped 'slew'
# scan 136 ( 127 samples) 0.055 0.058 0.055 '3C138'
# scan 137 (  88 samples) skipped 'slew'
# scan 138 ( 128 samples) 0.112 0.116 0.114 '0537-441'
# scan 139 ( 162 samples) skipped 'slew'
# scan 140 ( 127 samples) 0.176 0.176 0.173 '0614-349'
# scan 141 (  58 samples) skipped 'slew'
# scan 142 ( 128 samples) 0.093 0.092 0.092 '0723-008'
# scan 143 (  21 samples) skipped 'slew'
# scan 144 ( 127 samples) 0.209 0.213 0.205 '0733-174'
# scan 145 (  44 samples) skipped 'slew'
# scan 146 ( 128 samples) 0.094 0.100 0.098 '0823-500'
# scan 147 (  44 samples) skipped 'slew'
# scan 148 ( 128 samples) 0.085 0.086 0.088 '3C237'
# scan 149 (  23 samples) skipped 'slew'
# scan 150 ( 127 samples) 0.116 0.115 0.108 '1127-145'
# scan 151 (  75 samples) skipped 'slew'
# scan 152 ( 129 samples) 0.122 0.123 0.123 '0008-421'
# scan 153 (  30 samples) skipped 'slew'
# scan 154 ( 127 samples) 0.082 0.083 0.083 '0237-233'
# scan 155 (  41 samples) skipped 'slew'
# scan 156 ( 127 samples) 0.086 0.089 0.085 '0252-712'
# scan 157 ( 132 samples) skipped 'slew'
# scan 158 ( 128 samples) 0.071 0.072 0.067 'CTA21'
# scan 159 (  62 samples) skipped 'slew'
# scan 160 ( 127 samples) 0.032 0.033 0.033 '0408-658'
# scan 161 (  72 samples) skipped 'slew'
# scan 162 ( 127 samples) 0.136 0.143 0.133 '0428+205'
# scan 163 (  16 samples) skipped 'slew'
# scan 164 ( 128 samples) 0.055 0.056 0.056 '3C138'
# scan 165 (  68 samples) skipped 'slew'
# scan 166 ( 128 samples) 0.112 0.114 0.112 '0537-441'
# scan 167 (  19 samples) skipped 'slew'
# scan 168 ( 127 samples) 0.168 0.175 0.167 '0614-349'
# scan 169 (  84 samples) skipped 'slew'
# scan 170 ( 128 samples) 0.093 0.091 0.091 '0723-008'
# scan 171 (  21 samples) skipped 'slew'
# scan 172 ( 128 samples) 0.206 0.212 0.202 '0733-174'
# scan 173 (  57 samples) skipped 'slew'
# scan 174 ( 128 samples) 0.089 0.088 0.089 '0823-500'
# scan 175 (  50 samples) skipped 'slew'
# scan 176 ( 127 samples) 0.140 0.141 0.128 '3C237'
# scan 177 (  25 samples) skipped 'slew'
# scan 178 ( 127 samples) 0.103 0.103 0.098 '1127-145'
# scan 179 (  92 samples) skipped 'slew'
# scan 180 ( 128 samples) 0.083 0.086 0.086 '0237-233'
# scan 181 (  37 samples) skipped 'slew'
# scan 182 ( 127 samples) 0.088 0.087 0.085 '0252-712'
# scan 183 ( 137 samples) skipped 'slew'
# scan 184 ( 129 samples) 0.074 0.073 0.070 'CTA21'
# scan 185 (  57 samples) skipped 'slew'
# scan 186 ( 127 samples) 0.032 0.033 0.033 '0408-658'
# scan 187 (  65 samples) skipped 'slew'
# scan 188 ( 127 samples) 0.146 0.143 0.157 '0428+205'
# scan 189 (  17 samples) skipped 'slew'
# scan 190 ( 128 samples) 0.057 0.057 0.057 '3C138'
# scan 191 (  56 samples) skipped 'slew'
# scan 192 ( 128 samples) 0.111 0.113 0.112 '0537-441'
# scan 193 (  17 samples) skipped 'slew'
# scan 194 ( 128 samples) 0.162 0.174 0.169 '0614-349'
# scan 195 (  65 samples) skipped 'slew'
# scan 196 ( 127 samples) 0.092 0.091 0.093 '0723-008'
# scan 197 (  24 samples) skipped 'slew'
# scan 198 ( 128 samples) 0.206 0.212 0.211 '0733-174'
# scan 199 (  79 samples) skipped 'slew'
# scan 200 ( 128 samples) 0.087 0.092 0.088 '0823-500'
# scan 201 (  59 samples) skipped 'slew'
# scan 202 ( 128 samples) 0.082 0.086 0.080 '3C237'
# scan 203 (  26 samples) skipped 'slew'
# scan 204 ( 127 samples) 0.095 0.096 0.097 '1127-145'
# scan 205 (  93 samples) skipped 'slew'
# scan 206 ( 127 samples) 0.089 0.088 0.087 '0237-233'
# scan 207 (  35 samples) skipped 'slew'
# scan 208 ( 127 samples) 0.086 0.087 0.085 '0252-712'
# scan 209 (  15 samples) skipped 'slew'
# scan 210 ( 127 samples) 0.033 0.033 0.033 '0408-658'
# scan 211 ( 136 samples) skipped 'slew'
# scan 212 ( 129 samples) 0.157 0.154 0.148 '0428+205'
# scan 213 (  18 samples) skipped 'slew'
# scan 214 ( 127 samples) 0.058 0.058 0.058 '3C138'
# scan 215 (  50 samples) skipped 'slew'
# scan 216 ( 128 samples) 0.110 0.114 0.110 '0537-441'
# scan 217 (  16 samples) skipped 'slew'
# scan 218 ( 127 samples) 0.164 0.171 0.165 '0614-349'
# scan 219 (  55 samples) skipped 'slew'
# scan 220 ( 127 samples) 0.093 0.092 0.093 '0723-008'
# scan 221 (  24 samples) skipped 'slew'
# scan 222 ( 128 samples) 0.208 0.216 0.207 '0733-174'
# scan 223 ( 104 samples) skipped 'slew'
# scan 224 ( 128 samples) 0.090 0.093 0.089 '0823-500'
# scan 225 (  71 samples) skipped 'slew'
# scan 226 ( 128 samples) 0.075 0.076 0.076 '3C237'
# scan 227 (  28 samples) skipped 'slew'
# scan 228 ( 127 samples) 0.095 0.094 0.095 '1127-145'
# scan 229 (  93 samples) skipped 'slew'
# scan 230 ( 127 samples) 0.094 0.098 0.096 '0237-233'
# scan 231 (  34 samples) skipped 'slew'
# scan 232 ( 127 samples) 0.087 0.088 0.087 '0252-712'
# scan 233 (  15 samples) skipped 'slew'
# scan 234 ( 127 samples) 0.032 0.034 0.033 '0408-658'
# scan 235 ( 136 samples) skipped 'slew'
# scan 236 ( 128 samples) 0.059 0.061 0.059 '3C138'
#
# Fitting 8 parameters to 40614 data points (discarded 4527)...
# Condition number = 1188.458
#
# Antenna m020
# ------------
# E (m):                92.683 +- 0.01769 (was  97.025) *
# N (m):               -298.059 +- 0.01550 (was -299.636) *
# U (m):                -3.173 +- 0.05457 (was   2.452) *
# Cable length (m):    5834.184 +- 0.02595 (was 5833.148) *
# Receiver delay (ns): 27801.063 +- 0.124   (was 27796.125) *
#
# Antenna m021  (*REFERENCE*)
# ------------
# E (m):               -295.948 +- 0.00000 (was -295.948)
# N (m):               -327.235 +- 0.00000 (was -327.235)
# U (m):                 0.692 +- 0.00000 (was   0.692)
# Cable length (m):    5871.254 +- 0.00000 (was 5871.254)
# Receiver delay (ns): 27977.708 +- 0.000   (was 27977.708)
#
# Antenna m023
# ------------
# E (m):               -322.694 +- 0.01763 (was -322.296) *
# N (m):               -142.029 +- 0.01556 (was -142.181) *
# U (m):                -1.106 +- 0.05454 (was  -0.589) *
# Cable length (m):    5872.267 +- 0.02590 (was 5872.170) *
# Receiver delay (ns): 27982.536 +- 0.123   (was 27982.072) *

# %%
res_h = !python  /home/tony/Desktop/katsdpscripts/reduction/baseline_cal_reduction.py -f 2200,2800 -p 'H' -r $ref_ant \
  -a $ants  $h5_filename

# %%
res_v = !python  /home/tony/Desktop/katsdpscripts/reduction/baseline_cal_reduction.py -f 2200,2800 -p 'V' -r $ref_ant \
  -a $ants  $h5_filename

# %%
delays_v = {}
for i,r in enumerate(res_v):
    if r.startswith('Antenna'):
        ant = r[8:12]
        delays_v[ant] = {}
        delays_v[ant]['E'] = float(res_v[i+2].split(':')[1].lstrip().split(' ')[0])
        delays_v[ant]['N'] = float(res_v[i+3].split(':')[1].lstrip().split(' ')[0])
        delays_v[ant]['U'] = float(res_v[i+4].split(':')[1].lstrip().split(' ')[0])
        delays_v[ant]['D'] = float(res_v[i+5].split(':')[1].lstrip().split(' ')[0])
delays_v
# Out:
# {'m020': {'D': 5834.184, 'E': 92.683, 'N': -298.059, 'U': -3.173},
#  'm021': {'D': 5871.254, 'E': -295.948, 'N': -327.235, 'U': 0.692},
#  'm023': {'D': 5872.267, 'E': -322.694, 'N': -142.029, 'U': -1.106}}

# %%
delays_h = {}
for i,r in enumerate(res_h):
    if r.startswith('Antenna'):
        ant = r[8:12]
        delays_h[ant] = {}
        delays_h[ant]['E'] = float(res_h[i+2].split(':')[1].lstrip().split(' ')[0])
        delays_h[ant]['N'] = float(res_h[i+3].split(':')[1].lstrip().split(' ')[0])
        delays_h[ant]['U'] = float(res_h[i+4].split(':')[1].lstrip().split(' ')[0])
        delays_h[ant]['D'] = float(res_h[i+5].split(':')[1].lstrip().split(' ')[0])
delays_h
# Out:
# {'m020': {'D': 5844.501, 'E': 128.781, 'N': -311.875, 'U': 43.972},
#  'm021': {'D': 5870.283, 'E': -295.948, 'N': -327.235, 'U': 0.692},
#  'm023': {'D': 5867.804, 'E': -305.993, 'N': -148.477, 'U': 20.722}}

# %%
# write solutions to file
matchRe = re.findall('[0-9]{10,}', h5_filename)
filename='delay_file_'+''.join(matchRe)+'.txt'

with open(filename, 'w') as f:
    for h,v in zip(delays_h,delays_v):
        print >> f, h,v, mean([delays_h[h]['E'],delays_v[v]['E']]) , \
                    mean([delays_h[h]['N'],delays_v[v]['N']]), \
                    mean([delays_h[h]['U'],delays_v[v]['U']]), \
                    delays_h[h]['D'],delays_v[v]['D']
    f.close()

# %%
# send file to ops server to process and push to github

opsServer='ops.kat.ac.za'
rPath='/home/kat/ops_team_sw/utilities/update_delay_models'
cmd = "sshpass -p {} scp -r {} kat@{}:{}".format('kat', filename, opsServer, rPath)
system(cmd)
# Out:
# 32512

# %%
# sort delay file by antenna name and load antennaLOC
sample = open(filename, 'r')
sorter = csv.reader(sample, delimiter=' ')
sort = sorted(sorter, key=operator.itemgetter(1))

with open('ant_loc.csv', 'r') as f:
    tocs = f.read()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-37-4ad61ec70eff> in <module>()
#       4 sort = sorted(sorter, key=operator.itemgetter(1))
#       5
# ----> 6 with open('ant_loc.csv', 'r') as f:
#       7     tocs = f.read()
#
# IOError: [Errno 2] No such file or directory: 'ant_loc.csv'

# %%
cols = ['Ants', 'Delay', 'East', 'North', 'UP', 'TOC']
df = pd.DataFrame(columns=cols)
for line in sort:
    p = re.compile(line[0]+',\s+\d{4}\.\d{1,3}')
    toc = float(p.search(tocs).group()[6:])
    df = df.append(pd.Series(
                             [
                                line[0],
                                line[-2],
                                line[2],
                                line[3],
                                line[4], 
                                toc
                             ], 
                              index=['Ants', 'Delay', 'East', 'North', 'UP', 'TOC']
                            ), ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-17a9a4c702fe> in <module>()
#       3 for line in sort:
#       4     p = re.compile(line[0]+',\s+\d{4}\.\d{1,3}')
# ----> 5     toc = float(p.search(tocs).group()[6:])
#       6     df = df.append(pd.Series(
#       7                              [
#
# NameError: name 'tocs' is not defined

# %%
deltaTOC, deltaUP = [], []
deltaTOC.append(0)
deltaUP.append(0)
for i in range(1, len(df.TOC[1:])+1):
    deltaTOC.append(df.TOC[i] - df.TOC[i-1])
    deltaUP.append(float(df.UP[i]) - float(df.UP[i-1]))

em  = [' ' for i in range(len(deltaUP))]
df[' '] =  pd.Series(em,  index = df.index)

df['delta UP']  = pd.Series(deltaUP,  index = df.index)
df['delta TOC'] = pd.Series(deltaTOC, index = df.index)

print('\nDelay Solutions and antenna locations\n')
df
