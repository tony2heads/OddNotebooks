# %%
# %matplotlib inline
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import katarchive

import datetime

import logging
logging.root.setLevel(logging.ERROR)

# %%
katarchive.product_filter.only_ar1()

begin="01/03/2017"
end="31/03/2017"

# %%
def channels(details):
    ch32k="32768"
    mode="4k" # default
    if ch32k in details:
        mode="32k"
    return mode

# %%
print katarchive.search_archive(startdate=begin,enddate=end)
# Out:
# Searched using: CAS.ProductTypeName:(MeerKATAR1TelescopeProduct) AND CAS.ProductTransferStatus:RECEIVED AND StartTime:[2017-02-28T22:00:00Z TO 2017-03-31T21:59:59Z]
# Returning 132 results
# [['1489327995.h5', '2017-03-12 16:13:16 SAST', 'Audrey', 93375917088], ['1489306255.h5', '2017-03-12 10:10:56 SAST', 'AR1', 69761303055], ['1489306062.h5', '2017-03-12 10:07:43 SAST', 'Fannie', 413195983], ['1489298405.h5', '2017-03-12 08:00:09 SAST', 'Audrey', 16326028143], ['1489296111.h5', '2017-03-12 07:21:55 SAST', 'Sarah', 430480982], ['1489295721.h5', '2017-03-12 07:15:26 SAST', 'Sarah', 506594216], ['1489253756.h5', '2017-03-11 19:36:00 SAST', 'Audrey', 93405221963], ['1489253386.h5', '2017-03-11 19:29:51 SAST', 'Audrey', 439174477], ['1489240950.h5', '2017-03-11 16:02:30 SAST', 'Fannie', 165170968], ['1489240455.h5', '2017-03-11 15:54:16 SAST', 'Fannie', 508554652], ['1489239295.h5', '2017-03-11 15:34:59 SAST', 'Fannie', 237545913], ['1489238888.h5', '2017-03-11 15:28:12 SAST', 'Fannie', 724185777], ['1489238376.h5', '2017-03-11 15:19:41 SAST', 'Fannie', 235294040], ['1489237854.h5', '2017-03-11 15:10:58 SAST', 'Fannie', 721754001], ['1489237089.h5', '2017-03-11 14:58:24 SAST', 'Fannie', 899703190], ['1489153349.h5', '2017-03-10 15:42:37 SAST', 'CAM', 3195740], ['1489152979.h5', '2017-03-10 15:36:29 SAST', 'CAM', 3226187], ['1489152124.h5', '2017-03-10 15:22:15 SAST', 'CAM', 3193217], ['1489151032.h5', '2017-03-10 15:04:02 SAST', 'CAM', 3195044], ['1489149886.h5', '2017-03-10 14:45:49 SAST', 'CAM', 3030157], ['1489149548.h5', '2017-03-10 14:39:09 SAST', 'AR1', 53687539271], ['1489149314.h5', '2017-03-10 14:35:15 SAST', 'KB', 219494356], ['1489146714.h5', '2017-03-10 13:52:55 SAST', 'CAM', 3294436], ['1489140423.h5', '2017-03-10 12:07:45 SAST', 'CAM', 3010909], ['1489128105.h5', '2017-03-10 08:41:49 SAST', 'KB', 36458437787], ['1489127998.h5', '2017-03-10 08:40:02 SAST', 'AR1', 142617481], ['1489127835.h5', '2017-03-10 08:37:21 SAST', 'Lindsay', 67968042], ['1489097011.h5', '2017-03-10 00:03:36 SAST', 'Tom', 65148506759], ['1489071776.h5', '2017-03-09 17:03:01 SAST', 'Audrey', 57276649720], ['1489071607.h5', '2017-03-09 17:00:11 SAST', 'Audrey', 269956454], ['1489069933.h5', '2017-03-09 16:32:19 SAST', 'AR1', 3441246864], ['1489066825.h5', '2017-03-09 15:40:30 SAST', 'KB', 375875025], ['1489064833.h5', '2017-03-09 15:08:19 SAST', 'CAM', 3031924], ['1489059915.h5', '2017-03-09 13:45:21 SAST', 'Lindsay', 8066838752], ['1489058620.h5', '2017-03-09 13:23:41 SAST', 'KB', 40835999], ['1489058079.h5', '2017-03-09 13:14:39 SAST', 'KB', 238279356], ['1489055954.h5', '2017-03-09 12:39:15 SAST', 'CAM', 234736291], ['1489055293.h5', '2017-03-09 12:28:14 SAST', 'CAM', 230526884], ['1489054669.h5', '2017-03-09 12:17:51 SAST', 'schwardt', 228903326], ['1489049138.h5', '2017-03-09 10:45:51 SAST', 'CAM', 2993857], ['1489048910.h5', '2017-03-09 10:41:55 SAST', 'Lindsay', 2596572799], ['1489048761.h5', '2017-03-09 10:39:34 SAST', 'CAM', 1978491], ['1489048310.h5', '2017-03-09 10:31:57 SAST', 'CAM', 2993534], ['1489047991.h5', '2017-03-09 10:26:50 SAST', 'CAM', 2999750], ['1489044469.h5', '2017-03-09 09:28:37 SAST', 'chris', 3234145], ['1488995870.h5', '2017-03-08 19:57:51 SAST', 'Audrey', 357766714], ['1488994533.h5', '2017-03-08 19:35:34 SAST', 'Lindsay', 1706203743], ['1488992652.h5', '2017-03-08 19:04:13 SAST', 'Audrey', 345722590], ['1488986896.h5', '2017-03-08 17:28:21 SAST', 'Audrey', 204241965], ['1488985028.h5', '2017-03-08 16:57:12 SAST', 'Audrey', 284072183], ['1488984373.h5', '2017-03-08 16:46:18 SAST', 'Audrey', 293708072], ['1488981200.h5', '2017-03-08 15:53:24 SAST', 'AR1', 2447563958], ['1488980716.h5', '2017-03-08 15:45:20 SAST', 'AR1', 422571539], ['1488980253.h5', '2017-03-08 15:37:38 SAST', 'AR1', 146906035], ['1488979714.h5', '2017-03-08 15:28:38 SAST', 'AR1', 264861800], ['1488979423.h5', '2017-03-08 15:23:49 SAST', 'AR1', 52897131], ['1488977204.h5', '2017-03-08 14:46:53 SAST', 'CAM', 224931712], ['1488976702.h5', '2017-03-08 14:43:27 SAST', 'CAM', 261852215], ['1488976826.h5', '2017-03-08 14:40:44 SAST', 'CAM', 67164216], ['1488975563.h5', '2017-03-08 14:19:41 SAST', 'CAM', 66707641], ['1488974304.h5', '2017-03-08  ...

# %%
f = katarchive.search_archive(startdate=begin,enddate=end)
start = datetime.datetime.strptime(f[-1].__str__().split('\'')[3],'%Y-%m-%d %H:%M:%S %Z')
end = datetime.datetime.strptime(f[0].__str__().split('\'')[3],'%Y-%m-%d %H:%M:%S %Z')
# Out:
# Searched using: CAS.ProductTypeName:(MeerKATAR1TelescopeProduct) AND CAS.ProductTransferStatus:RECEIVED AND StartTime:[2017-02-28T22:00:00Z TO 2017-03-31T21:59:59Z]
# Returning 132 results

# %%
#print 'First file in run: ' , start.isoformat()
#print 'Last file in run: ' , end.isoformat()

# %%
f.sort(key=lambda k: k.metadata.StartTime)

# %%
for fi in f:
    txts=fi.metadata.InstructionSet
    #p=findproj(txts)
    print fi.metadata.ExperimentID, np.round(fi.metadata.Duration/3600.,2),"hrs",\
    len(fi.metadata.Antennas),channels(fi.metadata.Details),fi.metadata.Description
    
    #print("%13s %6.2fhrs %2dants %3s %s") %(fi.metadata.ExperimentID, np.round(fi.metadata.Duration/3600.,2),\
    #len(fi.metadata.Antennas),channels(fi.metadata.Details),fi.metadata.Description)
# Out:
# 20170301-0001 0.12 hrs 9 4k Generic AR1 phaseup
# 20170301-0001 0.0 hrs 1 4k Target track
# 20170301-0001 0.06 hrs 1 4k Target track
# 20170301-0003 0.02 hrs 1 4k Testing beamformer capture (full-band, 1min)
# 20170303-0043 0.02 hrs 1 4k PTUSE: Testing
# 20170302-0002 0.02 hrs 1 4k Testing beamformer capture (full-band, 1min)
# 20170302-0003 0.02 hrs 1 4k Testing beamformer capture (full-band, 1min)
# 20170302-0004 0.02 hrs 1 4k Testing beamformer capture (full-band, 1min)
# 20170306-0003 0.02 hrs 1 4k PTUSE: Testing
# 20170302-0005 0.02 hrs 1 4k Testing beamformer capture (full-band, 1min)
# 20170303-0001 0.02 hrs 1 4k Testing beamformer capture (full-band, 1min)
# 20170303-0002 0.02 hrs 1 4k Testing beamformer capture (full-band, 1min)
# 20170303-0003 0.02 hrs 1 4k Testing beamformer capture (full-band, 1min)
# 20170303-0004 0.02 hrs 1 4k Testing beamformer capture (full-band, 1min)
# 20170303-0005 0.02 hrs 1 4k Testing beamformer capture (full-band, 1min)
# 20170303-0002 0.03 hrs 2 4k Basic test
# 20170303-0011 0.02 hrs 1 4k Testing beamformer capture (full-band, 1min)
# 20170303-0021 0.02 hrs 1 4k Testing beamformer capture (full-band, 1min)
# 20170303-0004 0.1 hrs 10 4k Basic track
# 20170303-0004 0.02 hrs 10 4k Basic track
# 20170303-0004 0.07 hrs 10 4k Basic phase-up
# 20170303-0004 0.06 hrs 10 4k Basic phase-up
# 20170303-0004 0.07 hrs 10 4k Basic phase-up
# 20170303-0004 0.08 hrs 10 4k Basic phase-up
# 20170303-0004 0.02 hrs 10 4k Basic track
# 20170303-0004 0.08 hrs 10 4k Basic phase-up
# 20170303-0004 0.12 hrs 10 4k Basic phase-up
# 20170303-0004 0.01 hrs 10 4k Basic beamform
# 20170303-0005 0.02 hrs 10 4k Basic beamform on pulsar
# 20170303-0005 0.08 hrs 10 4k Basic phase-up
# 20170303-0005 0.03 hrs 10 4k Basic beamform on pulsar
# 20170303-0006 0.02 hrs 10 32k Basic track
# 20170303-0006 0.09 hrs 10 32k Basic phase-up
# 20170303-0006 0.02 hrs 10 32k Basic phase-up
# 20170303-0006 0.02 hrs 10 32k Basic phase-up
# 20170303-0006 0.02 hrs 10 32k Basic phase-up
# 20170303-0006 0.05 hrs 10 32k Basic phase-up
# 20170306-0005 0.34 hrs 1 4k PTUSE: Testing
# 20170307-0019 0.15 hrs 11 32k Operation test
# 20170307-0021 0.38 hrs 11 32k AR1: Basic functionality test
# 20170307-0022 0.05 hrs 11 32k Generic AR1 phaseup
# 20170307-0023 0.05 hrs 11 32k Generic AR1 phaseup
# 20170307-0024 0.03 hrs 11 32k Generic AR1 phaseup
# 20170307-0026 0.05 hrs 11 32k Generic AR1 phaseup
# 20170307-0028 0.12 hrs 11 32k AR1: MKAIV-111 L-band Pointing L Band
# 20170307-0034 0.52 hrs 11 32k Baseline Calibration (Delay model calculation)
# 20170307-0035 0.04 hrs 11 4k Generic AR1 phaseup
# 20170307-0036 0.03 hrs 11 4k Generic AR1 phaseup
# 20170307-0037 0.35 hrs 11 4k AR1: Basic functionality test
# 20170307-0041 0.52 hrs 11 4k Baseline Calibration (Delay model calculation)
# 20170307-0045 6.05 hrs 11 4k Interferometric Pointing Calibration
# 20170308-0001 0.34 hrs 1 4k PTUSE: Testing
# 20170308-0002 0.34 hrs 1 4k PTUSE: Testing
# 20170308-0001 0.36 hrs 9 4k AR1: Basic functionality test
# 20170308-0003 0.34 hrs 1 4k PTUSE: Testing
# 20170308-0003 0.13 hrs 9 4k AR1: MKAIV-78 Quick Check Point Source Scan
# 20170308-0004 0.34 hrs 1 4k PTUSE: Testing
# 20170308-0005 0.0 hrs 1 4k PTUSE: Testing
# 20170308-0006 0.0 hrs 1 4k PTUSE: Testing
# 20170308-0011 0.34 hrs 1 4k PTUSE: Testing junk J0437-4715
# 20170308-0004 0.03 hrs 9 4k beamformer capture test
# 20170308-0005 0.03 hrs 9 4k beamformer capture test
# 20170308-0006 0.03 hrs 9 4k beamformer capture test
# 20170308-0012 0.34 hrs 1 4k PTUSE: Testing junk J0437-4715
# 20170308-0007 0.03 hrs 9 4k beamformer capture test
# 20170308-0008 0.03 hrs 9 4k beamformer capture test
# 20170308-0013 0.34 hrs 1 4k PTUSE: Testing junk J0437-4715
# 20170308-0009 0.03 hrs 9 4k beamformer capture test
# 20170308-0014 0.34 hrs 1 4k PTUSE: Testing junk J0437-4715
# 20170308-0010 0.03 hrs 9 4k beamformer capture test
# 20170308-0011 0.03 hrs 9 4k beamformer capture test
# 20170308-0015 0.34 hrs 1 4k PTUSE: Testing junk J0437-4715
# 20170308-0016 0.34 hrs 1 4k PTUSE: Testing junk J0437-4715
# 20170308-0017 0.34 hrs 1 4k PTUSE: Testing junk J0437-4715
# 20170308-0012 0.04 hrs 9 4k beamformer capture test
# 20170308-0013 0.03 hrs 9 4k beamformer capture test
# 20170308-0014 0.01 hrs 9 4k Generic AR1 phaseup
# 20170308-0015 0.04 hrs 9 4k Generic AR1 phaseup
# 20170308-0016 0.02 hrs 9 4k AR1: MKAIV-215 Phase-up 0408
# 20170308-0017 0.06 hrs 9 4k AR1: Basic functionality test
# 20170308-0018 0.35 hrs 9 4k AR1: Basic functionality test
# 20170308-0019 0.03 hrs 10 4k Generic AR1 phaseup
# 20170308-0020 0.03 hrs 10 4k Generic AR1 phaseup
# 20170308-0021 0.02 hrs 10 4k Generic AR1 phaseup
# 20170308-0022 0.06 hrs 8 4k AR1: Basic functionality test
# 20170308-0023 0.32 hrs 8 4k Interferometric Pointing Calibration
# 20170308-0024 0.07 hrs 8 4k AR1: Basic functionality test
# 20170309-0003 0.02 hrs 1 4k Beamformer: J1909-3744
# 20170309-0004 0.02 hrs 1 4k Beamformer: J1909-3744
# 20170309-0005 0.02 hrs 1 4k Beamformer: J1909-3744
# 20170309-0006 0.01 hrs 1 4k Beamformer: J1909-3744
# 20170309-0001 0.32 hrs 10 4k Interferometric Pointing Calibration
# 20170309-0007 0.02 hrs 1 4k Beamformer: J1909-3744
# 20170309-0002 0.1 hrs 10 4k Very basic single-pol test
# 20170309-0003 0.1 hrs 10 4k Very basic single-pol test
# 20170309-0004 0.1 hrs 10 4k Generic AR1 phaseup
# 20170309-0005 0.1 hrs 10 4k Generic AR1 phaseup
# 20170309-0006 0.01 hrs 10 4k Interferometric Pointing Calibration
# 20170309-0009 1.5 hrs 8 4k Interferometric Pointing Calibration
# 20170309-0001 0.02 hrs 1 4k Beamformer: J0437-4715
# 20170309-0010 0.06 hrs 8 4k Generic AR1 phaseup
# 20170309-0011 0.42 hrs 10 4k Three calibrator imaging
# 20170309-0013 0.03 hrs 10 4k Generic AR1 phaseup
# 20170309-0012 7.0 hrs 10 4k Three calibrator imaging
# 20170309-0014 7.95 hrs 10 4k Imaging observation SCP
# 20170310-0001 0.01 hrs 9 4k Baseline Calibration (Delay model calculation)
# 20170310-0003 0.02 hrs 9 4k AR1: MKAIV-216 Phase-down
# 20170310-0002 5.44 hrs 9 4k Baseline Calibration (Delay model calculation)
# 20170310-0001 0.02 hrs 1 4k Beamformer: J0437-4715
# 20170310-0002 0.02 hrs 1 4k Beamformer: J1909-3744
# 20170310-0007 0.03 hrs 9 4k Generic AR1 phaseup
# 20170310-0005 8.0 hrs 9 4k Three calibrator imaging
# 20170310-0004 0.02 hrs 1 4k Beamformer: J0437-4715
# 20170310-0005 0.02 hrs 1 4k Beamformer: J0437-4715
# 20170310-0006 0.02 hrs 1 4k Beamformer: J0437-4715
# 20170310-0007 0.02 hrs 1 4k Beamformer: J0437-4715
# 20170310-0008 0.02 hrs 1 4k Beamformer: J0437-4715
# 20170311-0001 0.08 hrs 12 4k AR1: Basic functionality test
# 20170311-0002 0.06 hrs 12 4k AR1: Basic functionality test
# 20170311-0003 0.02 hrs 12 4k Generic AR1 phaseup
# 20170311-0004 0.06 hrs 12 4k AR1: Basic functionality test
# 20170311-0005 0.02 hrs 12 4k Generic AR1 phaseup
# 20170311-0006 0.06 hrs 10 4k AR1: Basic functionality test
# 20170311-0007 0.02 hrs 10 4k Generic AR1 phaseup
# 20170311-0009 0.04 hrs 12 4k Generic AR1 phaseup
# 20170311-0008 8.07 hrs 12 4k Imaging observation SCP
# 20170312-0001 0.03 hrs 12 4k Generic AR1 phaseup
# 20170312-0002 0.02 hrs 12 4k Generic AR1 phaseup
# 20170311-0011 1.39 hrs 12 4k Three calibrator imaging
# 20170312-0004 0.03 hrs 12 4k Generic AR1 phaseup
# 20170312-0005 6.0 hrs 12 4k Three calibrator imaging
# 20170311-0012 8.03 hrs 12 4k Imaging observation SCP

# %% [markdown]
# Only select observations that are longer than 1 hrs then extract the project id from the script parameters. If there is no project id then allocated No_project_id

# %%
sbd = [] #Experiment ID
pid = [] #project ID
fnd = [] #Filename
dud = [] #Duration
antsd = [] #number of antennas
scrd = [] #script  -NOT USED NOW

for fi in f:
    if fi.metadata.Duration < 3600: #only pick hour long or greater observations for analysis
        continue
    # now try extract the project-id from the instruction-set string
    """
    script = fi.metadata.InstructionSet
    scrd.append(script)
    spl = script.split()
    """
    txts=fi.metadata.InstructionSet
    #p=findproj(txts)
    p=fi.metadata.Description# ignore "AR1...
    sbd.append(fi.metadata.ExperimentID) 
    pid.append(p)
    fnd.append(fi.metadata.Filename)
    dud.append(fi.metadata.Duration)
    antsd.append(len(fi.metadata.Antennas))
    #print p

# %%
pi = np.array(pid)
sb = np.array(sbd)
du = np.array(dud)
ants = np.array(antsd)

p_cent = (sum(du)/((end.toordinal()-start.toordinal())*24*3600))*100

print 'Percentage system usage: ', np.floor(p_cent),'%'
# Out:
# Percentage system usage:  22.0 %

# %%
a_id = []
a_time = []
for p in set(pi):
    ind = pi == p
    #print p,round(sum(du[ind])/3600,2)
    a_id.append(p)
    a_time.append(round(sum(du[ind])/3600,2))

# %%
ind = np.argsort(a_id)
for i in ind:
    print ("%-16s %5.1fhrs with %d ants") %(a_id[i],a_time[i],ants[i])
# Out:
# Baseline Calibration (Delay model calculation)   5.4hrs with 11 ants
# Imaging observation SCP  24.1hrs with 10 ants
# Interferometric Pointing Calibration   7.5hrs with 8 ants
# Three calibrator imaging  22.4hrs with 10 ants

# %% [markdown]
# Find the unique project ids and determine the total observation duration.

# %% [markdown]
# Sort ID and time for display

# %% [markdown]
# Plot as pie-chart

# %%
cmap = plt.cm.prism
colors = cmap(np.linspace(0., 1., 7))

# %%
plt.figure(figsize=(20,20))
plt.pie(a_time,labels=a_id,colors=colors,autopct='%1.1f%%');

# %%
plt.show()
