# %%
# %matplotlib inline
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import katarchive

import datetime

import logging
logging.root.setLevel(logging.ERROR)

# %%
def findproj(text):
    found='Unknown'        # default
    chx=text.find('prop')
    if chx >0  :
        pr2=text[chx+11:chx+38].split()
        code=pr2[0]
        found=code.replace("=","")
    else:
        if text.find('maser') >0:
            found="Maser monitoring"
            #print text
    return found

# %%
today=datetime.datetime.today()
ago=datetime.timedelta(-7)
lastweek=today+ago
print today,lastweek
begin=lastweek.strftime(format="%d/%m/%Y")
end=today.strftime(format="%d/%m/%Y")
# Out:
# 2016-05-17 16:28:57.579226 2016-05-10 16:28:57.579226

# %%
print katarchive.search_archive(startdate=begin,enddate=end)
# Out:
# Searched using: CAS.ProductTypeName:(KatFile) AND CAS.ProductTransferStatus:RECEIVED AND StartTime:[2016-05-09T22:00:00Z TO 2016-05-17T21:59:59Z]
# Returning 88 results
# [['1', '2016-05-17 16:07:22 SAST', 'comm_test', [140656451]], ['1', '2016-05-17 15:48:22 SAST', 'BF', [831778011]], ['1', '2016-05-17 15:45:05 SAST', 'comm_test', [141474885]], ['1', '2016-05-17 15:13:23 SAST', 'BF', [925488944]], ['1', '2016-05-17 15:09:31 SAST', 'comm_test', [159449268]], ['1', '2016-05-17 15:07:45 SAST', 'BF', [62608785]], ['1', '2016-05-17 14:11:15 SAST', 'BF', [277354999]], ['1', '2016-05-17 14:05:48 SAST', 'comm_test', [164892633]], ['1', '2016-05-17 14:04:05 SAST', 'BF', [63368614]], ['1', '2016-05-17 13:47:27 SAST', 'BF', [278148880]], ['1', '2016-05-17 13:43:25 SAST', 'comm_test', [162557492]], ['1', '2016-05-17 13:36:47 SAST', 'BF', [89147690]], ['1', '2016-05-17 09:22:06 SAST', 'Sean', [5774175950]], ['1', '2016-05-17 09:12:32 SAST', 'operator', [77435387]], ['1', '2016-05-17 00:11:15 SAST', 'Nadeem', [158755902]], ['1', '2016-05-17 00:08:30 SAST', 'operator', [87549883]], ['1', '2016-05-16 19:14:17 SAST', 'Sean', [5288049474]], ['1', '2016-05-16 19:11:25 SAST', 'operator', [368355768]], ['1', '2016-05-16 17:51:40 SAST', 'Nadeem', [381893044]], ['1', '2016-05-16 17:50:19 SAST', 'operator', [35272402]], ['1', '2016-05-16 17:45:18 SAST', 'operator', [90718733]], ['1', '2016-05-16 17:30:17 SAST', 'Nadeem', [31998516]], ['1', '2016-05-16 17:28:46 SAST', 'operator', [35292975]], ['1', '2016-05-16 17:11:08 SAST', 'operator', [293739182]], ['1', '2016-05-16 15:49:17 SAST', 'Tony', [39935033]], ['1', '2016-05-16 15:43:37 SAST', 'operator', [36068533]], ['1', '2016-05-16 15:38:58 SAST', 'operator', [118824728]], ['1', '2016-05-16 13:19:00 SAST', 'Nadeem', [2979769496]], ['1', '2016-05-16 13:16:33 SAST', 'operator', [88372061]], ['1', '2016-05-16 11:16:59 SAST', 'Sean', [3417716060]], ['1', '2016-05-16 11:14:31 SAST', 'operator', [88365590]], ['1', '2016-05-16 07:51:38 SAST', 'Tony', [600992810]], ['1', '2016-05-16 07:49:13 SAST', 'operator', [80588222]], ['1', '2016-05-16 02:40:17 SAST', 'Lindsay', [1511580537]], ['1', '2016-05-16 02:36:11 SAST', 'operator', [88392196]], ['1', '2016-05-15 18:28:22 SAST', 'Tony', [2359181766]], ['1', '2016-05-15 18:24:12 SAST', 'operator', [87569146]], ['1', '2016-05-15 14:12:39 SAST', 'Nadeem', [1216499944]], ['1', '2016-05-15 14:10:06 SAST', 'operator', [87614950]], ['1', '2016-05-15 08:02:17 SAST', 'Nadeem', [1802439161]], ['1', '2016-05-15 07:58:15 SAST', 'operator', [80562111]], ['1', '2016-05-15 00:19:14 SAST', 'Nadeem', [162732529]], ['1', '2016-05-15 00:15:15 SAST', 'operator', [88392022]], ['1', '2016-05-14 15:01:01 SAST', 'Tony', [2654544944]], ['1', '2016-05-14 14:59:00 SAST', 'operator', [58728719]], ['1', '2016-05-14 07:50:17 SAST', 'Nadeem', [2100176861]], ['1', '2016-05-14 07:46:16 SAST', 'operator', [80564348]], ['1', '2016-05-14 00:23:12 SAST', 'Nadeem', [162721463]], ['1', '2016-05-14 00:19:14 SAST', 'operator', [125863971]], ['1', '2016-05-13 20:35:21 SAST', 'Nadeem', [1057043909]], ['1', '2016-05-13 20:31:16 SAST', 'operator', [87577497]], ['1', '2016-05-13 16:56:17 SAST', 'Nadeem', [909146019]], ['1', '2016-05-13 16:40:03 SAST', 'operator', [50118621]], ['1', '2016-05-13 13:52:29 SAST', 'Sean', [1732935822]], ['1', '2016-05-13 13:49:41 SAST', 'operator', [368368919]], ['1', '2016-05-13 09:00:27 SAST', 'Nadeem', [1264711409]], ['1', '2016-05-13 08:57:55 SAST', 'operator', [88362660]], ['1', '2016-05-12 23:38:20 SAST', 'Nadeem', [2651177904]], ['1', '2016-05-12 23:34:15 SAST', 'operator', [88367838]], ['1', '2016-05-12 16:45:58 SAST', 'Nadeem', [1672648995]], ['1', '2016-05-12 16:43:36 SAST', 'operator', [35274170]], ['1', '2016-05-12 16:39:11 SAST', 'operator', [35267170]], ['1', '2016-05-12 14:44:53 SAST', 'operator', [59490325]], ['1', '2016-05-12 14:36:59 SAST', 'operator', [7758637]], ['1', '2016-05-12 12:57:51 SAST', 'operator', [8095993]], ['1', '2016-05-12 11:42:18 SAST', 'operator', [7281534]], ['1', '2016-05-12 11:29:04 SAST', 'operator', [13549604]], ['1', '2016-05-12 11:22:41 SAST', 'operator', [13599589]], ['1', '2016-05-12 09:24:25 SAST', 'Nad ...

# %%
f = katarchive.search_archive(startdate=begin)
start = datetime.datetime.strptime(f[-1].__str__().split('\'')[3],'%Y-%m-%d %H:%M:%S %Z')
end = datetime.datetime.strptime(f[0].__str__().split('\'')[3],'%Y-%m-%d %H:%M:%S %Z')
# Out:
# Searched using: CAS.ProductTypeName:(KatFile) AND CAS.ProductTransferStatus:RECEIVED AND StartTime:[2016-05-09T22:00:00Z TO 2016-05-17T21:59:59Z]
# Returning 88 results

# %%
#print 'First file in run: ' , start.isoformat()
#print 'Last file in run: ' , end.isoformat()

# %%
for fi in f:
    txts=fi.metadata.InstructionSet
    p=findproj(txts)
    print fi.metadata.ExperimentID, p, fi.metadata.Duration, fi.metadata.Description, len(fi.metadata.Antennas)
# Out:
# 2 Unknown 179.01 Phaseup observation setting f-engine weights 6
# 2 Unknown 1064.08 Cand obs with ant1-6 and phaseup 6
# 2 Unknown 180.01 Phaseup observation setting f-engine weights 6
# 2 Unknown 1186.09 Cand obs with ant1-6 and phaseup 6
# 2 Unknown 203.02 Phaseup observation setting f-engine weights 6
# 2 Unknown 79.01 Auto atten 6
# 2 Unknown 354.03 Vela obs with ant1-6 and phaseup 6
# 2 Unknown 210.02 Phaseup observation setting f-engine weights 6
# 2 Unknown 80.01 Auto atten 6
# 2 Unknown 356.03 Vela obs with ant1-6 and phaseup 6
# 2 Unknown 207.02 Phaseup observation setting f-engine weights 6
# 2 Unknown 113.01 Auto atten 6
# 2 COMM_RFI_SP 7394.59 Basic RFI Scan: RFI SCAN 6
# 2 COMM_Atten 98.01 Auto atten 6
# 2 20140729RT-01 990.01 N4_Observe_2_1822Mhz 6
# 2 COMM_Atten 111.01 Auto atten 6
# 2 20150825YL-01 16115.5 HI Galaxy Clusters : RR 210 mosaic 6
# 2 COMM_Atten 113.75 Auto atten 6
# 2 COMM_Image_NO 4660.06 Imaging Calibration 6
# 2 COMM_Atten 44.0 Auto atten 6
# 2 COMM_Atten 115.01 Auto atten 6
# 2 COMM_Image_NO 380.01 Imaging Calibration 6
# 2 COMM_Atten 44.0 Auto atten 6
# 2 COMM_Atten 90.6 Auto atten 6
# 2 COMM_Bandpass_TF 50.0 Interferometric Pointining 6
# 2 COMM_Atten 45.0 Auto atten 6
# 2 COMM_Atten 151.01 Auto atten 6
# 2 COMM_Tipping_NO 3815.3 Tipping Curve 6
# 2 COMM_Atten 112.01 Auto atten 6
# 2 COMM_RFI_SP 4376.35 Basic RFI Scan: RFI SCAN 6
# 2 COMM_Atten 112.01 Auto atten 6
# 2 COMM_Bandpass_TF 7340.1 Bandpass Calibrators 6
# 2 COMM_Atten 102.01 Auto atten 6
# 2 20141111IM-01 18480.26 LS5039_2 6
# 2 COMM_Atten 112.01 Auto atten 6
# 2 20150619TF-01 28850.4 3C279 6
# 2 COMM_Atten 111.01 Auto atten 6
# 2 COMM_Image_NO 14870.21 Imaging Calibration 6
# 2 COMM_Atten 111.01 Auto atten 6
# 2 20150217RT-01 22030.3 NGC_1808 - 1850MHz 6
# 2 COMM_Atten 102.01 Auto atten 6
# 2 20140729RT-01 1015.01 N4_Observe_2 6
# 2 COMM_Atten 112.01 Auto atten 6
# 2 COMM_Bandpass_TF 32460.45 Bandpass Calibrators 6
# 2 COMM_Atten 74.01 Auto atten 6
# 2 20130822NO-01 25680.36 W2332_5056 6
# 2 COMM_Atten 102.01 Auto atten 6
# 2 20140729RT-01 1015.01 N4_Observe_2_1822Mhz 6
# 2 COMM_Atten 160.01 Auto atten 6
# 2 20141125NO-01 12920.18 ATEL6733 6
# 2 COMM_Atten 111.01 Auto atten 6
# 2 COMM_Image_NO 11110.15 Imaging Calibration 6
# 2 COMM_Atten 63.0 Auto atten 6
# 2 COMM_RFI_SP 3231.1 RFI Scan in c16n25M4k 6
# 2 COMM_Atten 113.75 Auto atten 6
# 2 20141219SS-01 15460.21 W2332 Low 6
# 2 COMM_Atten 112.01 Auto atten 6
# 2 20141002MB-01 32420.45 SS433 6
# 2 COMM_Atten 112.01 Auto atten 6
# 2 COMM_Image_NO 20450.28 Imaging Calibration 6
# 2 COMM_Atten 44.0 Auto atten 6
# 2 COMM_Atten 44.0 Auto atten 6
# 2 COMM_Atten 75.01 Auto atten 6
# 2 COMM_Atten 59.0 Auto atten 2
# 2 COMM_Atten 62.0 Auto atten 2
# 2 COMM_Atten 55.0 Auto atten 2
# 2 COMM_Atten 306.02 Auto atten 1
# 2 COMM_Atten 307.02 Auto atten 1
# 2 20130822NO-01 3500.05 W2332_5056 6
# 2 COMM_Atten 111.01 Auto atten 6
# 2 20141219SS-01 14930.21 W2332 Low 6
# 2 COMM_Atten 112.01 Auto atten 6
# 2 20131211NO-01 18310.25 PKS1510-089 6
# 2 COMM_Atten 144.01 Auto atten 6
# 2 20150619TF-01 18060.25 3C279 6
# 2 COMM_Atten 44.0 Auto atten 6
# 2 COMM_Atten 91.01 Auto atten 6
# 2 20150210SS-01 19850.27 Field11Feb_Low 6
# 2 COMM_Atten 75.01 Auto atten 6
# 2 20140513DL-01 33105.46 GC Night 15 6
# 2 COMM_Atten 111.01 Auto atten 6
# 2 COMM_Point_LM 14526.15 Pointing Observation 6
# 2 COMM_Atten 43.0 Auto atten 6
# 2 COMM_Atten 145.01 Auto atten 6
# 2 COMM_Image_NO 14470.2 Imaging Calibration 6
# 2 COMM_Atten 111.01 Auto atten 6
# 2 COMM_RFI_SP 5885.47 Basic RFI Scan: RFI SCAN 6
# 2 COMM_Atten 74.01 Auto atten 6

# %% [markdown]
# Only select observations that are longer than 1 hrs then extract the project id from the script parameters. If there is no project id then allocated No_project_id

# %%
sbd = [] #Experiment ID
pid = [] #project ID
fnd = [] #Filename
dud = [] #Duration
antsd = [] #number of antennas
scrd = [] #script  -NOT USED NOW

for fi in f:
    if fi.metadata.Duration < 3600: #only pick hour long or greater observations for analysis
        continue
    # now try extract the project-id from the instruction-set string
    """
    script = fi.metadata.InstructionSet
    scrd.append(script)
    spl = script.split()
    """
    txts=fi.metadata.InstructionSet
    p=findproj(txts)
    if p == "Unknown":
        p="Maser Monitoring"
    sbd.append(fi.metadata.ExperimentID)
    pid.append(p)
    fnd.append(fi.metadata.Filename)
    dud.append(fi.metadata.Duration)
    antsd.append(len(fi.metadata.Antennas))

# %%
pi = np.array(pid)
sb = np.array(sbd)
du = np.array(dud)
ants = np.array(antsd)

p_cent = (sum(du)/((end.toordinal()-start.toordinal())*24*3600))*100

print 'Percentage system usage: ', np.floor(p_cent),'%'
# Out:
# Percentage system usage:  69.0 %

# %%
a_id = []
a_time = []
for p in set(pi):
    ind = pi == p
    print p,round(sum(du[ind])/3600,2)
    a_id.append(p)
    a_time.append(round(sum(du[ind])/3600,2))
# Out:
# 20141111IM-01 5.13
# COMM_Tipping_NO 1.06
# 20150217RT-01 6.12
# 20130822NO-01 7.13
# COMM_Bandpass_TF 11.06
# 20141002MB-01 9.01
# 20131211NO-01 5.09
# 20150619TF-01 13.03
# 20140513DL-01 9.2
# 20141219SS-01 8.44
# COMM_Image_NO 18.21
# 20150210SS-01 5.51
# COMM_RFI_SP 4.9
# COMM_Point_LM 4.04
# 20150825YL-01 4.48
# 20141125NO-01 3.59

# %%
ind = np.argsort(a_id)
for i in ind:
    print ("%-16s %5.1f %d") %(a_id[i],a_time[i],ants[i])
# Out:
# 20130822NO-01      7.1 6
# 20131211NO-01      5.1 6
# 20140513DL-01      9.2 6
# 20141002MB-01      9.0 6
# 20141111IM-01      5.1 6
# 20141125NO-01      3.6 6
# 20141219SS-01      8.4 6
# 20150210SS-01      5.5 6
# 20150217RT-01      6.1 6
# 20150619TF-01     13.0 6
# 20150825YL-01      4.5 6
# COMM_Bandpass_TF  11.1 6
# COMM_Image_NO     18.2 6
# COMM_Point_LM      4.0 6
# COMM_RFI_SP        4.9 6
# COMM_Tipping_NO    1.1 6

# %% [markdown]
# Find the unique project ids and determine the total observation duration.

# %% [markdown]
# Sort ID and time for display

# %% [markdown]
# Plot as pie-chart

# %%
cmap = plt.cm.prism
colors = cmap(np.linspace(0., 1., 7))

# %%
plt.figure(figsize=(15,15))
plt.pie(a_time,labels=a_id,colors=colors,autopct='%1.1f%%');

# %%
plt.show()

# %%
fi.metadata.InstructionSet
# Out:
# u'/home/kat/scripts/observation/auto_attenuate.py -t radec,0,-90 --mode=bc16n400M1k -f 1822 --proposal-id COMM_Atten program-block-id=00ob3000000 --sb-id-code=20160509-0011 --description= AutoAttenuation for 00ob3000000  --observer=operator --config-label=Auto2016-03-01T11h45m26.0Z'
