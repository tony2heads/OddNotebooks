# %%
from IPython.core.display import Image

# %% [markdown]
# All access to the data archive and elogs for KAT-7 is restricted to from in the SKA SA office network.
#
# Accessing your files on the archive
# http://kat-archive.kat.ac.za/katsearch/
#
# Currently the search function is a little clunky and to do a general search, such as for the typical New Health script, use the wildcard character * as shown in the example below. The example below lists all observations with the word "health" in the description

# %%
Image(filename='/home/ruby/files/archive_search.png')

# %% [markdown]
# The result is a displayed listing of all results found for the value in the "Description" field.
#
# The filename (.h5) can be obtained from this listing for access and analysis.

# %%
Image(filename='/home/ruby/files/archive_items.png')

# %% [markdown]
# This same method of search can be used in the command line interface from IPython.

# %%
import katarchive

# %%
fn = katarchive.search_archive(description='*health*')
print fn
# Out:
# Searched using: CAS.ProductTypeName:KatFile AND CAS.ProductTransferStatus:RECEIVED AND Description:*health*
# Returning 62 results
# [['1408366499.h5', '2014-08-18 14:55:04 SAST', 'Lindsay', 811088332], ['1407770482.h5', '2014-08-11 17:21:27 SAST', 'Lindsay', 811600958], ['1407328823.h5', '2014-08-06 14:40:28 SAST', 'Lindsay', 811601119], ['1407257758.h5', '2014-08-05 18:56:02 SAST', 'Lindsay', 812641771], ['1406562831.h5', '2014-07-28 17:53:56 SAST', 'Lindsay', 607568069], ['1406201323.h5', '2014-07-24 13:28:48 SAST', 'Lindsay', 608344843], ['1406119498.h5', '2014-07-23 14:45:03 SAST', 'Lindsay', 608346420], ['1405947366.h5', '2014-07-21 14:56:11 SAST', 'Lindsay', 811600959], ['1405590136.h5', '2014-07-17 11:42:21 SAST', 'Lindsay', 811601789], ['1405527597.h5', '2014-07-16 18:20:02 SAST', 'Lindsay', 811601126], ['1405403723.h5', '2014-07-15 07:55:28 SAST', 'Lindsay', 811600512], ['1404996697.h5', '2014-07-10 14:51:42 SAST', 'Lindsay', 812642466], ['1404833367.h5', '2014-07-08 17:29:32 SAST', 'Lindsay', 812641750], ['1404394139.h5', '2014-07-03 15:29:04 SAST', 'Lindsay', 812643738], ['1403779498.h5', '2014-06-26 12:45:03 SAST', 'Lindsay', 810085604], ['1403696166.h5', '2014-06-25 13:36:10 SAST', 'Lindsay', 811600934], ['1403349846.h5', '2014-06-21 13:24:11 SAST', 'Lindsay', 811600802], ['1403285853.h5', '2014-06-20 19:37:37 SAST', 'Lindsay', 811601157], ['1403096554.h5', '2014-06-18 15:02:39 SAST', 'Lindsay', 812641725], ['1402583336.h5', '2014-06-12 16:29:01 SAST', 'Lindsay', 438492655], ['1402506108.h5', '2014-06-11 19:01:53 SAST', 'Lindsay', 811600443], ['1402323007.h5', '2014-06-09 16:10:12 SAST', 'Lindsay', 812642697], ['1401980040.h5', '2014-06-05 16:54:05 SAST', 'Lindsay', 811600919], ['1401436853.h5', '2014-05-30 10:
# %% [markdown]
# If the filename is known, the archive can be queried directly for the file

# %%
fn = katarchive.search_archive(filename='1362743782.h5')
print fn
# Out:
# Searched using: CAS.ProductTypeName:KatFile AND CAS.ProductTransferStatus:RECEIVED AND Filename:1362743782.h5
# Returning 1 results
# [['1362743782.h5', '2013-03-08 13:56:25 SAST', 'audrey', 781447075]]

# %% [markdown]
# The observation file can then be read and processed

# %%
import katfile

# %%
h5 = katfile.open(fn[0].path_to_file)
print h5
# Out:
# ===============================================================================
# Name: /var/kat/archive/data/comm/2013/03/08/1362743782.h5 (version 2.1)
# ===============================================================================
# Observer: audrey  Experiment ID: 20130308-0005
# Description: 'new health'
# Observed from 2013-03-08 13:56:25.272 SAST to 2013-03-08 14:02:40.801 SAST
# Dump rate / period: 1.99984 Hz / 0.500 s
# Subarrays: 1
#   ID  Antennas                            Inputs  Corrprods
#    0  ant1,ant2,ant3,ant4,ant5,ant6,ant7  14      112
# Spectral Windows: 6
#   ID  Mode       CentreFreq(MHz)  Bandwidth(MHz)  Channels  ChannelWidth(kHz)
#    0  c16n400M1k  1264.000         400.000          1024      390.625
#    1  c16n400M1k  1392.000         400.000          1024      390.625
#    2  c16n400M1k  1520.000         400.000          1024      390.625
#    3  c16n400M1k  1648.000         400.000          1024      390.625
#    4  c16n400M1k  1776.000         400.000          1024      390.625
#    5  c16n400M1k  1904.000         400.000          1024      390.625
# -------------------------------------------------------------------------------
# Data selected according to the following criteria:
#   subarray=0
#   ants=['ant1', 'ant2', 'ant3', 'ant4', 'ant5', 'ant6', 'ant7']
#   spw=0
# -------------------------------------------------------------------------------
# Shape: (126 dumps, 1024 channels, 112 correlation products) => Size: 115.606 MB
# Antennas: *ant1,ant2,ant3,ant4,ant5,ant6,ant7  Inputs: 14  Autocorr: yes  Crosscorr: yes
# Channels: 1024 (index 0 - 1023, 1464.000 MHz - 1064.391 MHz), each 390.625 kHz wide
# Targets: 1 selected out of 1 in catalogue
#   ID  Name                             Type      RA(J2000)     DEC(J2000)  Tags  Dumps  ModelFlux(Jy)
#    0  Ra: 0:00:00.00 Dec: -90:00:00.0  radec      0:00:00.00  -90:00:00.0          126
# Scans: 2 selected out of 12 total       Compscans: 1 selected out of 1 total
#   Date        Timerange(UTC)       ScanState  CompScanLabel  Dumps  Target
#   08-Mar-2013/11:56:25 - 11:56:28    0:slew     0:               6    0:Ra: 0:00:00.00 Dec: -90:00:00.0
#               11:56:28 - 11:57:28    1:track    0:             120    0:Ra: 0:00:00.00 Dec: -90:00:00.0
# -------------------------------------------------------------------------------
# Process log:
#   RFIThreshold2:  axis=0   n_sigma=11.0   spike_width=6
#           Scale:  scale_factor=1.0
#        VanVleck:  accum_per_int=195328.0
