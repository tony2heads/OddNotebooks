# %%
import katarchive
import datetime

# %%
#%matplotlib inline
import numpy as np

# %%
#import matplotlib.pyplot as plt

# %%
import katdal as katfile
#import katfile
import datetime

#import logging
#logging.root.setLevel(logging.ERROR)

# %%
katarchive.product_filter.only_rts()

# %%
#print katarchive.search_archive(startdate='1/11/2015',enddate='31/11/2015')

# %%
start="1/9/2015"
end="30/9/2015"

# %%
#Look for pointing

f=katarchive.search_archive(description="Point",startdate=start,enddate=end)

start = datetime.datetime.strptime(f[-1].__str__().split('\'')[3],'%Y-%m-%d %H:%M:%S %Z')
end = datetime.datetime.strptime(f[0].__str__().split('\'')[3],'%Y-%m-%d %H:%M:%S %Z')
# Out:
# Searched using: CAS.ProductTypeName:(RTSTelescopeProduct) AND CAS.ProductTransferStatus:RECEIVED AND Description:Point AND StartTime:[2015-08-31T22:00:00Z TO 2015-09-30T21:59:59Z]
# Returning 63 results

# %%
print 'First file in run: ' , start.isoformat()
print 'Last file in run: ' , end.isoformat()
# Out:
# First file in run:  2015-09-01T10:21:01
# Last file in run:  2015-09-26T20:10:34

# %%
f.sort(key=lambda k: k.metadata.StartTime)

# %%
for fi in f:
    print fi.metadata.Description
    print fi.metadata.FileLocation
    print fi.metadata.Filename
    print fi.metadata.Antennas
    print fi.metadata.Targets
    print fi.metadata.InstructionSet
    print "."*88
# Out:
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/01
# 1441095660.h5
# [u'm062', u'm063']
# [u'EUTELSAT 36B']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAT 36B -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=4.0 --sb-id-code=20150901-0003 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/01
# 1441096353.h5
# [u'm062', u'm063']
# [u'EUTELSAT 36B']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAT 36B -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=4.0 --sb-id-code=20150901-0004 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/01
# 1441103971.h5
# [u'm062', u'm063']
# [u'EUTELSAT 36B']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAT 36B -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=4.0 --sb-id-code=20150901-0009 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/01
# 1441105261.h5
# [u'm062', u'm063']
# [u'EUTELSAT 36B']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAT 36B -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=4.0 --sb-id-code=20150901-0010 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/01
# 1441106673.h5
# [u'm062', u'm063']
# [u'EUTELSAT 36B']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAT 36B -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=4.0 --sb-id-code=20150901-0011 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# RTS: 2.7 Ku-band Pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/01
# 1441107455.h5
# [u'm062', u'm063']
# [u'EUTELSAT 36B']
# /home/kat/RTS/2.7-Pointing/point_source_scan.py EUTELSAT 36B -f 12500.5 -r 1 -n off -m 33000 --fine --product=c856M4k --horizon=16 --proposal-id=COMM-RTS --search-fine --sb-id-code=20150901-0012 --description=RTS: 2.7 Ku-band Pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/01
# 1441108028.h5
# [u'm062', u'm063']
# [u'EUTELSAT 36B']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAT 36B -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=4.0 --sb-id-code=20150901-0013 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# RTS: 2.7 Ku-band Pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/01
# 1441137705.h5
# [u'm062', u'm063']
# [u'0430 052', u'0420-014', u'0130-171', u'0605-085', u'1830-210', u'1741-038', u'0426-380', u'1954-388', u'3C138', u'2145 067', u'0458-020', u'0451-282', u'1730-130', u'1921-293', u'2128-123', u'1824-582', u'1613-586', u'2131-021', u'0238-084', u'0537-441', u'1920-211', u'0637-752', u'1908-201', u'2134 004', u'0208-512', u'2052-474', u'1622-253', u'0607-157', u'0521-365', u'1958-179', u'0402-362', u'1718-649', u'0003-066', u'3C123', u'0332-403', u'0454-234', u'0252-549', u'1514-241', u'1657-261', u'0106 013', u'0454-463']
# /home/kat/RTS/2.7-Pointing/point_source_scan.py /home/kat/RTS/sources_pnt_Ku.csv -f 12500.5 -r 1 -n off -m 33000 --fine --product=c856M4k --horizon=16 --stow-when-done --proposal-id=COMM-RTS --stow-when-done --sb-id-code=20150901-0016 --description=RTS: 2.7 Ku-band Pointing --observer=RTS
# ........................................................................................
# RTS: 2.7 Ku-band Pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/02
# 1441199653.h5
# [u'm062', u'm063']
# [u'0637-752']
# /home/kat/RTS/2.7-Pointing/point_source_scan.py /home/kat/RTS/sources_pnt_Ku.csv -f 12500.5 -r 1 -n off -m 33000 --fine --product=c856M4k --horizon=16 --stow-when-done --proposal-id=COMM-RTS --stow-when-done --sb-id-code=20150902-0002 --description=RTS: 2.7 Ku-band Pointing --observer=RTS
# ........................................................................................
# RTS: 2.7 Ku-band Pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/02
# 1441202692.h5
# [u'm062', u'm063']
# [u'1334-127', u'1055 018', u'0130-171', u'0238-084', u'1830-210', u'1741-038', u'0426-380', u'1954-388', u'0454-463', u'2145 067', u'1730-130', u'1921-293', u'2128-123', u'0637-752', u'1613-586', u'1510-089', u'1421-490', u'1749 096', u'1920-211', u'1424-418', u'1908-201', u'3C279', u'1548 056', u'CenB', u'3C446', u'3C273', u'1622-253', u'2052-474', u'2203-188', u'1958-179', u'2355-534', u'0402-362', u'2255-282', u'1718-649', u'3C286', u'0003-066', u'0252-549', u'1322-427', u'CTA102', u'1127-145', u'1824-582', u'2131-021', u'2153-699', u'1057-797', u'0332-403', u'J1152-0841', u'2223-052', u'1514-241', u'2155-152', u'1657-261', u'0208-512', u'0106 013', u'2134 004']
# /home/kat/RTS/2.7-Pointing/point_source_scan.py /home/kat/RTS/sources_pnt_Ku.csv -f 12500.5 -r 1 -n off -m 33000 --fine --product=c856M4k --horizon=16 --stow-when-done
observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/07
# 1441608897.h5
# [u'm062', u'm063']
# [u'EUTELSAT 36B', u'EUTELSAT 36A']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAt 36B -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=5 --scan-duration=60 --scan-extent=4.0 --sb-id-code=20150907-0005 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# RTS: 2.7 Ku-band Pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/08
# 1441673676.h5
# [u'm062', u'm063']
# [u'0430 052', u'0420-014', u'0130-171', u'0605-085', u'0003-066', u'0454-463', u'3C138', u'0458-020', u'0451-282', u'0653-033', u'1127-145', u'1055 018', u'0238-084', u'0537-441', u'0637-752', u'0208-512', u'CenB', u'0727-115', u'0607-157', u'0521-365', u'2355-534', u'0402-362', u'0426-380', u'2153-699', u'1322-427', u'3C123', u'0332-403', u'0454-234', u'0252-549', u'1057-797', u'J1152-0841', u'0823 033', u'0648-165', u'0106 013', u'0723-008']
# /home/kat/RTS/2.7-Pointing/point_source_scan.py /home/kat/RTS/sources_pnt_Ku.csv -f 12500.5 -r 1 -n off -m 33000 --fine --product=c856M4k --horizon=16 --stow-when-done --proposal-id=COMM-RTS --stow-when-done --sb-id-code=20150907-0007 --description=RTS: 2.7 Ku-band Pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/10
# 1441867467.h5
# [u'm062', u'm063']
# [u'EUTELSAT 36B']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAt 36B -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=4.0 --sb-id-code=20150910-0003 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# RTS: 2.7 Ku-band Pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/10
# 1441882260.h5
# [u'm062', u'm063']
# [u'0637-752', u'0648-165']
# /home/kat/RTS/2.7-Pointing/point_source_scan.py /home/kat/RTS/sources_pnt_Ku.csv -f 12500.5 -r 1 -n off -m 33000 --fine --product=c856M4k --horizon=16 --stow-when-done --proposal-id=COMM-RTS --stow-when-done --sb-id-code=20150910-0006 --description=RTS: 2.7 Ku-band Pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/10
# 1441883715.h5
# [u'm062', u'm063']
# [u'EUTELSAT 36B']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAt 36B -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=4.0 --sb-id-code=20150910-0008 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/10
# 1441884662.h5
# [u'm062', u'm063']
# [u'EUTELSAT 36B']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAt 36B -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=4.0 --sb-id-code=20150910-0009 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/10
# 1441887305.h5
# [u'm062', u'm063']
# [u'EUTELSAT 36A']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAt 36A -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=4.0 --sb-id-code=20150910-0012 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/10
# 1441890007.h5
# [u'm062', u'm063']
# [u'EUTELSAT 36A']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAt 36A -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=4.0 --sb-id-code=20150910-0013 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/10
# 1441890777.h5
# [u'm062', u'm063']
# [u'EUTELSAT 36B']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAt 36B -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=7 --scan-duration=60 --scan-extent=2.0 --sb-id-code=20150910-0014 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# RTS: 2.7 Ku-band Pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/12
# 1442056832.h5
# [u'm062', u'm063']
# [u'0637-752', u'0823 033']
# /home/kat/RTS/2.7-Pointing/point_source_scan.py /home/kat/RTS/sources_pnt_Ku.csv -f 12500.5 -r 1 -n off -m 33000 --fine --product=c856M4k --horizon=16 --stow-when-done --proposal-id=COMM-RTS --stow-when-done --sb-id-code=20150910-0007 --description=RTS: 2.7 Ku-band Pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/12
# 1442057654.h5
# [u'm062', u'm063']
# [u'INTELSAT 12 (IS-12)']
# /home/kat/sdpscripts/observation/raster_scan.py INTELSAT 12 (IS-12) -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=2.0 --sb-id-code=20150912-0006 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/12
# 1442058603.h5
# [u'm062', u'm063']
# [u'EUTELSAT 7A']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAT 7A -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=2.0 --sb-id-code=20150912-0007 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/12
# 1442059446.h5
# [u'm062', u'm063']
# [u'EUTELSAT 36B']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAT 36B -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=2.0 --sb-id-code=20150912-0004 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/12
# 1442060263.h5
# [u'm062', u'm063']
# [u'EUTELSAT 36A']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAT 36A -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=2.0 --sb-id-code=20150912-0003 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/12
# 1442061034.h5
# [u'm062', u'm063']
# [u'EUTELSAT 7A']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAT 7A -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=2.0 --sb-id-code=20150912-0002 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/12
# 1442061865.h5
# [u'm062', u'm063']
# [u'EUTELSAT 7A']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAT 7A -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=2.0 --sb-id-code=20150912-0008 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/12
# 1442062637.h5
# [u'm062', u'm063']
# [u'EUTELSAT 7A']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAT 7A -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=2.0 --sb-id-code=20150912-0009 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/12
# 1442063409.h5
# [u'm062', u'm063']
# [u'EUTELSAT 7A']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAT 7A -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=2.0 --sb-id-code=20150912-0011 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/12
# 1442064177.h5
# [u'm062', u'm063']
# [u'EUTELSAT 7A']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAT 7A -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=2.0 --sb-id-code=20150912-0010 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/13
# 1442153361.h5
# [u'm062', u'm063']
# [u'EUTELSAT 7A']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAT 7A -m 0.25 -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=2.0 --sb-id-code=20150912-0013 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing m = 0.02
# /var/kat/archive/data/RTS/telescope_products/2015/09/13
# 1442158030.h5
# [u'm062', u'm063']
# [u'EUTELSAT 36A']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAT 36A -m 0.02 -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=18 --scan-duration=60 --scan-extent=2.0 --sb-id-code=20150913-0003 --description=Raster scans for pointing m = 0.02 --observer=RTS
# ........................................................................................
# Raster scans for pointing m = 0.02
# /var/kat/archive/data/RTS/telescope_products/2015/09/13
# 1442158211.h5
# [u'm062', u'm063']
# [u'EUTELSAT 36A']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAT 36A -m 0.02 -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=18 --scan-duration=60 --scan-extent=2.0 --sb-id-code=20150913-0005 --description=Raster scans for pointing m = 0.02 --observer=RTS
# ........................................................................................
# Raster scans for pointing m = 0.02
# /var/kat/archive/data/RTS/telescope_products/2015/09/13
# 1442159516.h5
# [u'm062', u'm063']
# [u'EUTELSAT 36B']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAT 36B -m 0.02 -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=18 --scan-duration=60 --scan-extent=2.0 --sb-id-code=20150913-0004 --description=Raster scans for pointing m = 0.02 --observer=RTS
# ........................................................................................
# Raster scans for pointing m = 0.02
# /var/kat/archive/data/RTS/telescope_products/2015/09/13
# 1442160818.h5
# [u'm062', u'm063']
# [u'INTELSAT 12 (IS-12)']
# /home/kat/sdpscripts/observation/raster_scan.py INTELSAT 12  (IS-12) -m 0.02 -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=18 --scan-duration=60 --scan-extent=2.0 --sb-id-code=20150913-0002 --description=Raster scans for pointing m = 0.02 --observer=RTS
# ........................................................................................
# Raster scans for pointing m = 0.02
# /var/kat/archive/data/RTS/telescope_products/2015/09/13
# 1442162187.h5
# [u'm062', u'm063']
# [u'EUTELSAT 7A']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAT 7A -m 0.02 -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=18 --scan-duration=60 --scan-extent=2.0 --sb-id-code=20150913-0001 --description=Raster scans for pointing m = 0.02 --observer=RTS
# ........................................................................................
# RTS: 2.7 Ku-band Pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/13
# 1442174675.h5
# [u'm062', u'm063']
# [u'0430 052', u'0420-014', u'0130-171', u'0605-085', u'1830-210', u'1741-038', u'0003-066', u'1954-388', u'3C138', u'2145 067', u'0458-020', u'0451-282', u'1730-130', u'1921-293', u'2128-123', u'1824-582', u'1613-586', u'2131-021', u'0238-084', u'0537-441', u'1920-211', u'0637-752', u'1908-201', u'2134 004', u'0208-512', u'2203-188', u'3C446', u'2052-474', u'0607-157', u'0521-365', u'1958-179', u'2355-534', u'0402-362', u'2255-282', u'1718-649', u'0426-380', u'2153-699', u'CTA102', u'0332-403', u'0454-234', u'0252-549', u'1057-797', u'2223-052', u'0648-165', u'2155-152', u'1657-261', u'0106 013', u'0454-463']
# /home/kat/RTS/2.7-Pointing/point_source_scan.py /home/kat/RTS/sources_pnt_Ku.csv -f 12500.5 -r 1 -n off -m 33000 --fine --product=c856M4k --horizon=16 --stow-when-done --proposal-id=COMM-RTS --stow-when-done --sb-id-code=20150911-0005 --description=RTS: 2.7 Ku-band Pointing --observer=RTS
# ........................................................................................
# RTS: 2.7 Ku-band Pointing IS12
# /var/kat/archive/data/RTS/telescope_products/2015/09/14
# 1442230339.h5
# [u'm062', u'm063']
# [u'INTELSAT 12']
# /home/kat/RTS/2.7-Pointing/point_source_scan.py xephem tle, INTELSAT 12~E~9/11.77847222/2015| 6/3.77734/2015|12/20.7773/2015~0.048799999~267.27991~0.0003137~275.76089~132.6839~1.00271114~2.2500001e-06~1~0 -f 12500.5 -r 1 -n off -m 60 --fine --product=c856M4k --horizon=16 --proposal-id=COMM-RTS --search-fine --sb-id-code=20150914-0004 --description=RTS: 2.7 Ku-band Pointing IS12 --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/14
# 1442232430.h5
# [u'm062', u'm063']
# [u'EUTELSAT 36B']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAT 36B -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=4.0 --sb-id-code=20150914-0005 --description=Raster scans for pointing --observer=ta
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/14
# 1442233339.h5
# [u'm062', u'm063']
# [u'EUTELSAT 36B']
# /home/kat/sdpscripts/observation/raster_scan.py EUTELSAT 36B -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=4.0 --sb-id-code=20150914-0006 --description=Raster scans for pointing --observer=ta
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/14
# 1442251823.h5
# [u'm062', u'm063']
# [u'INTELSAT 12']
# /home/kat/sdpscripts/observation/raster_scan.py xephem tle, INTELSAT 12~E~9/11.77847222/2015| 6/3.77734/2015|12/20.7773/2015~0.048799999~267.27991~0.0003137~275.76089~132.6839~1.00271114~2.2500001e-06~1~0 -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=11 --scan-duration=60 --scan-extent=1.0 --sb-id-code=20150914-0013 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/14
# 1442253819.h5
# [u'm062', u'm063']
# [u'INTELSAT 12']
# /home/kat/sdpscripts/observation/raster_scan.py xephem tle, INTELSAT 12~E~9/11.77847222/2015| 6/3.77734/2015|12/20.7773/2015~0.048799999~267.27991~0.0003137~275.76089~132.6839~1.00271114~2.2500001e-06~1~0 -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=5 --scan-duration=60 --scan-extent=1.0 --sb-id-code=20150914-0014 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/14
# 1442254592.h5
# [u'm062', u'm063']
# [u'INTELSAT 12']
# /home/kat/sdpscripts/observation/raster_scan.py xephem tle, INTELSAT 12~E~9/11.77847222/2015| 6/3.77734/2015|12/20.7773/2015~0.048799999~267.27991~0.0003137~275.76089~132.6839~1.00271114~2.2500001e-06~1~0 -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=5 --scan-duration=60 --scan-extent=1.0 --sb-id-code=20150914-0015 --description=Raster scans for pointing --observer=RTS
# ........................................................................................
# RTS: 2.7 Ku-band Pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09/14
# 1442255944.h5
# [u'm062', u'm063']
# [u'0605-085', u'0430 052', u'0420-014', u'0537-441', u'0130-171', u'3C454.3', u'0238-084', u'1830-210', u'1741-038', u'0426-380', u'2255-282', u'0723-008', u'1954-388', u'3C138', u'2145 067', u'0458-020', u'0451-282', u'1730-130', u'3C123', u'1921-293', u'2128-123', u'1824-582', u'1613-586', u'2131-021', u'1421-490', u'1749 096', u'1920-211', u'1424-418', u'1908-201', u'2134 004', u'0208-512', u'2203-188', u'CenB', u'3C446', u'2052-474', u'1622-253', u'0607-157', u'0521-365', u'1958-179', u'2355-534', u'0402-362', u'0637-752', u'1718-649', u'0003-066', u'2153-699', u'CTA102', u'0332-403', u'0454-234', u'0252-549', u'1057-797', u'0653-033', u'2223-052', u'0648-165', u'1514-241', u'2155-152', u'1657-261', u'0106 013', u'0454-463']
# /home/kat/RTS/2.7-Pointing/point_source_scan.py /home/kat/RTS/sources_pnt_Ku.csv -f 12500.5 -r 1 -n off -m 33000 --fine --product=c856M4k --horizon=16 --stow-when-done --proposal-id=COMM-RTS --stow-when-done --sb-id-code=20150914-0016 --description=RTS: 2.7 Ku-band Pointing --observer=RTS
# ........................................................................................
# Raster scans for pointing is12
# /var/kat/archive/data/RTS/telescope_products/2015/09/15
# 1442300050.h5
# [u'm062', u'm063']
# [u'INTELSAT 12']
# /home/kat/sdpscripts/observation/raster_scan.py xephem tle, INTELSAT 12~E~9/11.77847222/2015| 6/3.77734/2015|12/20.7773/2015~0.048799999~267.27991~0.0003137~275.76089~132.6839~1.00271114~2.2500001e-06~1~0 -m 0.02 -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=19 --scan-duration=60 --scan-extent=2.0 --sb-id-code=20150915-0002 --description=Raster scans for pointing is12 --observer=RTS
# ........................................................................................
# Raster scans for pointing is12
# /var/kat/archive/data/RTS/telescope_products/2015/09/15
# 1442303582.h5
# [u'm062', u'm063']
# [u'INTELSAT 12']
# /home/kat/sdpscripts/observation/raster_scan.py xephem tle, INTELSAT 12~E~9/11.77847222/2015| 6/3.77734/2015|12/20.7773/2015~0.048799999~267.27991~0.0003137~275.76089~132.6839~1.00271114~2.2500001e-06~1~0 -m 0.02 -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=19 --scan-duration=60 --scan-extent=2.0 --sb-id-code=20150915-0003 --description=Raster scans for pointing is12 --observer=RTS
# ........................................................................................
# Raster scans for pointing is12
# /var/kat/archive/data/RTS/telescope_products/2015/09/15
# 1442305321.h5
# [u'm062', u'm063']
# [u'INTELSAT 12']
# /home/kat/sdpscripts/observation/raster_scan.py xephem tle, INTELSAT 12~E~9/11.77847222/2015| 6/3.77734/2015|12/20.7773/2015~0.048799999~267.27991~0.0003137~275.76089~132.6839~1.00271114~2.2500001e-06~1~0 -m 0.02 -n OFF --dump-rate=1 --proposal-id=RTS --num-scans=19 --scan-duration=60 --scan-extent=2.0 --sb-id-code=20150915-0004 --description=Raster scans for pointing is12 --observer=RTS
# ........................................................................................
# RTS: 2.7.1 Ku-band Pointing
# /var/kat/archive/data/RTS/telescope_products/2015/09
# /home/kat/RTS/2.7-Pointing/point_source_scan.py /home/kat/RTS/sources_pnt_Ku.csv -f 12500.5 -r 1 -n off -m 33000 --fine --product=c856M4k --horizon=16 --stow-when-done --proposal-id=COMM-RTS --stow-when-done --sb-id-code=20150926-0001 --description=RTS: 2.7 Ku-band Pointing -no tilt --observer=RTS
# ........................................................................................

# %%
for fi in f:
    x= repr(fi)
    pr=x.split(",")
    print pr[1][10:12],pr[0][2:-1],fi.metadata.Description,fi.metadata.Antennas
# Out:
# 01 1441095660.h5 Raster scans for pointing [u'm062', u'm063']
# 01 1441096353.h5 Raster scans for pointing [u'm062', u'm063']
# 01 1441103971.h5 Raster scans for pointing [u'm062', u'm063']
# 01 1441105261.h5 Raster scans for pointing [u'm062', u'm063']
# 01 1441106673.h5 Raster scans for pointing [u'm062', u'm063']
# 01 1441107455.h5 RTS: 2.7 Ku-band Pointing [u'm062', u'm063']
# 01 1441108028.h5 Raster scans for pointing [u'm062', u'm063']
# 01 1441137705.h5 RTS: 2.7 Ku-band Pointing [u'm062', u'm063']
# 02 1441199653.h5 RTS: 2.7 Ku-band Pointing [u'm062', u'm063']
# 02 1441202692.h5 RTS: 2.7 Ku-band Pointing [u'm062', u'm063']
# 03 1441279799.h5 Raster scans for pointing [u'm062', u'm063']
# 03 1441292063.h5 RTS: 2.7 Ku-band Pointing [u'm062', u'm063']
# 04 1441350266.h5 Raster scans for pointing [u'm062', u'm063']
# 04 1441360298.h5 Raster scans for pointing [u'm062', u'm063']
# 04 1441360711.h5 Raster scans for pointing [u'm062', u'm063']
# 04 1441363889.h5 Raster scans for pointing [u'm062', u'm063']
# 04 1441370534.h5 Raster scans for pointing [u'm062', u'm063']
# 07 1441586571.h5 RTS: 2.7.1 Ku-band Pointing [u'm062', u'm063']
# 07 1441597990.h5 RTS: 2.7.2 - Ku-band Pointing Jitter [u'm062', u'm063']
# 07 1441608897.h5 Raster scans for pointing [u'm062', u'm063']
# 08 1441673676.h5 RTS: 2.7 Ku-band Pointing [u'm062', u'm063']
# 10 1441867467.h5 Raster scans for pointing [u'm062', u'm063']
# 10 1441882260.h5 RTS: 2.7 Ku-band Pointing [u'm062', u'm063']
# 10 1441883715.h5 Raster scans for pointing [u'm062', u'm063']
# 10 1441884662.h5 Raster scans for pointing [u'm062', u'm063']
# 10 1441887305.h5 Raster scans for pointing [u'm062', u'm063']
# 10 1441890007.h5 Raster scans for pointing [u'm062', u'm063']
# 10 1441890777.h5 Raster scans for pointing [u'm062', u'm063']
# 12 1442056832.h5 RTS: 2.7 Ku-band Pointing [u'm062', u'm063']
# 12 1442057654.h5 Raster scans for pointing [u'm062', u'm063']
# 12 1442058603.h5 Raster scans for pointing [u'm062', u'm063']
# 12 1442059446.h5 Raster scans for pointing [u'm062', u'm063']
# 12 1442060263.h5 Raster scans for pointing [u'm062', u'm063']
# 12 1442061034.h5 Raster scans for pointing [u'm062', u'm063']
# 12 1442061865.h5 Raster scans for pointing [u'm062', u'm063']
# 12 1442062637.h5 Raster scans for pointing [u'm062', u'm063']
# 12 1442063409.h5 Raster scans for pointing [u'm062', u'm063']
# 12 1442064177.h5 Raster scans for pointing [u'm062', u'm063']
# 13 1442153361.h5 Raster scans for pointing [u'm062', u'm063']
# 13 1442158030.h5 Raster scans for pointing m = 0.02 [u'm062', u'm063']
# 13 1442158211.h5 Raster scans for pointing m = 0.02 [u'm062', u'm063']
# 13 1442159516.h5 Raster scans for pointing m = 0.02 [u'm062', u'm063']
# 13 1442160818.h5 Raster scans for pointing m = 0.02 [u'm062', u'm063']
# 13 1442162187.h5 Raster scans for pointing m = 0.02 [u'm062', u'm063']
# 13 1442174675.h5 RTS: 2.7 Ku-band Pointing [u'm062', u'm063']
# 14 1442230339.h5 RTS: 2.7 Ku-band Pointing IS12 [u'm062', u'm063']
# 14 1442232430.h5 Raster scans for pointing [u'm062', u'm063']
# 14 1442233339.h5 Raster scans for pointing [u'm062', u'm063']
# 14 1442251823.h5 Raster scans for pointing [u'm062', u'm063']
# 14 1442253819.h5 Raster scans for pointing [u'm062', u'm063']
# 14 1442254592.h5 Raster scans for pointing [u'm062', u'm063']
# 14 1442255944.h5 RTS: 2.7 Ku-band Pointing [u'm062', u'm063']
# 15 1442300050.h5 Raster scans for pointing is12 [u'm062', u'm063']
# 15 1442303582.h5 Raster scans for pointing is12 [u'm062', u'm063']
# 15 1442305321.h5 Raster scans for pointing is12 [u'm062', u'm063']
# 18 1442565537.h5 RTS: 2.7.1 Ku-band Pointing [u'm062']
# 25 1443165648.h5 RTS: 2.7.1 Ku-band Pointing [u'm062']
# 25 1443171430.h5 RTS: 2.7.1 Ku-band Pointing [u'm062']
# 25 1443186324.h5 RTS: 2.7.1 Ku-band Pointing [u'm062']
# 25 1443197686.h5 RTS: 2.7.1 Ku-band Pointing [u'm062']
# 25 1443214679.h5 RTS: 2.7 Ku-band Pointing -no tilt [u'm062']
# 26 1443247998.h5 RTS: 2.7 Ku-band Pointing -no tilt [u'm062']
# 26 1443291032.h5 RTS: 2.7 Ku-band Pointing -no tilt [u'm062']

# %%
start="1/9/2015"
end="30/9/2015"

# %%
f2=katarchive.search_archive(description="Interferometric_Pointing",startdate=start,enddate=end)
f2.sort(key=lambda k: k.metadata.StartTime)
f2
# Out:
# Searched using: CAS.ProductTypeName:(RTSTelescopeProduct) AND CAS.ProductTransferStatus:RECEIVED AND Description:Interferometric_Pointing AND StartTime:[2015-08-31T22:00:00Z TO 2015-09-30T21:59:59Z]
# Returning 0 results
# []
