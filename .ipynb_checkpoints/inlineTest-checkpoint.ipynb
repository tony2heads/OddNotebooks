# %%
# %pylab inline
from scipy import *
x=arange(-10.0,10.0,0.2)
pylab.figure(1)
pylab.plot(x,cos(x),label='cos(x)')
pylab.legend()
pylab.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
