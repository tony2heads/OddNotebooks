# %%
#!wget -O 1585917174_sdp_l0.full.rdb  https://archive-gw-1.kat.ac.za/1585917174/1585917174_sdp_l0.full.rdb?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJFUzI1NiJ9.eyJpc3MiOiJrYXQtYXJjaGl2ZS5rYXQuYWMuemEiLCJhdWQiOiJhcmNoaXZlLWd3LTEua2F0LmFjLnphIiwiaWF0IjoxNTg2Mjc3MDY4LCJwcmVmaXgiOlsiMTU4NTkxNzE3NCJdLCJleHAiOjE1ODY4ODE4NjgsInN1YiI6InRvbnlAc2thLmFjLnphIiwic2NvcGVzIjpbInJlYWQiXX0.x4-VUDqb6LrZlY5chCBqkwWQrpEwJbPgYluIrC5ukV11spkHyOYM4cnisg6jjfY0mnfYNriTVycsuPvS0yuTcQ

# %%
# !/usr/bin/python3 /home/tony/Desktop/katsdpscripts/reduction/analyse_interferometric_pointing.py  -h
# Out:
# /usr/lib/python3/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Usage: analyse_interferometric_pointing.py [opts] <HDF5 file>
#
# This processes an HDF5 dataset and extracts fitted beam parameters from the
# compound scans in it.
#
# Options:
#   -h, --help            show this help message and exit
#   -a ANTS, --ants=ANTS  List of antennas to use in the reduction default is
#                         all antennas in the data set
#   --exclude-ants=EX_ANTS
#                         List of antennas to exculde from the reduction default
#                         is None of the antennas in the data set
#   --use-weights         Use SDP visability weights
#   --debug               Produce a debug file with fitting infomation for each
# ...

# %%
# !/usr/bin/python3 /home/tony/Desktop/katsdpscripts/reduction/analyse_interferometric_pointing.py  \
-c /home/tony/Desktop/katsdpscripts_OLD/RTS/rfi_mask.pickle \
/home/tony/Desktop/katsdpscripts_OLD/reduction/Interferometric/RDB/1585917174_sdp_l0.full.rdb
# Out:
# /usr/lib/python3/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'J0010-4153, 0008-421' in catalogue
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'J0025-2602, 0023-263' in catalogue
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'J0137+3309, 0134+439, 3C48' in catalogue
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'J0240-2309, 0237-233' in catalogue
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'J0252-7104, 0252-712' in catalogue
# WARNING:katpoint.catalogue:Found different targets with same name(s) 'J0318+1628, 0316+162, CTA21' in catalogue
# ...
