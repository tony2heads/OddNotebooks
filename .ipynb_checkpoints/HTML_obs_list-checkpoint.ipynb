# %%
import pysolr
from IPython.core.display import display, HTML
archive = pysolr.Solr('http://192.168.1.50:8983/solr/kat_core')
search_str = []
search_str.append('CAS.ProductTypeName:MeerKATAR1TelescopeProduct')

# %%
search_str.append('StartTime:[2017-08-29T00:00:00Z TO 2020-06-01T00:00:00Z]')

# %%
search_string = ' AND '.join(search_str)

# %%
ar_res = archive.search( search_string ,rows=10000,**{'sort':'StartTime desc'})
h = '<table>'
h += "<tr><th>Owner<th>UT Start<th>Schedule block<th>Description<th>chan<th>ants<th>size<th>Archive</tr>"

# %%
for r in ar_res.docs[::-1]:
    link = 'http://kat-archive.kat.ac.za:8080/archive_search/#{"ei":"%s","so":true,\
    "r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}'%(r['ScheduleBlockIdCode'])
    h += '<tr> <td> %s <td> %s <td> <a href=\'%s\'>%s</a> <td>\
    # %s <td> %d <td> %d <td> %5.2f <td> %s  </tr>'%(r['Observer'],r['StartTime'],\
    link,r['ScheduleBlockIdCode'],r['Description'],
    r['NumFreqChannels'],len(r['Antennas']),r['FileSize'][0]/1024.0**3,\
    r['CAS.ReferenceDatastore'][0][5:])

# %%
h += "</table>"
display(HTML(h))
h += "<tr><th>Owner<th>UT Start<th>Schedule block<th>Description<th>chan<th>ants\
<th>size<th>Archive</tr>"
from BeautifulSoup import BeautifulSoup
soup = BeautifulSoup(h)
# Out:
# <table><tr><th>Owner<th>UT Start<th>Schedule block<th>Description<th>chan<th>ants<th>size<th>Archive</tr><tr> <td> Tom <td> 2017-08-29T02:24:07Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#{"ei":"20170828-0053","so":true,    "r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}'>20170828-0053</a> <td>    MKAIV-608 Imaging observation PHOENIX_DEEP <td> 32768 <td> 12 <td> 176.15 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/08/29/1503973447.h5  </tr><tr> <td> Lindsay <td> 2017-08-29T05:24:38Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#{"ei":"20170829-0001","so":true,    "r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}'>20170829-0001</a> <td>    MKAIV-232 Baseline Calibration (Delay model calculation) <td> 4096 <td> 3 <td>  0.63 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/08/29/1503984278.h5  </tr><tr> <td> Lindsay <td> 2017-08-29T06:38:54Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#{"ei":"20170829-0002","so":true,    "r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}'>20170829-0002</a> <td>    MKAIV-584 Generic AR1 delaycal <td> 4096 <td> 12 <td>  0.29 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/08/29/1503988729.h5  </tr><tr> <td> Lindsay <td> 2017-08-29T06:43:45Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#{"ei":"20170828-0054","so":true,    "r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}'>20170828-0054</a> <td>    MKAIV-405 Generic AR1 Phaseup <td> 4096 <td> 12 <td>  0.34 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/08/29/1503989024.h5  </tr><tr> <td> sarah <td> 2017-08-29T06:48:59Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#{"ei":"20170828-0055","so":true,    "r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}'>20170828-0055</a> <td>    MKAIV-387: CBF J0437-4715 <td> 4096 <td> 12 <td>  0.93 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/08/29/1503989306.h5  </tr><tr> <td> sarah <td> 2017-08-29T07:08:50Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#{"ei":"20170828-0056","so":true,    "r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}'>20170828-0056</a> <td>    MKAIV-387 CBF J0738-4042 <td> 4096 <td> 12 <td>  0.94 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/08/29/1503990472.h5  </tr><tr> <td> Lindsay <td> 2017-08-29T07:09:11Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#{"ei":"20170829-0003","so":true,    "r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}'>20170829-0003</a> <td>    MKAIV-232 Baseline Calibration (Delay model calculation) <td> 4096 <td> 2 <td>  0.24 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/08/29/1503990548.h5  </tr><tr> <td> Lindsay <td> 2017-08-29T07:19:55Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#{"ei":"20170828-0057","so":true,    "r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}'>20170828-0057</a> <td>    MKAIV-405 Generic AR1 Phaseup <td> 4096 <td> 12 <td>  0.41 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/08/29/1503991194.h5  </tr><tr> <td> sarah <td> 2017-08-29T07:27:14Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#{"ei":"20170828-0058","so":true,    "r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}'>20170828-0058</a> <td>    MKAIV-387 CBF J0742-2822 <td> 4096 <td> 12 <td>  0.96 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/08/29/1503991541.h5  </tr><tr> <td> Lindsay <td> 2017-08-29T07:39:49Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#{"ei":"20170828-0060","so":true,    "r":true,"k":true,"a":true,"b":true,"ob":"1","rs":{}}'>20170828-0060</a> <td>    MKAIV-405 Generic AR1 Phaseup <td> 4096 <td> 12 <td>  0.51 <td> /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/08/29/1503992388.h5  </tr><tr> <td> sarah <td> 2017-08-29T07:47:00Z <td> <a href='http://kat-archive.kat.ac.za:8080/archive_search/#{"ei":"20170828 ...

# %%
with open("2017-08-30.html", "wb") as file:
    file.write(soup.prettify("utf-8"))
