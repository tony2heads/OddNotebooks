# %%
import katdal
import matplotlib.pylab as plt
# %matplotlib inline
import numpy as np
import pickle

# %%
filename='/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/03/09/1489066825.h5'

# %%
h = katdal.open(filename)

# %%
print h
# Out:
# ===============================================================================
# Name: /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/03/09/1489066825.h5 (version 3.0)
# ===============================================================================
# Observer: KB  Experiment ID: 20170309-0010
# Description: 'Generic AR1 phaseup'
# Observed from 2017-03-09 15:40:30.379 SAST to 2017-03-09 15:44:22.281 SAST
# Dump rate / period: 0.25011 Hz / 3.998 s
# Subarrays: 1
#   ID  Antennas                            Inputs  Corrprods
#    0  m001,m012,m014,m015,m018,m031,m034,m063  16      144
# Spectral Windows: 1
#   ID Band Product  CentreFreq(MHz)  Bandwidth(MHz)  Channels  ChannelWidth(kHz)
#    0 L    bc856M4k   1284.000         856.000           4096       208.984
# -------------------------------------------------------------------------------
# Data selected according to the following criteria:
#   subarray=0
#   ants=['m018', 'm001', 'm014', 'm015', 'm063', 'm034', 'm031', 'm012']
#   spw=0
# -------------------------------------------------------------------------------
# Shape: (58 dumps, 4096 channels, 144 correlation products) => Size: 273.678 MB
# Antennas: m001,m012,m014,m015,*m018,m031,m034,m063  Inputs: 16  Autocorr: yes  Crosscorr: yes
# Channels: 4096 (index 0 - 4095,  856.000 MHz - 1711.791 MHz), each 208.984 kHz wide
# Targets: 2 selected out of 2 in catalogue
#   ID  Name         Type      RA(J2000)     DEC(J2000)  Tags                       Dumps  ModelFlux(Jy)
#    0  PKS 0408-65  radec      4:08:20.38  -65:45:09.1  bfcal single_accumulation     51      14.81
#    1  Nothing      special             -            -                                 7
# Scans: 6 selected out of 6 total       Compscans: 2 selected out of 2 total
#   Date        Timerange(UTC)       ScanState  CompScanLabel  Dumps  Target
#   09-Mar-2017/13:40:32 - 13:42:28    0:slew     0:un_corrected     30    0:PKS 0408-65
#               13:42:32 - 13:43:12    1:track    0:un_corrected     11    0:PKS 0408-65
#               13:43:16 - 13:43:40    2:stop     0:un_corrected      7    1:Nothing
#               13:43:44 - 13:43:48    3:stop     1:corrected      2    0:PKS 0408-65
#               13:43:52 - 13:43:56    4:slew     1:corrected      2    0:PKS 0408-65
#               13:44:00 - 13:44:20    5:track    1:corrected      6    0:PKS 0408-65

# %%
# check what cal products we have
print 'Solutions:'
print '    Product             Number of solutions'
for k in h.file['TelescopeState'].keys():
    if 'cal_product' in k:
        print '   ', k, ' --- ' , len(h.file['TelescopeState'][k])
# Out:
# Solutions:
#     Product             Number of solutions
#     cal_product_B  ---  1
#     cal_product_K  ---  1
#     cal_product_G  ---  464

# %%
np.set_printoptions(precision=4,suppress=True)

# %%
# check antenna ordering
print h.file['TelescopeState']['cal_antlist']
a_list=[]
aa=h.file['TelescopeState']['cal_antlist']
for i,ai in enumerate(aa):
    a_list.append(pickle.loads(ai[1]))
a_array=np.array(a_list)
print a_list
print a_array[0]
labels=a_array[0]
# Out:
# <HDF5 dataset "cal_antlist": shape (1,), type "|V110">
# [['m001', 'm012', 'm014', 'm015', 'm018', 'm031', 'm034', 'm063']]
# ['m001' 'm012' 'm014' 'm015' 'm018' 'm031' 'm034' 'm063']

# %% [markdown]
# # Delays

# %%
k = h.file['TelescopeState']['cal_product_K']
k_list = []
for i, ki in enumerate(k):
    k_list.append(pickle.loads(ki[1]))
k_array = np.array(k_list)

k_0 = k_array[:,0,:]*1e9
k_1 = k_array[:,1,:]*1e9

# %%
k_array.shape #Times,Pols,Antennas
# Out:
# (1, 2, 8)

# %%
# print delays (if there are few delays)
print 'POL 0: ', k_0
print 'POL 1: ', k_1
# Out:
# POL 0:  [[    9.99   -1158.0247    31.0282    35.1779 -1116.5198    18.7461     0.
#      23.4844]]
# POL 1:  [[  -83.4155 -1153.8594    19.4114    83.8268 -1116.2892    18.9762     0.
#      23.6331]]

# %%
print labels
# Out:
# ['m001' 'm012' 'm014' 'm015' 'm018' 'm031' 'm034' 'm063']

# %%
colors=['r','g','b','c','m','k','darkorange','darkgreen','maroon','darkviolet','olive','saddlebrown','darkorchid']

# %%
#plot delays (if there are many delays)
fig, ax = plt.subplots(2,1,figsize=(20, 10))
for i in range(len(labels)):
    ax[0].plot(k_0[:,i],'-x',markersize=8,label=labels[i],color=colors[i]);
#ax[0].set_ylim([-0.2,0.2]);
    ax[1].plot(k_1[:,i],'-x',markersize=8,label=labels[i],color=colors[i]);
#ax[1].set_ylim([-0.2,0.2]);
plt.legend(loc='upper center')

# %% [markdown]
# # Gains

# %%
g = h.file['TelescopeState']['cal_product_G']
g_list = []
for i, gi in enumerate(g):
    g_list.append(pickle.loads(gi[1]))
g_array = np.array(g_list)
print g_array.shape

g_0 = g_array[:,0,:]
g_1 = g_array[:,1,:]
# Out:
# (464, 2, 8)

# %%
#First
print np.abs(g_0)[0]
print np.abs(g_1)[0]
# Out:
# [ 0.0875  0.0113  0.1125  0.0404  0.0031  5.9638  0.0363  0.0968]
# [ 0.0603  0.0055  0.7466  0.0433  0.0228  0.5644  0.18    0.646 ]

# %%
#Last
print np.abs(g_0)[-1]
print np.abs(g_1)[-1]
# Out:
# [ 1.9192  2.2655  1.9333  2.2778  1.4964  2.8466  2.0632  1.7881]
# [ 1.9433  1.671   1.574   2.3436  1.7351  1.5428  1.5292  1.7662]

# %%
#Ratio
print np.abs(g_0)[-1]/np.abs(g_0)[0]
print np.abs(g_1)[-1]/np.abs(g_1)[0]
# Out:
# [  21.9222  200.3983   17.1782   56.3142  490.1823    0.4773   56.9039
#    18.4701]
# [  32.2047  301.6305    2.1082   54.1637   76.011     2.7335    8.4949
#     2.7338]

# %%
#Before
print np.rad2deg(np.angle(g_0)[0])
print np.rad2deg(np.angle(g_1)[0])
# Out:
# [-162.5143    2.5393  -26.1787  -76.2339  -81.3303  -52.4556    0.
#  -101.1836]
# [  64.932    10.9278  -94.3707  150.6782  125.9387  -68.8953   -0.
#    52.6437]

# %%
#After
print np.rad2deg(np.angle(g_0)[-1])
print np.rad2deg(np.angle(g_1)[-1])
# Out:
# [-110.6053  -56.9192  -98.0886   51.7697  175.9587   50.2268    0.
#   115.3008]
# [ -89.6762  118.1448  -83.5616 -112.7348 -163.271    10.9361   -0.
#    74.7631]

# %%
#Differences
print np.rad2deg(np.angle(g_0)[-1])-np.rad2deg(np.angle(g_0)[0])
print np.rad2deg(np.angle(g_1)[-1])-np.rad2deg(np.angle(g_1)[0])
# Out:
# [  51.909   -59.4585  -71.9099  128.0036  257.289   102.6823    0.
#   216.4844]
# [-154.6082  107.217    10.8091 -263.413  -289.2097   79.8315   -0.
#    22.1194]

# %%
#plot gains - amplitude
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].plot(np.abs(g_0),'-x');
#ax[0].set_ylim([0,5.0]);
ax[1].plot(np.abs(g_1),'-x');
#ax[1].set_ylim([0,5.0]);
plt.xlabel('Dump')
plt.ylabel('Gain')
plt.legend()
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/axes.py:4747: UserWarning: No labeled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labeled objects found. "

# %%
#plot gains - phase
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].plot(np.rad2deg(np.angle(g_0)),'-x');
ax[0].set_ylim([-180,180]);
ax[1].plot(np.rad2deg(np.angle(g_1)),'-x');
ax[1].set_ylim([-180,180]);

# %% [markdown]
# # Bandpasses

# %%
b = h.file['TelescopeState']['cal_product_B']
b_list = []
for i, bi in enumerate(b):
    b_list.append(pickle.loads(bi[-1]))
b_array = np.array(b_list)
print b_array.shape
# bandpass shape is ntimes x channels x pol x antenna 
# where ntimes is the number of bandpasses

# just look at LAST bandpass for now
b_0_0 = b_array[-1,:,0,:]
b_1_0 = b_array[-1,:,1,:]
# Out:
# (1, 4096, 2, 8)

# %%
#plot bandpass - amplitude
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].plot(np.abs(b_0_0),'.');
ax[0].set_ylim([0,10]);
ax[0].set_xlabel('gains')
ax[1].plot(np.abs(b_1_0),'.');
ax[1].set_ylim([0,10]);
ax[1].set_xlabel('gains')
#plt.xlabel('channel')
#plt.ylabel('gains')

# %%
#plot bandpass - phase
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].plot(np.rad2deg(np.angle(b_0_0)),'.');
ax[0].set_ylim([-70,70]);
ax[1].plot(np.rad2deg(np.angle(b_1_0)),'.');
ax[1].set_ylim([-70,70]);

# %%
b_array.shape
# Time,channels,pols,antennas
# Out:
# (1, 4096, 2, 8)

# %%
#last bandpass
b_0_1 = b_array[0,:,0,8]
b_1_1 = b_array[0,:,1,8]
b_1_1.shape
print a_array[:,8]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-5638589c8c6f> in <module>()
#       1 #last bandpass
# ----> 2 b_0_1 = b_array[0,:,0,8]
#       3 b_1_1 = b_array[0,:,1,8]
#       4 b_1_1.shape
#       5 print a_array[:,8]
#
# IndexError: index 8 is out of bounds for axis 3 with size 8

# %%
#plot bandpass - amplitude
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].plot(np.abs(b_0_1),'.');
ax[0].set_ylim([0,10]);
ax[0].set_xlabel('gains')
ax[1].plot(np.abs(b_1_1),'.');
ax[1].set_ylim([0,10]);
ax[1].set_xlabel('gains')
#plt.xlabel('channel')
#plt.ylabel('gains')

# %%
#plot bandpass - phase
fig, ax = plt.subplots(2,1,figsize=(20, 10))
ax[0].plot(np.rad2deg(np.angle(b_0_1)),'.');
ax[0].set_ylim([-70,70]);
ax[1].plot(np.rad2deg(np.angle(b_1_1)),'.');
ax[1].set_ylim([-70,70]);
