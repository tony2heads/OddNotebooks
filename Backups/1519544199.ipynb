# %%
from katsdpscripts.reduction.analyse_point_source_scans import analyse_point_source_scans
# Out:
# INFO: Generating grammar tables from /usr/lib/python2.7/lib2to3/Grammar.txt
# INFO: Generating grammar tables from /usr/lib/python2.7/lib2to3/PatternGrammar.txt

# %%
import katsdpscripts

# %%
#print "Scape version: %s"%scape.__version__
#print "katdal version: %s"%katdal.__version__
#print "katpoint version: %s"%katpoint.__version__
print "katsdpscripts version: %s"%katsdpscripts.__version__
# Out:
# katsdpscripts version: 0.1.dev2711+master.c897e37

# %%
class my_opts:
    def __init__(self, **kwds):
        self.__dict__.update(kwds)

# %% [markdown]
# # done with  1sec dump period

# %%
h5name='/var/kat/archive3/data/MeerKATAR1/telescope_products/2018/02/25/1519544199.h5'
ants=['m015', 'm009', 'm003', 'm011', 'm012', 'm014', 'm006', 'm016', 'm062', 'm021', 'm010', 'm023', 'm022', \
      'm034', 'm017', 'm039']
ants.sort()
print ants
# Out:
# ['m003', 'm006', 'm009', 'm010', 'm011', 'm012', 'm014', 'm015', 'm016', 'm017', 'm021', 'm022', 'm023', 'm034', 'm039', 'm062']

# %%
for baseline in ants :
    print "\n Starting ",baseline,"\n"
    opts = my_opts(outfilebase=None, keepfilename=None, baseline=baseline, mc_iterations=1, freq_centre=1284.0, \
    freq_chans="200,4000", channel_mask='/var/kat/katsdpscripts/RTS/rfi_mask.pickle', \
    time_offset=0.0, pointing_model=None, old_loader=None, nd_models=None, \
    ku_band=False, keep_all=False,remove_spikes=False,batch=True,plot_spectrum=False)
    analyse_point_source_scans(h5name,opts)
    print "\n\n***************Done",baseline,"*************\n"
print "\nDONE ALL"
# Out:
#  Starting  m003
#
# INFO: Loading dataset '/var/kat/archive3/data/MeerKATAR1/telescope_products/2018/02/25/1519544199.h5'
# INFO: Loading baseline 'm003,m003'
# DEBUG: Found int_time=0.9995771214 in telstate['sdp_l0_int_time']
# DEBUG: Found scale_factor_timestamp=1712000000.0 in telstate[u'i0_scale_factor_timestamp']
# DEBUG: Found sync_time=1519540499.0 in telstate[u'i0_sync_time']
# DEBUG: Found n_chans=4096 in telstate['sdp_l0_n_chans']
# DEBUG: Found bandwidth=856000000.0 in telstate['sdp_l0_bandwidth']
# DEBUG: Found center_freq=1284000000.0 in telstate['sdp_l0_center_freq']
# DEBUG: Added 'PKS 1610-60' [radec] (and 2 aliases)
# DEBUG: Added 'Her A' [radec] (and 4 aliases)
# DEBUG: Added '3C 353' [radec] (and 2 aliases)
# DEBUG: Added 'PKS 2153-69' [radec] (and 2 aliases)
# DEBUG: Added 'PKS 0410-75' [radec] (and 1 aliases)
# DEBUG: Added '3C 358' [radec] (and 2 aliases)
# DEBUG: Added 'PKS 1814-63' [radec] (and 1 aliases)
# DEBUG: Added 'PKS 1934-63' [radec] (and 1 aliases)
# DEBUG: Added '3C 409' [radec] (and 2 aliases)
# DEBUG: Added 'PKS 2104-25' [radec] (and 2 aliases)
# DEBUG: Added '3C 433' [radec] (and 1 aliases)
# DEBUG: Added '3C 454.3' [radec] (and 2 aliases)
# DEBUG: Added 'PKS 0408-65' [radec] (and 1 aliases)
# DEBUG: Added 'For A' [radec] (and 4 aliases)
# DEBUG: Added 'Pic A' [radec] (and 3 aliases)
# DEBUG: Added '3C 48' [radec] (and 1 aliases)
# DEBUG: Added 'PKS 0521-36' [radec] (and 2 aliases)
# DEBUG: Added 'Ori A' [radec] (and 5 aliases)
# DEBUG: Added '3C 123' [radec] (and 1 aliases)
# DEBUG: Added '3C 161' [radec] (and 2 aliases)
# DEBUG: Added 'Tau A' [radec] (and 5 aliases)
# DEBUG: Added 'Hyd A' [radec] (and 4 aliases)
# WARNING: Extending flux density model frequency range of 'Her A' from 1408-10550 MHz to 855-10550 MHz
# WARNING: Extending flux density model frequency range of '3C 353' from 1408-10550 MHz to 855-10550 MHz
# WARNING: Extending flux density model frequency range of 'PKS 1814-63' from 1410-8400 MHz to 855-8400 MHz
# WARNING: Extending flux density model frequency range of '3C 454.3' from 1410-8400 MHz to 855-8400 MHz
# WARNING: Extending flux density model frequency range of 'PKS 0408-65' from 1410-8400 MHz to 855-8400 MHz
# WARNING: Extending flux density model frequency range of 'For A' from 1200-2000 MHz to 855-2000 MHz
# WARNING: Extending flux density model frequency range of '3C 48' from 1408-23780 MHz to 855-23780 MHz
# WARNING: Extending flux density model frequency range of 'PKS 0521-36' from 1410-8400 MHz to 855-8400 MHz
# WARNING: Extending flux density model frequency range of 'Ori A' from 1000-10000 MHz to 855-10000 MHz
# WARNING: Extending flux density model frequency range of '3C 123' from 1408-23780 MHz to 855-23780 MHz
# WARNING: Extending flux density model frequency range of '3C 161' from 1408-10550 MHz to 855-10550 MHz
# WARNING: Extending flux density model frequency range of 'Tau A' from 1400-10000 MHz to 855-10000 MHz
# WARNING: Extending flux density model frequency range of 'Hyd A' from 1408-10550 MHz to 855-10550 MHz
# WARNING: Last data point for sensor 'Enviro/air_pressure' arrives 4.12469 seconds before end of data set - extrapolation may lead to ridiculous values
# INFO: Defaulting to 'coupler' noise diode (either no or both diodes are firing)
# WARNING: Cannot find coupler noise diode H polarisation model for antenna m003 - using default.
# WARNING: Cannot find coupler noise diode V polarisation model for antenna m003 - using default.
# INFO: ==== Processing compound scan 1 of 121: 'm003 1519544199 PKS 1610-60 2018-02-25 07:38:43.961' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target 'PKS 1610-60':
# DEBUG: Iteration 0: residual = inf, beam height = 60.386, width = 0.980 deg, inner region = 74/151
# DEBUG: Iteration 1: residual = 16.13, beam height = 71.710, width = 1.237 deg, inner region = 75/151
# DEBUG: Iteration 2: residual = -0.01, beam height = 71.807, width = 1.239 deg, inner region = 76/151
# DEBUG: Refinement: beam height = 72.819, width = 1.280 deg, first null = 1.573 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target 'PKS 1610-60':
# DEBUG: Iteration 0: residual = inf, beam height = 75.424, width = 0.946 deg, inner region = 75/151
# DEBUG: Iteration 1: residual = 13.76, beam height = 88.727, width = 1.141 deg, inner region = 74/151
# DEBUG: Iteration 2: residual = 0.02, beam height = 88.656, width = 1.143 deg, inner region = 74/151
# DEBUG: Iteration 3: residual = 0.00, beam height = 88.656, width = 1.143 deg, inner region = 74/151
# DEBUG: Refinement: beam height = 90.053, width = 1.232 deg, first null = 1.429 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target 'PKS 1610-60':
# DEBUG: Iteration 0: residual = inf, beam height = 135.773, width = 0.961 deg, inner region = 74/151
# DEBUG: Iteration 1: residual = 17.88, beam height = 160.364, width = 1.183 deg, inner region = 75/151
# DEBUG: Iteration 2: residual = 0.00, beam height = 160.413, width = 1.183 deg, inner region = 75/151
# DEBUG: Iteration 3: residual = 0.00, beam height = 160.413, width = 1.183 deg, inner region = 75/151
# DEBUG: Refinement: beam height = 161.961, width = 1.249 deg, first null = 1.432 deg, based on 5 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 2 of 121: 'm003 1519544199 Her A 2018-02-25 07:45:16.295' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target 'Her A':
# DEBUG: Iteration 0: residual = inf, beam height = 37.082, width = 0.817 deg, inner region = 230/302
# DEBUG: Iteration 1: residual = 0.39, beam height = 55.756, width = 1.395 deg, inner region = 226/302
# DEBUG: Iteration 2: residual = -0.91, beam height = 68.328, width = 0.982 deg, inner region = 222/302
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target 'Her A':
# DEBUG: Iteration 0: residual = inf, beam height = 46.449, width = 0.820 deg, inner region = 230/302
# DEBUG: Iteration 1: residual = 2.31, beam height = 62.790, width = 1.238 deg, inner region = 229/302
# DEBUG: Iteration 2: residual = 0.01, beam height = 63.158, width = 1.241 deg, inner region = 229/302
# DEBUG: Iteration 3: residual = 0.00, beam height = 63.158, width = 1.241 deg, inner region = 229/302
# DEBUG: Refinement: beam height = 52.039, width = 1.472 deg, first null = 1.849 deg, based on 2 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target 'Her A':
# DEBUG: Iteration 0: residual = inf, beam height = 83.525, width = 0.818 deg, inner region = 231/302
# DEBUG: Iteration 1: residual = 1.24, beam height = 119.196, width = 1.306 deg, inner region = 227/302
# DEBUG: Iteration 2: residual = -0.04, beam height = 120.797, width = 1.242 deg, inner region = 228/302
# DEBUG: Refinement: beam height = 112.534, width = 1.250 deg, first null = 1.751 deg, based on 3 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 3 of 121: 'm003 1519544199 3C 353 2018-02-25 07:51:07.147' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target '3C 353':
# DEBUG: Iteration 0: residual = inf, beam height = 42.935, width = 0.849 deg, inner region = 231/296
# DEBUG: Iteration 1: residual = 102.63, beam height = 59.180, width = 1.191 deg, inner region = 229/296
# DEBUG: Iteration 2: residual = -0.89, beam height = 62.922, width = 1.257 deg, inner region = 228/296
# DEBUG: Refinement: beam height = 58.243, width = 1.215 deg, first null = 1.508 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target '3C 353':
# DEBUG: Iteration 0: residual = inf, beam height = 57.785, width = 0.828 deg, inner region = 229/296
# DEBUG: Iteration 1: residual = 19.14, beam height = 78.877, width = 1.148 deg, inner region = 228/296
# DEBUG: Iteration 2: residual = -0.53, beam height = 82.744, width = 1.201 deg, inner region = 226/296
# DEBUG: Refinement: beam height = 77.756, width = 1.185 deg, first null = 1.441 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target '3C 353':
# DEBUG: Iteration 0: residual = inf, beam height = 100.697, width = 0.837 deg, inner region = 230/296
# DEBUG: Iteration 1: residual = 34.08, beam height = 137.895, width = 1.166 deg, inner region = 229/296
# DEBUG: Iteration 2: residual = -0.65, beam height = 145.489, width = 1.226 deg, inner region = 227/296
# DEBUG: Refinement: beam height = 135.842, width = 1.198 deg, first null = 1.471 deg, based on 5 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 4 of 121: 'm003 1519544199 PKS 2153-69 2018-02-25 07:57:24.487' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target 'PKS 2153-69':
# DEBUG: Iteration 0: residual = inf, beam height = 26.259, width = 0.955 deg, inner region = 78/145
# DEBUG: Iteration 1: residual = 39.44, beam height = 31.005, width = 1.181 deg, inner region = 78/145
# DEBUG: Iteration 2: residual = 0.00, beam height = 31.005, width = 1.181 deg, inner region = 78/145
# DEBUG: Refinement: beam height = 31.461, width = 1.241 deg, first null = 1.618 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target 'PKS 2153-69':
# DEBUG: Iteration 0: residual = inf, beam height = 33.665, width = 0.876 deg, inner region = 75/145
# DEBUG: Iteration 1: residual = 14.79, beam height = 39.083, width = 1.031 deg, inner region = 74/145
# DEBUG: Iteration 2: residual = 0.02, beam height = 39.077, width = 1.032 deg, inner region = 74/145
# DEBUG: Iteration 3: residual = 0.00, beam height = 39.077, width = 1.032 deg, inner region = 74/145
# DEBUG: Refinement: beam height = 38.832, width = 1.148 deg, first null = 1.394 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target 'PKS 2153-69':
# DEBUG: Iteration 0: residual = inf, beam height = 59.795, width = 0.909 deg, inner region = 77/145
# DEBUG: Iteration 1: residual = 39.10, beam height = 69.926, width = 1.095 deg, inner region = 76/145
# DEBUG: Iteration 2: residual = -0.00, beam height = 69.914, width = 1.095 deg, inner region = 76/145
# DEBUG: Refinement: beam height = 69.562, width = 1.176 deg, first null = 1.445 deg, based on 5 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 5 of 121: 'm003 1519544199 PKS 0410-75 2018-02-25 08:01:01.396' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target 'PKS 0410-75':
# DEBUG: Iteration 0: residual = inf, beam height = 12.279, width = 0.939 deg, inner region = 76/147
# DEBUG: Iteration 1: residual = 11.53, beam height = 14.811, width = 1.150 deg, inner region = 75/147
# DEBUG: Iteration 2: residual = 0.02, beam height = 14.822, width = 1.157 deg, inner region = 76/147
# DEBUG: Iteration 3: residual = -0.01, beam height = 14.831, width = 1.154 deg, inner region = 75/147
# DEBUG: Refinement: beam height = 14.991, width = 1.236 deg, first null = 1.569 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target 'PKS 0410-75':
# DEBUG: Iteration 0: residual = inf, beam height = 13.955, width = 0.947 deg, inner region = 76/147
# DEBUG: Iteration 1: residual = 15.11, beam height = 16.698, width = 1.239 deg, inner region = 76/147
# DEBUG: Iteration 2: residual = -0.02, beam height = 16.724, width = 1.240 deg, inner region = 76/147
# DEBUG: Refinement: beam height = 17.625, width = 1.249 deg, first null = 1.550 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target 'PKS 0410-75':
# DEBUG: Iteration 0: residual = inf, beam height = 26.217, width = 0.943 deg, inner region = 76/147
# DEBUG: Iteration 1: residual = 47.01, beam height = 31.525, width = 1.193 deg, inner region = 76/147
# DEBUG: Iteration 2: residual = -0.02, beam height = 31.554, width = 1.196 deg, inner region = 75/147
# DEBUG: Refinement: beam height = 31.641, width = 1.232 deg, first null = 1.579 deg, based on 5 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 6 of 121: 'm003 1519544199 3C 358 2018-02-25 08:06:13.264' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target '3C 358':
# DEBUG: Iteration 0: residual = inf, beam height = 9.094, width = 0.959 deg, inner region = 76/147
# DEBUG: Iteration 1: residual = 0.29, beam height = 11.849, width = 1.159 deg, inner region = 74/147
# DEBUG: Iteration 2: residual = 0.03, beam height = 11.917, width = 1.180 deg, inner region = 73/147
# DEBUG: Iteration 3: residual = 0.01, beam height = 12.067, width = 1.193 deg, inner region = 73/147
# DEBUG: Iteration 4: residual = 0.00, beam height = 12.067, width = 1.193 deg, inner region = 73/147
# DEBUG: Refinement: beam height = 13.344, width = 1.837 deg, first null = 1.479 deg, based on 4 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target '3C 358':
# DEBUG: Iteration 0: residual = inf, beam height = 13.844, width = 0.958 deg, inner region = 77/147
# DEBUG: Iteration 1: residual = 0.21, beam height = 17.057, width = 1.734 deg, inner region = 75/147
# DEBUG: Iteration 2: residual = 0.11, beam height = 24.205, width = 2.266 deg, inner region = 74/147
# DEBUG: Iteration 3: residual = -0.12, beam height = 46.892, width = 2.882 deg, inner region = 61/147
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target '3C 358':
# DEBUG: Iteration 0: residual = inf, beam height = 22.556, width = 0.972 deg, inner region = 75/147
# DEBUG: Iteration 1: residual = 0.23, beam height = 28.500, width = 1.514 deg, inner region = 73/147
# DEBUG: Iteration 2: residual = 0.04, beam height = 30.892, width = 1.818 deg, inner region = 75/147
# DEBUG: Iteration 3: residual = -0.04, beam height = 34.431, width = 2.129 deg, inner region = 73/147
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=False, keep=False
# INFO: ==== Processing compound scan 7 of 121: 'm003 1519544199 PKS 1814-63 2018-02-25 08:11:16.136' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target 'PKS 1814-63':
# DEBUG: Iteration 0: residual = inf, beam height = 11.141, width = 0.880 deg, inner region = 228/295
# DEBUG: Iteration 1: residual = 30.12, beam height = 15.601, width = 1.275 deg, inner region = 229/295
# DEBUG: Iteration 2: residual = -0.25, beam height = 15.670, width = 1.274 deg, inner region = 229/295
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target 'PKS 1814-63':
# DEBUG: Iteration 0: residual = inf, beam height = 14.321, width = 0.891 deg, inner region = 232/295
# DEBUG: Iteration 1: residual = 22.66, beam height = 19.582, width = 1.255 deg, inner region = 231/295
# DEBUG: Iteration 2: residual = -0.94, beam height = 20.641, width = 1.253 deg, inner region = 229/295
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target 'PKS 1814-63':
# DEBUG: Iteration 0: residual = inf, beam height = 25.443, width = 0.886 deg, inner region = 229/295
# DEBUG: Iteration 1: residual = 38.77, beam height = 35.205, width = 1.262 deg, inner region = 231/295
# DEBUG: Iteration 2: residual = -0.93, beam height = 36.451, width = 1.266 deg, inner region = 229/295
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 8 of 121: 'm003 1519544199 PKS 1934-63 2018-02-25 08:15:48.520' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target 'PKS 1934-63':
# DEBUG: Iteration 0: residual = inf, beam height = 9.818, width = 0.829 deg, inner region = 76/148
# DEBUG: Iteration 1: residual = 1.76, beam height = 11.269, width = 0.911 deg, inner region = 76/148
# DEBUG: Iteration 2: residual = 0.00, beam height = 11.269, width = 0.911 deg, inner region = 76/148
# DEBUG: Refinement: beam height = 11.661, width = 1.125 deg, first null = 1.448 deg, based on 4 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target 'PKS 1934-63':
# DEBUG: Iteration 0: residual = inf, beam height = 12.742, width = 0.843 deg, inner region = 76/148
# DEBUG: Iteration 1: residual = 3.35, beam height = 14.696, width = 0.976 deg, inner region = 78/148
# DEBUG: Iteration 2: residual = -0.00, beam height = 14.705, width = 0.977 deg, inner region = 78/148
# DEBUG: Refinement: beam height = 15.432, width = 1.120 deg, first null = 1.417 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target 'PKS 1934-63':
# DEBUG: Iteration 0: residual = inf, beam height = 22.561, width = 0.836 deg, inner region = 76/148
# DEBUG: Iteration 1: residual = 2.99, beam height = 26.011, width = 0.945 deg, inner region = 77/148
# DEBUG: Iteration 2: residual = 0.00, beam height = 26.016, width = 0.945 deg, inner region = 77/148
# DEBUG: Iteration 3: residual = 0.00, beam height = 26.016, width = 0.945 deg, inner region = 77/148
# DEBUG: Refinement: beam height = 26.976, width = 1.121 deg, first null = 1.456 deg, based on 4 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 9 of 121: 'm003 1519544199 3C 409 2018-02-25 08:20:32.900' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target '3C 409':
# DEBUG: Iteration 0: residual = inf, beam height = 12.921, width = 0.975 deg, inner region = 76/145
# DEBUG: Iteration 1: residual = 3.75, beam height = 15.426, width = 1.273 deg, inner region = 75/145
# DEBUG: Iteration 2: residual = 0.00, beam height = 15.451, width = 1.274 deg, inner region = 75/145
# DEBUG: Iteration 3: residual = 0.00, beam height = 15.451, width = 1.274 deg, inner region = 75/145
# DEBUG: Refinement: beam height = 16.518, width = 1.319 deg, first null = 1.669 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target '3C 409':
# DEBUG: Iteration 0: residual = inf, beam height = 17.840, width = 0.924 deg, inner region = 76/145
# DEBUG: Iteration 1: residual = 4.15, beam height = 20.962, width = 1.168 deg, inner region = 75/145
# DEBUG: Iteration 2: residual = 0.00, beam height = 20.994, width = 1.168 deg, inner region = 75/145
# DEBUG: Iteration 3: residual = 0.00, beam height = 20.994, width = 1.168 deg, inner region = 75/145
# DEBUG: Refinement: beam height = 22.008, width = 1.228 deg, first null = 1.659 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target '3C 409':
# DEBUG: Iteration 0: residual = inf, beam height = 30.742, width = 0.945 deg, inner region = 76/145
# DEBUG: Iteration 1: residual = 4.01, beam height = 36.344, width = 1.213 deg, inner region = 75/145
# DEBUG: Iteration 2: residual = 0.00, beam height = 36.401, width = 1.213 deg, inner region = 75/145
# DEBUG: Iteration 3: residual = 0.00, beam height = 36.401, width = 1.213 deg, inner region = 75/145
# DEBUG: Refinement: beam height = 38.456, width = 1.266 deg, first null = 1.784 deg, based on 5 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 10 of 121: 'm003 1519544199 PKS 2104-25 2018-02-25 08:25:40.770' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target 'PKS 2104-25':
# DEBUG: Iteration 0: residual = inf, beam height = 9.936, width = 0.881 deg, inner region = 232/297
# DEBUG: Iteration 1: residual = 66.00, beam height = 13.012, width = 1.214 deg, inner region = 232/297
# DEBUG: Iteration 2: residual = 0.00, beam height = 13.012, width = 1.214 deg, inner region = 232/297
# DEBUG: Refinement: beam height = 13.152, width = 1.236 deg, first null = 1.481 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target 'PKS 2104-25':
# DEBUG: Iteration 0: residual = inf, beam height = 13.335, width = 0.899 deg, inner region = 232/297
# DEBUG: Iteration 1: residual = 35.72, beam height = 17.616, width = 1.312 deg, inner region = 232/297
# DEBUG: Iteration 2: residual = 0.00, beam height = 17.616, width = 1.312 deg, inner region = 232/297
# DEBUG: Refinement: beam height = 18.269, width = 1.301 deg, first null = 1.613 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target 'PKS 2104-25':
# DEBUG: Iteration 0: residual = inf, beam height = 23.268, width = 0.891 deg, inner region = 232/297
# DEBUG: Iteration 1: residual = 51.52, beam height = 30.614, width = 1.269 deg, inner region = 232/297
# DEBUG: Iteration 2: residual = 0.00, beam height = 30.614, width = 1.269 deg, inner region = 232/297
# DEBUG: Refinement: beam height = 31.411, width = 1.271 deg, first null = 1.561 deg, based on 5 of 5 scans
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 11 of 121: 'm003 1519544199 3C 433 2018-02-25 08:30:50.639' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target '3C 433':
# DEBUG: Iteration 0: residual = inf, beam height = 8.479, width = 0.863 deg, inner region = 75/147
# DEBUG: Iteration 1: residual = 5.71, beam height = 9.935, width = 0.993 deg, inner region = 76/147
# DEBUG: Iteration 2: residual = -0.00, beam height = 9.936, width = 0.992 deg, inner region = 76/147
# DEBUG: Refinement: beam height = 9.958, width = 1.144 deg, first null = 1.459 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target '3C 433':
# DEBUG: Iteration 0: residual = inf, beam height = 11.010, width = 0.877 deg, inner region = 77/147
# DEBUG: Iteration 1: residual = 10.03, beam height = 12.818, width = 1.031 deg, inner region = 77/147
# DEBUG: Iteration 2: residual = 0.00, beam height = 12.818, width = 1.031 deg, inner region = 77/147
# DEBUG: Refinement: beam height = 13.045, width = 1.139 deg, first null = 1.341 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target '3C 433':
# DEBUG: Iteration 0: residual = inf, beam height = 19.481, width = 0.870 deg, inner region = 76/147
# DEBUG: Iteration 1: residual = 9.20, beam height = 22.771, width = 1.012 deg, inner region = 75/147
# DEBUG: Iteration 2: residual = 0.01, beam height = 22.759, width = 1.013 deg, inner region = 75/147
# DEBUG: Iteration 3: residual = 0.00, beam height = 22.759, width = 1.013 deg, inner region = 75/147
# DEBUG: Refinement: beam height = 22.894, width = 1.134 deg, first null = 1.317 deg, based on 5 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 12 of 121: 'm003 1519544199 3C 454.3 2018-02-25 08:35:34.519' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target '3C 454.3':
# DEBUG: Iteration 0: residual = inf, beam height = 9.894, width = 0.827 deg, inner region = 229/297
# DEBUG: Iteration 1: residual = 0.93, beam height = 15.989, width = 1.349 deg, inner region = 220/297
# DEBUG: Iteration 2: residual = 1.47, beam height = 14.967, width = 1.561 deg, inner region = 217/297
# DEBUG: Iteration 3: residual = 0.09, beam height = 14.918, width = 1.531 deg, inner region = 218/297
# DEBUG: Iteration 4: residual = -0.04, beam height = 14.914, width = 1.541 deg, inner region = 218/297
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target '3C 454.3':
# DEBUG: Iteration 0: residual = inf, beam height = 14.576, width = 0.844 deg, inner region = 228/297
# DEBUG: Iteration 1: residual = -0.25, beam height = 14.026, width = 1.043 deg, inner region = 229/297
# DEBUG: Refinement: beam height = 21.118, width = 1.275 deg, first null = 1.251 deg, based on 4 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target '3C 454.3':
# DEBUG: Iteration 0: residual = inf, beam height = 24.439, width = 0.838 deg, inner region = 228/297
# DEBUG: Iteration 1: residual = 4.34, beam height = 30.852, width = 1.124 deg, inner region = 227/297
# DEBUG: Iteration 2: residual = -0.00, beam height = 30.847, width = 1.126 deg, inner region = 227/297
# DEBUG: Refinement: beam height = 34.477, width = 1.222 deg, first null = 1.385 deg, based on 5 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 13 of 121: 'm003 1519544199 PKS 1610-60 2018-02-25 08:41:25.870' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target 'PKS 1610-60':
# DEBUG: Iteration 0: residual = inf, beam height = 57.346, width = 0.952 deg, inner region = 77/148
# DEBUG: Iteration 1: residual = 9.03, beam height = 68.541, width = 1.165 deg, inner region = 74/148
# DEBUG: Iteration 2: residual = 0.05, beam height = 68.538, width = 1.170 deg, inner region = 74/148
# DEBUG: Iteration 3: residual = 0.00, beam height = 68.538, width = 1.170 deg, inner region = 74/148
# DEBUG: Refinement: beam height = 68.496, width = 1.259 deg, first null = 1.427 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target 'PKS 1610-60':
# DEBUG: Iteration 0: residual = inf, beam height = 67.641, width = 0.907 deg, inner region = 78/148
# DEBUG: Iteration 1: residual = 9.28, beam height = 79.088, width = 1.065 deg, inner region = 77/148
# DEBUG: Iteration 2: residual = 0.01, beam height = 79.160, width = 1.065 deg, inner region = 77/148
# DEBUG: Iteration 3: residual = 0.00, beam height = 79.160, width = 1.065 deg, inner region = 77/148
# DEBUG: Refinement: beam height = 78.196, width = 1.190 deg, first null = 1.278 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target 'PKS 1610-60':
# DEBUG: Iteration 0: residual = inf, beam height = 124.898, width = 0.927 deg, inner region = 77/148
# DEBUG: Iteration 1: residual = 9.90, beam height = 147.548, width = 1.109 deg, inner region = 75/148
# DEBUG: Iteration 2: residual = 0.05, beam height = 147.483, width = 1.114 deg, inner region = 75/148
# DEBUG: Iteration 3: residual = 0.00, beam height = 147.483, width = 1.114 deg, inner region = 75/148
# DEBUG: Refinement: beam height = 145.541, width = 1.215 deg, first null = 1.448 deg, based on 5 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 14 of 121: 'm003 1519544199 Her A 2018-02-25 08:48:10.699' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target 'Her A':
# DEBUG: Iteration 0: residual = inf, beam height = 36.451, width = 0.820 deg, inner region = 227/298
# DEBUG: Iteration 1: residual = 2.80, beam height = 57.337, width = 1.429 deg, inner region = 217/298
# DEBUG: Iteration 2: residual = 0.52, beam height = 56.344, width = 1.536 deg, inner region = 214/298
# DEBUG: Iteration 3: residual = 0.03, beam height = 56.138, width = 1.528 deg, inner region = 214/298
# DEBUG: Iteration 4: residual = 0.00, beam height = 56.138, width = 1.528 deg, inner region = 214/298
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target 'Her A':
# DEBUG: Iteration 0: residual = inf, beam height = 45.367, width = 0.819 deg, inner region = 229/298
# DEBUG: Iteration 1: residual = 17.44, beam height = 65.745, width = 1.169 deg, inner region = 227/298
# DEBUG: Iteration 2: residual = 0.78, beam height = 64.433, width = 1.226 deg, inner region = 226/298
# DEBUG: Iteration 3: residual = 0.00, beam height = 64.453, width = 1.225 deg, inner region = 226/298
# DEBUG: Iteration 4: residual = 0.00, beam height = 64.453, width = 1.225 deg, inner region = 226/298
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target 'Her A':
# DEBUG: Iteration 0: residual = inf, beam height = 81.776, width = 0.819 deg, inner region = 227/298
# DEBUG: Iteration 1: residual = 5.56, beam height = 123.931, width = 1.220 deg, inner region = 223/298
# DEBUG: Iteration 2: residual = 0.66, beam height = 119.522, width = 1.368 deg, inner region = 222/298
# DEBUG: Iteration 3: residual = -0.00, beam height = 119.557, width = 1.369 deg, inner region = 222/298
# DEBUG: Refinement: beam height = 114.566, width = 1.156 deg, first null = 1.697 deg, based on 2 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 15 of 121: 'm003 1519544199 3C 353 2018-02-25 08:54:01.550' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target '3C 353':
# DEBUG: Iteration 0: residual = inf, beam height = 42.056, width = 0.838 deg, inner region = 228/296
# DEBUG: Iteration 1: residual = 40.51, beam height = 61.190, width = 1.220 deg, inner region = 226/296
# DEBUG: Iteration 2: residual = -0.24, beam height = 60.134, width = 1.280 deg, inner region = 225/296
# DEBUG: Refinement: beam height = 58.719, width = 1.213 deg, first null = 1.536 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target '3C 353':
# DEBUG: Iteration 0: residual = inf, beam height = 56.374, width = 0.820 deg, inner region = 229/296
# DEBUG: Iteration 1: residual = 68.77, beam height = 80.097, width = 1.176 deg, inner region = 226/296
# DEBUG: Iteration 2: residual = -0.24, beam height = 79.052, width = 1.215 deg, inner region = 225/296
# DEBUG: Refinement: beam height = 76.630, width = 1.178 deg, first null = 1.458 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target '3C 353':
# DEBUG: Iteration 0: residual = inf, beam height = 98.417, width = 0.828 deg, inner region = 229/296
# DEBUG: Iteration 1: residual = 58.70, beam height = 141.254, width = 1.195 deg, inner region = 226/296
# DEBUG: Iteration 2: residual = -0.24, beam height = 139.129, width = 1.243 deg, inner region = 225/296
# DEBUG: Refinement: beam height = 135.083, width = 1.191 deg, first null = 1.492 deg, based on 5 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 16 of 121: 'm003 1519544199 PKS 2153-69 2018-02-25 09:03:00.822' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target 'PKS 2153-69':
# DEBUG: Iteration 0: residual = inf, beam height = 24.826, width = 0.996 deg, inner region = 75/151
# DEBUG: Iteration 1: residual = 39.95, beam height = 29.394, width = 1.237 deg, inner region = 76/151
# DEBUG: Iteration 2: residual = 0.00, beam height = 29.391, width = 1.238 deg, inner region = 76/151
# DEBUG: Iteration 3: residual = 0.00, beam height = 29.391, width = 1.238 deg, inner region = 76/151
# DEBUG: Refinement: beam height = 30.183, width = 1.283 deg, first null = 1.746 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target 'PKS 2153-69':
# DEBUG: Iteration 0: residual = inf, beam height = 31.590, width = 0.956 deg, inner region = 76/151
# DEBUG: Iteration 1: residual = 17.41, beam height = 36.798, width = 1.198 deg, inner region = 77/151
# DEBUG: Iteration 2: residual = 0.00, beam height = 36.786, width = 1.200 deg, inner region = 77/151
# DEBUG: Iteration 3: residual = 0.00, beam height = 36.786, width = 1.200 deg, inner region = 77/151
# DEBUG: Refinement: beam height = 38.398, width = 1.216 deg, first null = 1.884 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target 'PKS 2153-69':
# DEBUG: Iteration 0: residual = inf, beam height = 56.370, width = 0.974 deg, inner region = 75/151
# DEBUG: Iteration 1: residual = 40.17, beam height = 66.172, width = 1.216 deg, inner region = 77/151
# DEBUG: Iteration 2: residual = -0.00, beam height = 66.185, width = 1.217 deg, inner region = 77/151
# DEBUG: Refinement: beam height = 68.099, width = 1.237 deg, first null = 1.923 deg, based on 5 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 17 of 121: 'm003 1519544199 PKS 0408-65 2018-02-25 09:07:53.698' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target 'PKS 0408-65':
# DEBUG: Iteration 0: residual = inf, beam height = 12.548, width = 0.880 deg, inner region = 227/297
# DEBUG: Iteration 1: residual = -0.02, beam height = 13.197, width = 1.144 deg, inner region = 231/297
# DEBUG: Refinement: beam height = 18.842, width = 1.325 deg, first null = 1.544 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target 'PKS 0408-65':
# DEBUG: Iteration 0: residual = inf, beam height = 15.668, width = 0.856 deg, inner region = 229/297
# DEBUG: Iteration 1: residual = -0.01, beam height = 16.217, width = 1.065 deg, inner region = 229/297
# DEBUG: Refinement: beam height = 22.652, width = 1.275 deg, first null = 1.512 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target 'PKS 0408-65':
# DEBUG: Iteration 0: residual = inf, beam height = 28.203, width = 0.866 deg, inner region = 229/297
# DEBUG: Iteration 1: residual = -0.01, beam height = 29.400, width = 1.098 deg, inner region = 228/297
# DEBUG: Refinement: beam height = 41.478, width = 1.295 deg, first null = 1.559 deg, based on 5 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 18 of 121: 'm003 1519544199 PKS 0410-75 2018-02-25 09:12:27.083' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target 'PKS 0410-75':
# DEBUG: Iteration 0: residual = inf, beam height = 12.276, width = 0.960 deg, inner region = 76/148
# DEBUG: Iteration 1: residual = 48.84, beam height = 14.547, width = 1.253 deg, inner region = 76/148
# DEBUG: Iteration 2: residual = 0.00, beam height = 14.547, width = 1.253 deg, inner region = 76/148
# DEBUG: Refinement: beam height = 15.065, width = 1.238 deg, first null = 2.205 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target 'PKS 0410-75':
# DEBUG: Iteration 0: residual = inf, beam height = 15.433, width = 1.013 deg, inner region = 76/148
# DEBUG: Iteration 1: residual = 8.20, beam height = 18.137, width = 1.433 deg, inner region = 76/148
# DEBUG: Iteration 2: residual = 0.00, beam height = 18.137, width = 1.433 deg, inner region = 76/148
# DEBUG: Refinement: beam height = 20.177, width = 1.420 deg, first null = 2.207 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target 'PKS 0410-75':
# DEBUG: Iteration 0: residual = inf, beam height = 27.705, width = 0.989 deg, inner region = 76/148
# DEBUG: Iteration 1: residual = 18.30, beam height = 32.699, width = 1.348 deg, inner region = 76/148
# DEBUG: Iteration 2: residual = 0.00, beam height = 32.699, width = 1.348 deg, inner region = 76/148
# DEBUG: Refinement: beam height = 35.234, width = 1.311 deg, first null = 2.197 deg, based on 5 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 19 of 121: 'm003 1519544199 3C 358 2018-02-25 09:16:33.978' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target '3C 358':
# DEBUG: Iteration 0: residual = inf, beam height = 9.801, width = 0.770 deg, inner region = 76/152
# DEBUG: Iteration 1: residual = 0.00, beam height = 10.639, width = 0.798 deg, inner region = 77/152
# DEBUG: Iteration 2: residual = -0.00, beam height = 10.635, width = 0.804 deg, inner region = 77/152
# DEBUG: Refinement: beam height = 14.126, width = 1.314 deg, first null = 1.374 deg, based on 4 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target '3C 358':
# DEBUG: Iteration 0: residual = inf, beam height = 8.795, width = 1.142 deg, inner region = 46/152
# DEBUG: Iteration 1: residual = 0.66, beam height = 20.939, width = 1.766 deg, inner region = 46/152
# DEBUG: Iteration 2: residual = 0.00, beam height = 20.939, width = 1.766 deg, inner region = 46/152
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target '3C 358':
# DEBUG: Iteration 0: residual = inf, beam height = 19.912, width = 0.699 deg, inner region = 77/152
# DEBUG: Iteration 1: residual = -0.08, beam height = 20.379, width = 0.673 deg, inner region = 77/152
# DEBUG: Refinement: beam height = 29.624, width = 1.313 deg, first null = 1.212 deg, based on 4 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 20 of 121: 'm003 1519544199 PKS 1814-63 2018-02-25 09:21:28.853' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target 'PKS 1814-63':
# DEBUG: Iteration 0: residual = inf, beam height = 10.706, width = 0.860 deg, inner region = 231/302
# DEBUG: Iteration 1: residual = 35.05, beam height = 14.235, width = 1.151 deg, inner region = 228/302
# DEBUG: Iteration 2: residual = 0.01, beam height = 14.204, width = 1.153 deg, inner region = 228/302
# DEBUG: Iteration 3: residual = 0.00, beam height = 14.204, width = 1.153 deg, inner region = 228/302
# DEBUG: Refinement: beam height = 14.364, width = 1.194 deg, first null = 1.465 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target 'PKS 1814-63':
# DEBUG: Iteration 0: residual = inf, beam height = 14.916, width = 0.871 deg, inner region = 229/302
# DEBUG: Iteration 1: residual = 15.95, beam height = 20.231, width = 1.311 deg, inner region = 231/302
# DEBUG: Iteration 2: residual = -0.00, beam height = 20.214, width = 1.308 deg, inner region = 231/302
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target 'PKS 1814-63':
# DEBUG: Iteration 0: residual = inf, beam height = 25.585, width = 0.867 deg, inner region = 229/302
# DEBUG: Iteration 1: residual = 37.03, beam height = 34.449, width = 1.240 deg, inner region = 231/302
# DEBUG: Iteration 2: residual = -0.02, beam height = 34.530, width = 1.246 deg, inner region = 231/302
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 21 of 121: 'm003 1519544199 PKS 1934-63 2018-02-25 09:26:00.738' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target 'PKS 1934-63':
# DEBUG: Iteration 0: residual = inf, beam height = 8.828, width = 0.829 deg, inner region = 76/146
# DEBUG: Iteration 1: residual = 2.54, beam height = 10.099, width = 0.919 deg, inner region = 75/146
# DEBUG: Iteration 2: residual = 0.02, beam height = 10.089, width = 0.921 deg, inner region = 75/146
# DEBUG: Iteration 3: residual = 0.00, beam height = 10.089, width = 0.921 deg, inner region = 75/146
# DEBUG: Refinement: beam height = 10.092, width = 1.158 deg, first null = 1.335 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target 'PKS 1934-63':
# DEBUG: Iteration 0: residual = inf, beam height = 12.378, width = 0.823 deg, inner region = 76/146
# DEBUG: Iteration 1: residual = 1.65, beam height = 13.866, width = 0.897 deg, inner region = 75/146
# DEBUG: Iteration 2: residual = 0.01, beam height = 13.850, width = 0.899 deg, inner region = 75/146
# DEBUG: Iteration 3: residual = 0.00, beam height = 13.850, width = 0.899 deg, inner region = 75/146
# DEBUG: Refinement: beam height = 15.139, width = 1.130 deg, first null = 1.277 deg, based on 4 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target 'PKS 1934-63':
# DEBUG: Iteration 0: residual = inf, beam height = 21.197, width = 0.825 deg, inner region = 76/146
# DEBUG: Iteration 1: residual = 2.23, beam height = 23.965, width = 0.906 deg, inner region = 75/146
# DEBUG: Iteration 2: residual = 0.02, beam height = 23.940, width = 0.908 deg, inner region = 75/146
# DEBUG: Iteration 3: residual = 0.00, beam height = 23.940, width = 0.908 deg, inner region = 75/146
# DEBUG: Refinement: beam height = 25.367, width = 1.116 deg, first null = 1.317 deg, based on 4 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 22 of 121: 'm003 1519544199 3C 409 2018-02-25 09:30:54.114' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target '3C 409':
# DEBUG: Iteration 0: residual = inf, beam height = 13.514, width = 1.016 deg, inner region = 75/147
# DEBUG: Iteration 1: residual = 12.20, beam height = 16.232, width = 1.366 deg, inner region = 76/147
# DEBUG: Iteration 2: residual = 0.01, beam height = 16.243, width = 1.368 deg, inner region = 76/147
# DEBUG: Iteration 3: residual = 0.00, beam height = 16.243, width = 1.368 deg, inner region = 76/147
# DEBUG: Refinement: beam height = 17.040, width = 1.365 deg, first null = 2.216 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target '3C 409':
# DEBUG: Iteration 0: residual = inf, beam height = 17.040, width = 0.977 deg, inner region = 75/147
# DEBUG: Iteration 1: residual = 10.64, beam height = 20.083, width = 1.280 deg, inner region = 76/147
# DEBUG: Iteration 2: residual = 0.01, beam height = 20.106, width = 1.281 deg, inner region = 76/147
# DEBUG: Iteration 3: residual = 0.00, beam height = 20.106, width = 1.281 deg, inner region = 76/147
# DEBUG: Refinement: beam height = 20.941, width = 1.312 deg, first null = 2.191 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target '3C 409':
# DEBUG: Iteration 0: residual = inf, beam height = 30.537, width = 0.994 deg, inner region = 75/147
# DEBUG: Iteration 1: residual = 11.65, beam height = 36.276, width = 1.319 deg, inner region = 76/147
# DEBUG: Iteration 2: residual = 0.01, beam height = 36.309, width = 1.320 deg, inner region = 76/147
# DEBUG: Iteration 3: residual = 0.00, beam height = 36.309, width = 1.320 deg, inner region = 76/147
# DEBUG: Refinement: beam height = 37.936, width = 1.335 deg, first null = 2.205 deg, based on 5 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 23 of 121: 'm003 1519544199 PKS 2104-25 2018-02-25 09:36:11.980' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target 'PKS 2104-25':
# DEBUG: Iteration 0: residual = inf, beam height = 10.645, width = 0.975 deg, inner region = 229/295
# DEBUG: Iteration 1: residual = 8.02, beam height = 15.193, width = 1.500 deg, inner region = 231/295
# DEBUG: Iteration 2: residual = 0.00, beam height = 15.197, width = 1.504 deg, inner region = 230/295
# DEBUG: Iteration 3: residual = -0.00, beam height = 15.206, width = 1.505 deg, inner region = 231/295
# DEBUG: Refinement: beam height = 16.040, width = 1.539 deg, first null = 1.971 deg, based on 5 of 5 scans
# ...
# DEBUG: Iteration 0: residual = inf, beam height = 15.923, width = 0.960 deg, inner region = 77/145
# DEBUG: Iteration 1: residual = 14.03, beam height = 18.586, width = 1.203 deg, inner region = 77/145
# DEBUG: Iteration 2: residual = 0.00, beam height = 18.586, width = 1.203 deg, inner region = 77/145
# DEBUG: Refinement: beam height = 19.547, width = 1.244 deg, first null = 1.444 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target 'PKS 0410-75':
# DEBUG: Iteration 0: residual = inf, beam height = 11.123, width = 0.969 deg, inner region = 77/145
# DEBUG: Iteration 1: residual = 59.40, beam height = 12.984, width = 1.222 deg, inner region = 77/145
# DEBUG: Iteration 2: residual = 0.00, beam height = 12.984, width = 1.222 deg, inner region = 77/145
# DEBUG: Refinement: beam height = 13.372, width = 1.246 deg, first null = 2.200 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target 'PKS 0410-75':
# DEBUG: Iteration 0: residual = inf, beam height = 27.045, width = 0.964 deg, inner region = 77/145
# DEBUG: Iteration 1: residual = 30.97, beam height = 31.575, width = 1.210 deg, inner region = 77/145
# DEBUG: Iteration 2: residual = 0.00, beam height = 31.575, width = 1.210 deg, inner region = 77/145
# DEBUG: Refinement: beam height = 32.592, width = 1.237 deg, first null = 2.009 deg, based on 5 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 117 of 121: 'm010 1519544199 PKS 0521-36 2018-02-25 17:42:13.643' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target 'PKS 0521-36':
# DEBUG: Iteration 0: residual = inf, beam height = 16.303, width = 0.891 deg, inner region = 230/297
# DEBUG: Iteration 1: residual = 5.01, beam height = 21.286, width = 1.220 deg, inner region = 229/297
# DEBUG: Iteration 2: residual = 0.00, beam height = 21.358, width = 1.223 deg, inner region = 230/297
# DEBUG: Iteration 3: residual = -0.02, beam height = 21.293, width = 1.220 deg, inner region = 229/297
# DEBUG: Refinement: beam height = 23.706, width = 1.333 deg, first null = 1.562 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target 'PKS 0521-36':
# DEBUG: Iteration 0: residual = inf, beam height = 11.059, width = 0.851 deg, inner region = 228/297
# DEBUG: Iteration 1: residual = 6.16, beam height = 13.763, width = 1.131 deg, inner region = 228/297
# DEBUG: Iteration 2: residual = 0.00, beam height = 13.756, width = 1.133 deg, inner region = 228/297
# DEBUG: Iteration 3: residual = 0.00, beam height = 13.756, width = 1.133 deg, inner region = 228/297
# DEBUG: Refinement: beam height = 14.649, width = 1.242 deg, first null = 1.359 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target 'PKS 0521-36':
# DEBUG: Iteration 0: residual = inf, beam height = 27.319, width = 0.875 deg, inner region = 230/297
# DEBUG: Iteration 1: residual = 10.15, beam height = 35.071, width = 1.187 deg, inner region = 228/297
# DEBUG: Iteration 2: residual = -0.02, beam height = 35.072, width = 1.191 deg, inner region = 229/297
# DEBUG: Refinement: beam height = 39.137, width = 1.291 deg, first null = 1.905 deg, based on 5 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 118 of 121: 'm010 1519544199 3C 161 2018-02-25 17:49:06.968' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target '3C 161':
# DEBUG: Iteration 0: residual = inf, beam height = 18.168, width = 0.865 deg, inner region = 231/298
# DEBUG: Iteration 1: residual = 27.97, beam height = 23.652, width = 1.123 deg, inner region = 230/298
# DEBUG: Iteration 2: residual = -0.00, beam height = 23.657, width = 1.123 deg, inner region = 230/298
# DEBUG: Refinement: beam height = 23.529, width = 1.198 deg, first null = 1.348 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target '3C 161':
# DEBUG: Iteration 0: residual = inf, beam height = 13.447, width = 0.871 deg, inner region = 231/298
# DEBUG: Iteration 1: residual = 220.66, beam height = 17.303, width = 1.176 deg, inner region = 231/298
# DEBUG: Iteration 2: residual = 0.00, beam height = 17.303, width = 1.176 deg, inner region = 231/298
# DEBUG: Refinement: beam height = 17.138, width = 1.210 deg, first null = 1.423 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target '3C 161':
# DEBUG: Iteration 0: residual = inf, beam height = 31.614, width = 0.868 deg, inner region = 231/298
# DEBUG: Iteration 1: residual = 76.49, beam height = 40.949, width = 1.145 deg, inner region = 230/298
# DEBUG: Iteration 2: residual = -0.00, beam height = 40.955, width = 1.145 deg, inner region = 230/298
# DEBUG: Refinement: beam height = 40.642, width = 1.198 deg, first null = 1.386 deg, based on 5 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 119 of 121: 'm010 1519544199 For A 2018-02-25 17:54:36.828' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target 'For A':
# DEBUG: Iteration 0: residual = inf, beam height = 128.593, width = 0.999 deg, inner region = 76/146
# DEBUG: Iteration 1: residual = 176.38, beam height = 150.897, width = 1.260 deg, inner region = 75/146
# DEBUG: Iteration 2: residual = 0.00, beam height = 150.901, width = 1.260 deg, inner region = 75/146
# DEBUG: Iteration 3: residual = 0.00, beam height = 150.901, width = 1.260 deg, inner region = 75/146
# DEBUG: Refinement: beam height = 150.063, width = 1.289 deg, first null = 2.016 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target 'For A':
# DEBUG: Iteration 0: residual = inf, beam height = 99.492, width = 0.991 deg, inner region = 76/146
# DEBUG: Iteration 1: residual = 110.27, beam height = 116.360, width = 1.244 deg, inner region = 76/146
# DEBUG: Iteration 2: residual = 0.00, beam height = 116.360, width = 1.244 deg, inner region = 76/146
# DEBUG: Refinement: beam height = 115.271, width = 1.275 deg, first null = 2.239 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target 'For A':
# DEBUG: Iteration 0: residual = inf, beam height = 228.076, width = 0.996 deg, inner region = 76/146
# DEBUG: Iteration 1: residual = 145.21, beam height = 267.247, width = 1.253 deg, inner region = 76/146
# DEBUG: Iteration 2: residual = 0.00, beam height = 267.247, width = 1.253 deg, inner region = 76/146
# DEBUG: Refinement: beam height = 265.242, width = 1.283 deg, first null = 2.155 deg, based on 5 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 120 of 121: 'm010 1519544199 3C 123 2018-02-25 17:59:55.194' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target '3C 123':
# DEBUG: Iteration 0: residual = inf, beam height = 49.044, width = 0.882 deg, inner region = 229/297
# DEBUG: Iteration 1: residual = 392.75, beam height = 63.912, width = 1.196 deg, inner region = 229/297
# DEBUG: Iteration 2: residual = 0.00, beam height = 63.912, width = 1.196 deg, inner region = 229/297
# DEBUG: Refinement: beam height = 63.619, width = 1.221 deg, first null = 1.710 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target '3C 123':
# DEBUG: Iteration 0: residual = inf, beam height = 33.560, width = 0.882 deg, inner region = 229/297
# DEBUG: Iteration 1: residual = 393.53, beam height = 43.740, width = 1.222 deg, inner region = 229/297
# DEBUG: Iteration 2: residual = 0.00, beam height = 43.740, width = 1.222 deg, inner region = 229/297
# DEBUG: Refinement: beam height = 44.231, width = 1.234 deg, first null = 1.528 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target '3C 123':
# DEBUG: Iteration 0: residual = inf, beam height = 82.598, width = 0.882 deg, inner region = 229/297
# DEBUG: Iteration 1: residual = 810.79, beam height = 107.656, width = 1.206 deg, inner region = 229/297
# DEBUG: Iteration 2: residual = 0.00, beam height = 107.656, width = 1.206 deg, inner region = 229/297
# DEBUG: Refinement: beam height = 107.385, width = 1.220 deg, first null = 1.785 deg, based on 5 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
# INFO: ==== Processing compound scan 121 of 121: 'm010 1519544199 Pic A 2018-02-25 18:05:26.553' ====
# WARNING: Empty data set - gain calibration not done
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absHH' of target 'Pic A':
# DEBUG: Iteration 0: residual = inf, beam height = 74.653, width = 0.996 deg, inner region = 77/148
# DEBUG: Iteration 1: residual = 207.94, beam height = 87.653, width = 1.256 deg, inner region = 77/148
# DEBUG: Iteration 2: residual = 0.00, beam height = 87.653, width = 1.256 deg, inner region = 77/148
# DEBUG: Refinement: beam height = 88.987, width = 1.263 deg, first null = 2.260 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absVV' of target 'Pic A':
# DEBUG: Iteration 0: residual = inf, beam height = 53.209, width = 0.974 deg, inner region = 76/148
# DEBUG: Iteration 1: residual = 418.72, beam height = 62.101, width = 1.214 deg, inner region = 76/148
# DEBUG: Iteration 2: residual = 0.00, beam height = 62.101, width = 1.214 deg, inner region = 76/148
# DEBUG: Refinement: beam height = 62.464, width = 1.225 deg, first null = 2.100 deg, based on 5 of 5 scans
# DEBUG: Fitting beam and initial baseline of degree (1, 3) to pol 'absI' of target 'Pic A':
# DEBUG: Iteration 0: residual = inf, beam height = 127.849, width = 0.987 deg, inner region = 77/148
# DEBUG: Iteration 1: residual = 369.97, beam height = 149.727, width = 1.238 deg, inner region = 77/148
# DEBUG: Iteration 2: residual = 0.00, beam height = 149.727, width = 1.238 deg, inner region = 77/148
# DEBUG: Refinement: beam height = 151.532, width = 1.244 deg, first null = 2.229 deg, based on 5 of 5 scans
# WARNING: No suitable noise diode on/off blocks were found - gain calibration not done
# DEBUG: keep_all=False, main_compscan.beam.is_valid=True, keep=True
#
#
# ***************Done m010 *************
#
#
#  Starting  m011
#
# INFO: Loading dataset '/var/kat/archive3/data/MeerKATAR1/telescope_products/2018/02/25/1519544199.h5'
# IOErrorTraceback (most recent call last)
# <ipython-input-6-205aeacfa205> in <module>()
#       2     print "\n Starting ",baseline,"\n"
#       3     opts = my_opts(outfilebase=None, keepfilename=None, baseline=baseline, mc_iterations=1, freq_centre=1284.0,     freq_chans="200,4000", channel_mask='/var/kat/katsdpscripts/RTS/rfi_mask.pickle',     time_offset=0.0, pointing_model=None, old_loader=None, nd_models=None,     ku_band=False, keep_all=False,remove_spikes=False,batch=True,plot_spectrum=False)
# ----> 4     analyse_point_source_scans(h5name,opts)
#       5     print "\n\n***************Done",baseline,"*************\n"
#       6 print "\nDONE ALL"
#
# /usr/local/lib/python2.7/dist-packages/katsdpscripts/reduction/analyse_point_source_scans.pyc in analyse_point_source_scans(filename, opts)
#     367     logger.info("Loading dataset '%s'" % (filename,))
#     368     dataset = scape.DataSet(filename, baseline=opts.baseline, nd_models=opts.nd_models,
# --> 369                             time_offset=opts.time_offset, katfile=not opts.old_loader, **kwargs)
#     370
#     371     # Select frequency channels and setup defaults if not specified
#
# /usr/local/lib/python2.7/dist-packages/scape/dataset.pyc in __init__(self, filename, compscanlist, experiment_id, observer, description, data_unit, corrconf, antenna, antenna2, nd_h_model, nd_v_model, enviro, **kwargs)
#     127                 if kwargs.get('katdal', True):
#     128                     compscanlist, experiment_id, observer, description, data_unit, \
# --> 129                         corrconf, antenna, antenna2, nd_h_model, nd_v_model, enviro = hdf5_load(filename, **kwargs)
#     130                 else:
#     131                     compscanlist, experiment_id, observer, description, data_unit, \
#
# /usr/local/lib/python2.7/dist-packages/scape/kathdf5.pyc in load_dataset(filename, baseline, selected_pointing, noise_diode, nd_models, time_offset, **kwargs)
#     119
#     120     # Get antennas in file
# --> 121     file_ants = filename.ants if isinstance(filename, katdal.DataSet) else katdal.get_ants(filename)
#     122
#     123     if baseline is 'sd':
#
# /usr/local/lib/python2.7/dist-packages/katdal/__init__.pyc in get_ants(filename)
#     347
#     348     """
# --> 349     return _file_action('_get_ants', filename)
#     350
#     351
#
# /usr/local/lib/python2.7/dist-packages/katdal/__init__.pyc in _file_action(action, filename, *args, **kwargs)
#     281     for format in formats:
#     282         try:
# --> 283             result = getattr(format, action)(filename, *args, **kwargs)
#     284             break
#     285         except WrongVersion:
#
# /usr/local/lib/python2.7/dist-packages/katdal/h5datav3.pyc in _get_ants(filename)
#     794
#     795         """
# --> 796         f, version = H5DataV3._open(filename)
#     797         tm_group = f['TelescopeModel']
#     798         stream_name = f['Data'].attrs.get('stream_name', 'sdp_l0')
#
# /usr/local/lib/python2.7/dist-packages/katdal/h5datav3.pyc in _open(filename, mode)
#     772     def _open(filename, mode='r'):
#     773         """Open file and do basic version sanity check."""
# --> 774         f = h5py.File(filename, mode)
#     775         version = f.attrs.get('version', '1.x')
#     776         if not version.startswith('3.'):
#
# /usr/local/lib/python2.7/dist-packages/h5py/_hl/files.pyc in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     270
#     271                 fapl = make_fapl(driver, libver, **kwds)
# --> 272                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     273
#     274                 if swmr_support:
#
# /usr/local/lib/python2.7/dist-packages/h5py/_hl/files.pyc in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#      90         if swmr and swmr_support:
#      91             flags |= h5f.ACC_SWMR_READ
# ---> 92         fid = h5f.open(name, flags, fapl=fapl)
#      93     elif mode == 'r+':
#      94         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/tmp/pip-4rPeHA-build/h5py/_objects.c:2684)()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/tmp/pip-4rPeHA-build/h5py/_objects.c:2642)()
#
# h5py/h5f.pyx in h5py.h5f.open (/tmp/pip-4rPeHA-build/h5py/h5f.c:1930)()
#
# IOError: Unable to open file (Unable to open file: name = '/var/kat/archive3/data/meerkatar1/telescope_products/2018/02/25/1519544199.h5', errno = 2, error message = 'no such file or directory', flags = 0, o_flags = 0)

# %%
# !ls -l 1519544199*.csv
