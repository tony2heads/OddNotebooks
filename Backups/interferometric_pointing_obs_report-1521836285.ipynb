# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import scape
import katdal
import katpoint
import katsdpscripts
import glob
# Out:
# INFO: Generating grammar tables from /usr/lib/python2.7/lib2to3/Grammar.txt
# INFO: Generating grammar tables from /usr/lib/python2.7/lib2to3/PatternGrammar.txt

# %%
print "Scape version: %s"%scape.__version__
print "katdal version: %s"%katdal.__version__
print "katpoint version: %s"%katpoint.__version__
print "katsdpscripts version: %s"%katsdpscripts.__version__
# Out:
# Scape version: 0.1.dev616+master.e836eb2
# katdal version: 0.9.6.dev661+master.49bf3f1
# katpoint version: 0.8.dev355+master.341001f
# katsdpscripts version: 0.1.dev2762+master.6232d26

# %%
h5_filename = '/var/kat/archive3/data/MeerKATAR1/telescope_products/2018/03/23/1521836285.h5'
# %set_env h5_filename = $h5_filename
# Out:
# env: h5_filename=/var/kat/archive3/data/MeerKATAR1/telescope_products/2018/03/23/1521836285.h5

# %%
run -i /var/kat/katsdpscripts/reduction/analyse_interferometric_pointing.py -h
# Out:
# Usage: analyse_interferometric_pointing.py [opts] <HDF5 file>
#
# This processes an HDF5 dataset and extracts fitted beam parameters from the
# compound scans in it.
#
# Options:
#   -h, --help            show this help message and exit
#   -a ANTS, --ants=ANTS  List of antennas to use in the reduction default is
#                         all antennas in the data set
#   --exclude-ants=EX_ANTS
#                         List of antennas to exculde from the reduction default
#                         is None of the antennas in the data set
#   -c CHANNEL_MASK, --channel-mask=CHANNEL_MASK
#                         Optional pickle file with boolean array specifying
#                         channels to mask (default is no mask)
#   -o OUTFILEBASE, --output=OUTFILEBASE
#                         Base name of output files (*.csv for output data and
#                         *.log for messages, default is
#                         '<dataset_name>_interferometric_pointing')

# %%
run -i /var/kat/katsdpscripts/reduction/analyse_interferometric_pointing.py \
-c /var/kat/katsdpscripts/RTS/rfi_mask.pickle  $h5_filename
# Out:
# DEBUG: Found int_time=0.9995771214 in telstate['sdp_l0_int_time']
# DEBUG: Found scale_factor_timestamp=1712000000.0 in telstate[u'i0_scale_factor_timestamp']
# DEBUG: Found sync_time=1521835285.0 in telstate[u'i0_sync_time']
# DEBUG: Found n_chans=4096 in telstate['sdp_l0_n_chans']
# DEBUG: Found bandwidth=856000000.0 in telstate['sdp_l0_bandwidth']
# DEBUG: Found center_freq=1284000000.0 in telstate['sdp_l0_center_freq']
# DEBUG: Added 'PKS 0252-712' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0407-658' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0410-752' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0637-752' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0741-063' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0823-500' [radec] (and 0 aliases)
# DEBUG: Added '3C237' [radec] (and 1 aliases)
# DEBUG: Added 'PKS 1127-145' [radec] (and 0 aliases)
# DEBUG: Added '3C279' [radec] (and 1 aliases)
# DEBUG: Added '3C286' [radec] (and 1 aliases)
# DEBUG: Added 'PKS 1421-490' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 1740-517' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 1814-637' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 1827-360' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 1934-638' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 1830-210' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 1921-293' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 2203-188' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0023-263' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0252-712' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0407-658' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0410-752' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0637-752' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0741-063' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0823-500' [radec] (and 0 aliases)
# DEBUG: Added '3C237' [radec] (and 1 aliases)
# DEBUG: Added 'PKS 1127-145' [radec] (and 0 aliases)
# DEBUG: Added '3C279' [radec] (and 1 aliases)
# DEBUG: Added '3C286' [radec] (and 1 aliases)
# DEBUG: Added 'PKS 1421-490' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 1740-517' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 1814-637' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 1827-360' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 1934-638' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 1830-210' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 1921-293' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 2203-188' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0023-263' [radec] (and 0 aliases)
# Compound scan 0 of field PKS 0252-712
# WARNING: Last data point for sensor 'Enviro/air_pressure' arrives 70.9987 seconds before end of data set - extrapolation may lead to ridiculous values
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# DEBUG: Sensor u'Antennas/m002/pos_actual_scan_elev' has duplicate timestamps with different values
# DEBUG: At 2018-03-24 00:19:14.474 UTC, sensor u'Antennas/m002/pos_actual_scan_elev' has values of 25.046514372 and 25.0465143733 - keeping last one
# DEBUG: At 2018-03-24 03:29:22.240 UTC, sensor u'Antennas/m002/pos_actual_scan_elev' has values of 16.1448696428 and 16.1448696431 - keeping last one
# DEBUG: Sensor u'Antennas/m005/pos_actual_scan_elev' has duplicate timestamps with different values
# DEBUG: At 2018-03-24 03:15:30.822 UTC, sensor u'Antennas/m005/pos_actual_scan_elev' has values of 17.7549177046 and 17.7549177556 - keeping last one
# DEBUG: Sensor u'Antennas/m006/pos_actual_scan_elev' has duplicate timestamps with different values
# DEBUG: At 2018-03-24 02:16:01.825 UTC, sensor u'Antennas/m006/pos_actual_scan_elev' has values of 49.1229944567 and 49.1229944586 - keeping last one
# DEBUG: Sensor u'Antennas/m026/pos_actual_scan_elev' has duplicate timestamps with different values
# DEBUG: At 2018-03-24 03:00:03.134 UTC, sensor u'Antennas/m026/pos_actual_scan_elev' has values of 45.2688842388 and 45.2688842413 - keeping last one
# DEBUG: Sensor u'Antennas/m027/pos_actual_scan_azim' has duplicate timestamps with different values
# DEBUG: At 2018-03-24 05:45:31.099 UTC, sensor u'Antennas/m027/pos_actual_scan_azim' has values of -43.4081580961 and -43.4081549251 - keeping last one
# DEBUG: Sensor u'Antennas/m033/pos_actual_scan_azim' has duplicate timestamps with different values
# DEBUG: At 2018-03-24 05:26:23.916 UTC, sensor u'Antennas/m033/pos_actual_scan_azim' has values of 108.252474498 and 108.252474722 - keeping last one
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.py:68: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# /var/kat/katsdpscripts/reduction/analyse_interferometric_pointing.py:88: RuntimeWarning: divide by zero encountered in divide
#   y_err = 1./np.sqrt(np.array(stdv[pol])[:,freq,:][:,rfi,ant].sum(axis=1))
# Valid data obtained from the Compound scan
# Compound scan 1 of field PKS 0407-658
# Valid data obtained from the Compound scan
# Compound scan 2 of field PKS 0410-752
# Valid data obtained from the Compound scan
# Compound scan 3 of field PKS 0410-752
# Valid data obtained from the Compound scan
# Compound scan 4 of field PKS 0741-063
# Valid data obtained from the Compound scan
# Compound scan 5 of field PKS 0823-500
# Valid data obtained from the Compound scan
# Compound scan 6 of field 3C237
# Valid data obtained from the Compound scan
# Compound scan 7 of field PKS 1127-145
# Valid data obtained from the Compound scan
# Compound scan 8 of field PKS 1127-145
# Valid data obtained from the Compound scan
# Compound scan 9 of field 3C286
# Valid data obtained from the Compound scan
# Compound scan 10 of field PKS 1421-490
# Valid data obtained from the Compound scan
# Compound scan 11 of field PKS 1740-517
# Valid data obtained from the Compound scan
# Compound scan 12 of field PKS 1814-637
# Valid data obtained from the Compound scan
# Compound scan 13 of field PKS 1814-637
# Valid data obtained from the Compound scan
# Compound scan 14 of field PKS 1934-638
# /usr/local/lib/python2.7/dist-packages/scikits/fitting/gaussian.py:182: RuntimeWarning: invalid value encountered in sqrt
#   std_params = np.sqrt(np.diag(self._interp.cov_params))
# Valid data obtained from the Compound scan
# Compound scan 15 of field PKS 1830-210
# /var/kat/katsdpscripts/reduction/analyse_interferometric_pointing.py:127: RuntimeWarning: divide by zero encountered in divide
#   if np.any(np.isfinite(w_average(gaussian_centre[:,:,ant],axis=0,weights=1./gaussian_centre_std[:,:,ant]**2)) ) : # a bit overboard
# /var/kat/katsdpscripts/reduction/analyse_interferometric_pointing.py:25: RuntimeWarning: invalid value encountered in multiply
#   return np.nansum(arr*weights,axis=axis)/np.nansum(weights,axis=axis)
# /var/kat/katsdpscripts/reduction/analyse_interferometric_pointing.py:157: RuntimeWarning: divide by zero encountered in divide
#   azel_beam = w_average(gaussian_centre[pol_ind["I"],:,ant],axis=0,weights=1./gaussian_centre_std[pol_ind["I"],:,ant]**2)
# /var/kat/katsdpscripts/reduction/analyse_interferometric_pointing.py:165: RuntimeWarning: divide by zero encountered in divide
#   ant_pointing[name]["beam_height_%s"%(pol)]     = w_average(gaussian_height[pol_ind[pol],ant],axis=0,weights=1./gaussian_height_std[pol_ind[pol],ant]**2)
# /var/kat/katsdpscripts/reduction/analyse_interferometric_pointing.py:166: RuntimeWarning: divide by zero encountered in divide
#   ant_pointing[name]["beam_height_%s_std"%(pol)] = np.sqrt(np.nansum(1./gaussian_height_std[pol_ind[pol],ant]**2) )
# /var/kat/katsdpscripts/reduction/analyse_interferometric_pointing.py:167: RuntimeWarning: divide by zero encountered in divide
#   ant_pointing[name]["beam_width_%s"%(pol)]      = w_average(gaussian_width[pol_ind[pol],:,ant],axis=0,weights=1./gaussian_width_std[pol_ind[pol],:,ant]**2).mean()
# /var/kat/katsdpscripts/reduction/analyse_interferometric_pointing.py:168: RuntimeWarning: divide by zero encountered in divide
#   ant_pointing[name]["beam_width_%s_std"%(pol)]  = np.sqrt(np.nansum(1./gaussian_width_std[pol_ind[pol],:,ant]**2) )
# /var/kat/katsdpscripts/reduction/analyse_interferometric_pointing.py:172: RuntimeWarning: divide by zero encountered in divide
#   ant_pointing[name]["azimuth_%s"%(pol)]       =w_average(gaussian_centre[pol_ind[pol],0,ant],axis=0,weights=1./gaussian_centre_std[pol_ind[pol],0,ant]**2)
# /var/kat/katsdpscripts/reduction/analyse_interferometric_pointing.py:173: RuntimeWarning: divide by zero encountered in divide
#   ant_pointing[name]["elevation_%s"%(pol)]     =w_average(gaussian_centre[pol_ind[pol],1,ant],axis=0,weights=1./gaussian_centre_std[pol_ind[pol],1,ant]**2)
# /var/kat/katsdpscripts/reduction/analyse_interferometric_pointing.py:174: RuntimeWarning: divide by zero encountered in divide
#   ant_pointing[name]["azimuth_%s_std"%(pol)]   =np.sqrt(np.nansum(1./gaussian_centre_std[pol_ind[pol],0,ant]**2) )
# /var/kat/katsdpscripts/reduction/analyse_interferometric_pointing.py:175: RuntimeWarning: divide by zero encountered in divide
#   ant_pointing[name]["elevation_%s_std"%(pol)] =np.sqrt(np.nansum(1./gaussian_centre_std[pol_ind[pol],1,ant]**2) )
# Valid data obtained from the Compound scan
# Compound scan 16 of field PKS 0410-752
# Valid data obtained from the Compound scan
# Compound scan 17 of field PKS 0410-752
# Valid data obtained from the Compound scan
# Compound scan 18 of field PKS 0823-500
# Valid data obtained from the Compound scan
# Compound scan 19 of field 3C237
# Valid data obtained from the Compound scan
# Compound scan 20 of field PKS 1127-145
# Valid data obtained from the Compound scan
# Compound scan 21 of field 3C279
# Valid data obtained from the Compound scan
# Compound scan 22 of field 3C279
# Valid data obtained from the Compound scan
# Compound scan 23 of field PKS 1421-490
# Valid data obtained from the Compound scan
# Compound scan 24 of field PKS 1740-517
# Valid data obtained from the Compound scan
# Compound scan 25 of field PKS 1814-637
# Valid data obtained from the Compound scan
# Compound scan 26 of field PKS 1827-360
# Valid data obtained from the Compound scan
# Compound scan 27 of field PKS 1827-360
# Valid data obtained from the Compound scan
# Compound scan 28 of field PKS 1921-293
# Valid data obtained from the Compound scan
# Compound scan 29 of field PKS 1934-638
# Valid data obtained from the Compound scan
# Compound scan 30 of field PKS 1934-638
# Valid data obtained from the Compound scan
# Compound scan 31 of field PKS 0410-752
# Valid data obtained from the Compound scan
# Compound scan 32 of field PKS 0637-752
# Valid data obtained from the Compound scan
# Compound scan 33 of field 3C279
# Valid data obtained from the Compound scan
# Compound scan 34 of field PKS 1421-490
# Valid data obtained from the Compound scan
# Compound scan 35 of field PKS 0252-712
# Valid data obtained from the Compound scan
# Compound scan 36 of field PKS 1740-517
# Valid data obtained from the Compound scan
# Compound scan 37 of field PKS 1814-637
# Valid data obtained from the Compound scan
# Compound scan 38 of field PKS 1827-360
# Valid data obtained from the Compound scan
# Compound scan 39 of field PKS 1827-360
# Valid data obtained from the Compound scan
# Compound scan 40 of field PKS 1830-210
# Valid data obtained from the Compound scan
# Compound scan 41 of field PKS 1830-210
# Valid data obtained from the Compound scan
# Compound scan 42 of field PKS 1934-638
# Valid data obtained from the Compound scan

# %%
tmp = h5_filename.split('/')[-1].split('.')[0]
gl = glob.glob("%s*.csv"%tmp)

# %%
print h5.antlist
# Out:
# ['m002', 'm005', 'm006', 'm009', 'm019', 'm022', 'm023', 'm024', 'm026', 'm027', 'm033', 'm040', 'm049', 'm057', 'm058', 'm061']

# %%
# !pwd
for g in sorted(gl):
    print g
# Out:
# /data/Pointing/Interferometric
# 1521836285_interferometric_pointing_m002.csv
# 1521836285_interferometric_pointing_m005.csv
# 1521836285_interferometric_pointing_m006.csv
# 1521836285_interferometric_pointing_m009.csv
# 1521836285_interferometric_pointing_m019.csv
# 1521836285_interferometric_pointing_m022.csv
# 1521836285_interferometric_pointing_m023.csv
# 1521836285_interferometric_pointing_m024.csv
# 1521836285_interferometric_pointing_m026.csv
# 1521836285_interferometric_pointing_m027.csv
# 1521836285_interferometric_pointing_m033.csv
# 1521836285_interferometric_pointing_m040.csv
# 1521836285_interferometric_pointing_m049.csv
# 1521836285_interferometric_pointing_m057.csv
# 1521836285_interferometric_pointing_m058.csv
# 1521836285_interferometric_pointing_m061.csv

# %% [markdown]
# # Delete wildly discepant points

# %%
#!sed -i /Nothing/d 1516731881*.csv

# %%
# !sed -i /1830-210,\ 2018-03-23\ 23:49/d 1521836285_interferometric_pointing_m0*.csv

# %%
matplotlib.rcParams['figure.figsize'] = (15.0, 10.0)

# %%
for fl in sorted(gl):
    figure(figsize=[15.0,10.0])
    # %run /var/kat/katsdpscripts/reduction/fit_pointing_model.py -m 1.0 $fl
