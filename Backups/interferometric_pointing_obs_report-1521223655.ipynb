# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import scape
import katdal
import katpoint
import katsdpscripts
import glob
# Out:
# INFO: Generating grammar tables from /usr/lib/python2.7/lib2to3/Grammar.txt
# INFO: Generating grammar tables from /usr/lib/python2.7/lib2to3/PatternGrammar.txt

# %%
print "Scape version: %s"%scape.__version__
print "katdal version: %s"%katdal.__version__
print "katpoint version: %s"%katpoint.__version__
print "katsdpscripts version: %s"%katsdpscripts.__version__
# Out:
# Scape version: 0.1.dev616+master.e836eb2
# katdal version: 0.9.6.dev657+master.1e4b378
# katpoint version: 0.8.dev355+master.341001f
# katsdpscripts version: 0.1.dev2752+master.d23625e

# %%
h5_filename = '/var/kat/archive3/data/MeerKATAR1/telescope_products/2018/03/16/1521223655.h5'
# %set_env h5_filename = $h5_filename
# Out:
# env: h5_filename=/var/kat/archive3/data/MeerKATAR1/telescope_products/2018/03/16/1521223655.h5

# %%
run -i /var/kat/katsdpscripts/reduction/analyse_interferometric_pointing.py -h
# Out:
# Usage: analyse_interferometric_pointing.py [opts] <HDF5 file>
#
# This processes an HDF5 dataset and extracts fitted beam parameters from the
# compound scans in it.
#
# Options:
#   -h, --help            show this help message and exit
#   -a ANTS, --ants=ANTS  List of antennas to use in the reduction default is
#                         all antennas in the data set
#   --exclude-ants=EX_ANTS
#                         List of antennas to exculde from the reduction default
#                         is None of the antennas in the data set
#   -c CHANNEL_MASK, --channel-mask=CHANNEL_MASK
#                         Optional pickle file with boolean array specifying
#                         channels to mask (default is no mask)
#   -o OUTFILEBASE, --output=OUTFILEBASE
#                         Base name of output files (*.csv for output data and
#                         *.log for messages, default is
#                         '<dataset_name>_interferometric_pointing')

# %%
run -i /var/kat/katsdpscripts/reduction/analyse_interferometric_pointing.py \
-c /var/kat/katsdpscripts/RTS/rfi_mask.pickle  --exclude-ants='m007' $h5_filename
# Out:
# DEBUG: Found int_time=0.9995771214 in telstate['sdp_l0_int_time']
# DEBUG: Found scale_factor_timestamp=1712000000.0 in telstate[u'i0_scale_factor_timestamp']
# DEBUG: Found sync_time=1521221621.0 in telstate[u'i0_sync_time']
# DEBUG: Found n_chans=4096 in telstate['sdp_l0_n_chans']
# DEBUG: Found bandwidth=856000000.0 in telstate['sdp_l0_bandwidth']
# DEBUG: Found center_freq=1284000000.0 in telstate['sdp_l0_center_freq']
# DEBUG: Added 'PKS 0237-233' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0252-712' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0407-658' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0410-752' [radec] (and 0 aliases)
# DEBUG: Added '3C138' [radec] (and 1 aliases)
# DEBUG: Added 'PKS 0637-752' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0741-063' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0823-500' [radec] (and 0 aliases)
# DEBUG: Added '3C237' [radec] (and 1 aliases)
# DEBUG: Added 'PKS 1127-145' [radec] (and 0 aliases)
# DEBUG: Added '3C279' [radec] (and 1 aliases)
# DEBUG: Added 'PKS 1421-490' [radec] (and 0 aliases)
# DEBUG: Added '3C286' [radec] (and 1 aliases)
# DEBUG: Added 'PKS 1740-517' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 1814-637' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 1827-360' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 1830-210' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 1934-638' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 1921-293' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 2203-188' [radec] (and 0 aliases)
# DEBUG: Added '3C446' [radec] (and 1 aliases)
# DEBUG: Added 'PKS 2230+114' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0023-263' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0237-233' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0252-712' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0407-658' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0410-752' [radec] (and 0 aliases)
# DEBUG: Added '3C138' [radec] (and 1 aliases)
# DEBUG: Added 'PKS 0637-752' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0741-063' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0823-500' [radec] (and 0 aliases)
# DEBUG: Added '3C237' [radec] (and 1 aliases)
# DEBUG: Added 'PKS 1127-145' [radec] (and 0 aliases)
# DEBUG: Added '3C279' [radec] (and 1 aliases)
# DEBUG: Added 'PKS 1421-490' [radec] (and 0 aliases)
# DEBUG: Added '3C286' [radec] (and 1 aliases)
# DEBUG: Added 'PKS 1740-517' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 1814-637' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 1827-360' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 1830-210' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 1934-638' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 1921-293' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 2203-188' [radec] (and 0 aliases)
# DEBUG: Added '3C446' [radec] (and 1 aliases)
# DEBUG: Added 'PKS 2230+114' [radec] (and 0 aliases)
# DEBUG: Added 'PKS 0023-263' [radec] (and 0 aliases)
# Compound scan 0 of field PKS 0237-233
# WARNING: Last data point for sensor 'Enviro/wind_direction' arrives 6.75641 seconds before end of data set - extrapolation may lead to ridiculous values
# DEBUG: Sensor u'Antennas/m002/pos_actual_scan_azim' has duplicate timestamps with different values
# DEBUG: At 2018-03-17 02:45:29.074 UTC, sensor u'Antennas/m002/pos_actual_scan_azim' has values of -145.574589619 and -145.574589487 - keeping last one
# DEBUG: Sensor u'Antennas/m011/pos_actual_scan_elev' has duplicate timestamps with different values
# DEBUG: At 2018-03-17 01:11:34.735 UTC, sensor u'Antennas/m011/pos_actual_scan_elev' has values of 23.6670536869 and 23.6670536952 - keeping last one
# DEBUG: Sensor u'Antennas/m012/pos_actual_scan_azim' has duplicate timestamps with different values
# DEBUG: At 2018-03-16 21:05:52.475 UTC, sensor u'Antennas/m012/pos_actual_scan_azim' has values of 198.975786567 and 198.975786588 - keeping last one
# DEBUG: At 2018-03-17 05:55:02.236 UTC, sensor u'Antennas/m012/pos_actual_scan_azim' has values of 59.9803441317 and 59.9803441583 - keeping last one
# DEBUG: Sensor u'Antennas/m012/pos_actual_scan_elev' has duplicate timestamps with different values
# DEBUG: At 2018-03-16 22:52:17.430 UTC, sensor u'Antennas/m012/pos_actual_scan_elev' has values of 62.317988764 and 62.3179889731 - keeping last one
# DEBUG: Sensor u'Antennas/m014/pos_actual_scan_elev' has duplicate timestamps with different values
# DEBUG: At 2018-03-16 19:08:51.164 UTC, sensor u'Antennas/m014/pos_actual_scan_elev' has values of 27.4891533479 and 27.4891534114 - keeping last one
# DEBUG: Sensor u'Antennas/m019/pos_actual_scan_azim' has duplicate timestamps with different values
# DEBUG: At 2018-03-17 04:53:49.878 UTC, sensor u'Antennas/m019/pos_actual_scan_azim' has values of 165.740423498 and 165.740431117 - keeping last one
# DEBUG: Sensor u'Antennas/m019/pos_actual_scan_elev' has duplicate timestamps with different values
# DEBUG: At 2018-03-16 21:57:54.301 UTC, sensor u'Antennas/m019/pos_actual_scan_elev' has values of 39.1725901446 and 39.172590151 - keeping last one
# DEBUG: At 2018-03-17 04:55:33.547 UTC, sensor u'Antennas/m019/pos_actual_scan_elev' has values of 16.950334332 and 16.9503343528 - keeping last one
# /var/kat/katsdpscripts/reduction/analyse_interferometric_pointing.py:88: RuntimeWarning: divide by zero encountered in divide
#   y_err = 1./np.sqrt(np.array(stdv[pol])[:,freq,:][:,rfi,ant].sum(axis=1))
# Valid data obtained from the Compound scan
# Compound scan 1 of field PKS 0237-233
# Valid data obtained from the Compound scan
# Compound scan 2 of field PKS 0407-658
# Valid data obtained from the Compound scan
# Compound scan 3 of field PKS 0410-752
# Valid data obtained from the Compound scan
# Compound scan 4 of field PKS 0410-752
# Valid data obtained from the Compound scan
# Compound scan 5 of field PKS 0637-752
# Valid data obtained from the Compound scan
# Compound scan 6 of field PKS 0741-063
# Valid data obtained from the Compound scan
# Compound scan 7 of field PKS 0823-500
# Valid data obtained from the Compound scan
# Compound scan 8 of field 3C237
# Valid data obtained from the Compound scan
# Compound scan 9 of field PKS 1127-145
# Valid data obtained from the Compound scan
# Compound scan 10 of field PKS 1127-145
# Valid data obtained from the Compound scan
# Compound scan 11 of field PKS 1421-490
# Valid data obtained from the Compound scan
# Compound scan 12 of field PKS 0252-712
# Valid data obtained from the Compound scan
# Compound scan 13 of field PKS 0407-658
# Valid data obtained from the Compound scan
# Compound scan 14 of field PKS 0407-658
# Valid data obtained from the Compound scan
# Compound scan 15 of field PKS 0637-752
# Valid data obtained from the Compound scan
# Compound scan 16 of field PKS 0741-063
# Valid data obtained from the Compound scan
# Compound scan 17 of field PKS 0823-500
# Valid data obtained from the Compound scan
# Compound scan 18 of field 3C237
# Valid data obtained from the Compound scan
# Compound scan 19 of field PKS 1127-145
# Valid data obtained from the Compound scan
# Compound scan 20 of field PKS 1127-145
# Valid data obtained from the Compound scan
# Compound scan 21 of field 3C286
# Valid data obtained from the Compound scan
# Compound scan 22 of field PKS 1421-490
# Valid data obtained from the Compound scan
# Compound scan 23 of field PKS 1740-517
# Valid data obtained from the Compound scan
# Compound scan 24 of field PKS 1814-637
# Valid data obtained from the Compound scan
# Compound scan 25 of field PKS 1814-637
# Valid data obtained from the Compound scan
# Compound scan 26 of field PKS 1830-210
# Valid data obtained from the Compound scan
# Compound scan 27 of field PKS 1934-638
# Valid data obtained from the Compound scan
# Compound scan 28 of field PKS 1934-638
# Valid data obtained from the Compound scan
# Compound scan 29 of field PKS 0410-752
# Valid data obtained from the Compound scan
# Compound scan 30 of field PKS 0637-752
# Valid data obtained from the Compound scan
# Compound scan 31 of field PKS 0823-500
# Valid data obtained from the Compound scan
# Compound scan 32 of field PKS 1127-145
# Valid data obtained from the Compound scan
# Compound scan 33 of field 3C279
# Valid data obtained from the Compound scan
# Compound scan 34 of field 3C286
# Valid data obtained from the Compound scan
# Compound scan 35 of field PKS 1421-490
# Valid data obtained from the Compound scan
# Compound scan 36 of field PKS 1740-517
# Valid data obtained from the Compound scan
# Compound scan 37 of field PKS 1814-637
# Valid data obtained from the Compound scan
# Compound scan 38 of field PKS 1827-360
# Valid data obtained from the Compound scan
# Compound scan 39 of field PKS 1830-210
# Valid data obtained from the Compound scan
# Compound scan 40 of field PKS 1921-293
# Valid data obtained from the Compound scan
# Compound scan 41 of field PKS 1934-638
# Valid data obtained from the Compound scan
# Compound scan 42 of field PKS 0252-712
# Valid data obtained from the Compound scan
# Compound scan 43 of field PKS 2203-188
# Valid data obtained from the Compound scan
# Compound scan 44 of field 3C446
# Valid data obtained from the Compound scan
# Compound scan 45 of field PKS 2230+114
# Valid data obtained from the Compound scan
# Compound scan 46 of field PKS 0023-263
# Valid data obtained from the Compound scan

# %%
tmp = h5_filename.split('/')[-1].split('.')[0]
gl = glob.glob("%s*.csv"%tmp)

# %%
print h5.antlist
# Out:
# ['m002', 'm011', 'm012', 'm013', 'm014', 'm015', 'm019']

# %%
# !pwd
for g in sorted(gl):
    print g
# Out:
# /data/Pointing/Interferometric
# 1521223655_interferometric_pointing_m002.csv
# 1521223655_interferometric_pointing_m007.csv
# 1521223655_interferometric_pointing_m011.csv
# 1521223655_interferometric_pointing_m012.csv
# 1521223655_interferometric_pointing_m013.csv
# 1521223655_interferometric_pointing_m014.csv
# 1521223655_interferometric_pointing_m015.csv
# 1521223655_interferometric_pointing_m019.csv

# %% [markdown]
# # Delete wildly discepant points

# %%
#!sed -i /Nothing/d 1516731881*.csv

# %%
#!sed -i /2018-01-27\ 15:/d 1517050827_interferometric_pointing*.csv
#!sed -i /3C138,\ 2018-02-27\ 20:04/d 1519747734_interferometric_pointing*.csv
#!sed -i /1127-145,\ 2018-02-27\ 18:54/d 1519747734_interferometric_pointing*.csv

# %%
matplotlib.rcParams['figure.figsize'] = (15.0, 10.0)

# %%
for fl in sorted(gl):
    figure(figsize=[15.0,10.0])
    # %run /var/kat/katsdpscripts/reduction/fit_pointing_model.py -m 1.0 $fl
