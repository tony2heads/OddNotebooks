# %%
import katdal
import matplotlib.pylab as plt
# %matplotlib inline
import numpy as np
import pickle

# %%
filenames=['/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/14/1487034060.h5',\
    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/15/1487146520.h5',\
    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/15/1487184329.h5',\
    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/15/1487196176.h5',\
    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/16/1487232439.h5',\
    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/16/1487266271.h5',\
    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/16/1487266744.h5',\
    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/16/1487268905.h5',\
    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/18/1487431901.h5',\
    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/18/1487432387.h5',\
    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/19/1487462945.h5',\
    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/19/1487537109.h5',\
    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/20/1487584834.h5',\
    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/20/1487608922.h5',\
    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/21/1487666463.h5']

# %%
for f in filenames:
    h = katdal.open(f)
    print h
    print '    Product             Number of solutions'
    for k in h.file['TelescopeState'].keys():
        if 'cal_product' in k:
            print '   ', k, ' --- ' , len(h.file['TelescopeState'][k])
    print '\n\n'
# Out:
# WARNING:katdal.h5datav3:Irregular timestamps detected in file '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/14/1487034060.h5': expected 128.955 dumps based on dump period and start/end times, got 129 instead
# ...
# Name: /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/14/1487034060.h5 (version 3.0)
# ...
# Observer: AR1  Experiment ID: 20170213-0015
# Description: 'Generic AR1 phaseup'
# Observed from 2017-02-14 03:01:06.306 SAST to 2017-02-14 03:09:41.909 SAST
# Dump rate / period: 0.25011 Hz / 3.998 s
# Subarrays: 1
#   ID  Antennas                            Inputs  Corrprods
#    0  m001,m003,m006,m010,m014,m015,m021,m025,m031,m034,m063  22      264
# Spectral Windows: 1
#   ID Band Product  CentreFreq(MHz)  Bandwidth(MHz)  Channels  ChannelWidth(kHz)
#    0 L    bc856M32k  1284.000         856.000          32768        26.123
# -------------------------------------------------------------------------------
# Data selected according to the following criteria:
# ...

# %% [markdown]
# # Comments
# * '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/14/1487034060.h5'
# No Solution
# * '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/15/1487146520.h5'
# No solution applied
# *   '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/15/1487184329.h5'
# Solutions there but not applied
# *    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/15/1487196176.h5'
# Has Bandpass as well- solutions are BAD. Why does scan label say 'raster', not 'track'
# *    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/16/1487232439.h5'
# Has Bandpass, HH OK, and a few VV OK,
# *    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/16/1487266271.h5'
# Has Bandpass, Partial (m001 bad)
# *    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/16/1487266744.h5'
# Has Bandpass Few HH look OK
# *    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/16/1487268905.h5'
# Has  bandpass BAD
# *    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/18/1487431901.h5'
# OK
# *    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/18/1487432387.h5'
# OK
# * '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/19/1487462945.h5'
# Has Bandpass. Looks like multiple solutions. BAD
# * /var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/19/1487537109.h5'
# OK
# * '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/20/1487584834.h5'
# Partial (m063 bad)
# *    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/20/1487608922.h5'
# Has bandpass. OK
# *    '/var/kat/archive2/data/MeerKATAR1/telescope_products/2017/02/21/1487666463.h5'
# OK
