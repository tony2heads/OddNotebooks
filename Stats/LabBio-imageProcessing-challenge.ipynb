# %% [markdown]
#  Lab-BioRelate 8/26/2017 - Mauricio Cerda (mauriciocerda@med.uchile.cl)

# %%
print 'Hello jupyter notebook world!'
# Out:
# Hello jupyter notebook world!

# %% [markdown]
# Open and show an image

# %%
import numpy as np
from matplotlib.pyplot import imshow
from  skimage import filters, morphology, io, img_as_uint
# %matplotlib notebook

image=io.imread('chagas.png')
imshow(image, cmap='gray')

# %% [markdown]
# A global manual threshold

# %%
import numpy as np
from matplotlib.pyplot import imshow
from  skimage import filters, morphology, io, img_as_uint
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %matplotlib notebook

def showthreshold(x):
    threshold=40
    image=io.imread('chagas.png')
    binary=image>threshold
    imshow(binary, cmap='gray')

interact(showthreshold, x=10);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Building the histogram

# %%
import numpy as np
import matplotlib.pyplot as plt
from  skimage import filters, morphology, io, img_as_uint
# %matplotlib notebook

#get histogram of an image
def getHistogram(gray_im):
    h=np.zeros(256, dtype=np.float32)
    for i in range(gray_im.shape[0]):
        for j in range(gray_im.shape[1]):
            h[gray_im[i,j]]+=1.0
    return h

image=io.imread('chagas.png')
h = getHistogram( image )
plt.bar(range(0,256), h)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 256 artists>

# %% [markdown]
# Computing a threshold value with k-means (please correct me!)

# %%
import numpy as np
from matplotlib.pyplot import imshow
from  skimage import filters, morphology, io, img_as_uint
# %matplotlib notebook

#get histogram of an image
def getHistogram(gray_im):
    h=np.zeros(256, dtype=np.float32)
    for i in range(gray_im.shape[0]):
        for j in range(gray_im.shape[1]):
            h[gray_im[i,j]]+=1.0
    return h

#kmeans for k=2
def kmeans(histogram):
    print 'Starting...'
    k0=0
    k1=255
    
    sumk0=0.0
    nk0=0
    sumk1=0.0
    nk1=0
    for i in range(256):
        if abs(i-k0) < abs(i-k1):
            sumk0=sumk0+i*histogram[i]
            nk0=nk0+histogram[i]
        else:
            sumk1=sumk1+i*histogram[i]
            nk1=nk1+histogram[i]    
    
    threshold = k0 + (k1-k0)/2
    
    print 'Cluster 0=%s' % k0
    print 'Cluster 1=%s' % k1
    print 'Threshold=%s' % threshold
    print ''
    return threshold

image=io.imread('chagas.png')
h = getHistogram( image )
threshold = kmeans(h)

binary=image>threshold
imshow(binary, cmap='gray')
# Out:
# Starting...
# Cluster 0=0
# Cluster 1=255
# Threshold=127
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Display objects, showing how to iterate over binary objects

# %%
import numpy as np
import matplotlib.pyplot as plt
from  skimage import filters, morphology, io, measure
# %matplotlib notebook

#get histogram of an image
def getHistogram(gray_im):
    h=np.zeros(256, dtype=np.float32)
    for i in range(gray_im.shape[0]):
        for j in range(gray_im.shape[1]):
            h[gray_im[i,j]]+=1.0
    return h

image=io.imread('chagas.png')
h = getHistogram( image )
threshold = 40

binary=image>threshold
all_labels = measure.label(binary, background=0)
properties = measure.regionprops(all_labels)
print 'Number of objects=%s' % len(properties)
for i in range(0,len(properties)):
    print 'Object %s, area=%s' % (i, properties[i].area)

imshow(all_labels, cmap='rainbow')
# Out:
# Number of objects=336
# Object 0, area=1720
# Object 1, area=3149
# Object 2, area=2754
# Object 3, area=19
# Object 4, area=4186
# Object 5, area=42
# Object 6, area=200
# Object 7, area=41
# Object 8, area=18
# Object 9, area=2365
# Object 10, area=31
# Object 11, area=54
# Object 12, area=48
# Object 13, area=47
# Object 14, area=23
# Object 15, area=50
# Object 16, area=86
# Object 17, area=5
# Object 18, area=1
# Object 19, area=14
# Object 20, area=95
# Object 21, area=47
# Object 22, area=10
# Object 23, area=20
# Object 24, area=25
# Object 25, area=1
# Object 26, area=30
# Object 27, area=24
# Object 28, area=51
# Object 29, area=30
# Object 30, area=32
# Object 31, area=26
# Object 32, area=71
# Object 33, area=38
# Object 34, area=2956
# Object 35, area=31
# Object 36, area=20
# Object 37, area=27
# Object 38, area=62
# Object 39, area=36
# Object 40, area=66
# Object 41, area=4919
# Object 42, area=29
# Object 43, area=50
# Object 44, area=56
# Object 45, area=55
# Object 46, area=25
# Object 47, area=20
# Object 48, area=27
# Object 49, area=116
# Object 50, area=1
# Object 51, area=34
# Object 52, area=32
# Object 53, area=21
# Object 54, area=16
# Object 55, area=25
# Object 56, area=29
# Object 57, area=35
# Object 58, area=68
# Object 59, area=23
# Object 60, area=3575
# Object 61, area=26
# Object 62, area=8
# Object 63, area=22
# Object 64, area=12
# Object 65, area=28
# Object 66, area=61
# Object 67, area=33
# Object 68, area=3
# Object 69, area=1
# Object 70, area=13
# Object 71, area=17
# Object 72, area=12
# Object 73, area=5178
# Object 74, area=89
# Object 75, area=16
# Object 76, area=16
# Object 77, area=22
# Object 78, area=25
# Object 79, area=13
# Object 80, area=31
# Object 81, area=10
# Object 82, area=31
# Object 83, area=64
# Object 84, area=16
# Object 85, area=29
# Object 86, area=24
# Object 87, area=10
# Object 88, area=25
# Object 89, area=25
# Object 90, area=28
# Object 91, area=18
# Object 92, area=27
# Object 93, area=11
# Object 94, area=26
# Object 95, area=14
# Object 96, area=60
# Object 97, area=32
# Object 98, area=31
# Object 99, area=14
# Object 100, area=37
# Object 101, area=24
# Object 102, area=2960
# Object 103, area=3
# Object 104, area=5
# Object 105, area=20
# Object 106, area=63
# Object 107, area=28
# Object 108, area=37
# Object 109, area=25
# Object 110, area=31
# Object 111, area=13
# Object 112, area=29
# Object 113, area=25
# Object 114, area=26
# Object 115, area=26
# Object 116, area=53
# Object 117, area=24
# Object 118, area=53
# Object 119, area=6
# Object 120, area=39
# Object 121, area=1
# Object 122, area=24
# Object 123, area=22
# Object 124, area=27
# Object 125, area=13
# Object 126, area=13
# Object 127, area=22
# Object 128, area=20
# Object 129, area=97
# Object 130, area=6
# Object 131, area=19
# Object 132, area=22
# Object 133, area=31
# Object 134, area=19
# Object 135, area=35
# Object 136, area=18
# Object 137, area=31
# Object 138, area=29
# Object 139, area=27
# Object 140, area=28
# Object 141, area=52
# Object 142, area=34
# Object 143, area=57
# Object 144, area=15
# Object 145, area=28
# Object 146, area=24
# Object 147, area=29
# Object 148, area=10
# Object 149, area=28
# Object 150, area=47
# Object 151, area=27
# Object 152, area=36
# Object 153, area=57
# Object 154, area=28
# Object 155, area=32
# Object 156, area=61
# Object 157, area=24
# Object 158, area=25
# Object 159, area=27
# Object 160, area=30
# Object 161, area=23
# Object 162, area=52
# Object 163, area=28
# Object 164, area=29
# Object 165, area=52
# Object 166, area=25
# Object 167, area=14
# Object 168, area=30
# Object 169, area=30
# Object 170, area=62
# Object 171, area=27
# Object 172, area=61
# Object 173, area=70
# Object 174, area=21
# Object 175, area=28
# Object 176, area=20
# Object 177, area=11
# Object 178, area=9
# Object 179, area=26
# Object 180, area=25
# Object 181, area=10
# Object 182, area=17
# Object 183, area=30
# Object 184, area=32
# Object 185, area=9
# Object 186, area=59
# Object 187, area=1754
# Object 188, area=15
# Object 189, area=3
# Object 190, area=2792
# Object 191, area=64
# Object 192, area=10
# Object 193, area=5
# Object 194, area=20
# Object 195, area=14
# Object 196, area=62
# Object 197, area=26
# Object 198, area=32
# Object 199, area=1
# Object 200, area=59
# Object 201, area=29
# Object 202, area=29
# Object 203, area=13
# Object 204, area=16
# Object 205, area=44
# Object 206, area=64
# Object 207, area=29
# Object 208, area=30
# Object 209, area=9
# Object 210, area=27
# Object 211, area=14
# Object 212, area=51
# Object 213, area=66
# Object 214, area=21
# Object 215, area=6
# Object 216, area=57
# Object 217, area=14
# Object 218, area=3
# Object 219, area=29
# Object 220, area=7
# Object 221, area=9
# Object 222, area=11
# Object 223, area=1
# Object 224, area=2
# Object 225, area=2832
# Object 226, area=24
# Object 227, area=24
# Object 228, area=48
# Object 229, area=32
# Object 230, area=10
# Object 231, area=63
# Object 232, area=29
# Object 233, area=37
# Object 234, area=22
# Object 235, area=15
# Object 236, area=29
# Object 237, area=40
# Object 238, area=15
# Object 239, area=70
# Object 240, area=64
# Object 241, area=59
# Object 242, area=27
# Object 243, area=1
# Object 244, area=26
# Object 245, area=29
# Object 246, area=26
# Object 247, area=1
# Object 248, area=15
# Object 249, area=26
# Object 250, area=1126
# Object 251, area=48
# Object 252, area=30
# Object 253, area=40
# Object 254, area=49
# Object 255, area=2
# Object 256, area=23
# Object 257, area=25
# Object 258, area=24
# Object 259, area=58
# Object 260, area=24
# Object 261, area=103
# Object 262, area=54
# Object 263, area=21
# Object 264, area=22
# Object 265, area=50
# Object 266, area=145
# Object 267, area=107
# Object 268, area=29
# Object 269, area=3
# Object 270, area=28
# Object 271, area=57
# Object 272, area=23
# Object 273, area=57
# Object 274, area=105
# Object 275, area=1326
# Object 276, area=58
# Object 277, area=19
# Object 278, area=4198
# Object 279, area=54
# Object 280, area=20
# Object 281, area=12
# Object 282, area=57
# Object 283, area=1
# Object 284, area=20
# Object 285, area=22
# Object 286, area=3460
# Object 287, area=1
# Object 288, area=80
# Object 289, area=4
# Object 290, area=73
# Object 291, area=31
# Object 292, area=8
# Object 293, area=6
# Object 294, area=2395
# Object 295, area=2
# Object 296, area=4
# Object 297, area=395
# Object 298, area=27
# Object 299, area=116
# Object 300, area=5289
# Object 301, area=21
# Object 302, area=5
# Object 303, area=3
# Object 304, area=18
# Object 305, area=187
# Object 306, area=17896
# Object 307, area=1
# Object 308, area=5
# Object 309, area=25
# Object 310, area=4984
# Object 311, area=70
# Object 312, area=12
# Object 313, area=4
# Object 314, area=1
# Object 315, area=4
# Object 316, area=22
# Object 317, area=16
# Object 318, area=1013
# Object 319, area=2
# Object 320, area=6
# Object 321, area=3693
# Object 322, area=42
# Object 323, area=7
# Object 324, area=27
# Object 325, area=24
# Object 326, area=10
# Object 327, area=44
# Object 328, area=3909
# Object 329, area=3
# Object 330, area=41
# Object 331, area=3752
# Object 332, area=2174
# Object 333, area=4070
# Object 334, area=3027
# Object 335, area=2
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# For each object compute PCA, and the eccentricity index using moments (please correct me!)

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import filters, morphology, io, measure
from scipy.spatial import Voronoi, voronoi_plot_2d

#get histogram of an image
def getHistogram(gray_im):
    h=np.zeros(256, dtype=np.float32)
    for i in range(gray_im.shape[0]):
        for j in range(gray_im.shape[1]):
            h[gray_im[i,j]]+=1.0
    return h

#get set of points image moments
def getmoments(x,y):
    meanx=np.mean(x)
    meany=np.mean(y)
    mu00=len(x)
    mu10=sum(x-meanx)
    mu01=sum(y-meany)
    mu11=sum((x-meanx)*(y-meany))
    mu20=sum((x-meanx)**2)
    mu02=sum((y-meany)**2)
    
    return mu00, mu10, mu01, mu11, mu20, mu02
    
image=io.imread('chagas.png')
h = getHistogram( image )
threshold = 40

binary=image > threshold
all_labels = measure.label(binary, background=0)
properties = measure.regionprops(all_labels)
print 'Number of objects=%s' % len(properties)

centers=np.zeros((len(properties),2), 'float')

for i in range(0,len(properties)):
    coords = properties[i].coords
    mu00, mu10, mu01, mu11, mu20, mu02 =getmoments(coords[:,1], coords[:,0])
    covxx=mu20/mu00
    covyy=mu02/mu00
    covxy=mu11/mu00
    
    #always 0?
    eccentricity=0
    centers[i,0]=(properties[i].centroid)[0]
    centers[i,1]=(properties[i].centroid)[1]

#if you have time you can use voronoi diagram
#or something else to estimate infection rate
#vor = Voronoi(centers)
# Out:
# Number of objects=336
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:49: RuntimeWarning: invalid value encountered in double_scalars
